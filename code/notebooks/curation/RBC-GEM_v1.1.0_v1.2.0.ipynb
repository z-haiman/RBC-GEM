# %% [markdown]
# # RBC-GEM 1.2.0 Updates
# ## Setup
# ### Import packages

# %%
from warnings import warn

import pandas as pd
from cobra.core import Gene, Metabolite, Reaction
from rbc_gem_utils import (
    COBRA_CONFIGURATION,
    build_string,
    get_dirpath,
    read_cobra_model,
    split_string,
    write_cobra_model,
)
from rbc_gem_utils.qc import (
    reset_reaction_bounds,
    reset_subsystem_groups,
    standardardize_metabolite_formulas,
)

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -1000.0
# upper_bound: 1000.0
# processes: 15
# cache_directory: /Users/zhaiman/Library/Caches/cobrapy
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## Load RBC-GEM model
# ### Version: 1.1.0

# %%
model_dirpath = get_dirpath("model")
model = read_cobra_model(filename=model_dirpath / f"{GEM_NAME}.yml")
model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21

# %% [markdown]
# ### Deprecate identifiers

# %%
id_mapping_dicts = {
    "metabolites": {
        "PPP2CA_leu__L_c": "pp2a_leu__L_c",
        "PPP2CA_leumeo_c": "pp2a_leumeo_c",
        # Protein ID updates required for protein constrained modeling compatibility
        "protein_aclys__L_c": "protres_aclys__L_c",
        "protein_admarg__L_c": "protres_admarg__L_c",
        "protein_arg__L_c": "protres_arg__L_c",
        "protein_arg__L_e": "protres_arg__L_e",
        "protein_asn__L_c": "protres_asn__L_c",
        "protein_asp__D_c": "protres_asp__D_c",
        "protein_asp__L_c": "protres_asp__L_c",
        "protein_aspmeo__D_c": "protres_aspmeo__D_c",
        "protein_cys__L_c": "protres_cys__L_c",
        "protein_frulys_c": "protres_frulys_c",
        "protein_frulys3p_c": "protres_frulys3p_c",
        "protein_frulys6p_c": "protres_frulys6p_c",
        "protein_gln__L_c": "protres_gln__L_c",
        "protein_glu__L_c": "protres_glu__L_c",
        "protein_glu5meo__L_c": "protres_glu5meo__L_c",
        "protein_gludpam_c": "protres_gludpam_c",
        "protein_gluhista_c": "protres_gluhista_c",
        "protein_glunpphr_c": "protres_glunpphr_c",
        "protein_glusrtn_c": "protres_glusrtn_c",
        "protein_his__L_c": "protres_his__L_c",
        "protein_hxdcacys_c": "protres_hxdcacys_c",
        "protein_isoasp__D_c": "protres_isoasp__D_c",
        "protein_isoasp__L_c": "protres_isoasp__L_c",
        "protein_isoaspmeo__L_c": "protres_isoaspmeo__L_c",
        "protein_lacarg_c": "protres_lacarg_c",
        "protein_laccys_c": "protres_laccys_c",
        "protein_laclys_c": "protres_laclys_c",
        "protein_lys__L_c": "protres_lys__L_c",
        "protein_lysglu_protein_c": "protres_lysglu_protres_c",
        "protein_mmarg__L_c": "protres_mmarg__L_c",
        "protein_Nproshispi_c": "protres_Nproshispi_c",
        "protein_Ntelehispi_c": "protres_Ntelehispi_c",
        "protein_Nwadpribarg__L_e": "protres_Nwadpribarg__L_e",
        "protein_oadpribser_c": "protres_oadpribser_c",
        "protein_ocdcacys_c": "protres_ocdcacys_c",
        "protein_pepproW0_c": "protres_pepproW0_c",
        "protein_pepproW180_c": "protres_pepproW180_c",
        "protein_rbllys_c": "protres_rbllys_c",
        "protein_rbllys3p_c": "protres_rbllys3p_c",
        "protein_rbllys5p_c": "protres_rbllys5p_c",
        "protein_sadpribcys_c": "protres_sadpribcys_c",
        "protein_sdmarg__L_c": "protres_sdmarg__L_c",
        "protein_ser__L_c": "protres_ser__L_c",
        "protein_ser3oacgam_c": "protres_ser3oacgam_c",
        "protein_serpi_c": "protres_serpi_c",
        "protein_serTAg_c": "protres_serTAg_c",
        "protein_serTnAg_c": "protres_serTnAg_c",
        "protein_sucim__D_c": "protres_sucim__D_c",
        "protein_sucim__L_c": "protres_sucim__L_c",
        "protein_thr__L_c": "protres_thr__L_c",
        "protein_thr3oacgam_c": "protres_thr3oacgam_c",
        "protein_thrpi_c": "protres_thrpi_c",
        "protein_thrTAg_c": "protres_thrTAg_c",
        "protein_thrTnAg_c": "protres_thrTnAg_c",
        "protein_ttdcacys_c": "protres_ttdcacys_c",
        "protein_tyr__L_c": "protres_tyr__L_c",
        "protein_tyrpi_c": "protres_tyrpi_c",
    },
    "genes": {},
    "reactions": {
        "ClPItex": "Cl_PItex",
        "NO22Natex": "NO2_2Natex",
        "CYSL": "CYSLNET",
        "CYSTCYSL": "CYSTL1",
        "SELCYSTL": "SELCYSTL1",
        "SELMETHL": "SELMETHL1",
        "LCMTPPP2CA": "LCMTPP2A",
        "PPMEPPP2CA": "PPMEPP2A",
        "GALt1r": "GAL_Dt",
        "EX_protein_Nwadpribarg__L_e": "EX_protres_Nwadpribarg__L_e",
        "EX_protein_arg__L_e": "EX_protres_arg__L_e",
        "IMRBVPT": "RBVIMPT",
        # Cleanup of nucleotide IDs --> NTD(D)(N)MP
        "NTD1": "NTDDUMP",
        "NTD2": "NTDUMP",
        "NTD3": "NTDDCMP",
        "NTD4": "NTDCMP",
        "NTD5": "NTDDTMP",
        "NTD6": "NTDDAMP",
        "NTD7": "NTDAMP",
        "NTD8": "NTDDGMP",
        "NTD9": "NTDGMP",
        "NTD10": "NTDXMP",
        "NTD11": "NTDIMP",
        "NTD12": "NTDDIMP",
        "NTD15": "NTDPSUMP",
        "2NTDA": "NTD2AMP",
        "2NTDC": "NTD2CMP",
        "2NTDG": "NTD2GMP",
        "2NTDU": "NTD2UMP",
        "NTDAe": "NTDAMPe",
        "NDPAe": "NDPADPe",
        "NTDADPe": "NDPADPe",
    },
}

# %% [markdown]
# #### Metabolites

# %%
attribute_type = "metabolites"
id_mapping_dict = id_mapping_dicts[attribute_type]

id_mapping_df = pd.DataFrame.from_dict(id_mapping_dict, orient="index")
id_mapping_df = id_mapping_df.reset_index(drop=False)
id_mapping_df.columns = ["metRetired", "mets"]
id_mapping_df = id_mapping_df.loc[:, id_mapping_df.columns[::-1]]

previous_id_mapping_df = pd.read_csv(
    get_dirpath("deprecatedIdentifiers")
    / f"{attribute_type}_deprecatedIdentifiers.tsv",
    sep="\t",
    index_col=None,
)

for idx, row in id_mapping_df.iterrows():
    new_id, retiring = row[["mets", "metRetired"]]
    previously_retired = previous_id_mapping_df[
        previous_id_mapping_df["mets"] == retiring
    ]
    retired_set_of_ids = {retiring}
    if not previously_retired.empty:
        # Get all previously retired IDs
        retired_set_of_ids.update(
            previously_retired["metRetired"].apply(split_string).item()
        )
        # Pulling the ID out of retirement
        if new_id in retired_set_of_ids:
            retired_set_of_ids.remove(new_id)
        retired_set_of_ids.add(retiring)
    id_mapping_df.loc[idx, "metRetired"] = build_string(retired_set_of_ids, sep=";")

for old, new in id_mapping_dict.items():
    try:
        metabolite = model.metabolites.get_by_id(old)
    except KeyError:
        print(f"Could not map {old} to new ID.")
    else:
        try:
            metabolite.id = id_mapping_dict[metabolite.id]
        except ValueError as e:
            warn(f"{e}, this is expected if removing/renaming a duplicate")
            model.remove_metabolites([metabolite])

model.repair()

id_mapping_df = pd.concat((id_mapping_df, previous_id_mapping_df), axis=0)
id_mapping_df = (
    id_mapping_df.drop_duplicates()
    .sort_values("mets", ascending=True)
    .reset_index(drop=True)
)
id_mapping_df.to_csv(
    get_dirpath("deprecatedIdentifiers")
    / f"{attribute_type}_deprecatedIdentifiers.tsv",
    sep="\t",
    index=False,
)
id_mapping_df
# Out:
# Could not map PPP2CA_leu__L_c to new ID.
# Could not map PPP2CA_leumeo_c to new ID.
# Could not map protein_aclys__L_c to new ID.
# Could not map protein_admarg__L_c to new ID.
# Could not map protein_arg__L_c to new ID.
# Could not map protein_arg__L_e to new ID.
# Could not map protein_asn__L_c to new ID.
# Could not map protein_asp__D_c to new ID.
# Could not map protein_asp__L_c to new ID.
# Could not map protein_aspmeo__D_c to new ID.
# Could not map protein_cys__L_c to new ID.
# Could not map protein_frulys_c to new ID.
# Could not map protein_frulys3p_c to new ID.
# Could not map protein_frulys6p_c to new ID.
# Could not map protein_gln__L_c to new ID.
# Could not map protein_glu__L_c to new ID.
# Could not map protein_glu5meo__L_c to new ID.
# Could not map protein_gludpam_c to new ID.
# Could not map protein_gluhista_c to new ID.
# Could not map protein_glunpphr_c to new ID.
# Could not map protein_glusrtn_c to new ID.
# Could not map protein_his__L_c to new ID.
# Could not map protein_hxdcacys_c to new ID.
# Could not map protein_isoasp__D_c to new ID.
# Could not map protein_isoasp__L_c to new ID.
# Could not map protein_isoaspmeo__L_c to new ID.
# Could not map protein_lacarg_c to new ID.
# Could not map protein_laccys_c to new ID.
# Could not map protein_laclys_c to new ID.
# Could not map protein_lys__L_c to new ID.
# Could not map protein_lysglu_protein_c to new ID.
# Could not map protein_mmarg__L_c to new ID.
# Could not map protein_Nproshispi_c to new ID.
# Could not map protein_Ntelehispi_c to new ID.
# Could not map protein_Nwadpribarg__L_e to new ID.
# Could not map protein_oadpribser_c to new ID.
# Could not map protein_ocdcacys_c to new ID.
# Could not map protein_pepproW0_c to new ID.
# Could not map protein_pepproW180_c to new ID.
# Could not map protein_rbllys_c to new ID.
# Could not map protein_rbllys3p_c to new ID.
# Could not map protein_rbllys5p_c to new ID.
# Could not map protein_sadpribcys_c to new ID.
# Could not map protein_sdmarg__L_c to new ID.
# Could not map protein_ser__L_c to new ID.
# Could not map protein_ser3oacgam_c to new ID.
# Could not map protein_serpi_c to new ID.
# Could not map protein_serTAg_c to new ID.
# Could not map protein_serTnAg_c to new ID.
# Could not map protein_sucim__D_c to new ID.
# Could not map protein_sucim__L_c to new ID.
# Could not map protein_thr__L_c to new ID.
# Could not map protein_thr3oacgam_c to new ID.
# Could not map protein_thrpi_c to new ID.
# Could not map protein_thrTAg_c to new ID.
# Could not map protein_thrTnAg_c to new ID.
# Could not map protein_ttdcacys_c to new ID.
# Could not map protein_tyr__L_c to new ID.
# Could not map protein_tyrpi_c to new ID.
#                    mets          metRetired
# 0                35camp                camp
# 1            FA_hs_16_0                hdca
# 2           FA_hs_18_9Z              ocdcea
# 3        FA_hs_18_9Z12Z                lnlc
# 4         FAcoa_hs_16_0              pmtcoa
# ..                  ...                 ...
# 133  protres_ttdcacys_c  protein_ttdcacys_c
# 134    protres_tyr__L_c    protein_tyr__L_c
# 135     protres_tyrpi_c     protein_tyrpi_c
# 136            slgth__R              lgt__S
# 137           udpglc__D                udpg
#
# [138 rows x 2 columns]

# %% [markdown]
# #### Reactions

# %%
attribute_type = "reactions"
id_mapping_dict = id_mapping_dicts[attribute_type]


id_mapping_df = pd.DataFrame.from_dict(id_mapping_dict, orient="index")
id_mapping_df = id_mapping_df.reset_index(drop=False)
id_mapping_df.columns = ["rxnRetired", "rxns"]
id_mapping_df = id_mapping_df.loc[:, id_mapping_df.columns[::-1]]

previous_id_mapping_df = pd.read_csv(
    get_dirpath("deprecatedIdentifiers")
    / f"{attribute_type}_deprecatedIdentifiers.tsv",
    sep="\t",
    index_col=None,
)

for idx, row in id_mapping_df.iterrows():
    new_id, retiring = row[["rxns", "rxnRetired"]]
    previously_retired = previous_id_mapping_df[
        previous_id_mapping_df["rxns"] == retiring
    ]
    retired_set_of_ids = {retiring}
    if not previously_retired.empty:
        # Get all previously retired IDs
        print(previously_retired)
        retired_set_of_ids.update(
            previously_retired["rxnRetired"].apply(split_string).item()
        )
        # Pulling the ID out of retirement
        if new_id in retired_set_of_ids:
            retired_set_of_ids.remove(new_id)
        retired_set_of_ids.add(retiring)
    id_mapping_df.loc[idx, "rxnRetired"] = build_string(retired_set_of_ids, sep=";")

for old, new in id_mapping_dict.items():
    try:
        reaction = model.reactions.get_by_id(old)
    except KeyError:
        print(f"Could not map {old} to new ID.")
    else:
        try:
            reaction.id = id_mapping_dict[reaction.id]
        except ValueError as e:
            warn(f"{e}, this is expected if removing/renaming a duplicate")
            model.remove_reactions([reaction])

model.repair()

id_mapping_df = pd.concat((id_mapping_df, previous_id_mapping_df), axis=0)
id_mapping_df = (
    id_mapping_df.drop_duplicates()
    .sort_values("rxns", ascending=True)
    .reset_index(drop=True)
)
id_mapping_df.to_csv(
    get_dirpath("deprecatedIdentifiers")
    / f"{attribute_type}_deprecatedIdentifiers.tsv",
    sep="\t",
    index=False,
)
id_mapping_df
# Out:
#         rxns rxnRetired
# 119  NTDADPe      NDPAe
# Could not map ClPItex to new ID.
# Could not map NO22Natex to new ID.
# Could not map CYSL to new ID.
# Could not map CYSTCYSL to new ID.
# Could not map SELCYSTL to new ID.
# Could not map SELMETHL to new ID.
# Could not map LCMTPPP2CA to new ID.
# Could not map PPMEPPP2CA to new ID.
# Could not map EX_protein_Nwadpribarg__L_e to new ID.
# Could not map EX_protein_arg__L_e to new ID.
# Could not map IMRBVPT to new ID.
# Could not map NTD1 to new ID.
# Could not map NTD2 to new ID.
# Could not map NTD3 to new ID.
# Could not map NTD4 to new ID.
# Could not map NTD5 to new ID.
# Could not map NTD6 to new ID.
# Could not map NTD7 to new ID.
# Could not map NTD8 to new ID.
# Could not map NTD9 to new ID.
# Could not map NTD10 to new ID.
# Could not map NTD11 to new ID.
# Could not map NTD12 to new ID.
# Could not map NTD15 to new ID.
# Could not map 2NTDA to new ID.
# Could not map 2NTDC to new ID.
# Could not map 2NTDG to new ID.
# Could not map 2NTDU to new ID.
# Could not map NTDAe to new ID.
# Could not map NDPAe to new ID.
# /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/ipykernel_3116/3331829275.py:43: UserWarning: The model already contains a reaction with the id: GAL_Dt, this is expected if removing/renaming a duplicate
#   warn(f"{e}, this is expected if removing/renaming a duplicate")
# /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/ipykernel_3116/3331829275.py:43: UserWarning: The model already contains a reaction with the id: NDPADPe, this is expected if removing/renaming a duplicate
#   warn(f"{e}, this is expected if removing/renaming a duplicate")
#             rxns rxnRetired
# 0    4PYRDXABCte     4PYRDX
# 1           ACt2      ACt2r
# 2         ADRNLt    ADRNLtu
# 3            AHC       AHCi
# 4         ARDFE2        ARD
# ..           ...        ...
# 216        UMPK1       UMPK
# 217      UPPG3DC     UPPDC1
# 218       UPPG3S      UPP3S
# 219     XYLTD_Dx    XYLTD_D
# 220     XYLUR_Ly      XYLUR
#
# [221 rows x 2 columns]

# %% [markdown]
# ### Update model based on curation and proteomic evidence
# * Add metabolites first, then genes and lastly, reactions
# * Add metabolites with mass and charge balanced formulas (ChemAxon)

# %%
dataframes_updated = {}
dataframes_evidence = {}
dataframes_removed = {}
overwrite = True

# %% [markdown]
# #### Metabolites

# %%
attribute_type = "metabolites"

df_updated = pd.read_csv(
    get_dirpath("curated") / f"{attribute_type}_updated_1.2.0.tsv",
    sep="\t",
    index_col=None,
).fillna("")

attr_cols = ["metabolites", "name", "formula", "charge", "compartment"]
for idx, row in df_updated.iterrows():
    mid, name, formula, charge, compartment = row[attr_cols]
    if not model.metabolites.has_id(mid):
        # Add reaction to model
        model.add_metabolites([Metabolite(mid)])
        # print(mid)

    metabolite = model.metabolites.get_by_id(mid)
    metabolite.name = name
    metabolite.formula = formula
    metabolite.charge = int(charge)
    metabolite.compartment = compartment

    annotations_dict = row[~row.index.isin(attr_cols)].to_dict()
    notes = annotations_dict.pop("notes")
    if notes:
        metabolite.notes.update({"notes": str(notes)})
    annotations_dict = {
        k: v
        for k, v in annotations_dict.items()
        if not k.startswith("metabolomic") and v
    }
    metabolite.annotation.update(annotations_dict)

met_formulas = standardardize_metabolite_formulas(
    dict(zip(model.metabolites.list_attr("id"), model.metabolites.list_attr("formula")))
)
for mid, formula in met_formulas.items():
    model.metabolites.get_by_id(mid).formula = formula


dataframes_updated[attribute_type] = df_updated
try:
    df_previous_evidence = pd.read_csv(
        get_dirpath("curated") / f"{attribute_type}_evidence.tsv",
        sep="\t",
        index_col=None,
        dtype=str,
    )
except FileNotFoundError:
    df_previous_evidence = pd.DataFrame([], columns=[attribute_type], dtype=str)

df_evidence = pd.concat((df_updated, df_previous_evidence), axis=0)
df_evidence[attribute_type] = df_evidence[attribute_type].replace(
    id_mapping_dicts[attribute_type]
)
df_evidence = (
    df_evidence.drop_duplicates(subset=[attribute_type])
    .sort_values(attribute_type, ascending=True)
    .reset_index(drop=True)
)[df_previous_evidence.columns]

dataframes_evidence[attribute_type] = df_evidence
dataframes_updated[attribute_type]
# Out:
#       metabolites  metabolite                                 name  \
# 0         2amac_c       2amac             2-aminoprop-2-enoic acid
# 1        2imppa_c      2imppa                    2-Iminopropanoate
# 2          2mop_c        2mop             2-methyl-3-oxopropanoate
# 3      34dhmald_c    34dhmald          3,4-dihydroxymandelaldehyde
# 4    34dhoxmand_c  34dhoxmand               3,4-dihydroxymandelate
# ..            ...         ...                                  ...
# 219        3mob_e        3mob               3-methyl-2-oxobutyrate
# 220      crm_hs_e      crm_hs                 Ceramide (Cer d18:2)
# 221       alltn_e       alltn                            Allantoin
# 222       3dfru_e       3dfru                      3-deoxyfructose
# 223   mtthiogmp_e   mtthiogmp  6-methylthioguanosine monophosphate
#
#           formula  charge compartment metabolomic evidence (#studies)  \
# 0         C3H5NO2       0           c
# 1         C3H5NO2       0           c
# 2          C4H5O3      -1           c
# 3          C8H8O4       0           c
# 4          C8H7O5      -1           c
# ..            ...     ...         ...                             ...
# 219        C5H7O3      -1           e
# 220    C19H36NO3R       0           e
# 221      C4H6N4O3       0           e
# 222       C6H12O5       0           e
# 223  C11H14N5O7PS      -2           e
#
#     metabolomic evidence (pubmed) references notes
# 0
# 1
# 2
# 3
# 4
# ..                            ...        ...   ...
# 219
# 220
# 221
# 222
# 223
#
# [224 rows x 10 columns]

# %% [markdown]
# #### Genes

# %%
attribute_type = "genes"

df_updated = pd.read_csv(
    get_dirpath("curation") / f"{attribute_type}_updated_1.2.0.tsv",
    sep="\t",
    index_col=None,
).fillna("")

attr_cols = ["genes"]
for idx, row in df_updated.iterrows():
    # Between these three annotation fields, should be likely that the rest can get extracted from UniProt.
    gid = row[attr_cols[0]]
    if not model.genes.has_id(gid):
        gene = Gene(gid)
        model.genes.extend([gene])
        # print(gene.id)
    gene = model.genes.get_by_id(gid)
    annotations_dict = row[~row.index.isin(attr_cols)].to_dict()
    annotations_dict = {
        k: v for k, v in annotations_dict.items() if not k.startswith("proteomic") and v
    }
    gene.annotation.update(annotations_dict)


dataframes_updated[attribute_type] = df_updated
try:
    df_previous_evidence = pd.read_csv(
        get_dirpath("curation") / f"{attribute_type}_evidence.tsv",
        sep="\t",
        index_col=None,
        dtype=str,
    )
except FileNotFoundError:
    df_previous_evidence = pd.DataFrame([], columns=[attribute_type], dtype=str)


df_evidence = pd.concat((df_updated, df_previous_evidence), axis=0)
df_evidence[attribute_type] = df_evidence[attribute_type].replace(
    id_mapping_dicts[attribute_type]
)
df_evidence = (
    df_evidence.drop_duplicates(subset=[attribute_type])
    .sort_values(attribute_type, ascending=True)
    .reset_index(drop=True)
)[df_previous_evidence.columns]

dataframes_evidence[attribute_type] = df_evidence
dataframes_updated[attribute_type]
# Out:
#       genes uniprot ncbigene hgnc.symbol proteomic evidence (#studies)  \
# 0     ACER2  Q5QJU3   340485       ACER2                           0.0
# 1     ACER3  Q9NUN7    55331       ACER3
# 2     ACSS2  Q9NR19    55902       ACSS2                           2.0
# 3     ACTA1  P68133       58       ACTA1                           8.0
# 4      ACTB  P60709       60        ACTB                          19.0
# ..      ...     ...      ...         ...                           ...
# 150  VCPIP1  Q96JH7    80124      VCPIP1
# 151   VPS4A  Q9UN37    27183       VPS4A                          11.0
# 152   VPS4B  O75351     9525       VPS4B
# 153   WDR77  Q9BQA1    79084       WDR77
# 154    YES1  P07947     7525        YES1
#
#                            proteomic evidence (pubmed)  \
# 0
# 1
# 2                      pubmed:30327373;pubmed:38260479
# 3    pubmed:16861337;pubmed:18614565;pubmed:2777734...
# 4    pubmed:12362340;pubmed:16861337;pubmed:1839964...
# ..                                                 ...
# 150
# 151  pubmed:18494517;pubmed:18614565;pubmed:2826317...
# 152
# 153
# 154
#
#                                             references notes
# 0    pubmed:20207939;pubmed:35886939;pubmed:2940161...
# 1      pubmed:20207939;pubmed:35886939;pubmed:29401619
# 2        pubmed:4379089;pubmed:6115779;pubmed:38513237
# 3    pubmed:284418;pubmed:6682109;pubmed:25717184;p...
# 4    pubmed:284418;pubmed:6682109;pubmed:25717184;p...
# ..                                                 ...   ...
# 150
# 151                                    pubmed:33186543
# 152
# 153
# 154
#
# [155 rows x 8 columns]

# %% [markdown]
# #### Reactions
# * Addition of hemoglobin glycation
# * All intracellular reactions converted to use/consume NH4, which is dominant at pH 7.25. Transport and protonation reactions for NH3 kept.
# * Add NEDD8 neddylation and fix ubiquitin reaction GPRs accordingly
# * Reversibility updates for phosphoribosyltransferase reactions
# * GPR updates according to Complex Portal and proteomic data
#     * Add PRMT5 methylsome complex
#     * Add PI3K class III complex proteins
#     * Multiple Ubiquination complexes
#     * Multiple VCP complexes and other ATPases
# * Add IDH2 and MDH2 to GPRs
# * Add SLC22A4 and SLC22A16 GPRs

# %%
attribute_type = "reactions"

df_updated = pd.read_csv(
    get_dirpath("curated") / f"{attribute_type}_updated_1.2.0.tsv",
    sep="\t",
    index_col=None,
).fillna("")
attr_cols = ["reactions", "name", "reaction", "gene reaction rule", "subsystem"]
for idx, row in df_updated.iterrows():
    rid, name, reaction_str, gpr, subsystem = row[attr_cols]
    try:
        if not model.reactions.has_id(rid):
            # Add reaction to model
            model.add_reactions([Reaction(rid)])
    except ValueError as e:
        print(idx, rid, name)
        raise e

    reaction = model.reactions.get_by_id(rid)
    reaction.build_reaction_from_string(reaction_str)
    reaction.name = name
    reaction.gene_reaction_rule = gpr
    reaction.subsystem = subsystem

    annotations_dict = row[~row.index.isin(attr_cols)].to_dict()
    notes = annotations_dict.pop("notes")
    if notes:
        reaction.notes.update({"notes": str(notes)})
    if "proteomic evidence (#studies)" in annotations_dict:
        annotations_dict.pop("proteomic evidence (#studies)")
    annotations_dict = {
        k: v for k, v in annotations_dict.items() if not k.startswith("proteomic") and v
    }
    reaction.annotation.update(annotations_dict)


dataframes_updated[attribute_type] = df_updated
try:
    df_previous_evidence = pd.read_csv(
        get_dirpath("curated") / f"{attribute_type}_evidence.tsv",
        sep="\t",
        index_col=None,
        dtype=str,
    )
except FileNotFoundError:
    df_previous_evidence = pd.DataFrame([], columns=[attribute_type], dtype=str)

df_evidence = pd.concat((df_updated, df_previous_evidence), axis=0)
df_evidence[attribute_type] = df_evidence[attribute_type].replace(
    id_mapping_dicts[attribute_type]
)
df_evidence = (
    df_evidence.drop_duplicates(subset=[attribute_type])
    .sort_values(
        ["subsystem", "reactions"],
        ascending=[True, True],
    )
    .reset_index(drop=True)
)[df_previous_evidence.columns]

dataframes_evidence[attribute_type] = df_evidence
dataframes_updated[attribute_type]
# Out:
#          reactions                                               name  \
# 0          5FLUDPK  Nucleoside-diphosphate kinase (ATP:5-fluorouri...
# 1          5FLUMPK  Uridylate kinase (ATP:5-fluorouridine 5-monoph...
# 2         5FLURAPT           5-fluorouracil phosphoribosyltransferase
# 3         D5FURADy  5,6-dihydro-5-fluorouracil:NADP + 5-oxidoreduc...
# 4          L2HGDHx                 L-2-hydroxyglutarate dehydrogenase
# ..             ...                                                ...
# 534        UBIQE1T  [E1 ubiquitin-activating enzyme]-S-ubiquitinyl...
# 535    UBIQE2CONJT  [E2 ubiquitin-conjugating enzyme]-S-ubiquitiny...
# 536       MMALNDHx  (S)-methylmalonate semialdehyde:NAD + oxidored...
# 537        PYDXPPe                  Pyridoxal 5-phosphate phosphatase
# 538  AVITE1RCYTB5R  Reduction of alpha-tocopherol radical via L-as...
#
#                                               reaction  \
# 0                atp_c + 5fludp_c --> adp_c + 5flutp_c
# 1                atp_c + 5flump_c --> adp_c + 5fludp_c
# 2               5flura_c + prpp_c --> 5flump_c + ppi_c
# 3    5flura_c + nadph_c + h_c --> 56dh5flura_c + na...
# 4         akg_c + h_c + nadh_c --> 2hglut__L_c + nad_c
# ..                                                 ...
# 534  accprot_lys__L_c + ubiqSe1act_cys__L_c --> acc...
# 535  accprot_lys__L_c + ubiqSe2conj_cys__L_c --> ac...
# 536  h2o_c + nad_c + 2mop_c --> 2.0 h_c + nadh_c + ...
# 537                 h2o_e + pydx5p_e --> pi_e + pydx_e
# 538  avite1r_c + focytb5_c + h_c --> avite1_c + fic...
#
#                                     gene reaction rule  \
# 0    NME1 or (NME1 and NME2) or NME2 or (NME1 and N...
# 1                                                CMPK1
# 2                                                 UMPS
# 3                                                 DPYD
# 4    LDHB or LDHA or PHGDH or MDH1 or MDH2 or (LDHA...
# ..                                                 ...
# 534                                     UBE2O or CDC34
# 535  UBR4 or HUWE1 or (UBAC1 and RNF123) or (RBX1 a...
# 536                                 ALDH9A1 or ALDH3A2
# 537                                               ALPL
# 538           (CYB5R3 and CYB5B) or (CYB5R3 and CYB5A)
#
#                                        subsystem  spontaneous  \
# 0                      5-fluorouracil metabolism            0
# 1                      5-fluorouracil metabolism            0
# 2                      5-fluorouracil metabolism            0
# 3                      5-fluorouracil metabolism            0
# 4    Alanine, aspartate and glutamate metabolism            0
# ..                                           ...          ...
# 534               Ubiquitin mediated proteolysis            0
# 535               Ubiquitin mediated proteolysis            0
# 536   Valine, leucine, and isoleucine metabolism            0
# 537                        Vitamin B6 metabolism            0
# 538                         Vitamin E metabolism            0
#
#                          proteomic evidence (#studies)  \
# 0
# 1
# 2
# 3
# 4              LDHA (22);LDHB (22);MDH1 (16);PHGDH (2)
# ..                                                 ...
# 534                               CDC34 (5);UBE2O (16)
# 535  CAND1 (18);CUL1 (18);HUWE1 (16);RBX1 (11);RNF1...
# 536
# 537
# 538                   CYB5A (10);CYB5B (9);CYB5R3 (21)
#
#                                             references notes  metatlas
# 0
# 1
# 2
# 3
# 4                      pubmed:27813142;pubmed:31473074
# ..                                                 ...   ...       ...
# 534  pubmed:15095787;pubmed:21508250;pubmed:3456453...
# 535  pubmed:15095787;pubmed:21508250;pubmed:3456453...
# 536                                                           MAR04797
# 537  pubmed:1322411;pubmed:14522954;pubmed:7448195;...
# 538                                     pubmed:8388377
#
# [539 rows x 10 columns]

# %% [markdown]
# ### Refine model through removing items
# #### Reactions

# %%
attribute_type = "reactions"
try:
    df_removed = pd.read_csv(
        get_dirpath("curation") / f"{attribute_type}_removed.tsv",
        sep="\t",
        index_col=None,
    )
except FileNotFoundError:
    df_removed = pd.DataFrame([], columns=[attribute_type], dtype=str)

to_remove = []
for reaction in df_removed[attribute_type]:
    try:
        reaction = getattr(model, attribute_type).get_by_id(reaction)
    except KeyError:
        continue
    to_remove.append(reaction)

model.remove_reactions(to_remove)
# Clean up removal file before archival
df_removed = (
    df_removed.drop_duplicates(subset=[attribute_type])
    .sort_values(attribute_type, ascending=True)
    .reset_index(drop=True)
)
dataframes_evidence[attribute_type] = dataframes_evidence[attribute_type][
    ~dataframes_evidence[attribute_type][attribute_type].isin(
        df_removed[attribute_type].values
    )
]
dataframes_removed[attribute_type] = df_removed
dataframes_removed[attribute_type]
# Out:
#                   reactions  \
# 0              3MOXTYRESSte
# 1                     ALAt4
# 2                    BANDMT
# 3                 BILGLCURt
# 4                   BILIRBU
# ..                      ...
# 171  SK_pe_hs_18_9Z_18_9Z_c
# 172               THMMPtrbc
# 173                  TMDPPK
# 174                   UDPGD
# 175                  UDPGNP
#
#                                                   name  \
# 0    3-Methoxytyramine secretion via secretory vesi...
# 1                             Alanine-Sodium symporter
# 2              Band membrane protein-methyltransferase
# 3    Bilirubin monoglucuronide transport via bicarb...
# 4                Bilirubin UDP-glucuronosyltransferase
# ..                                                 ...
# 171                            Sink pe hs 18 1 18 1(c)
# 172  Thiamine monophosphate transport (passive - re...
# 173                        Thiamine diphosphate kinase
# 174                         UDPglucose 6-dehydrogenase
# 175                 UDP-glucuronate glucuronohydrolase
#
#                                                  notes
# 0    Replaced by simple transport reaction (3MOXTYR...
# 1    Replaced by reactions involving the amino acid...
# 2    Replaced by generic methylation reactions. Ban...
# 3    Heme oxygenase occurs in macrophages. Furtherm...
# 4    Heme oxygenase occurs in macrophages. Furtherm...
# ..                                                 ...
# 171  Lipids are pooled, replaced with pooled versio...
# 172  Replaced by reactions involving reduced folate...
# 173  Replaced by ADK7. Adenylate kinase isozyme 1 h...
# 174                  No proteomic or activity evidence
# 175                  No proteomic or activity evidence
#
# [176 rows x 3 columns]

# %% [markdown]
# #### Genes

# %%
attribute_type = "genes"
try:
    df_removed = pd.read_csv(
        get_dirpath("curation") / f"{attribute_type}_removed.tsv",
        sep="\t",
        index_col=None,
        dtype=str,
    )
except FileNotFoundError:
    df_removed = pd.DataFrame([], columns=[attribute_type], dtype=str)

to_remove = []
for gene in df_removed[attribute_type]:
    try:
        gene = model.genes.get_by_id(gene)
    except KeyError:
        continue
    to_remove.append(gene)
model.genes -= to_remove

# Clean up removal file before archival
df_removed = (
    df_removed.drop_duplicates(subset=[attribute_type])
    .sort_values(attribute_type, ascending=True)
    .reset_index(drop=True)
)
for gene in model.genes:
    if gene.reactions:
        continue
    print(f"Orphaned: {gene}")

dataframes_evidence[attribute_type] = dataframes_evidence[attribute_type][
    ~dataframes_evidence[attribute_type][attribute_type].isin(
        df_removed[attribute_type].values
    )
]
dataframes_removed[attribute_type] = df_removed
dataframes_removed[attribute_type]
# Out:
#       genes uniprot ncbigene hgnc.symbol  \
# 0    ABCC10  Q5T3U5    89845      ABCC10
# 1     ADCY1  Q08828      107       ADCY1
# 2     ADCY3  O60266      109       ADCY3
# 3     ADCY4  Q8NFM4   196883       ADCY4
# 4     ADCY5  O95622      111       ADCY5
# ..      ...     ...      ...         ...
# 110     TAT  P17735     6898         TAT
# 111    UGDH  O60701     7358        UGDH
# 112  UGT1A1  P22309    54658      UGT1A1
# 113  UGT1A4  P22310    54657      UGT1A4
# 114  ZNF384  Q8TF68   171017      ZNF384
#
#                                                  notes
# 0    evidence indicates other enzymes are present i...
# 1    no proteomic evidence. evidence indicates othe...
# 2    no proteomic evidence. evidence indicates othe...
# 3    no proteomic evidence. evidence indicates othe...
# 4    no proteomic evidence. evidence indicates othe...
# ..                                                 ...
# 110  no proteomic evidence. evidence indicates othe...
# 111                             no proteomic evidence.
# 112                             no proteomic evidence.
# 113                             no proteomic evidence.
# 114  no proteomic evidence. evidence indicates othe...
#
# [115 rows x 5 columns]

# %% [markdown]
# #### Metabolites

# %%
attribute_type = "metabolites"
try:
    df_removed = pd.read_csv(
        get_dirpath("curation") / f"{attribute_type}_removed.tsv",
        sep="\t",
        index_col=None,
        dtype=str,
    )
except FileNotFoundError:
    df_removed = pd.DataFrame([], columns=[attribute_type], dtype=str)

to_remove = []
for metabolite in df_removed[attribute_type]:
    try:
        metabolite = model.metabolites.get_by_id(metabolite)
    except KeyError:
        continue
    model.remove_metabolites([metabolite])
model.remove_metabolites(to_remove)

# Clean up removal file before archival
df_removed = (
    df_removed.drop_duplicates(subset=[attribute_type])
    .sort_values(attribute_type, ascending=True)
    .reset_index(drop=True)
)
for metabolite in model.metabolites:
    if metabolite.reactions:
        continue
    print(f"Orphaned: {metabolite}")

dataframes_evidence[attribute_type] = dataframes_evidence[attribute_type][
    ~dataframes_evidence[attribute_type][attribute_type].isin(
        df_removed[attribute_type].values
    )
]
dataframes_removed[attribute_type] = df_removed
dataframes_removed[attribute_type]
# Out:
#                metabolites                                               name  \
# 0                   band_c  Band membrane protein (universal, erythrocyte ...
# 1                 bandmt_c  Band membrane protein (methylated, universal, ...
# 2               bilglcur_c                          Bilirubin monoglucuronide
# 3               bilglcur_e                          Bilirubin monoglucuronide
# 4    cdpdag_hs_16_0_16_0_c    CDP diacylglycerol (homo sapiens, C16:0, C16:0)
# ..                     ...                                                ...
# 65  pe_hs_18_9Z12Z_18_9Z_c  Phosphatidylethanolamine (homo sapiens, C18:2,...
# 66  pe_hs_18_9Z_18_9Z12Z_c  Phosphatidylethanolamine (homo sapiens, C18:1,...
# 67     pe_hs_18_9Z_18_9Z_c  Phosphatidylethanolamine (homo sapiens, C18:1,...
# 68                 pppg9_c                              protoporphyrinogen IX
# 69              udpglcur_c                                  UDP-D-glucuronate
#
#                                                 notes
# 0   Replaced by generic methylation reactions. Ban...
# 1   Replaced by generic methylation reactions. Ban...
# 2   Heme oxygenase occurs in macrophages. Furtherm...
# 3   Heme oxygenase occurs in macrophages. Furtherm...
# 4   Lipids are pooled, replaced with pooled versio...
# ..                                                ...
# 65  Lipids are pooled, replaced with pooled versio...
# 66  Lipids are pooled, replaced with pooled versio...
# 67  Lipids are pooled, replaced with pooled versio...
# 68  Protoporphyrinogen oxidase is a mitochondrial ...
# 69  Heme oxygenase occurs in macrophages. Furtherm...
#
# [70 rows x 3 columns]

# %%
for attribute_type in ["reactions", "genes", "metabolites"]:
    df_evidence = dataframes_evidence[attribute_type]
    df_removed = dataframes_removed[attribute_type]
    if overwrite:
        df_evidence.to_csv(
            get_dirpath("curated") / f"{attribute_type}_evidence.tsv",
            sep="\t",
            index=False,
        )
        df_removed.to_csv(
            get_dirpath("curated") / f"{attribute_type}_removed.tsv",
            sep="\t",
            index=False,
        )

# %% [markdown]
# ### Ensure all metabolites, genes, and reactions exist
# If removed (e.g., a duplicate), will show up in missing.

# %%
missing_metabolites = set(model.metabolites.list_attr("id")).symmetric_difference(
    dataframes_evidence["metabolites"]["metabolites"].values
)

missing_genes = set(model.genes.list_attr("id")).symmetric_difference(
    dataframes_evidence["genes"]["genes"].values
)

missing_reactions = set(
    model.reactions.query(lambda x: not x.subsystem == "Pseudoreactions").list_attr(
        "id"
    )
).symmetric_difference(dataframes_evidence["reactions"]["reactions"].values)

print(len(missing_genes))
print(len(missing_metabolites))
print(len(missing_reactions))
# Out:
# 0
# 0
# 0

# %%
for x in missing_metabolites:
    print(x)

# %%
for x in missing_genes:
    print(x)

# %%
for x in missing_reactions:
    print(x)

# %% [markdown]
# ### Check for extra metabolites, genes, and reactions

# %%
for met in model.metabolites.query(lambda x: not len(x.reactions)):
    print(f"{met.id}")

# %%
for gene in model.genes.query(lambda x: not len(x.reactions)):
    print(gene.id)

# %%
for reaction in model.reactions.query(lambda x: not len(x.metabolites)):
    print(reaction.id)

# %% [markdown]
# ### Cleanup model values

# %%
for mid, row in dataframes_evidence["metabolites"].set_index("metabolites").iterrows():
    if gid in missing_metabolites:
        continue
    metabolite = model.metabolites.get_by_id(mid)
    metabolite.name = row["name"]
    metabolite.formula = row["formula"]
    metabolite.charge = int(row["charge"])
    metabolite.compartment = row["compartment"]
    metabolite.annotation["metabolite"] = metabolite.id.replace(
        f"_{metabolite.compartment}", ""
    )

for rid, row in dataframes_evidence["reactions"].set_index("reactions").iterrows():
    if rid in missing_reactions:
        continue
    reaction = model.reactions.get_by_id(rid)
    reaction.name = row["name"]

for gid, row in dataframes_evidence["genes"].set_index("genes").iterrows():
    if gid in missing_genes:
        continue
    gene = model.genes.get_by_id(gid)
    gene.name = row["hgnc.symbol"]

# %% [markdown]
# #### Add boundary reactions

# %%
boundaries = {
    # All exchange boundary reactions added
    "exchange": model.metabolites.query(lambda x: x.compartment == "e").list_attr("id"),
    # Intracellular demands, only used for accumulation is allowed for a compound
    "demand": [],
    # Intracellular sinks, only used for when a source is needed for a compound
    "sink": [
        # Globin/Hemoglobin
        "oxyhb_c",
        "hb4_23dpg_c",
        "hb_hco2_c",
        "globin_c",
        "hbsno_c",
        "carboxyhb_c",
        "cclglobin_c",
        "hemedegprods_c",
        "hba1c_c",
        # Amino acids
        # AA protein Residues
        "protres_arg__L_c",
        "protres_asn__L_c",
        "protres_asp__L_c",
        "protres_cys__L_c",
        "protres_gln__L_c",
        "protres_glu__L_c",
        "protres_his__L_c",
        "protres_lys__L_c",
        "protres_met__L_c",
        "protres_ser__L_c",
        "protres_thr__L_c",
        "protres_tyr__L_c",
        "protres_tyr__L_c",
        # Other AA residues
        "protres_asp__D_c",
        "protres_isoasp__L_c",
        "protres_isoasp__D_c",
        # Phosphorylated residues
        "protres_Nproshispi_c",
        "protres_Ntelehispi_c",
        "protres_serpi_c",
        "protres_thrpi_c",
        "protres_tyrpi_c",
        # Acetylated residues
        "protres_aclys__L_c",
        # Glycosylated residues
        "protres_ser3oacgam_c",
        "protres_thr3oacgam_c",
        "protres_serTAg_c",
        "protres_thrTAg_c",
        # Glycated residues
        "protres_frulys_c",
        "protres_rbllys_c",
        # Methylated residues
        "protres_admarg__L_c",
        "protres_sdmarg__L_c",
        # Lipidated residues
        "protres_ttdcacys_c",
        "protres_hxdcacys_c",
        "protres_ocdcacys_c",
        # Oxidized residues
        "protres_metSox__SL_c",
        # Nitrosylated residues
        "protres_snocys__L_c",
        # ADP-ribosylated residues
        "protres_oadpribser_c",
        "protres_sadpribcys_c",
        # Amine
        "protres_gludpam_c",
        "protres_gluhista_c",
        "protres_glunpphr_c",
        "protres_glusrtn_c",
        "protres_glu5meo__L_c",
        "protres_lysglu_protres_c",
        # Ubiquitin
        "polyubb_c",
        "ubiquitin_c",
        "accprot_monoubiqlys_c",
        "accprot_ubiqlys_c",
        "accprot_lys__L_c",
        "cullin_lys__L_c",
        "cullin_nedd8lys_c",
        "nedd8_c",
        # Small ions
        "na1_c",
        "k_c",
        "ca2_c",
        "hno_c",
        "co3r_c",
        # Vitamin E
        "avite1_c",
        "avite1qn_c",
        # 'Redoxins'
        "prdx2crd_c",
        "prdx2cso3_c",
        "grdx2crd_c",
        "grdx2cox_c",
        # CoA
        # 'FAcoa_10_DC_c',
        # 'FAcoa_12_DC_c',
        # 'FAcoa_16_DC_c',
        # 'FAcoa_4_DC_c',
        # 'FAcoa_5_2EDC_c',
        # 'FAcoa_5_DC_c',
        # 'FAcoa_6_DC_c',
        # 'FAcoa_7_DC_c',
        # 'FAcoa_8_DC_c',
        # 'FAcoa_5_3M3OH__S_c',
        # 'FAcoa_hs_10_3OH__S_c',
        # 'FAcoa_hs_12_3OH__S_c',
        # 'FAcoa_hs_14_3OH__S_c',
        # 'FAcoa_hs_14_5E8Z3OH__S_c',
        # 'FAcoa_hs_14_7Z3OH__S_c',
        # 'FAcoa_hs_16_3OH__R_c',
        # 'FAcoa_hs_16_3OH__S_c',
        # 'FAcoa_hs_16_7E10Z3OH__S_c',
        # 'FAcoa_hs_16_9Z3OH__S_c',
        # 'FAcoa_hs_17_3OH__R_c',
        # 'FAcoa_hs_18_3OH__R_c',
        # 'FAcoa_hs_18_3OH__S_c',
        # 'FAcoa_hs_18_9Z12Z3OH__S_c',
        # 'FAcoa_hs_18_9Z3OH__S_c',
        # 'FAcoa_hs_19_3OH__R_c',
        # 'FAcoa_hs_20_11Z14Z17Z3OH__R_c',
        # 'FAcoa_hs_20_11Z14Z3OH__R_c',
        # 'FAcoa_hs_20_11Z3OH__R_c',
        # 'FAcoa_hs_20_13Z3OH__R_c',
        # 'FAcoa_hs_20_3OH__R_c',
        # 'FAcoa_hs_20_8Z11Z14Z17Z3OH__R_c',
        # 'FAcoa_hs_20_8Z11Z14Z3OH__R_c',
        # 'FAcoa_hs_20_8Z11Z3OH__R_c',
        # 'FAcoa_hs_20_9Z3OH__R_c',
        # 'FAcoa_hs_21_3OH__R_c',
        # 'FAcoa_hs_22_10Z13Z16Z19Z3OH__R_c',
        # 'FAcoa_hs_22_10Z13Z16Z3OH__R_c',
        # 'FAcoa_hs_22_11Z3OH__R_c',
        # 'FAcoa_hs_22_13Z16Z19Z3OH__R_c',
        # 'FAcoa_hs_22_13Z16Z3OH__R_c',
        # 'FAcoa_hs_22_13Z3OH__R_c',
        # 'FAcoa_hs_22_3OH__R_c',
        # 'FAcoa_hs_22_7Z10Z13Z16Z19Z3OH__R_c',
        # 'FAcoa_hs_22_7Z10Z13Z16Z3OH__R_c',
        # 'FAcoa_hs_23_3OH__R_c',
        # 'FAcoa_hs_24_12Z15Z18Z21Z3OH__R_c',
        # 'FAcoa_hs_24_15Z3OH__R_c',
        # 'FAcoa_hs_24_3OH__R_c',
        # 'FAcoa_hs_24_9Z12Z15Z18Z21Z3OH__R_c',
        # 'FAcoa_hs_24_9Z12Z15Z18Z3OH__R_c',
        # 'FAcoa_hs_26_17Z3OH__R_c',
        # 'FAcoa_hs_26_3OH__R_c',
        # 'FAcoa_hs_3_3OH__S_c',
        # 'FAcoa_hs_4_3OH__R_c',
        # 'FAcoa_hs_6_3OH__S_c',
        # 'FAcoa_hs_7_3OH__S_c',
        # 'FAcoa_hs_8_3OH__S_c',
        # 'FAcoa_hs_9_3OH__S_c',
        # 'FAcoa_5_2E2M_c',
        # 'FAcoa_5_2M_c',
        # 'FAcoa_hs_10_2E6Z_c',
        # 'FAcoa_hs_10_2E_c',
        # 'FAcoa_hs_12_2E_c',
        # 'FAcoa_hs_14_2E_c',
        # 'FAcoa_hs_16_2E_c',
        # 'FAcoa_hs_17_2E_c',
        # 'FAcoa_hs_18_2E_c',
        # 'FAcoa_hs_19_2E_c',
        # 'FAcoa_hs_20_2E11Z14Z17Z_c',
        # 'FAcoa_hs_20_2E11Z14Z_c',
        # 'FAcoa_hs_20_2E11Z_c',
        # 'FAcoa_hs_20_2E13Z_c',
        # 'FAcoa_hs_20_2E8Z11Z14Z17Z_c',
        # 'FAcoa_hs_20_2E8Z11Z14Z_c',
        # 'FAcoa_hs_20_2E8Z11Z_c',
        # 'FAcoa_hs_20_2E9Z_c',
        # 'FAcoa_hs_20_2E_c',
        # 'FAcoa_hs_21_2E_c',
        # 'FAcoa_hs_22_2E10Z13Z16Z19Z_c',
        # 'FAcoa_hs_22_2E10Z13Z16Z_c',
        # 'FAcoa_hs_22_2E11Z_c',
        # 'FAcoa_hs_22_2E13Z16Z19Z_c',
        # 'FAcoa_hs_22_2E13Z16Z_c',
        # 'FAcoa_hs_22_2E13Z_c',
        # 'FAcoa_hs_22_2E7Z10Z13Z16Z19Z_c',
        # 'FAcoa_hs_22_2E7Z10Z13Z16Z_c',
        # 'FAcoa_hs_22_2E_c',
        # 'FAcoa_hs_23_2E_c',
        # 'FAcoa_hs_24_2E12Z15Z18Z21Z_c',
        # 'FAcoa_hs_24_2E15Z_c',
        # 'FAcoa_hs_24_2E9Z12Z15Z18Z21Z_c',
        # 'FAcoa_hs_24_2E9Z12Z15Z18Z_c',
        # 'FAcoa_hs_24_2E_c',
        # 'FAcoa_hs_26_2E17Z_c',
        # 'FAcoa_hs_26_2E_c',
        # 'FAcoa_hs_3_2E_c',
        # 'FAcoa_hs_4_2E_c',
        # 'FAcoa_hs_6_2E_c',
        # 'FAcoa_hs_8_2E_c',
        # 'FAcoa_hs_14_5E8Z_c',
        # 'FAcoa_4_2M_c',
        # 'FAcoa_hs_16_3O_c',
        # 'FAcoa_hs_17_3O_c',
        # 'FAcoa_hs_18_3O_c',
        # 'FAcoa_hs_19_3O_c',
        # 'FAcoa_hs_20_11Z14Z17Z3O_c',
        # 'FAcoa_hs_20_11Z14Z3O_c',
        # 'FAcoa_hs_20_11Z3O_c',
        # 'FAcoa_hs_20_13Z3O_c',
        # 'FAcoa_hs_20_3O_c',
        # 'FAcoa_hs_20_8Z11Z14Z17Z3O_c',
        # 'FAcoa_hs_20_8Z11Z14Z3O_c',
        # 'FAcoa_hs_20_8Z11Z3O_c',
        # 'FAcoa_hs_20_9Z3O_c',
        # 'FAcoa_hs_21_3O_c',
        # 'FAcoa_hs_22_10Z13Z16Z19Z3O_c',
        # 'FAcoa_hs_22_10Z13Z16Z3O_c',
        # 'FAcoa_hs_22_11Z3O_c',
        # 'FAcoa_hs_22_13Z16Z19Z3O_c',
        # 'FAcoa_hs_22_13Z16Z3O_c',
        # 'FAcoa_hs_22_13Z3O_c',
        # 'FAcoa_hs_22_3O_c',
        # 'FAcoa_hs_22_7Z10Z13Z16Z19Z3O_c',
        # 'FAcoa_hs_22_7Z10Z13Z16Z3O_c',
        # 'FAcoa_hs_23_3O_c',
        # 'FAcoa_hs_24_12Z15Z18Z21Z3O_c',
        # 'FAcoa_hs_24_15Z3O_c',
        # 'FAcoa_hs_24_3O_c',
        # 'FAcoa_hs_24_9Z12Z15Z18Z21Z3O_c',
        # 'FAcoa_hs_24_9Z12Z15Z18Z3O_c',
        # 'FAcoa_hs_26_17Z3O_c',
        # 'FAcoa_hs_26_3O_c',
        # 'dmnoncoa_c',
        # 'dmhptcoa_c',
        # # Carnitine
        # 'FAcrn_10_DC_c',
        # 'FAcrn_12_DC_c',
        # 'FAcrn_16_DC_c',
        # 'FAcrn_4_2M_c',
        # 'FAcrn_4_DC_c',
        # 'FAcrn_5_2E2M_c',
        # 'FAcrn_5_2EDC_c',
        # 'FAcrn_5_2M_c',
        # 'FAcrn_5_3M3OH__S_c',
        # 'FAcrn_5_DC_c',
        # 'FAcrn_6_DC_c',
        # 'FAcrn_7_DC_c',
        # 'FAcrn_8_DC_c',
        # 'FAcrn_hs_10_0_c',
        # 'FAcrn_hs_10_2E6Z_c',
        # 'FAcrn_hs_10_2E_c',
        # 'FAcrn_hs_10_3OH__S_c',
        # 'FAcrn_hs_11_0_c',
        # 'FAcrn_hs_12_0_c',
        # 'FAcrn_hs_12_2E_c',
        # 'FAcrn_hs_12_3OH__S_c',
        # 'FAcrn_hs_13_0_c',
        # 'FAcrn_hs_14_0_c',
        # 'FAcrn_hs_14_2E_c',
        # 'FAcrn_hs_14_3OH__S_c',
        # 'FAcrn_hs_14_5E8Z3OH__S_c',
        # 'FAcrn_hs_14_5E8Z_c',
        # 'FAcrn_hs_14_5Z_c',
        # 'FAcrn_hs_14_7Z3OH__S_c',
        # 'FAcrn_hs_14_7Z_c',
        # 'FAcrn_hs_14_9Z_c',
        # 'FAcrn_hs_15_0_c',
        # 'FAcrn_hs_16_0_c',
        # 'FAcrn_hs_16_2E_c',
        # 'FAcrn_hs_16_3OH__S_c',
        # 'FAcrn_hs_16_7E10Z3OH__S_c',
        # 'FAcrn_hs_16_7Z_c',
        # 'FAcrn_hs_16_9Z3OH__S_c',
        # 'FAcrn_hs_16_9Z_c',
        # 'FAcrn_hs_17_0_c',
        # 'FAcrn_hs_17_10Z_c',
        # 'FAcrn_hs_17_9Z_c',
        # 'FAcrn_hs_18_0_c',
        # 'FAcrn_hs_18_11Z_c',
        # 'FAcrn_hs_18_13Z_c',
        # 'FAcrn_hs_18_2E_c',
        # 'FAcrn_hs_18_3OH__S_c',
        # 'FAcrn_hs_18_6Z9Z12Z15Z_c',
        # 'FAcrn_hs_18_6Z9Z12Z_c',
        # 'FAcrn_hs_18_6Z9Z_c',
        # 'FAcrn_hs_18_7Z_c',
        # 'FAcrn_hs_18_9E_c',
        # 'FAcrn_hs_18_9Z12Z15Z_c',
        # 'FAcrn_hs_18_9Z12Z3OH__S_c',
        # 'FAcrn_hs_18_9Z12Z_c',
        # 'FAcrn_hs_18_9Z3OH__S_c',
        # 'FAcrn_hs_18_9Z_c',
        # 'FAcrn_hs_19_0_c',
        # 'FAcrn_hs_20_0_c',
        # 'FAcrn_hs_20_11Z14Z17Z_c',
        # 'FAcrn_hs_20_11Z14Z_c',
        # 'FAcrn_hs_20_11Z_c',
        # 'FAcrn_hs_20_13Z_c',
        # 'FAcrn_hs_20_5Z8Z11Z14Z17Z_c',
        # 'FAcrn_hs_20_5Z8Z11Z14Z_c',
        # 'FAcrn_hs_20_5Z8Z11Z_c',
        # 'FAcrn_hs_20_8Z11Z14Z17Z_c',
        # 'FAcrn_hs_20_8Z11Z14Z_c',
        # 'FAcrn_hs_20_8Z11Z_c',
        # 'FAcrn_hs_20_9Z_c',
        # 'FAcrn_hs_21_0_c',
        # 'FAcrn_hs_22_0_c',
        # 'FAcrn_hs_22_10Z13Z16Z19Z_c',
        # 'FAcrn_hs_22_10Z13Z16Z_c',
        # 'FAcrn_hs_22_11Z_c',
        # 'FAcrn_hs_22_13Z16Z19Z_c',
        # 'FAcrn_hs_22_13Z16Z_c',
        # 'FAcrn_hs_22_13Z_c',
        # 'FAcrn_hs_22_4Z7Z10Z13Z16Z19Z_c',
        # 'FAcrn_hs_22_4Z7Z10Z13Z16Z_c',
        # 'FAcrn_hs_22_7Z10Z13Z16Z19Z_c',
        # 'FAcrn_hs_22_7Z10Z13Z16Z_c',
        # 'FAcrn_hs_23_0_c',
        # 'FAcrn_hs_24_0_c',
        # 'FAcrn_hs_24_12Z15Z18Z21Z_c',
        # 'FAcrn_hs_24_15Z_c',
        # 'FAcrn_hs_24_6Z9Z12Z15Z18Z21Z_c',
        # 'FAcrn_hs_24_6Z9Z12Z15Z18Z_c',
        # 'FAcrn_hs_24_9Z12Z15Z18Z21Z_c',
        # 'FAcrn_hs_24_9Z12Z15Z18Z_c',
        # 'FAcrn_hs_26_0_c',
        # 'FAcrn_hs_26_17Z_c',
        # 'FAcrn_hs_3_0_c',
        # 'FAcrn_hs_3_2E_c',
        # 'FAcrn_hs_3_3OH__S_c',
        # 'FAcrn_hs_4_0_c',
        # 'FAcrn_hs_4_2E_c',
        # 'FAcrn_hs_4_3OH__R_c',
        # 'FAcrn_hs_5_0_c',
        # 'FAcrn_hs_6_0_c',
        # 'FAcrn_hs_6_2E_c',
        # 'FAcrn_hs_6_3OH__S_c',
        # 'FAcrn_hs_7_0_c',
        # 'FAcrn_hs_7_3OH__S_c',
        # 'FAcrn_hs_8_0_c',
        # 'FAcrn_hs_8_2E_c',
        # 'FAcrn_hs_8_3OH__S_c',
        # 'FAcrn_hs_9_0_c',
        # 'FAcrn_hs_9_3OH__S_c',
        # 'acrn_c',
        # 'dmhptcrn_c',
        # 'dmnoncrn_c',
        # 'malcrn_c',
        # tRNA
        # 'trnaala_c',
        # 'trnaarg_c',
        # 'trnaasn_c',
        # 'trnaasp_c',
        # 'trnacys_c',
        # 'trnagln_c',
        # 'trnaglu_c',
        # 'trnagly_c',
        # 'trnahis_c',
        # 'trnaile_c',
        # 'trnaleu_c',
        # 'trnalys_c',
        # 'trnamet_c',
        # 'trnaphe_c',
        # 'trnapro_c',
        # 'trnaser_c',
        # 'trnathr_c',
        # 'trnatrp_c',
        # 'trnatyr_c',
        # 'trnaval_c',
        # 'alatrna_c',
        # 'argtrna_c',
        # 'asntrna_c',
        # 'asptrna_c',
        # 'cystrna_c',
        # 'glntrna_c',
        # 'glutrna_c',
        # 'glytrna_c',
        # 'histrna_c',
        # 'iletrna_c',
        # 'leutrna_c',
        # 'lystrna_c',
        # 'mettrna_c',
        # 'phetrna_c',
        # 'protrna_c',
        # 'sertrna_c',
        # 'thrtrna_c',
        # 'trptrna_c',
        # 'tyrtrna_c',
        # 'valtrna_c',
        # Sugar
        # '2ddglcn_c',
        # '3dfru_c',
        # Nucleotides
        # "23camp_c",
        # "23ccmp_c",
        # "23cgmp_c",
        # "23cump_c",
        # "dctp_c",
        # "dgtp_c",
        # "datp_c",
        # "dttp_c",
        # 'dutp_c',
        # "psump_c",
        # "psi_c",
        # Sourced from somewhere/
        # Drains to somewhere/accumulates
        # 'so2gth_c',
        # "dh15kprostge1_c",
        # "dh15kprostge2_c",
        # "dh15kprostge3_c",
        # "dh15kprostgf1_c",
        # "dh15kprostgf2_c",
        # "dh15kprostgf3_c",
        # 'polyadprib2_c',
        # 'polyadprib1_c',
    ],
}
default_closed = []
for btype, met_list in boundaries.items():
    for met in met_list:
        met = model.metabolites.get_by_id(met)
        try:
            reaction = model.add_boundary(met, type=btype)
        except ValueError:
            rid = {
                "exchange": f"EX_{met}",
                "demand": f"DM_{met}",
                "sink": f"SK_{met}",
            }[btype]
            reaction = model.reactions.get_by_id(rid)
            reaction.name = f"{met.name} {btype}"

        if met in default_closed:
            reaction.lower_bound = 0

for reaction in model.boundary:
    reaction.subsystem = "Pseudoreactions"

# %% [markdown]
# #### Reset subsystem groups

# %%
reset_subsystem_groups(model)
model
# Out:
# <Model RBC_GEM at 0x14a880c50>

# %% [markdown]
# ### Check mass balancing

# %%
for reaction in model.reactions:
    if reaction.boundary:
        continue
    try:
        if reaction.check_mass_balance():
            print(reaction)
            print(reaction.check_mass_balance())
            print()
    except:
        print({m.id: m.charge for m in reaction.metabolites})
        raise
# Out:
# 6LTHPI: 6lthp_c --> h_c + sppt_c
# {'charge': 2.0}
#
# METHBCYTBR: 2.0 focytb5_c + methb_c --> 2.0 ficytb5_c + hb_c
# {'charge': 1.0}
#
# METHBFMNR: fmnh2_c + methb_c --> fmn_c + 3.0 h_c + hb_c
# {'charge': 1.0}
#
# POOL_FACOA: FAcoa_hs_c <=> 0.0004 FAcoa_hs_12_0_c + 0.0004 FAcoa_hs_13_0_c + 0.0133 FAcoa_hs_14_0_c + 0.0004 FAcoa_hs_14_5Z_c + 0.0004 FAcoa_hs_14_7Z_c + 0.0004 FAcoa_hs_14_9Z_c + 0.0004 FAcoa_hs_15_0_c + 0.222 FAcoa_hs_16_0_c + 0.0004 FAcoa_hs_16_7Z_c + 0.0219 FAcoa_hs_16_9Z_c + 0.0004 FAcoa_hs_17_0_c + 0.0004 FAcoa_hs_17_10Z_c + 0.0004 FAcoa_hs_17_9Z_c + 0.1498 FAcoa_hs_18_0_c + 0.025 FAcoa_hs_18_11Z_c + 0.0004 FAcoa_hs_18_13Z_c + 0.0025 FAcoa_hs_18_6Z9Z12Z15Z_c + 0.0029 FAcoa_hs_18_6Z9Z12Z_c + 0.0004 FAcoa_hs_18_6Z9Z_c + 0.0004 FAcoa_hs_18_7Z_c + 0.0004 FAcoa_hs_18_9E_c + 0.0084 FAcoa_hs_18_9Z12Z15Z_c + 0.1915 FAcoa_hs_18_9Z12Z_c + 0.1545 FAcoa_hs_18_9Z_c + 0.0004 FAcoa_hs_19_0_c + 0.0004 FAcoa_hs_20_0_c + 0.0215 FAcoa_hs_20_11Z14Z17Z_c + 0.0004 FAcoa_hs_20_11Z14Z_c + 0.0004 FAcoa_hs_20_11Z_c + 0.0004 FAcoa_hs_20_13Z_c + 0.0116 FAcoa_hs_20_5Z8Z11Z14Z17Z_c + 0.1083 FAcoa_hs_20_5Z8Z11Z14Z_c + 0.0004 FAcoa_hs_20_5Z8Z11Z_c + 0.0115 FAcoa_hs_20_8Z11Z14Z17Z_c + 0.0215 FAcoa_hs_20_8Z11Z14Z_c + 0.0004 FAcoa_hs_20_8Z11Z_c + 0.0004 FAcoa_hs_20_9Z_c + 0.0004 FAcoa_hs_21_0_c + 0.0004 FAcoa_hs_22_0_c + 0.0004 FAcoa_hs_22_10Z13Z16Z19Z_c + 0.0004 FAcoa_hs_22_10Z13Z16Z_c + 0.0004 FAcoa_hs_22_11Z_c + 0.0004 FAcoa_hs_22_13Z16Z19Z_c + 0.0004 FAcoa_hs_22_13Z16Z_c + 0.0004 FAcoa_hs_22_13Z_c + 0.0278 FAcoa_hs_22_4Z7Z10Z13Z16Z19Z_c + 0.0038 FAcoa_hs_22_4Z7Z10Z13Z16Z_c + 0.0059 FAcoa_hs_22_7Z10Z13Z16Z19Z_c + 0.0014 FAcoa_hs_22_7Z10Z13Z16Z_c + 0.0004 FAcoa_hs_23_0_c + 0.0004 FAcoa_hs_24_0_c + 0.0004 FAcoa_hs_24_12Z15Z18Z21Z_c + 0.0004 FAcoa_hs_24_15Z_c + 0.0004 FAcoa_hs_24_6Z9Z12Z15Z18Z21Z_c + 0.0004 FAcoa_hs_24_6Z9Z12Z15Z18Z_c + 0.0004 FAcoa_hs_24_9Z12Z15Z18Z21Z_c + 0.0004 FAcoa_hs_24_9Z12Z15Z18Z_c + 0.0004 FAcoa_hs_26_0_c + 0.0004 FAcoa_hs_26_17Z_c
# {'charge': -0.08439999999999515, 'C': 17.817500000000024, 'H': 33.30219999999997, 'N': 0.14769999999999328, 'O': 0.3586999999999705, 'P': 0.0632999999999968, 'S': 0.021099999999998786, 'R': -1.0}
#
# POOL_FA: FA_hs_c <=> 0.0004 FA_hs_12_0_c + 0.0004 FA_hs_13_0_c + 0.0133 FA_hs_14_0_c + 0.0004 FA_hs_14_5Z_c + 0.0004 FA_hs_14_7Z_c + 0.0004 FA_hs_14_9Z_c + 0.0004 FA_hs_15_0_c + 0.222 FA_hs_16_0_c + 0.0004 FA_hs_16_7Z_c + 0.0219 FA_hs_16_9Z_c + 0.0004 FA_hs_17_0_c + 0.0004 FA_hs_17_10Z_c + 0.0004 FA_hs_17_9Z_c + 0.1498 FA_hs_18_0_c + 0.025 FA_hs_18_11Z_c + 0.0004 FA_hs_18_13Z_c + 0.0025 FA_hs_18_6Z9Z12Z15Z_c + 0.0029 FA_hs_18_6Z9Z12Z_c + 0.0004 FA_hs_18_6Z9Z_c + 0.0004 FA_hs_18_7Z_c + 0.0004 FA_hs_18_9E_c + 0.0084 FA_hs_18_9Z12Z15Z_c + 0.1915 FA_hs_18_9Z12Z_c + 0.1545 FA_hs_18_9Z_c + 0.0004 FA_hs_19_0_c + 0.0004 FA_hs_20_0_c + 0.0215 FA_hs_20_11Z14Z17Z_c + 0.0004 FA_hs_20_11Z14Z_c + 0.0004 FA_hs_20_11Z_c + 0.0004 FA_hs_20_13Z_c + 0.0116 FA_hs_20_5Z8Z11Z14Z17Z_c + 0.1083 FA_hs_20_5Z8Z11Z14Z_c + 0.0004 FA_hs_20_5Z8Z11Z_c + 0.0115 FA_hs_20_8Z11Z14Z17Z_c + 0.0215 FA_hs_20_8Z11Z14Z_c + 0.0004 FA_hs_20_8Z11Z_c + 0.0004 FA_hs_20_9Z_c + 0.0004 FA_hs_21_0_c + 0.0004 FA_hs_22_0_c + 0.0004 FA_hs_22_10Z13Z16Z19Z_c + 0.0004 FA_hs_22_10Z13Z16Z_c + 0.0004 FA_hs_22_11Z_c + 0.0004 FA_hs_22_13Z16Z19Z_c + 0.0004 FA_hs_22_13Z16Z_c + 0.0004 FA_hs_22_13Z_c + 0.0278 FA_hs_22_4Z7Z10Z13Z16Z19Z_c + 0.0038 FA_hs_22_4Z7Z10Z13Z16Z_c + 0.0059 FA_hs_22_7Z10Z13Z16Z19Z_c + 0.0014 FA_hs_22_7Z10Z13Z16Z_c + 0.0004 FA_hs_23_0_c + 0.0004 FA_hs_24_0_c + 0.0004 FA_hs_24_12Z15Z18Z21Z_c + 0.0004 FA_hs_24_15Z_c + 0.0004 FA_hs_24_6Z9Z12Z15Z18Z21Z_c + 0.0004 FA_hs_24_6Z9Z12Z15Z18Z_c + 0.0004 FA_hs_24_9Z12Z15Z18Z21Z_c + 0.0004 FA_hs_24_9Z12Z15Z18Z_c + 0.0004 FA_hs_26_0_c + 0.0004 FA_hs_26_17Z_c
# {'charge': -0.021099999999998786, 'C': 17.374399999999994, 'H': 32.6481, 'O': 0.04219999999999757, 'R': -1.0}
#
# SNOHBNO: nitrosylhb_c --> h_c + hbsno_c
# {'charge': 1}

# %% [markdown]
# ### Set bounds

# %%
reset_reaction_bounds(model)

# %%
from cobra.flux_analysis.variability import find_blocked_reactions

blocked_reactions = find_blocked_reactions(model, open_exchanges=True)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp9oocremi.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmplm7ug58m.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpwid_7oxg.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp7wueqtt3.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpkx_hx7e3.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp46zpu650.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpckxoc6yz.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpmkhz9t35.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpk415hbeh.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpb6j6cne0.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp1rqundb2.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmphr_lnksj.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp8kmyl9yb.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp2b9_3nog.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpdh4aog0m.lp
# Reading time = 0.05 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpxg7flbbu.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpjuj3jq44.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpla4g0mfb.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpvyjyw1gc.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpzxlxnp6k.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpb3ef0jyz.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp1otv_mkl.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp7ig7804d.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpf11x2n7j.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpra2kma17.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmp3efei25x.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpowwwhldi.lp
# Reading time = 0.03 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpezw82wd3.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmphgfolpl9.lp
# Reading time = 0.02 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# Read LP format model from file /var/folders/5t/hk8m3g6d1jn25x5rssjgsrmm0000gn/T/tmpmfka3ko2.lp
# Reading time = 0.04 seconds
# : 2158 rows, 6551 columns, 24877 nonzeros

# %%
print(f"Number of blocked reactions: {len(blocked_reactions)}")
mets_one_reaction = model.metabolites.query(
    lambda x: len(x.reactions) == 1 and not any([r for r in x.reactions if r.boundary])
)
mets_one_reaction = sorted(mets_one_reaction.list_attr("id"))
print(f"Number of metabolites with one associated reaction {len(mets_one_reaction)}")
print()
for reaction in model.reactions.get_by_any(sorted(blocked_reactions)):
    # Expected blocked
    # if any([
    #     x in reaction.id
    #     for x in ["3OHAA", "BKAACP", 'EACPR1', 'CRNAT', 'FACOA3OHD', '3OXAACPR1', "ACPH", 'FACOA2ERy', '3OXAACPR', 'FACOA3ORy']
    # ]):
    #     continue
    print(reaction)
# Out:
# Number of blocked reactions: 695
# Number of metabolites with one associated reaction 487
#
# 15KPGE1Ry: 15kprostge1_c + h_c + nadph_c --> dh15kprostge1_c + nadp_c
# 15KPGE2Ry: 15kprostge2_c + h_c + nadph_c --> dh15kprostge2_c + nadp_c
# 15KPGE3Ry: 15kprostge3_c + h_c + nadph_c --> dh15kprostge3_c + nadp_c
# 15KPGF1Ry: 15kprostgf1_c + h_c + nadph_c --> dh15kprostgf1_c + nadp_c
# 15KPGF2Ry: 15kprostgf2_c + h_c + nadph_c --> dh15kprostgf2_c + nadp_c
# 15KPGF3Ry: 15kprostgf3_c + h_c + nadph_c --> dh15kprostgf3_c + nadp_c
# 23CN3PA: 23camp_c + h2o_c --> 2amp_c + h_c
# 23CN3PC: 23ccmp_c + h2o_c --> 2cmp_c + h_c
# 23CN3PG: 23cgmp_c + h2o_c --> 2gmp_c + h_c
# 23CN3PU: 23cump_c + h2o_c --> 2ump_c + h_c
# 2DCYTt: 2dcytd_c <=> 2dcytd_e
# 2H3MV: 3mop_c + h_c + nadh_c <=> 2h3mv_c + nad_c
# 2HIV: 3mob_c + h_c + nadh_c <=> 2hiv_c + nad_c
# 34HPLDH: 34hpp_c + h_c + nadh_c --> 34hpl_c + nad_c
# 34HPPT: 34hpp_c --> 2h34hppr_c
# 3DGDH: 3dglc_c + h2o_c + nad_c --> 2ddglcn_c + 2.0 h_c + nadh_c
# 3HKYNAKGAT: akg_c + hLkynr_c --> 42a3hp24db_c + glu__L_c + h_c
# 3MOBt2: 3mob_c + h_c <=> 3mob_e + h_e
# 3OHAACPDH1: bhbACP_c --> buteACP_2E_c + h2o_c
# 3OHAACPDH2: 3ohhxaACP_c --> h2o_c + hxeaACP_2E_c
# 3OHAACPDH3: 3ohocaACP_c --> h2o_c + oceaACP_2E_c
# 3OHAACPDH4: 3ohdcaACP_c --> dceaACP_2E_c + h2o_c
# 3OHAACPDH5: 3ohddcaACP_c --> ddceaACP_2E_c + h2o_c
# 3OHAACPDH6: 3ohttdcaACP_c --> h2o_c + ttdceaACP_2E_c
# 3OHAACPDH7: 3ohhxdcaACP_c --> h2o_c + hxdceaACP_2E_c
# 3OHAACPDH8: 3ohocdcaACP_c --> h2o_c + ocdceaACP_2E_c
# 3OXAACPR1y: aacACP_c + h_c + nadph_c --> bhbACP_c + nadp_c
# 3OXAACPR2y: 3oxhxaACP_c + h_c + nadph_c --> 3ohhxaACP_c + nadp_c
# 3OXAACPR3y: 3oxocaACP_c + h_c + nadph_c --> 3ohocaACP_c + nadp_c
# 3OXAACPR4y: 3oxdcaACP_c + h_c + nadph_c --> 3ohdcaACP_c + nadp_c
# 3OXAACPR5y: 3oxddcaACP_c + h_c + nadph_c --> 3ohddcaACP_c + nadp_c
# 3OXAACPR6y: 3oxttdcaACP_c + h_c + nadph_c --> 3ohttdcaACP_c + nadp_c
# 3OXAACPR7y: 3oxhxdcaACP_c + h_c + nadph_c --> 3ohhxdcaACP_c + nadp_c
# 3OXAACPR8y: 3oxocdcaACP_c + h_c + nadph_c --> 3ohocdcaACP_c + nadp_c
# 3SALAOX: 2.0 3sala__L_c + o2_c --> 2.0 Lcyst_c
# 4H2HXEAL2EDHx: 4h2hxeal_2E_c + h2o_c + nad_c --> 4h2hxea_2E_c + 2.0 h_c + nadh_c
# 4H2NNEAL2EDHx: 4h2noneal_2E_c + h2o_c + nad_c --> 4h2nonea_2E_c + 2.0 h_c + nadh_c
# 4HOXPACDORx: 4hoxpacd_c + h2o_c + nad_c --> 4hphac_c + 2.0 h_c + nadh_c
# 4HOXPACDORy: 4hoxpacd_c + h2o_c + nadp_c --> 4hphac_c + 2.0 h_c + nadph_c
# 4MOPt2: 4mop_c + h_c <=> 4mop_e + h_e
# 4PCYSK: 4pcys__R_c + atp_c --> 4ppcys__R_c + adp_c + h_c
# 4PERP: 4per_c + h2o_c --> erthn__D_c + pi_c
# 4PYRNDK: 4pyrdp_c + atp_c --> 4pyrtp_c + adp_c
# 4PYRNMAT: 4pyrmp_c + atp_c + h_c --> 4pyrnad_c + ppi_c
# 4PYRNMK: 4pyrmp_c + atp_c --> 4pyrdp_c + adp_c
# 4PYRNt: 4pyrn_c <=> 4pyrn_e
# 5ADHTRy: 5adtststerone_c + h_c + nadph_c <=> 5aand3a17bdiol_c + nadp_c
# 5FLUDPK: 5fludp_c + atp_c --> 5flutp_c + adp_c
# 5FLUMPK: 5flump_c + atp_c --> 5fludp_c + adp_c
# 5FLURAPT: 5flura_c + prpp_c --> 5flump_c + ppi_c
# 5HOXINDACTOX: 5hoxindact_c + h2o_c + nad_c --> 5hoxindoa_c + 2.0 h_c + nadh_c
# 5INS7P5PP: 5ppins5p_c + h2o_c --> h_c + ins6p_c + pi_c
# 5PPINSP5P1K: 5ppins5p_c + atp_c --> 15ppins4p_c + adp_c
# A4GALTc: galgluside_hs_c + udpgal_c --> h_c + thcrm_hs_c + udp_c
# ABO1A: fucgalacglcgalgluside_hs_c + udpacgal_c --> acgalfucgalacglcgalgluside_hs_c + h_c + udp_c
# ABO1B: fucgalacglcgalgluside_hs_c + udpgal_c --> galfucgalacglcgalgluside_hs_c + h_c + udp_c
# ABO2A: fuc12gal14acglcgalgluside_hs_c + udpacgal_c --> acgalfuc12gal14acglcgalgluside_hs_c + h_c + udp_c
# ABO2B: fuc12gal14acglcgalgluside_hs_c + udpgal_c --> galfuc12gal14acglcgalgluside_hs_c + h_c + udp_c
# ABO3A: fucgalacgalfuc12gal14acglcgalgluside_hs_c + udpacgal_c --> acgalfucgalacgalfuc12gal14acglcgalgluside_hs_c + h_c + udp_c
# ABO3AB: fucgalacgalfucgalacglcgal14acglcgalgluside_hs_c + udpacgal_c --> acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_c + h_c + udp_c
# ABO4A: globoH_hs_c + udpacgal_c --> globoA_hs_c + h_c + udp_c
# ABO4B: globoH_hs_c + udpgal_c --> globoB_hs_c + h_c + udp_c
# ABO5A: fucgalacglcgal14acglcgalgluside_hs_c + udpacgal_c --> acgalfucgalacglcgal14acglcgalgluside_hs_c + h_c + udp_c
# ABO5B: fucgalacglcgal14acglcgalgluside_hs_c + udpgal_c --> galfucgalacglcgal14acglcgalgluside_hs_c + h_c + udp_c
# AC4OACNAMDC: ac4oacnam_c + h2o_c --> ac_c + acnam_c + h_c
# AC9OACNAMDC: ac9oacnam_c + h2o_c --> ac_c + acnam_c + h_c
# ACACT1: aacoa_c + coa_c --> 2.0 accoa_c
# ACGAMNT2: galacglcgal14acglcgalgluside_hs_c + uacgam_c --> acglcgalacglcgal14acglcgalgluside_hs_c + h_c + udp_c
# ACHt: ach_c --> ach_e
# ACMAH: acmetala_c + h2o_c --> acmet__L_c + ala__L_c
# ACMDAC: acmet__L_c + h2o_c --> ac_c + met__L_c
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c
# ACYP2: actp_c + h2o_c --> ac_c + h_c + pi_c
# ADPGLCDP: adpglc_c + h2o_c --> amp_c + g1p_c + 2.0 h_c
# ADPMNDP: adpman_c + h2o_c --> amp_c + 2.0 h_c + man1p_c
# ADPRDACAC1: 1acadprib_c + h2o_c --> ac_c + adprib_c + h_c
# AG1tec: ag1_e --> ag1_c
# AIRC: air_c + co2_c <=> 5aizc_c + h_c
# ALATRS: ala__L_c + atp_c + trnaala_c --> alatrna_c + amp_c + ppi_c
# ALDD19x: h2o_c + nad_c + pacald_c --> 2.0 h_c + nadh_c + pac_c
# ALDD19y: h2o_c + nadp_c + pacald_c --> 2.0 h_c + nadph_c + pac_c
# ALDD20x: h2o_c + id3acald_c + nad_c --> 2.0 h_c + ind3ac_c + nadh_c
# ALLTN: alltn_c + h2o_c <=> alltt_c + h_c
# AMPAMD: ampamd_c + h2o_c --> amp_c + nh4_c
# ANDRSTRNRy: andrstrn_c + h_c + nadph_c <=> 5aand3a17bdiol_c + nadp_c
# ANGIO1THOP: angiotensin1_c + h2o_c --> angiotensin17_c + phehisleu_c
# ANGIO2ASPH: angiotensin2_c + h2o_c --> angiotensin3_c + asp__L_c + h_c
# ANGIO2DDP: angiotensin2_c + h2o_c --> angiotensin4_c + asparg_c
# ANGIO3ARGH: angiotensin3_c + h2o_c + h_c --> angiotensin4_c + arg__L_c
# ANGIO4DDP: angiotensin4_c + h2o_c --> angiotensin58_c + valtyr_c
# ANGIO58PEP: angiotensin58_c + h2o_c --> angiotensin57_c + phe__L_c
# AP5AH1: ap5a_c + h2o_c --> adp_c + atp_c + 2.0 h_c
# AP6AH1: ap6a_c + h2o_c --> 2.0 atp_c + 2.0 h_c
# AP6AH2: ap6a_c + h2o_c --> adp_c + 2.0 h_c + p4a_c
# APDPP: alapro_c + h2o_c --> ala__L_c + pro__L_c
# ARGSL: argsuc_c <=> arg__L_c + fum_c
# ARGTRS: arg__L_c + atp_c + trnaarg_c --> amp_c + argtrna_c + ppi_c
# ASNTRS: asn__L_c + atp_c + trnaasn_c --> amp_c + asntrna_c + ppi_c
# ASPCT: asp__L_c + cbp_c <=> cbasp_c + h_c + pi_c
# ASPTRS: asp__L_c + atp_c + trnaasp_c --> amp_c + asptrna_c + ppi_c
# A_MANASE: 2.0 h2o_c + m2mn_c --> 2.0 man_c + mn_c
# B3GALNT1c: thcrm_hs_c + udpacgal_c --> gbside_hs_c + h_c + udp_c
# BILIREDx: biliverd_c + h_c + nadh_c --> bilirub_c + nad_c
# BILIREDy: biliverd_c + h_c + nadph_c --> bilirub_c + nadp_c
# BILRUBABCte: atp_c + bilirub_c + h2o_c --> adp_c + bilirub_e + h_c + pi_c
# BKAACPSYN1: acACP_c + h_c + malACP_c --> ACP_c + aacACP_c + co2_c
# BKAACPSYN2: butACP_c + h_c + malACP_c --> 3oxhxaACP_c + ACP_c + co2_c
# BKAACPSYN3: h_c + hxaACP_c + malACP_c --> 3oxocaACP_c + ACP_c + co2_c
# BKAACPSYN4: h_c + malACP_c + ocaACP_c --> 3oxdcaACP_c + ACP_c + co2_c
# BKAACPSYN5: dcaACP_c + h_c + malACP_c --> 3oxddcaACP_c + ACP_c + co2_c
# BKAACPSYN6: ddcaACP_c + h_c + malACP_c --> 3oxttdcaACP_c + ACP_c + co2_c
# BKAACPSYN7: h_c + malACP_c + ttdcaACP_c --> 3oxhxdcaACP_c + ACP_c + co2_c
# BKAACPSYN8: h_c + hxdcaACP_c + malACP_c --> 3oxocdcaACP_c + ACP_c + co2_c
# BPNT2: h2o_c + paps_c --> aps_c + pi_c
# BZALDHx: bzal_c + h2o_c + nad_c --> bz_c + 2.0 h_c + nadh_c
# CADPRBPH: cadprbp_c + h2o_c --> adprbp_c
# CHLSTD78I: lthstrl_c --> zymstnl_c
# CHLSTI1: zymst_c --> chlstol_c
# CMPACNAGA1: cmpacna_c + ga1_hs_c --> cmp_c + gm1b_hs_c + h_c
# CMPACNAGALBSD: cmpacna_c + galgbside_hs_c --> acnagalgbside_hs_c + cmp_c + h_c
# CMPACNAGD1B: cmpacna_c + gd1b_hs_c --> cmp_c + gt1b_hs_c + h_c
# CMPACNAGM1: cmpacna_c + gm1_hs_c --> cmp_c + gd1a_hs_c + h_c
# CRNAT_10_0: FAcoa_hs_10_0_c + crn_c <=> FAcrn_hs_10_0_c + coa_c
# CRNAT_10_2E: FAcoa_hs_10_2E_c + crn_c <=> FAcrn_hs_10_2E_c + coa_c
# CRNAT_10_2E6Z: FAcoa_hs_10_2E6Z_c + crn_c <=> FAcrn_hs_10_2E6Z_c + coa_c
# CRNAT_10_3OH_S: FAcoa_hs_10_3OH__S_c + crn_c <=> FAcrn_hs_10_3OH__S_c + coa_c
# CRNAT_10_DC: FAcoa_10_DC_c + crn_c <=> FAcrn_10_DC_c + coa_c
# CRNAT_11_0: FAcoa_hs_11_0_c + crn_c <=> FAcrn_hs_11_0_c + coa_c
# CRNAT_11_4M8M_c: crn_c + dmnoncoa_c <=> coa_c + dmnoncrn_c
# CRNAT_12_0: FAcoa_hs_12_0_c + crn_c <=> FAcrn_hs_12_0_c + coa_c
# CRNAT_12_2E: FAcoa_hs_12_2E_c + crn_c <=> FAcrn_hs_12_2E_c + coa_c
# CRNAT_12_3OH_S: FAcoa_hs_12_3OH__S_c + crn_c <=> FAcrn_hs_12_3OH__S_c + coa_c
# CRNAT_12_DC: FAcoa_12_DC_c + crn_c <=> FAcrn_12_DC_c + coa_c
# CRNAT_13_0: FAcoa_hs_13_0_c + crn_c <=> FAcrn_hs_13_0_c + coa_c
# CRNAT_14_0: FAcoa_hs_14_0_c + crn_c <=> FAcrn_hs_14_0_c + coa_c
# CRNAT_14_2E: FAcoa_hs_14_2E_c + crn_c <=> FAcrn_hs_14_2E_c + coa_c
# CRNAT_14_3OH_S: FAcoa_hs_14_3OH__S_c + crn_c <=> FAcrn_hs_14_3OH__S_c + coa_c
# CRNAT_14_5E8Z: FAcoa_hs_14_5E8Z_c + crn_c <=> FAcrn_hs_14_5E8Z_c + coa_c
# CRNAT_14_5E8Z3OH_S: FAcoa_hs_14_5E8Z3OH__S_c + crn_c <=> FAcrn_hs_14_5E8Z3OH__S_c + coa_c
# CRNAT_14_5Z: FAcoa_hs_14_5Z_c + crn_c <=> FAcrn_hs_14_5Z_c + coa_c
# CRNAT_14_7Z: FAcoa_hs_14_7Z_c + crn_c <=> FAcrn_hs_14_7Z_c + coa_c
# CRNAT_14_7Z3OH_S: FAcoa_hs_14_7Z3OH__S_c + crn_c <=> FAcrn_hs_14_7Z3OH__S_c + coa_c
# CRNAT_14_9Z: FAcoa_hs_14_9Z_c + crn_c <=> FAcrn_hs_14_9Z_c + coa_c
# CRNAT_15_0: FAcoa_hs_15_0_c + crn_c <=> FAcrn_hs_15_0_c + coa_c
# CRNAT_16_0: FAcoa_hs_16_0_c + crn_c <=> FAcrn_hs_16_0_c + coa_c
# CRNAT_16_2E: FAcoa_hs_16_2E_c + crn_c <=> FAcrn_hs_16_2E_c + coa_c
# CRNAT_16_3OH_S: FAcoa_hs_16_3OH__S_c + crn_c <=> FAcrn_hs_16_3OH__S_c + coa_c
# CRNAT_16_7E10Z3OH_S: FAcoa_hs_16_7E10Z3OH__S_c + crn_c <=> FAcrn_hs_16_7E10Z3OH__S_c + coa_c
# CRNAT_16_7Z: FAcoa_hs_16_7Z_c + crn_c <=> FAcrn_hs_16_7Z_c + coa_c
# CRNAT_16_9Z: FAcoa_hs_16_9Z_c + crn_c <=> FAcrn_hs_16_9Z_c + coa_c
# CRNAT_16_9Z3OH_S: FAcoa_hs_16_9Z3OH__S_c + crn_c <=> FAcrn_hs_16_9Z3OH__S_c + coa_c
# CRNAT_16_DC: FAcoa_16_DC_c + crn_c <=> FAcrn_16_DC_c + coa_c
# CRNAT_17_0: FAcoa_hs_17_0_c + crn_c <=> FAcrn_hs_17_0_c + coa_c
# CRNAT_17_10Z: FAcoa_hs_17_10Z_c + crn_c <=> FAcrn_hs_17_10Z_c + coa_c
# CRNAT_17_9Z: FAcoa_hs_17_9Z_c + crn_c <=> FAcrn_hs_17_9Z_c + coa_c
# CRNAT_18_0: FAcoa_hs_18_0_c + crn_c <=> FAcrn_hs_18_0_c + coa_c
# CRNAT_18_11Z: FAcoa_hs_18_11Z_c + crn_c <=> FAcrn_hs_18_11Z_c + coa_c
# CRNAT_18_13Z: FAcoa_hs_18_13Z_c + crn_c <=> FAcrn_hs_18_13Z_c + coa_c
# CRNAT_18_2E: FAcoa_hs_18_2E_c + crn_c <=> FAcrn_hs_18_2E_c + coa_c
# CRNAT_18_3OH_S: FAcoa_hs_18_3OH__S_c + crn_c <=> FAcrn_hs_18_3OH__S_c + coa_c
# CRNAT_18_6Z9Z: FAcoa_hs_18_6Z9Z_c + crn_c <=> FAcrn_hs_18_6Z9Z_c + coa_c
# CRNAT_18_6Z9Z12Z: FAcoa_hs_18_6Z9Z12Z_c + crn_c <=> FAcrn_hs_18_6Z9Z12Z_c + coa_c
# CRNAT_18_6Z9Z12Z15Z: FAcoa_hs_18_6Z9Z12Z15Z_c + crn_c <=> FAcrn_hs_18_6Z9Z12Z15Z_c + coa_c
# CRNAT_18_7Z: FAcoa_hs_18_7Z_c + crn_c <=> FAcrn_hs_18_7Z_c + coa_c
# CRNAT_18_9E: FAcoa_hs_18_9E_c + crn_c <=> FAcrn_hs_18_9E_c + coa_c
# CRNAT_18_9Z: FAcoa_hs_18_9Z_c + crn_c <=> FAcrn_hs_18_9Z_c + coa_c
# CRNAT_18_9Z12Z: FAcoa_hs_18_9Z12Z_c + crn_c <=> FAcrn_hs_18_9Z12Z_c + coa_c
# CRNAT_18_9Z12Z15Z: FAcoa_hs_18_9Z12Z15Z_c + crn_c <=> FAcrn_hs_18_9Z12Z15Z_c + coa_c
# CRNAT_18_9Z12Z3OH_S: FAcoa_hs_18_9Z12Z3OH__S_c + crn_c <=> FAcrn_hs_18_9Z12Z3OH__S_c + coa_c
# CRNAT_18_9Z3OH_S: FAcoa_hs_18_9Z3OH__S_c + crn_c <=> FAcrn_hs_18_9Z3OH__S_c + coa_c
# CRNAT_19_0: FAcoa_hs_19_0_c + crn_c <=> FAcrn_hs_19_0_c + coa_c
# CRNAT_20_0: FAcoa_hs_20_0_c + crn_c <=> FAcrn_hs_20_0_c + coa_c
# CRNAT_20_11Z: FAcoa_hs_20_11Z_c + crn_c <=> FAcrn_hs_20_11Z_c + coa_c
# CRNAT_20_11Z14Z: FAcoa_hs_20_11Z14Z_c + crn_c <=> FAcrn_hs_20_11Z14Z_c + coa_c
# CRNAT_20_11Z14Z17Z: FAcoa_hs_20_11Z14Z17Z_c + crn_c <=> FAcrn_hs_20_11Z14Z17Z_c + coa_c
# CRNAT_20_13Z: FAcoa_hs_20_13Z_c + crn_c <=> FAcrn_hs_20_13Z_c + coa_c
# CRNAT_20_5Z8Z11Z: FAcoa_hs_20_5Z8Z11Z_c + crn_c <=> FAcrn_hs_20_5Z8Z11Z_c + coa_c
# CRNAT_20_5Z8Z11Z14Z: FAcoa_hs_20_5Z8Z11Z14Z_c + crn_c <=> FAcrn_hs_20_5Z8Z11Z14Z_c + coa_c
# CRNAT_20_5Z8Z11Z14Z17Z: FAcoa_hs_20_5Z8Z11Z14Z17Z_c + crn_c <=> FAcrn_hs_20_5Z8Z11Z14Z17Z_c + coa_c
# CRNAT_20_8Z11Z: FAcoa_hs_20_8Z11Z_c + crn_c <=> FAcrn_hs_20_8Z11Z_c + coa_c
# CRNAT_20_8Z11Z14Z: FAcoa_hs_20_8Z11Z14Z_c + crn_c <=> FAcrn_hs_20_8Z11Z14Z_c + coa_c
# CRNAT_20_8Z11Z14Z17Z: FAcoa_hs_20_8Z11Z14Z17Z_c + crn_c <=> FAcrn_hs_20_8Z11Z14Z17Z_c + coa_c
# CRNAT_20_9Z: FAcoa_hs_20_9Z_c + crn_c <=> FAcrn_hs_20_9Z_c + coa_c
# CRNAT_21_0: FAcoa_hs_21_0_c + crn_c <=> FAcrn_hs_21_0_c + coa_c
# CRNAT_22_0: FAcoa_hs_22_0_c + crn_c <=> FAcrn_hs_22_0_c + coa_c
# CRNAT_22_10Z13Z16Z: FAcoa_hs_22_10Z13Z16Z_c + crn_c <=> FAcrn_hs_22_10Z13Z16Z_c + coa_c
# CRNAT_22_10Z13Z16Z19Z: FAcoa_hs_22_10Z13Z16Z19Z_c + crn_c <=> FAcrn_hs_22_10Z13Z16Z19Z_c + coa_c
# CRNAT_22_11Z: FAcoa_hs_22_11Z_c + crn_c <=> FAcrn_hs_22_11Z_c + coa_c
# CRNAT_22_13Z: FAcoa_hs_22_13Z_c + crn_c <=> FAcrn_hs_22_13Z_c + coa_c
# CRNAT_22_13Z16Z: FAcoa_hs_22_13Z16Z_c + crn_c <=> FAcrn_hs_22_13Z16Z_c + coa_c
# CRNAT_22_13Z16Z19Z: FAcoa_hs_22_13Z16Z19Z_c + crn_c <=> FAcrn_hs_22_13Z16Z19Z_c + coa_c
# CRNAT_22_4Z7Z10Z13Z16Z: FAcoa_hs_22_4Z7Z10Z13Z16Z_c + crn_c <=> FAcrn_hs_22_4Z7Z10Z13Z16Z_c + coa_c
# CRNAT_22_4Z7Z10Z13Z16Z19Z: FAcoa_hs_22_4Z7Z10Z13Z16Z19Z_c + crn_c <=> FAcrn_hs_22_4Z7Z10Z13Z16Z19Z_c + coa_c
# CRNAT_22_7Z10Z13Z16Z: FAcoa_hs_22_7Z10Z13Z16Z_c + crn_c <=> FAcrn_hs_22_7Z10Z13Z16Z_c + coa_c
# CRNAT_22_7Z10Z13Z16Z19Z: FAcoa_hs_22_7Z10Z13Z16Z19Z_c + crn_c <=> FAcrn_hs_22_7Z10Z13Z16Z19Z_c + coa_c
# CRNAT_23_0: FAcoa_hs_23_0_c + crn_c <=> FAcrn_hs_23_0_c + coa_c
# CRNAT_24_0: FAcoa_hs_24_0_c + crn_c <=> FAcrn_hs_24_0_c + coa_c
# CRNAT_24_12Z15Z18Z21Z: FAcoa_hs_24_12Z15Z18Z21Z_c + crn_c <=> FAcrn_hs_24_12Z15Z18Z21Z_c + coa_c
# CRNAT_24_15Z: FAcoa_hs_24_15Z_c + crn_c <=> FAcrn_hs_24_15Z_c + coa_c
# CRNAT_24_6Z9Z12Z15Z18Z: FAcoa_hs_24_6Z9Z12Z15Z18Z_c + crn_c <=> FAcrn_hs_24_6Z9Z12Z15Z18Z_c + coa_c
# CRNAT_24_6Z9Z12Z15Z18Z21Z: FAcoa_hs_24_6Z9Z12Z15Z18Z21Z_c + crn_c <=> FAcrn_hs_24_6Z9Z12Z15Z18Z21Z_c + coa_c
# CRNAT_24_9Z12Z15Z18Z: FAcoa_hs_24_9Z12Z15Z18Z_c + crn_c <=> FAcrn_hs_24_9Z12Z15Z18Z_c + coa_c
# CRNAT_24_9Z12Z15Z18Z21Z: FAcoa_hs_24_9Z12Z15Z18Z21Z_c + crn_c <=> FAcrn_hs_24_9Z12Z15Z18Z21Z_c + coa_c
# CRNAT_26_0: FAcoa_hs_26_0_c + crn_c <=> FAcrn_hs_26_0_c + coa_c
# CRNAT_26_17Z: FAcoa_hs_26_17Z_c + crn_c <=> FAcrn_hs_26_17Z_c + coa_c
# CRNAT_2_0: accoa_c + crn_c <=> acrn_c + coa_c
# CRNAT_3_0: crn_c + ppcoa_c <=> FAcrn_hs_3_0_c + coa_c
# CRNAT_3_2E: FAcoa_hs_3_2E_c + crn_c <=> FAcrn_hs_3_2E_c + coa_c
# CRNAT_3_3OH_S: FAcoa_hs_3_3OH__S_c + crn_c <=> FAcrn_hs_3_3OH__S_c + coa_c
# CRNAT_3_DC: crn_c + malcoa_c <=> coa_c + malcrn_c
# CRNAT_4_0: btcoa_c + crn_c <=> FAcrn_hs_4_0_c + coa_c
# CRNAT_4_2E: FAcoa_hs_4_2E_c + crn_c <=> FAcrn_hs_4_2E_c + coa_c
# CRNAT_4_2M: FAcoa_4_2M_c + crn_c <=> FAcrn_4_2M_c + coa_c
# CRNAT_4_3OH_R: FAcoa_hs_4_3OH__R_c + crn_c <=> FAcrn_hs_4_3OH__R_c + coa_c
# CRNAT_4_DC: FAcoa_4_DC_c + crn_c <=> FAcrn_4_DC_c + coa_c
# CRNAT_5_0: FAcoa_hs_5_0_c + crn_c <=> FAcrn_hs_5_0_c + coa_c
# CRNAT_5_2EDC: FAcoa_5_2EDC_c + crn_c <=> FAcrn_5_2EDC_c + coa_c
# CRNAT_5_2M: FAcoa_5_2M_c + crn_c <=> FAcrn_5_2M_c + coa_c
# CRNAT_5_2M2E: FAcoa_5_2E2M_c + crn_c <=> FAcrn_5_2E2M_c + coa_c
# CRNAT_5_3M3OH__S: FAcoa_5_3M3OH__S_c + crn_c <=> FAcrn_5_3M3OH__S_c + coa_c
# CRNAT_5_DC: FAcoa_5_DC_c + crn_c <=> FAcrn_5_DC_c + coa_c
# CRNAT_6_0: FAcoa_hs_6_0_c + crn_c <=> FAcrn_hs_6_0_c + coa_c
# CRNAT_6_2E: FAcoa_hs_6_2E_c + crn_c <=> FAcrn_hs_6_2E_c + coa_c
# CRNAT_6_3OH_S: FAcoa_hs_6_3OH__S_c + crn_c <=> FAcrn_hs_6_3OH__S_c + coa_c
# CRNAT_6_DC: FAcoa_6_DC_c + crn_c <=> FAcrn_6_DC_c + coa_c
# CRNAT_7_0: FAcoa_hs_7_0_c + crn_c <=> FAcrn_hs_7_0_c + coa_c
# CRNAT_7_3OH_S: FAcoa_hs_7_3OH__S_c + crn_c <=> FAcrn_hs_7_3OH__S_c + coa_c
# CRNAT_7_DC: FAcoa_7_DC_c + crn_c <=> FAcrn_7_DC_c + coa_c
# CRNAT_8_0: FAcoa_hs_8_0_c + crn_c <=> FAcrn_hs_8_0_c + coa_c
# CRNAT_8_2E: FAcoa_hs_8_2E_c + crn_c <=> FAcrn_hs_8_2E_c + coa_c
# CRNAT_8_3OH_S: FAcoa_hs_8_3OH__S_c + crn_c <=> FAcrn_hs_8_3OH__S_c + coa_c
# CRNAT_8_DC: FAcoa_8_DC_c + crn_c <=> FAcrn_8_DC_c + coa_c
# CRNAT_9_0: FAcoa_hs_9_0_c + crn_c <=> FAcrn_hs_9_0_c + coa_c
# CRNAT_9_2M6M_c: crn_c + dmhptcoa_c <=> coa_c + dmhptcrn_c
# CRNAT_9_3OH_S: FAcoa_hs_9_3OH__S_c + crn_c <=> FAcrn_hs_9_3OH__S_c + coa_c
# CRTSLRy: crtsl_c + h_c + nadph_c --> 20bdhcrtsl_c + nadp_c
# CRTSLt: crtsl_c <=> crtsl_e
# CRTSTRNRy: crtstrn_c + h_c + nadph_c --> 20bdhcrtstrn_c + nadp_c
# CRTSTRNt: crtstrn_c <=> crtstrn_e
# CSND: csn_c + h2o_c + h_c --> nh4_c + ura_c
# CYSAMO: cysam_c + o2_c --> h_c + hyptaur_c
# CYSIL2: cysi__L_c --> 2amac_c + thcys_c
# CYSTRS: atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + ppi_c
# DAGOACAH: dagoac_hs_c + h2o_c --> ac_c + h_c + mago_hs_c
# DASCBH: dhdascb__L_c + h2o_c --> 23doguln_c
# DCMPCYTDPT: cytd_c + dcmp_c --> 2dcytd_c + cmp_c
# DCMPNH: dcmp_c + h2o_c <=> 2dr5p_c + csn_c
# DCMPURIPT: dcmp_c + uri_c --> 2dcytd_c + ump_c
# DCT: dpchrm__L_c <=> 56dhica_c
# DGK1: atp_c + dgmp_c --> adp_c + dgdp_c
# DGK2: datp_c + dgmp_c --> dadp_c + dgdp_c
# DHFRy: dhf_c + h_c + nadph_c --> nadp_c + thf_c
# DHORTS: dhor__S_c + h2o_c <=> cbasp_c + h_c
# DIIODTHYt2: diiodthy__L_c <=> diiodthy__L_e
# DLEUtec: leu__D_c <=> leu__D_e
# DMATT: dmpp_c + ipdp_c --> grdp_c + ppi_c
# DNADPL: dnadp_c <=> cadprbp_c + h_c + nac_c
# DOGULND1: 23doguln_c + h2o_c --> co2_c + lyxnt__L_c
# DOGULND2: 23doguln_c + h2o_c --> co2_c + xylnt__L_c
# DOGULNO1: 23doguln_c + h2o2_c --> 2.0 h_c + oxa_c + thrnt__L_c
# DOGULNO2: 23doguln_c + h2o_c --> eryth__L_c + h_c + oxa_c
# DOPACHRMDC_D: dpchrm__D_c + h_c --> 56dhi_c + co2_c
# DOPADC_D: dopa__D_c + h_c --> co2_c + dpam__D_c
# DPMVD: 5dpmev_c + atp_c --> adp_c + co2_c + ipdp_c + pi_c
# DRDPP: asparg_c + h2o_c --> arg__L_c + asp__L_c
# DTMPK1: atp_c + dtmp_c --> adp_c + dtdp_c
# DTMPK2: datp_c + dtmp_c --> dadp_c + dtdp_c
# DUMPK1: atp_c + dump_c --> adp_c + dudp_c
# DUMPK2: datp_c + dump_c --> dadp_c + dudp_c
# E4PD: e4p_c + nad_c + pi_c --> e14bp_c + 2.0 h_c + nadh_c
# EACPR1y: buteACP_2E_c + h_c + nadph_c --> butACP_c + nadp_c
# EACPR2y: h_c + hxeaACP_2E_c + nadph_c --> hxaACP_c + nadp_c
# EACPR3y: h_c + nadph_c + oceaACP_2E_c --> nadp_c + ocaACP_c
# EACPR4y: dceaACP_2E_c + h_c + nadph_c --> dcaACP_c + nadp_c
# EACPR5y: ddceaACP_2E_c + h_c + nadph_c --> ddcaACP_c + nadp_c
# EACPR6y: h_c + nadph_c + ttdceaACP_2E_c --> nadp_c + ttdcaACP_c
# EACPR7y: h_c + hxdceaACP_2E_c + nadph_c --> hxdcaACP_c + nadp_c
# EACPR8y: h_c + nadph_c + ocdceaACP_2E_c --> nadp_c + ocdcaACP_c
# EHGLAT: akg_c + e4hglu_c --> 4h2oglt_c + glu__L_c
# ERGOTHtuNa: ergoth_e + na1_e --> ergoth_c + na1_c
# ESTRONESte: estrones_e <=> estrones_c
# EX_23cgamp_e: 23cgamp_e <=>
# EX_2dcytd_e: 2dcytd_e <=>
# EX_3mob_e: 3mob_e <=>
# EX_4mop_e: 4mop_e <=>
# EX_4pyrn_e: 4pyrn_e <=>
# EX_5mthf_e: 5mthf_e <=>
# EX_FA_hs_10_0_e: FA_hs_10_0_e <=>
# EX_FA_hs_11_0_e: FA_hs_11_0_e <=>
# EX_L2aadp_e: L2aadp_e <=>
# EX_admarg__L_e: admarg__L_e <=>
# EX_ag1_e: ag1_e <=>
# EX_bilirub_e: bilirub_e <=>
# EX_but_e: but_e <=>
# EX_cd2_e: cd2_e <=>
# EX_cholate_e: cholate_e <=>
# EX_chsterol_e: chsterol_e <=>
# EX_cobalt2_e: cobalt2_e <=>
# EX_crn_e: crn_e <=>
# EX_crtsl_e: crtsl_e <=>
# EX_crtstrn_e: crtstrn_e <=>
# EX_dgchol_e: dgchol_e <=>
# EX_dheas_e: dheas_e <=>
# EX_diiodthy__L_e: diiodthy__L_e <=>
# EX_ergoth_e: ergoth_e <=>
# EX_estrones_e: estrones_e <=>
# EX_gchola_e: gchola_e <=>
# EX_gdchac_e: gdchac_e <=>
# EX_glcn_e: glcn_e <=>
# EX_gudchola_e: gudchola_e <=>
# EX_hLkynr_e: hLkynr_e <=>
# EX_his__L_e: his__L_e <=>
# EX_hpta_e: hpta_e <=>
# EX_hxa_e: hxa_e <=>
# EX_i_e: i_e <=>
# EX_ile__L_e: ile__L_e <=>
# EX_im4ac_e: im4ac_e <=>
# EX_inds_e: inds_e <=>
# EX_kynr__L_e: kynr__L_e <=>
# EX_leu__D_e: leu__D_e <=>
# EX_leu__L_e: leu__L_e <=>
# EX_li1_e: li1_e <=>
# EX_lys__L_e: lys__L_e <=>
# EX_mg2_e: mg2_e <=>
# EX_mma_e: mma_e <=>
# EX_mmarg__L_e: mmarg__L_e <=>
# EX_mn2_e: mn2_e <=>
# EX_mobd_e: mobd_e <=>
# EX_nona_e: nona_e <=>
# EX_octa_e: octa_e <=>
# EX_pheme_e: pheme_e <=>
# EX_ppa_e: ppa_e <=>
# EX_ppp9_e: ppp9_e <=>
# EX_prgnlone_e: prgnlone_e <=>
# EX_prgnlones_e: prgnlones_e <=>
# EX_pta_e: pta_e <=>
# EX_retinol_e: retinol_e <=>
# EX_ribavirin_e: ribavirin_e <=>
# EX_ribflv_e: ribflv_e <=>
# EX_tchola_e: tchola_e <=>
# EX_tdchola_e: tdchola_e <=>
# EX_tdechola_e: tdechola_e <=>
# EX_tetiodthy__L_e: tetiodthy__L_e <=>
# EX_triiodthy__L_e: triiodthy__L_e <=>
# EX_trp__L_e: trp__L_e <=>
# EX_tudchola_e: tudchola_e <=>
# EX_val__L_e: val__L_e <=>
# EX_zn2_e: zn2_e <=>
# F1PGT: fuc1p__L_c + gtp_c + h_c <=> gdpfuc_c + ppi_c
# FA120ACPH: ddcaACP_c + h2o_c --> ACP_c + FA_hs_12_0_c + h_c
# FA140ACPH: h2o_c + ttdcaACP_c --> ACP_c + FA_hs_14_0_c + h_c
# FA160ACPH: h2o_c + hxdcaACP_c --> ACP_c + FA_hs_16_0_c + h_c
# FA180ACPH: h2o_c + ocdcaACP_c --> ACP_c + FA_hs_18_0_c + h_c
# FACOA2ERy_16_2E: FAcoa_hs_16_2E_c + h_c + nadph_c --> FAcoa_hs_16_0_c + nadp_c
# FACOA2ERy_17_2E: FAcoa_hs_17_2E_c + h_c + nadph_c --> FAcoa_hs_17_0_c + nadp_c
# FACOA2ERy_18_2E: FAcoa_hs_18_2E_c + h_c + nadph_c --> FAcoa_hs_18_0_c + nadp_c
# FACOA2ERy_19_2E: FAcoa_hs_19_2E_c + h_c + nadph_c --> FAcoa_hs_19_0_c + nadp_c
# FACOA2ERy_20_2E: FAcoa_hs_20_2E_c + h_c + nadph_c --> FAcoa_hs_20_0_c + nadp_c
# FACOA2ERy_20_2E11Z: FAcoa_hs_20_2E11Z_c + h_c + nadph_c --> FAcoa_hs_20_11Z_c + nadp_c
# FACOA2ERy_20_2E11Z14Z: FAcoa_hs_20_2E11Z14Z_c + h_c + nadph_c --> FAcoa_hs_20_11Z14Z_c + nadp_c
# FACOA2ERy_20_2E11Z14Z17Z: FAcoa_hs_20_2E11Z14Z17Z_c + h_c + nadph_c --> FAcoa_hs_20_11Z14Z17Z_c + nadp_c
# FACOA2ERy_20_2E13Z: FAcoa_hs_20_2E13Z_c + h_c + nadph_c --> FAcoa_hs_20_13Z_c + nadp_c
# FACOA2ERy_20_2E5Z8Z11Z14Z: FAcoa_hs_20_2E8Z11Z14Z17Z_c + h_c + nadph_c --> FAcoa_hs_20_8Z11Z14Z17Z_c + nadp_c
# FACOA2ERy_20_2E8Z11Z: FAcoa_hs_20_2E8Z11Z_c + h_c + nadph_c --> FAcoa_hs_20_8Z11Z_c + nadp_c
# FACOA2ERy_20_2E8Z11Z14Z: FAcoa_hs_20_2E8Z11Z14Z_c + h_c + nadph_c --> FAcoa_hs_20_8Z11Z14Z_c + nadp_c
# FACOA2ERy_20_2E9Z: FAcoa_hs_20_2E9Z_c + h_c + nadph_c --> FAcoa_hs_20_9Z_c + nadp_c
# FACOA2ERy_21_2E: FAcoa_hs_21_2E_c + h_c + nadph_c --> FAcoa_hs_21_0_c + nadp_c
# FACOA2ERy_22_2E: FAcoa_hs_22_2E_c + h_c + nadph_c --> FAcoa_hs_22_0_c + nadp_c
# FACOA2ERy_22_2E10Z13Z16Z: FAcoa_hs_22_2E10Z13Z16Z_c + h_c + nadph_c --> FAcoa_hs_22_10Z13Z16Z_c + nadp_c
# FACOA2ERy_22_2E10Z13Z16Z19Z: FAcoa_hs_22_2E10Z13Z16Z19Z_c + h_c + nadph_c --> FAcoa_hs_22_10Z13Z16Z19Z_c + nadp_c
# FACOA2ERy_22_2E11Z: FAcoa_hs_22_2E11Z_c + h_c + nadph_c --> FAcoa_hs_22_11Z_c + nadp_c
# FACOA2ERy_22_2E13Z: FAcoa_hs_22_2E13Z_c + h_c + nadph_c --> FAcoa_hs_22_13Z_c + nadp_c
# FACOA2ERy_22_2E13Z16Z: FAcoa_hs_22_2E13Z16Z_c + h_c + nadph_c --> FAcoa_hs_22_13Z16Z_c + nadp_c
# FACOA2ERy_22_2E13Z16Z19Z: FAcoa_hs_22_2E13Z16Z19Z_c + h_c + nadph_c --> FAcoa_hs_22_13Z16Z19Z_c + nadp_c
# FACOA2ERy_22_2E7Z10Z13Z16Z: FAcoa_hs_22_2E7Z10Z13Z16Z_c + h_c + nadph_c --> FAcoa_hs_22_7Z10Z13Z16Z_c + nadp_c
# FACOA2ERy_22_2E7Z10Z13Z16Z19Z: FAcoa_hs_22_2E7Z10Z13Z16Z19Z_c + h_c + nadph_c --> FAcoa_hs_22_7Z10Z13Z16Z19Z_c + nadp_c
# FACOA2ERy_23_2E: FAcoa_hs_23_2E_c + h_c + nadph_c --> FAcoa_hs_23_0_c + nadp_c
# FACOA2ERy_24_2E: FAcoa_hs_24_2E_c + h_c + nadph_c --> FAcoa_hs_24_0_c + nadp_c
# FACOA2ERy_24_2E12Z15Z18Z21Z: FAcoa_hs_24_2E12Z15Z18Z21Z_c + h_c + nadph_c --> FAcoa_hs_24_12Z15Z18Z21Z_c + nadp_c
# FACOA2ERy_24_2E15Z: FAcoa_hs_24_2E15Z_c + h_c + nadph_c --> FAcoa_hs_24_15Z_c + nadp_c
# FACOA2ERy_24_2E9Z12Z15Z18Z: FAcoa_hs_24_2E9Z12Z15Z18Z_c + h_c + nadph_c --> FAcoa_hs_24_9Z12Z15Z18Z_c + nadp_c
# FACOA2ERy_24_2E9Z12Z15Z18Z21Z: FAcoa_hs_24_2E9Z12Z15Z18Z21Z_c + h_c + nadph_c --> FAcoa_hs_24_9Z12Z15Z18Z21Z_c + nadp_c
# FACOA2ERy_26_2E: FAcoa_hs_26_2E_c + h_c + nadph_c --> FAcoa_hs_26_0_c + nadp_c
# FACOA2ERy_26_2E17Z: FAcoa_hs_26_2E17Z_c + h_c + nadph_c --> FAcoa_hs_26_17Z_c + nadp_c
# FACOA3OHDH_16_3OH: FAcoa_hs_16_3OH__R_c --> FAcoa_hs_16_2E_c + h2o_c
# FACOA3OHDH_17_3OH: FAcoa_hs_17_3OH__R_c --> FAcoa_hs_17_2E_c + h2o_c
# FACOA3OHDH_18_3OH: FAcoa_hs_18_3OH__R_c --> FAcoa_hs_18_2E_c + h2o_c
# FACOA3OHDH_19_3OH: FAcoa_hs_19_3OH__R_c --> FAcoa_hs_19_2E_c + h2o_c
# FACOA3OHDH_20_11Z14Z17Z3OH: FAcoa_hs_20_11Z14Z17Z3OH__R_c --> FAcoa_hs_20_2E11Z14Z17Z_c + h2o_c
# FACOA3OHDH_20_11Z14Z3OH: FAcoa_hs_20_11Z14Z3OH__R_c --> FAcoa_hs_20_2E11Z14Z_c + h2o_c
# FACOA3OHDH_20_11Z3OH: FAcoa_hs_20_11Z3OH__R_c --> FAcoa_hs_20_2E11Z_c + h2o_c
# FACOA3OHDH_20_13Z3OH: FAcoa_hs_20_13Z3OH__R_c --> FAcoa_hs_20_2E13Z_c + h2o_c
# FACOA3OHDH_20_3OH: FAcoa_hs_20_3OH__R_c --> FAcoa_hs_20_2E_c + h2o_c
# FACOA3OHDH_20_5Z8Z11Z14Z3OH: FAcoa_hs_20_8Z11Z14Z17Z3OH__R_c --> FAcoa_hs_20_2E8Z11Z14Z17Z_c + h2o_c
# FACOA3OHDH_20_8Z11Z14Z3OH: FAcoa_hs_20_8Z11Z14Z3OH__R_c --> FAcoa_hs_20_2E8Z11Z14Z_c + h2o_c
# FACOA3OHDH_20_8Z11Z3OH: FAcoa_hs_20_8Z11Z3OH__R_c --> FAcoa_hs_20_2E8Z11Z_c + h2o_c
# FACOA3OHDH_20_9Z3OH: FAcoa_hs_20_9Z3OH__R_c --> FAcoa_hs_20_2E9Z_c + h2o_c
# FACOA3OHDH_21_3OH: FAcoa_hs_21_3OH__R_c --> FAcoa_hs_21_2E_c + h2o_c
# FACOA3OHDH_22_10Z13Z16Z19Z3OH: FAcoa_hs_22_10Z13Z16Z19Z3OH__R_c --> FAcoa_hs_22_2E10Z13Z16Z19Z_c + h2o_c
# FACOA3OHDH_22_10Z13Z16Z3OH: FAcoa_hs_22_10Z13Z16Z3OH__R_c --> FAcoa_hs_22_2E10Z13Z16Z_c + h2o_c
# FACOA3OHDH_22_11Z3OH: FAcoa_hs_22_11Z3OH__R_c --> FAcoa_hs_22_2E11Z_c + h2o_c
# FACOA3OHDH_22_13Z16Z19Z3OH: FAcoa_hs_22_13Z16Z19Z3OH__R_c --> FAcoa_hs_22_2E13Z16Z19Z_c + h2o_c
# FACOA3OHDH_22_13Z16Z3OH: FAcoa_hs_22_13Z16Z3OH__R_c --> FAcoa_hs_22_2E13Z16Z_c + h2o_c
# FACOA3OHDH_22_13Z3OH: FAcoa_hs_22_13Z3OH__R_c --> FAcoa_hs_22_2E13Z_c + h2o_c
# FACOA3OHDH_22_3OH: FAcoa_hs_22_3OH__R_c --> FAcoa_hs_22_2E_c + h2o_c
# FACOA3OHDH_22_7Z10Z13Z16Z19Z3OH: FAcoa_hs_22_7Z10Z13Z16Z19Z3OH__R_c --> FAcoa_hs_22_2E7Z10Z13Z16Z19Z_c + h2o_c
# FACOA3OHDH_22_7Z10Z13Z16Z3OH: FAcoa_hs_22_7Z10Z13Z16Z3OH__R_c --> FAcoa_hs_22_2E7Z10Z13Z16Z_c + h2o_c
# FACOA3OHDH_23_3OH: FAcoa_hs_23_3OH__R_c --> FAcoa_hs_23_2E_c + h2o_c
# FACOA3OHDH_24_12Z15Z18Z21Z3OH: FAcoa_hs_24_12Z15Z18Z21Z3OH__R_c --> FAcoa_hs_24_2E12Z15Z18Z21Z_c + h2o_c
# FACOA3OHDH_24_15Z3OH: FAcoa_hs_24_15Z3OH__R_c --> FAcoa_hs_24_2E15Z_c + h2o_c
# FACOA3OHDH_24_3OH: FAcoa_hs_24_3OH__R_c --> FAcoa_hs_24_2E_c + h2o_c
# FACOA3OHDH_24_9Z12Z15Z18Z21Z3OH: FAcoa_hs_24_9Z12Z15Z18Z21Z3OH__R_c --> FAcoa_hs_24_2E9Z12Z15Z18Z21Z_c + h2o_c
# FACOA3OHDH_24_9Z12Z15Z18Z3OH: FAcoa_hs_24_9Z12Z15Z18Z3OH__R_c --> FAcoa_hs_24_2E9Z12Z15Z18Z_c + h2o_c
# FACOA3OHDH_26_17Z3OH: FAcoa_hs_26_17Z3OH__R_c --> FAcoa_hs_26_2E17Z_c + h2o_c
# FACOA3OHDH_26_3OH: FAcoa_hs_26_3OH__R_c --> FAcoa_hs_26_2E_c + h2o_c
# FACOA3ORy_16_3O: FAcoa_hs_16_3O_c + h_c + nadph_c --> FAcoa_hs_16_3OH__R_c + nadp_c
# FACOA3ORy_17_3O: FAcoa_hs_17_3O_c + h_c + nadph_c --> FAcoa_hs_17_3OH__R_c + nadp_c
# FACOA3ORy_18_3O: FAcoa_hs_18_3O_c + h_c + nadph_c --> FAcoa_hs_18_3OH__R_c + nadp_c
# FACOA3ORy_19_3O: FAcoa_hs_19_3O_c + h_c + nadph_c --> FAcoa_hs_19_3OH__R_c + nadp_c
# FACOA3ORy_20_11Z14Z17Z3O: FAcoa_hs_20_11Z14Z17Z3O_c + h_c + nadph_c --> FAcoa_hs_20_11Z14Z17Z3OH__R_c + nadp_c
# FACOA3ORy_20_11Z14Z3O: FAcoa_hs_20_11Z14Z3O_c + h_c + nadph_c --> FAcoa_hs_20_11Z14Z3OH__R_c + nadp_c
# FACOA3ORy_20_11Z3O: FAcoa_hs_20_11Z3O_c + h_c + nadph_c --> FAcoa_hs_20_11Z3OH__R_c + nadp_c
# FACOA3ORy_20_13Z3O: FAcoa_hs_20_13Z3O_c + h_c + nadph_c --> FAcoa_hs_20_13Z3OH__R_c + nadp_c
# FACOA3ORy_20_3O: FAcoa_hs_20_3O_c + h_c + nadph_c --> FAcoa_hs_20_3OH__R_c + nadp_c
# FACOA3ORy_20_5Z8Z11Z14Z3O: FAcoa_hs_20_8Z11Z14Z17Z3O_c + h_c + nadph_c --> FAcoa_hs_20_8Z11Z14Z17Z3OH__R_c + nadp_c
# FACOA3ORy_20_8Z11Z14Z3O: FAcoa_hs_20_8Z11Z14Z3O_c + h_c + nadph_c --> FAcoa_hs_20_8Z11Z14Z3OH__R_c + nadp_c
# FACOA3ORy_20_8Z11Z3O: FAcoa_hs_20_8Z11Z3O_c + h_c + nadph_c --> FAcoa_hs_20_8Z11Z3OH__R_c + nadp_c
# FACOA3ORy_20_9Z3O: FAcoa_hs_20_9Z3O_c + h_c + nadph_c --> FAcoa_hs_20_9Z3OH__R_c + nadp_c
# FACOA3ORy_21_3O: FAcoa_hs_21_3O_c + h_c + nadph_c --> FAcoa_hs_21_3OH__R_c + nadp_c
# FACOA3ORy_22_10Z13Z16Z19Z3O: FAcoa_hs_22_10Z13Z16Z19Z3O_c + h_c + nadph_c --> FAcoa_hs_22_10Z13Z16Z19Z3OH__R_c + nadp_c
# FACOA3ORy_22_10Z13Z16Z3O: FAcoa_hs_22_10Z13Z16Z3O_c + h_c + nadph_c --> FAcoa_hs_22_10Z13Z16Z3OH__R_c + nadp_c
# FACOA3ORy_22_11Z3O: FAcoa_hs_22_11Z3O_c + h_c + nadph_c --> FAcoa_hs_22_11Z3OH__R_c + nadp_c
# FACOA3ORy_22_13Z16Z19Z3O: FAcoa_hs_22_13Z16Z19Z3O_c + h_c + nadph_c --> FAcoa_hs_22_13Z16Z19Z3OH__R_c + nadp_c
# FACOA3ORy_22_13Z16Z3O: FAcoa_hs_22_13Z16Z3O_c + h_c + nadph_c --> FAcoa_hs_22_13Z16Z3OH__R_c + nadp_c
# FACOA3ORy_22_13Z3O: FAcoa_hs_22_13Z3O_c + h_c + nadph_c --> FAcoa_hs_22_13Z3OH__R_c + nadp_c
# FACOA3ORy_22_3O: FAcoa_hs_22_3O_c + h_c + nadph_c --> FAcoa_hs_22_3OH__R_c + nadp_c
# FACOA3ORy_22_7Z10Z13Z16Z19Z3O: FAcoa_hs_22_7Z10Z13Z16Z19Z3O_c + h_c + nadph_c --> FAcoa_hs_22_7Z10Z13Z16Z19Z3OH__R_c + nadp_c
# FACOA3ORy_22_7Z10Z13Z16Z3O: FAcoa_hs_22_7Z10Z13Z16Z3O_c + h_c + nadph_c --> FAcoa_hs_22_7Z10Z13Z16Z3OH__R_c + nadp_c
# FACOA3ORy_23_3O: FAcoa_hs_23_3O_c + h_c + nadph_c --> FAcoa_hs_23_3OH__R_c + nadp_c
# FACOA3ORy_24_12Z15Z18Z21Z3O: FAcoa_hs_24_12Z15Z18Z21Z3O_c + h_c + nadph_c --> FAcoa_hs_24_12Z15Z18Z21Z3OH__R_c + nadp_c
# FACOA3ORy_24_15Z3O: FAcoa_hs_24_15Z3O_c + h_c + nadph_c --> FAcoa_hs_24_15Z3OH__R_c + nadp_c
# FACOA3ORy_24_3O: FAcoa_hs_24_3O_c + h_c + nadph_c --> FAcoa_hs_24_3OH__R_c + nadp_c
# FACOA3ORy_24_9Z12Z15Z18Z21Z3O: FAcoa_hs_24_9Z12Z15Z18Z21Z3O_c + h_c + nadph_c --> FAcoa_hs_24_9Z12Z15Z18Z21Z3OH__R_c + nadp_c
# FACOA3ORy_24_9Z12Z15Z18Z3O: FAcoa_hs_24_9Z12Z15Z18Z3O_c + h_c + nadph_c --> FAcoa_hs_24_9Z12Z15Z18Z3OH__R_c + nadp_c
# FACOA3ORy_26_17Z3O: FAcoa_hs_26_17Z3O_c + h_c + nadph_c --> FAcoa_hs_26_17Z3OH__R_c + nadp_c
# FACOA3ORy_26_3O: FAcoa_hs_26_3O_c + h_c + nadph_c --> FAcoa_hs_26_3OH__R_c + nadp_c
# FADRy: fad_c + 2.0 h_c + nadph_c --> fadh2_c + nadp_c
# FAWOXx_10_10OH: FA_hs_10_10OH_c + nad_c --> FA_hs_10_10O_c + h_c + nadh_c
# FAWOXx_10_10OXO: FA_hs_10_10O_c + h2o_c + nad_c --> FA_hs_10_DC_c + 2.0 h_c + nadh_c
# FAWOXx_12_12OH: FA_hs_12_12OH_c + nad_c --> FA_hs_12_12O_c + h_c + nadh_c
# FAWOXx_12_12OXO: FA_hs_12_12O_c + h2o_c + nad_c --> FA_hs_12_DC_c + 2.0 h_c + nadh_c
# FAWOXx_14_14OH: FA_hs_14_14OH_c + nad_c --> FA_hs_14_14O_c + h_c + nadh_c
# FAWOXx_14_14OXO: FA_hs_14_14O_c + h2o_c + nad_c --> FA_hs_14_DC_c + 2.0 h_c + nadh_c
# FAWOXx_16_016OH: FA_hs_16_16OH_c + nad_c --> FA_hs_16_16O_c + h_c + nadh_c
# FAWOXx_16_016OXO: FA_hs_16_16O_c + h2o_c + nad_c --> FA_hs_16_DC_c + 2.0 h_c + nadh_c
# FAWOXx_20_5Z8Z11Z14Z20OH: FA_hs_20_5Z8Z11Z14Z20OH_c + nad_c --> FA_hs_20_5Z8Z11Z14Z20O_c + h_c + nadh_c
# FAWOXx_20_5Z8Z11Z14Z20OXO: FA_hs_20_5Z8Z11Z14Z20O_c + h2o_c + nad_c --> FA_hs_20_5Z8Z11Z14Z20DC_c + 2.0 h_c + nadh_c
# FAWOXx_22_22OH: FA_hs_22_22OH_c + nad_c --> FA_hs_22_22O_c + h_c + nadh_c
# FAWOXx_22_22OXO: FA_hs_22_22O_c + h2o_c + nad_c --> FA_hs_22_DC_c + 2.0 h_c + nadh_c
# FAt_hs_10_0: FA_hs_10_0_e <=> FA_hs_10_0_c
# FAt_hs_11_0: FA_hs_11_0_e <=> FA_hs_11_0_c
# FAt_hs_5_0: pta_e <=> pta_c
# FAt_hs_6_0: hxa_e <=> hxa_c
# FAt_hs_7_0: hpta_e <=> hpta_c
# FAt_hs_8_0: octa_e <=> octa_c
# FAt_hs_9_0: nona_e <=> nona_c
# FBA3: s17bp_c <=> dhap_c + e4p_c
# FBA6: o18bp_c <=> dhap_c + r5p_c
# FE2PHEMEABCte: atp_c + h2o_c + pheme_c --> adp_c + h_c + pheme_e + pi_c
# FE2PHEMEOX: h2o_c + o2_c + pheme_c --> h_c + hematin_c + o2s_c
# FISC: 4.0 fe2_c + 6.0 h2o_c + o2_c --> 4.0 fe3ooh_c + 8.0 h_c
# FK: atp_c + fuc__L_c --> adp_c + fuc1p__L_c + h_c
# FKYNH: Lfmkynr_c + h2o_c --> for_c + h_c + kynr__L_c
# FLDPP: h2o_c + pheleu_c --> leu__L_c + phe__L_c
# FLVRy: 2.0 h_c + nadph_c + ribflv_c --> nadp_c + rblvrd_c
# FPDPP: h2o_c + phepro_c --> phe__L_c + pro__L_c
# FRNSL2E6EDH: frnsl2e6e_c + h2o_c + nad_c --> frnsn2e6e_c + 2.0 h_c + nadh_c
# FRU3K: atp_c + fru_c --> adp_c + f3p_c + h_c
# FUTGAL2A: galacgalfuc12gal14acglcgalgluside_hs_c + gdpfuc_c --> fucgalacgalfuc12gal14acglcgalgluside_hs_c + gdp_c + h_c
# FUTGLOBO1: galgbside_hs_c + gdpfuc_c --> gdp_c + globoH_hs_c + h_c
# FUTINLC8CER1: galacglcgalacglcgal14acglcgalgluside_hs_c + gdpfuc_c --> fucgalacglcgalacglcgal14acglcgalgluside_hs_c + gdp_c + h_c
# FUTINLC8CER2: fucgalacglcgalacglcgal14acglcgalgluside_hs_c + gdpfuc_c --> fucfucgalacglcgalacglcgal14acglcgalgluside_hs_c + gdp_c + h_c
# FUTLC4CER: galacglcgalgluside_hs_c + gdpfuc_c --> fucgalacglcgalgluside_hs_c + gdp_c + h_c
# FUTLC5CER: galgalacglcgalgluside_hs_c + gdpfuc_c --> galfucgalacglcgalgluside_hs_c + gdp_c + h_c
# FUTNLC5CER: galgal14acglcgalgluside_hs_c + gdpfuc_c --> galfuc12gal14acglcgalgluside_hs_c + gdp_c + h_c
# FUTNLC6CER: galacglcgal14acglcgalgluside_hs_c + gdpfuc_c --> fucgalacglcgal14acglcgalgluside_hs_c + gdp_c + h_c
# FUTNLC7CER: galacgalfucgalacglcgal14acglcgalgluside_hs_c + gdpfuc_c --> fucgalacgalfucgalacglcgal14acglcgalgluside_hs_c + gdp_c + h_c
# FUTPGBSIDE: gdpfuc_c + paragbside_hs_c --> fuc12gal14acglcgalgluside_hs_c + gdp_c + h_c
# FYDPP: h2o_c + phetyr_c --> phe__L_c + tyr__L_c
# G5SAD: glu5sa__L_c <=> 1pyr5c__L_c + h2o_c + h_c
# GARFT: 10fthf_c + gar_c <=> fgam_c + h_c + thf_c
# GFDPP: glyphe_c + h2o_c --> gly_c + phe__L_c
# GFUCSx: gdpddman_c + h_c + nadh_c --> gdpfuc_c + nad_c
# GFUCSy: gdpddman_c + h_c + nadph_c --> gdpfuc_c + nadp_c
# GGDPP: glygly_c + h2o_c --> 2.0 gly_c
# GHBDHy: h_c + nadph_c + sucsal_c <=> 4ohbut_c + nadp_c
# GHMT3: 3htmelys_c + h_c --> 4tmeabut_c + gly_c
# GLACOx: glac_c + 2.0 h2o_c + nad_c --> glcr_c + 3.0 h_c + nadh_c
# GLCNte: glcn_c --> glcn_e
# GLDPP: glyleu_c + h2o_c --> gly_c + leu__L_c
# GLNTRS: atp_c + gln__L_c + trnagln_c --> amp_c + glntrna_c + ppi_c
# GLUTRS: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
# GLYTRS: atp_c + gly_c + trnagly_c --> amp_c + glytrna_c + ppi_c
# GMAND: gdpmann_c --> gdpddman_c + h2o_c
# GNK: atp_c + glcn_c --> 6pgc_c + adp_c + h_c
# GP4AH1: gp4g_c + h2o_c --> gmp_c + gtp_c + 2.0 h_c
# GPDDA6: g3pnae_hs_c + h2o_c --> glyc3p_c + h_c + nae_hs_c
# GPDPP: glypro_c + h2o_c --> gly_c + pro__L_c
# GRTT: grdp_c + ipdp_c --> frdp_c + ppi_c
# GTHNHOHD: gthnhoh_c --> gthnoh2_c
# GTHNOH2HYD: gthnoh2_c + h2o_c --> nh4_c + so2gth_c
# GTHNOH2RD: gthnhoh_c + gthrd_c --> gthox_c + ham_c
# GTHNORDx: gthno_c + h_c + nadh_c --> gthnhoh_c + nad_c
# GTHNORDy: gthno_c + h_c + nadph_c --> gthnhoh_c + nadp_c
# GWDPP: glytrp_c + h2o_c --> gly_c + trp__L_c
# HEXGA2: ga2_hs_c + h2o_c --> acgal_c + galgluside_hs_c
# HEXGBSIDE: gbside_hs_c + h2o_c --> acgal_c + thcrm_hs_c
# HEXGM2: gm2_hs_c + h2o_c --> acgal_c + gm3_hs_c
# HISD: his__L_c --> nh4_c + urcan_c
# HISTRS: atp_c + his__L_c + trnahis_c --> amp_c + histrna_c + ppi_c
# HMOBD_Cltex: cl_c + h_e + mobd_e <=> cl_e + h_c + mobd_c
# HPTALDHx: h2o_c + hptal_c + nad_c --> 2.0 h_c + hpta_c + nadh_c
# HPTEAL2EDHx: h2o_c + hpteal_2E_c + nad_c --> 2.0 h_c + hptea_2E_c + nadh_c
# HXALDHx: h2o_c + hxal_c + nad_c --> 2.0 h_c + hxa_c + nadh_c
# HXEAL2EDHx: h2o_c + hxeal_2E_c + nad_c --> 2.0 h_c + hxea_2E_c + nadh_c
# ILETRS: atp_c + ile__L_c + trnaile_c --> amp_c + iletrna_c + ppi_c
# IM4ACte: im4ac_c <=> im4ac_e
# IMACTD: h2o_c + im4act_c + nad_c --> 2.0 h_c + im4ac_c + nadh_c
# INS6P1K: atp_c + ins6p_c --> 1ppins5p_c + adp_c
# INSULINGTHOR: 2.0 gthrd_c + insulinox_c --> gthox_c + insulinrd_c
# It: i_c <=> i_e
# KLDPP: h2o_c + lysleu_c --> leu__L_c + lys__L_c
# KYNAKGAT: akg_c + kynr__L_c --> 4aphdob_c + glu__L_c
# KYNATESYN: 4aphdob_c --> h2o_c + kynate_c
# L2AADPt: L2aadp_e --> L2aadp_c
# L2HGDHx: akg_c + h_c + nadh_c --> 2hglut__L_c + nad_c
# L4HGSA: 4hglusa__L_c <=> 1p3h5c__L_c + h2o_c + h_c
# LADPP: h2o_c + leuala_c --> ala__L_c + leu__L_c
# LCYSTAT: Lcyst_c + akg_c <=> 3spyr_c + glu__L_c
# LEUTRS: atp_c + leu__L_c + trnaleu_c --> amp_c + leutrna_c + ppi_c
# LGDPP: h2o_c + leugly_c --> gly_c + leu__L_c
# LGFTPAP: h2o_c + leuglyphe_c --> glyphe_c + leu__L_c
# LGGTPAP: h2o_c + leuglygly_c --> glygly_c + leu__L_c
# LKYNRtr: kynr__L_c <=> kynr__L_e
# LLDPP: h2o_c + leuleu_c --> 2.0 leu__L_c
# LLLTPAP: h2o_c + leuleuleu_c --> leu__L_c + leuleu_c
# LNAPELPLD: h2o_c + lnape_hs_c --> h_c + lpa_hs_c + nae_hs_c
# LNSTLS: Ssq23epx_c --> lanost_c
# LPCOLPLD: h2o_c + lpco_hs_c --> chol_c + h_c + lpao_hs_c
# LPDPP: h2o_c + leupro_c --> leu__L_c + pro__L_c
# LYSTRS: atp_c + lys__L_c + trnalys_c --> amp_c + lystrna_c + ppi_c
# M16BPS1: 13dpg_c + man1p_c <=> 3pg_c + h_c + man16bp_c
# MAGOK: atp_c + mago_hs_c --> adp_c + h_c + lpao_hs_c
# MALDHx: h2o_c + mald_c + nad_c --> 2.0 h_c + msa_c + nadh_c
# MAN1PT: gtp_c + h_c + man1p_c <=> gdpmann_c + ppi_c
# MCLOR: h_c + mercppyr_c + nadh_c --> mercplac_c + nad_c
# MCOATA: ACP_c + malcoa_c --> coa_c + malACP_c
# METMSPYRAT: 2kmb_c + smscys__L_c <=> met__L_c + metselpyr_c
# METSELNEORy: h_c + methselne_c + nadph_c --> h2o_c + methsel_c + nadp_c
# METSELNIORy: 2.0 h_c + methselni_c + nadph_c --> h2o_c + methselne_c + nadp_c
# METTRS: atp_c + met__L_c + trnamet_c --> amp_c + mettrna_c + ppi_c
# MI13456P3PP: h2o_c + mi13456p_c --> mi1456p_c + pi_c
# MI1345P5PP: h2o_c + mi1345p_c --> mi134p_c + pi_c
# MI1456P6PP: h2o_c + mi1456p_c --> mi145p_c + pi_c
# MMALNDHx: 2mop_c + h2o_c + nad_c --> 2.0 h_c + mmaln_c + nadh_c
# MMAt2: mma_c <=> mma_e
# MNDN2ERy: h_c + mndn_c + nadph_c --> mndiol_c + nadp_c
# MPDPP: h2o_c + metpro_c --> met__L_c + pro__L_c
# MPMOBDT: h_c + mobd_c + mptamp_c --> amp_c + h2o_c + moco_c
# MPTAT: atp_c + h_c + mpt_c --> mptamp_c + ppi_c
# N1ASPMDOX: N1aspmd_c + h2o_c + o2_c --> aappal_c + h2o2_c + ptrc_c
# N1SPRMOX: N1sprm_c + h2o_c + o2_c --> aappal_c + h2o2_c + spmd_c
# NABTNO: h2o_c + n4abutn_c + nad_c --> 4aabutn_c + 2.0 h_c + nadh_c
# NADN2: anad_c + h2o_c --> adprib_c + h_c + ncam_c
# NADPL: nadp_c <=> cadprbp_c + h_c + ncam_c
# NADPN: h2o_c + nadp_c --> adprbp_c + h_c + ncam_c
# NAPEPLD: h2o_c + nape_hs_c --> h_c + nae_hs_c + pa_hs_c
# NDPK10: atp_c + didp_c --> adp_c + ditp_c
# NDPK4: atp_c + dtdp_c --> adp_c + dttp_c
# NDPK5: atp_c + dgdp_c --> adp_c + dgtp_c
# NDPK6: atp_c + dudp_c --> adp_c + dutp_c
# NEU24: gm1_hs_c + h2o_c --> acnam_c + ga1_hs_c
# NEU25: gm2_hs_c + h2o_c --> acnam_c + ga2_hs_c
# NEU31: gm3_hs_c + h2o_c --> acnam_c + galgluside_hs_c
# NEU32: gd1a_hs_c + h2o_c --> acnam_c + gm1_hs_c
# NEU33: gd1b_hs_c + h2o_c --> acnam_c + gm1_hs_c
# NEU34: gt1b_hs_c + h2o_c --> acnam_c + gd1b_hs_c
# NEU36: gq1b_hs_c + h2o_c --> acnam_c + gt1b_hs_c
# NNDPR: 2.0 h_c + prpp_c + quln_c --> co2_c + nicrnt_c + ppi_c
# NONALDHx: h2o_c + nad_c + nonal_c --> 2.0 h_c + nadh_c + nona_c
# NONEAL2EDHx: h2o_c + nad_c + noneal_2E_c --> 2.0 h_c + nadh_c + nonea_2E_c
# NTD2AMP: 2amp_c + h2o_c --> adn_c + pi_c
# NTD2CMP: 2cmp_c + h2o_c --> cytd_c + pi_c
# NTD2GMP: 2gmp_c + h2o_c --> gsn_c + pi_c
# NTD2UMP: 2ump_c + h2o_c --> pi_c + uri_c
# NTDDCMP: dcmp_c + h2o_c --> 2dcytd_c + pi_c
# NTDOMP: h2o_c + orot5p_c --> orotdn_c + pi_c
# NTDPSUMP: h2o_c + psump_c --> pi_c + psuri_c
# NTDSAMP: h2o_c + succamp_c --> pi_c + succadn_c
# NTPPDI: ditp_c + h2o_c --> dimp_c + h_c + ppi_c
# NTPPX: h2o_c + xtp_c --> h_c + ppi_c + xmp_c
# OCTALDHx: h2o_c + nad_c + octal_c --> 2.0 h_c + nadh_c + octa_c
# OCTEAL2EDHx: h2o_c + nad_c + octeal_2E_c --> 2.0 h_c + nadh_c + octea_2E_c
# P4AH: h2o_c + p4a_c --> atp_c + h_c + pi_c
# PEPTDPROI: protres_pepproW0_c <=> protres_pepproW180_c
# PFDPP: h2o_c + prophe_c --> phe__L_c + pro__L_c
# PGD21GH: h2o_c + prostgd21glyc_c --> glyc_c + h_c + prostgd2_c
# PGDF21GH: h2o_c + prostgf21glyc_c --> glyc_c + h_c + prostgf2_c
# PGE1DHy: nadp_c + prostge1_c <=> 15kprostge1_c + h_c + nadph_c
# PGE21GH: h2o_c + prostge21glyc_c --> glyc_c + h_c + prostge2_c
# PGE2DHy: nadp_c + prostge2_c <=> 15kprostge2_c + h_c + nadph_c
# PGE3DHy: nadp_c + prostge3_c <=> 15kprostge3_c + h_c + nadph_c
# PGF1DHy: nadp_c + prostgf1_c <=> 15kprostgf1_c + h_c + nadph_c
# PGF2DHy: nadp_c + prostgf2_c <=> 15kprostgf2_c + h_c + nadph_c
# PGF3DHy: nadp_c + prostgf3_c <=> 15kprostgf3_c + h_c + nadph_c
# PHEMEt: pheme_c --> pheme_e
# PHETRS: atp_c + phe__L_c + trnaphe_c --> amp_c + phetrna_c + ppi_c
# PHLAC: h_c + nadh_c + phpyr_c --> nad_c + phlac_c
# PHPYRT: phpyr_c --> 2h3ppr_c
# PI35P4K: atp_c + pail35p_hs_c --> adp_c + h_c + pail345p_hs_c
# PI3P4K: atp_c + pail3p_hs_c --> adp_c + h_c + pail34p_hs_c
# PLDPP: h2o_c + proleu_c --> leu__L_c + pro__L_c
# PMANM: man1p_c <=> man6p_c
# POLYADPRH: h2o_c + polyadprib2_c --> adprib_c + polyadprib1_c
# PPALDHx: h2o_c + nad_c + ppal_c --> 2.0 h_c + nadh_c + ppa_c
# PPDPP: h2o_c + propro_c --> 2.0 pro__L_c
# PPGPPDP: h2o_c + ppgpp_c --> gdp_c + h_c + ppi_c
# PPP9ABCte: atp_c + h2o_c + ppp9_c --> adp_c + h_c + pi_c + ppp9_e
# PRAGS: atp_c + gly_c + pram_c --> adp_c + gar_c + h_c + pi_c
# PRAIS: atp_c + fpram_c --> adp_c + air_c + 2.0 h_c + pi_c
# PRASCS: 5aizc_c + asp__L_c + atp_c --> adp_c + h_c + pi_c + saicar_c
# PRFGS: atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + fpram_c + glu__L_c + h_c + pi_c
# PRGNABCte: atp_c + h2o_c + prgnlone_c --> adp_c + h_c + pi_c + prgnlone_e
# PROTKACTPAC: actp_c + protres_lys__L_c --> h_c + pi_c + protres_aclys__L_c
# PROTKRBLK: atp_c + protres_rbllys_c --> adp_c + h_c + protres_rbllys3p_c
# PROTKRU3PDG: h2o_c + protres_rbllys3p_c --> 3dxyl_c + pi_c + protres_lys__L_c
# PROTKSUCT: FAcoa_4_DC_c + protres_lys__L_c <=> coa_c + h_c + protres_succlys_c
# PROTRS: atp_c + pro__L_c + trnapro_c --> amp_c + ppi_c + protrna_c
# PRPPSZ: aicar_c + h_c + prpp_c --> r5p_c + ztp_c
# PYRRLHYD: 4abutn_c <=> h2o_c + pyrrl_c
# QMPNH: h2o_c + qmp_c --> que_c + r5p_c
# QUILSYN: cmusa_c --> h2o_c + h_c + quln_c
# R5PCT: ctp_c + h_c + r5p_c --> cdprib_c + ppi_c
# RADH1x: h2o_c + nad_c + retinal_c --> 2.0 h_c + nadh_c + retn_c
# RADH2x: h2o_c + nad_c + retinal_9Z_c --> 2.0 h_c + nadh_c + retn_9Z_c
# RADH3x: h2o_c + nad_c + retinal_11Z_c --> 2.0 h_c + nadh_c + retn_11Z_c
# RADH4x: h2o_c + nad_c + retinal_13Z_c --> 2.0 h_c + nadh_c + retn_13Z_c
# RBTCT: ctp_c + h_c + rbt5p_c --> cdprbt_c + ppi_c
# RBTDG2_Dx: h_c + nadh_c + rbl__D_c --> nad_c + rbt_c
# RBVDA: h2o_c + ribavirin_c --> nh4_c + rbvcbxlt_c
# RBVPNP: pi_c + ribavirin_c <=> r1p_c + triaz3crbxam_c
# RBVt: ribavirin_c <=> ribavirin_e
# RDH1y: h_c + nadph_c + retinal_c <=> nadp_c + retinol_c
# RDH2y: h_c + nadph_c + retinal_9Z_c <=> nadp_c + retinol_9Z_c
# RDH3y: h_c + nadph_c + retinal_11Z_c <=> nadp_c + retinol_11Z_c
# RDH4y: h_c + nadph_c + retinal_13Z_c <=> nadp_c + retinol_13Z_c
# RETt: retinol_c <=> retinol_e
# RPPTPAP: argpropro_c + h2o_c --> arg__L_c + propro_c
# RU5PCT: ctp_c + h_c + ru5p__D_c --> cdpru5p__D_c + ppi_c
# SEAHCYSHYD: h2o_c + selahcys__L_c --> adn_c + selhcys__L_c
# SELCYSTL1: selcyst__L_c --> 2abuten_c + selcys__L_c
# SELCYSTL2: selcyst__L_c --> 2amac_c + selhcys__L_c
# SELMETAT: atp_c + h2o_c + selmet__L_c --> pi_c + ppi_c + selamet__L_c
# SELMETHL1: selmet__L_c --> 2abuten_c + methsel_c
# SERTRS: atp_c + ser__L_c + trnaser_c --> amp_c + ppi_c + sertrna_c
# SHPK: atp_c + sdhplse_c --> adp_c + h_c + s7p_c
# SLDx: 3spyr_c + h_c + nadh_c <=> nad_c + slac__L_c
# SMSCYSL2: smscys__L_c --> 2amac_c + methsel_c
# SNOCOARD: h_c + nadph_c + snocoa_c --> nadp_c + snoh2coa_c
# SPMDACT: accoa_c + spmd_c --> N1aspmd_c + coa_c + h_c
# SPRMACT: accoa_c + sprm_c --> N1sprm_c + coa_c + h_c
# SUCACETO: h_c + sucacetat_c --> co2_c + sucaceto_c
# TDECHOLAte: tdechola_e <=> tdechola_c
# TETIODTHYt2: tetiodthy__L_c <=> tetiodthy__L_e
# THGDPK: atp_c + thiogdp_c --> adp_c + thiogtp_c
# THGMPK: atp_c + thiogmp_c --> adp_c + thiogdp_c
# THIOGSNPNP: pi_c + thiogsn_c --> r1p_c + thiogua_c
# THIOGUAPRT: prpp_c + thiogua_c --> ppi_c + thiogmp_c
# THRTLD_Lx: nad_c + thrtl__L_c <=> eryth__L_c + h_c + nadh_c
# THRTRS: atp_c + thr__L_c + trnathr_c --> amp_c + ppi_c + thrtrna_c
# TMABADH: 4tmeabut_c + h2o_c + nad_c --> 4tmeabutn_c + 2.0 h_c + nadh_c
# TRIIODTHYt2: triiodthy__L_c <=> triiodthy__L_e
# TRPHLKYNR: hLkynr_e + trp__L_c <=> hLkynr_c + trp__L_e
# TRPTRS: atp_c + trnatrp_c + trp__L_c --> amp_c + ppi_c + trptrna_c
# TYRTRS: atp_c + trnatyr_c + tyr__L_c --> amp_c + ppi_c + tyrtrna_c
# UAGALDP: acgal1p_c + h_c + utp_c --> ppi_c + udpacgal_c
# UREAHYDL: urea_c <=> cynamd_c + h2o_c
# VALTRS: atp_c + trnaval_c + val__L_c --> amp_c + ppi_c + valtrna_c
# VLDPP: h2o_c + valleu_c --> leu__L_c + val__L_c
# VPDPP: h2o_c + valpro_c --> pro__L_c + val__L_c
# VYDPP: h2o_c + valtyr_c --> tyr__L_c + val__L_c
# XNTHRNSYN: 42a3hp24db_c + h_c --> h2o_c + xanthurn_c
# XOLEST2EH: h2o_c + xolest2_hs_c --> FA_hs_c + chsterol_c + h_c
# YYDPP: h2o_c + tyrtyr_c --> 2.0 tyr__L_c
# YYYTPAP: h2o_c + tyrtyrtyr_c --> tyr__L_c + tyrtyr_c

# %% [markdown]
# ### Ensure correct types before export

# %%
# SBML will not export charges correctly if they are float
for metabolite in model.metabolites:
    metabolite.charge = int(metabolite.charge)

# %% [markdown]
# ### Export model

# %%
write_cobra_model(
    filename=get_dirpath("model", use_temp="interim" if not overwrite else None)
    / f"{model.id}.xml"
)
write_cobra_model(
    filename=get_dirpath("model", use_temp="interim" if not overwrite else None)
    / f"{model.id}.json"
)
model
# Out:
# <Model RBC_GEM at 0x14a880c50>

# %%
print(f"Genes: {len(set([x.id for x in model.genes]))}")
print(f"Metabolites (all): {len(set([x.id for x in model.metabolites]))}")
nmets_unique = len({x.id.replace(f"_{x.compartment}", "") for x in model.metabolites})
print(f"Metabolites (unique): {nmets_unique}")
print(
    f"Reactions: {len(set([x.id for x in model.reactions.query(lambda x: not x.boundary)]))}"
)
# Out:
# Genes: 820
# Metabolites (all): 2157
# Metabolites (unique): 1685
# Reactions: 2725
