# %% [markdown]
# # Extract annotation information from UniProt
#
# Note: Requires internet connection to download information from the UniProt.
#
# ## Setup
# ### Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

from rbc_gem_utils import (
    COBRA_CONFIGURATION,
    ROOT_PATH,
    DATABASE_PATH,
    ANNOTATION_PATH,
    INTERIM_PATH,
    read_rbc_model,
    show_versions,
    get_annotation_df,
    compare_tables,
    visualize_comparison,
)
from rbc_gem_utils.database.uniprot import (
    UNIPROT_ISOFORM_ID_RE,
    UNIPROT_EXPECTED_VERSION,
    get_version_UniProt,
    query_UniProt,
    get_annotation_to_fromdb_UniProt,
    get_query_fields_UniProt,
    get_label_miriam_mapping_UniProt,
    get_query_fields_UniProt,
    parse_isoforms_UniProt,
    get_isoform_value_from_entry_UniProt,
)

# Display versions of last time notebook ran and worked
show_versions()
# Out:
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# cobra      0.29.0
# depinfo     2.2.0
# matplotlib  3.8.2
# memote     0.16.1
# notebook    7.0.6
# requests   2.31.0
# scipy      1.11.4
# seaborn    0.13.0
#
# Build Tools Information
# -----------------------
# pip        23.3.1
# setuptools 68.2.2
# wheel      0.41.2
#
# Platform Information
# --------------------
# Darwin  22.6.0-x86_64
# CPython        3.12.0

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -1000.0
# upper_bound: 1000.0
# processes: 15
# cache_directory: /Users/zhaiman/Library/Caches/cobrapy
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## Check UniProt version
# If the UniProt version does not match the expected version, it is because UniProt has been updated since the last time this code was utilized.
#
# ### Expected UniProt version: 2023_05
# * According to [UniProt](https://www.uniprot.org/help/downloads), updates to the database are made every eight weeks.
# * Last release utilized: [2023_05](https://www.uniprot.org/uniprotkb/statistics) published on **Wed Nov 08 2023**.

# %%
version = get_version_UniProt()
try:
    assert UNIPROT_EXPECTED_VERSION == version, "Expected and retrieved versions are not the same"
except AssertionError as e:
    warn("Expected and retrieved versions are not the same")
    print(f"Expected UniProt version: {UNIPROT_EXPECTED_VERSION}")
    print(f"Retrieved UniProt version {version}.")
else:
    print("Retrieved version matches expected version.")
# Out:
# Retrieved version matches expected version.

# %%
if UNIPROT_EXPECTED_VERSION != version:
    # Use different directory paths for unexpected behavior
    database_dirpath = f"{ROOT_PATH}{INTERIM_PATH}" 
    annotation_dirpath = f"{ROOT_PATH}{INTERIM_PATH}"
else:
    database_dirpath = f"{ROOT_PATH}{DATABASE_PATH}"
    annotation_dirpath = f"{ROOT_PATH}{ANNOTATION_PATH}"

# %% [markdown]
# ## Load RBC-GEM model
# ### Current Version: 0.2.0

# %%
model = read_rbc_model(filetype="xml")
model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-28
# <Model iAB_RBC_283 at 0x144f5b7a0>

# %% [markdown]
# ## Download data from UniProt
#
# ### Get IDs for query
# #### Using a customized method

# %%
from_db = "GeneID"   # From NCBI Gene ID

annotation_type = "genes"
annotation_key = "custom"

df_model = pd.DataFrame.from_dict({
    gene.id: gene.id.split("_AT")[0] for gene in model.genes
}, orient="index", columns=[annotation_key])
df_model.index.name = annotation_type
df_model = df_model.reset_index(drop=False)


query_ids = df_model[annotation_key].unique()
assert len(set(query_ids)) == len(query_ids), "Duplicate IDs in list to query"
model_search_mapping = df_model.set_index(annotation_type)[annotation_key].to_dict()
print(f"Number of model genes associated with query: {len(model_search_mapping)}")
print(f"Number of unique IDs to query: {len(query_ids)}")
# Out:
# Number of model genes associated with query: 349
# Number of unique IDs to query: 283

# %% [markdown]
# ### Set universal query parameters

# %%
miriam_query_fields = get_query_fields_UniProt(miriam_only=True)
miriam_query_fields
# Out:
# ['accession',
#  'gene_primary',
#  'organism_id',
#  'cc_alternative_products',
#  'uniparc_id',
#  'xref_ccds',
#  'xref_embl',
#  'xref_refseq',
#  'xref_bmrb',
#  'xref_pdb',
#  'xref_sasbdb',
#  'xref_smr',
#  'xref_biogrid',
#  'xref_corum',
#  'xref_complexportal',
#  'xref_dip',
#  'xref_elm',
#  'xref_intact',
#  'xref_mint',
#  'xref_string',
#  'xref_bindingdb',
#  'xref_chembl',
#  'xref_drugbank',
#  'xref_drugcentral',
#  'xref_swisslipids',
#  'xref_allergome',
#  'xref_cazy',
#  'xref_ideal',
#  'xref_merops',
#  'xref_peroxibase',
#  'xref_rebase',
#  'xref_tcdb',
#  'xref_depod',
#  'xref_phosphositeplus',
#  'xref_dbsnp',
#  'xref_compluyeast-2dpage',
#  'xref_epd',
#  'xref_massive',
#  'xref_maxqb',
#  'xref_pride',
#  'xref_paxdb',
#  'xref_peptideatlas',
#  'xref_proteomicsdb',
#  'xref_ensembl',
#  'xref_geneid',
#  'xref_kegg',
#  'xref_ctd',
#  'xref_genecards',
#  'xref_hgnc',
#  'xref_hpa',
#  'xref_mim',
#  'xref_nextprot',
#  'xref_orphanet',
#  'xref_pharmgkb',
#  'xref_eggnog',
#  'xref_genetree',
#  'xref_hogenom',
#  'xref_oma',
#  'xref_orthodb',
#  'xref_phylomedb',
#  'xref_treefam',
#  'xref_biocyc',
#  'xref_brenda',
#  'xref_pathwaycommons',
#  'xref_reactome',
#  'xref_signor',
#  'xref_genewiki',
#  'xref_bgee',
#  'xref_expressionatlas',
#  'xref_cdd',
#  'xref_disprot',
#  'xref_hamap',
#  'xref_interpro',
#  'xref_panther',
#  'xref_pfam',
#  'xref_pirsf',
#  'xref_prints',
#  'xref_prodom',
#  'xref_prosite',
#  'xref_smart',
#  'xref_supfam']

# %%
# Extract all relevant information for now and save
query_parameters = {
    "query": " && ".join([
        "(reviewed:true)",
        "(organism_id:9606)", # Homo sapiens (Human)
    ]),
    "format": "tsv",
    "size": 500,
    "compressed": True,
    "fields": ",".join(miriam_query_fields) 
}

# %% [markdown]
# ## Run queries

# %%
database_tag = "UniProt"
compare = True
overwrite = True

all_query_results = {}

# %% [markdown]
# ### Initial query

# %%
query_key = "initial"
df_results, failed_ids = query_UniProt(
    query_ids, 
    query_parameters=query_parameters,
    from_db="GeneID", 

)
if failed_ids:
    print(failed_ids)
all_query_results[query_key] = df_results
df_results
# Out:
# Number of failed query IDs : 3
# Fetched: 280 / 280
# ['2713', '2974', '6526']
#       From   Entry Gene Names (primary) Organism (ID)  \
# 0     5138  O00408                PDE2A          9606
# 1     8789  O00757                 FBP2          9606
# 2     8566  O00764                 PDXK          9606
# 3     8611  O14494                PLPP1          9606
# 4     8613  O14495                PLPP3          9606
# ..     ...     ...                  ...           ...
# 275   9468  Q9Y5K3               PCYT1B          9606
# 276  10723  Q9Y666              SLC12A7          9606
# 277  10390  Q9Y6K0                CEPT1          9606
# 278  10599  Q9Y6L6              SLCO1B1          9606
# 279   1607  Q9Y6T7                 DGKB          9606
#
#                        Alternative products (isoforms)        UniParc  \
# 0    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000003B340
# 1                              ALTERNATIVE PRODUCTS:    UPI000013CDC2
# 2    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000131524
# 3    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000073CF9
# 4                              ALTERNATIVE PRODUCTS:    UPI000006F261
# ..                                                 ...            ...
# 275  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000012864E
# 276  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000141815
# 277                            ALTERNATIVE PRODUCTS:    UPI0000062325
# 278                            ALTERNATIVE PRODUCTS:    UPI0000043BED
# 279  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000033B9B
#
#                                                   CCDS  \
# 0    CCDS44670.1 [O00408-3];CCDS53678.1 [O00408-4];...
# 1                                          CCDS6711.1;
# 2                              CCDS13699.1 [O00764-1];
# 3       CCDS34159.1 [O14494-1];CCDS34160.1 [O14494-2];
# 4                                           CCDS604.1;
# ..                                                 ...
# 275  CCDS14213.1 [Q9Y5K3-1];CCDS55391.1 [Q9Y5K3-2];...
# 276                            CCDS34129.1 [Q9Y666-1];
# 277                                         CCDS830.1;
# 278                                        CCDS8685.1;
# 279     CCDS47547.1 [Q9Y6T7-1];CCDS47548.1 [Q9Y6T7-2];
#
#                                                   EMBL  \
# 0    U67733;AY495087;AY495088;AY495089;AK092278;AK1...
# 1          Y10812;CR536483;AL161728;BC113632;BC117477;
# 2          U89606;AY303972;AP001752;BC000123;BC005825;
# 3    AB000888;AF014402;AF014403;Y14436;AF017116;AC0...
# 4    AB000889;AF017786;AF480883;AF043329;U79294;AK3...
# ..                                                 ...
# 275  AF052510;AF148464;AK296333;AK315323;EU181262;A...
# 276  AF105365;AC116351;BC007760;BC098390;AK024493;A...
# 277  AF068302;AF138862;AL355816;BC032610;BC049196;A...
# 278  AF060500;AF205071;AJ132573;AB026257;AJ400749;A...
# 279  AX032742;AC005039;AC005248;AC006150;AC011229;A...
#
#                                                 RefSeq BMRB  ...      HAMAP  \
# 0    NP_001137311.1 [O00408-3];NP_001139681.1 [O004...       ...
# 1                                         NP_003828.2;       ...  MF_01855;
# 2    NP_003672.1 [O00764-1];XP_005261256.1 [O00764-...       ...
# 3       NP_003702.2 [O14494-1];NP_795714.1 [O14494-2];       ...
# 4                                         NP_003704.3;       ...
# ..                                                 ...  ...  ...        ...
# 275  NP_001156736.1 [Q9Y5K3-4];NP_001156737.1 [Q9Y5...       ...
# 276                            NP_006589.2 [Q9Y666-1];       ...
# 277         NP_001007795.1;NP_001317672.1;NP_006081.1;       ...
# 278                                       NP_006437.3;       ...
# 279  NP_004071.1;NP_663733.1 [Q9Y6T7-2];XP_00524968...       ...
#
#                                               InterPro  \
# 0    IPR003018;IPR029016;IPR003607;IPR023088;IPR002...
# 1    IPR044015;IPR000146;IPR033391;IPR028343;IPR020...
# 2                       IPR013749;IPR004625;IPR029056;
# 3                       IPR036938;IPR000326;IPR043216;
# 4                       IPR036938;IPR000326;IPR043216;
# ..                                                 ...
# 275           IPR041723;IPR004821;IPR045049;IPR014729;
# 276           IPR004841;IPR000076;IPR018491;IPR004842;
# 277                     IPR000462;IPR043130;IPR014472;
# 278  IPR002350;IPR036058;IPR020846;IPR036259;IPR004...
# 279  IPR017438;IPR046349;IPR047471;IPR047470;IPR029...
#
#                         PANTHER                                      Pfam  \
# 0    PTHR11347:SF102;PTHR11347;                  PF01590;PF13185;PF00233;
# 1     PTHR11556:SF13;PTHR11556;                          PF00316;PF18913;
# 2      PTHR10534;PTHR10534:SF2;                                  PF08543;
# 3     PTHR10165;PTHR10165:SF26;                                  PF01569;
# 4     PTHR10165;PTHR10165:SF79;                                  PF01569;
# ..                          ...                                       ...
# 275   PTHR10739:SF20;PTHR10739;                                  PF01467;
# 276   PTHR11827:SF47;PTHR11827;                          PF00324;PF03522;
# 277   PTHR10414:SF27;PTHR10414;                                  PF01066;
# 278   PTHR11388;PTHR11388:SF82;                          PF07648;PF03137;
# 279   PTHR11255;PTHR11255:SF32;  PF00130;PF14513;PF00609;PF00781;PF13499;
#
#                         PIRSF    PRINTS ProDom  \
# 0                              PR00387;
# 1    PIRSF500210;PIRSF000904;  PR00115;
# 2
# 3
# 4
# ..                        ...       ...    ...
# 275
# 276                            PR01081;
# 277              PIRSF015665;
# 278
# 279
#
#                                       PROSITE  \
# 0                            PS00126;PS51845;
# 1                                    PS00124;
# 2
# 3
# 4
# ..                                        ...
# 275
# 276
# 277                                  PS00379;
# 278                          PS51465;PS50850;
# 279  PS50146;PS00018;PS50222;PS00479;PS50081;
#
#                                 SMART                        SUPFAM
# 0                    SM00065;SM00471;           SSF55781;SSF109604;
# 1                                                         SSF56655;
# 2                                                         SSF53613;
# 3                            SM00014;                     SSF48317;
# 4                            SM00014;                     SSF48317;
# ..                                ...                           ...
# 275                                                       SSF52374;
# 276
# 277
# 278                                            SSF100895;SSF103473;
# 279  SM00109;SM00045;SM00046;SM00054;  SSF57889;SSF47473;SSF111331;
#
# [280 rows x 82 columns]

# %% [markdown]
# ### Address failed IDs
# IDs that failed mapping are all pseudogenes in this case.
# They have UniProt IDs that can be looked up.

# %%
retry_ids = {
    # Failed ID, new ID
    "2713": "Q14409",
    "2974": "O75343",
    "6526": "P53794",
}

# %%
query_key = "retry_1"
df_results, failed_ids = query_UniProt(
    list(sorted(retry_ids.values())), 
    from_db="UniProtKB", 
    query_parameters=query_parameters
)
if failed_ids:
    print(failed_ids)
all_query_results[query_key] = df_results
model_search_mapping.update({
    k: retry_ids[v] for k, v in model_search_mapping.items()
    if v in retry_ids and v not in failed_ids
})
df_results
# Out:
# Fetched: 3 / 3
#      From   Entry Gene Names (primary) Organism (ID)  \
# 0  O75343  O75343              GUCY1B2          9606
# 1  P53794  P53794               SLC5A3          9606
# 2  Q14409  Q14409                  GK3          9606
#
#   Alternative products (isoforms)        UniParc          CCDS  \
# 0         ALTERNATIVE PRODUCTS:    UPI0000128C13
# 1         ALTERNATIVE PRODUCTS:    UPI0000EE4C60  CCDS33549.1;
# 2         ALTERNATIVE PRODUCTS:    UPI000013EB4C
#
#                         EMBL RefSeq BMRB  ... HAMAP  \
# 0         AF038499;AF218383;              ...
# 1  L38500;AF027153;AP001719;              ...
# 2  X78711;AC107059;BC066960;              ...
#
#                                             InterPro  \
# 0  IPR001054;IPR018297;IPR038158;IPR011644;IPR011...
# 1           IPR038377;IPR001734;IPR018212;IPR042731;
# 2  IPR043129;IPR000577;IPR018485;IPR018483;IPR018...
#
#                       PANTHER                      Pfam         PIRSF PRINTS  \
# 0   PTHR45655;PTHR45655:SF17;  PF00211;PF07700;PF07701;
# 1  PTHR11819:SF150;PTHR11819;                  PF00474;
# 2   PTHR10196:SF95;PTHR10196;          PF02782;PF00370;  PIRSF000538;
#
#   ProDom                   PROSITE     SMART               SUPFAM
# 0                 PS00452;PS50125;  SM00044;  SSF111126;SSF55073;
# 1         PS00456;PS00457;PS50283;
# 2                 PS00933;PS00445;                      SSF53067;
#
# [3 rows x 82 columns]

# %% [markdown]
# ## Map query results to model
# ### Concat and cleanup query results

# %%
print(f"Number of unique queries: {len(all_query_results)}")
df_query_results = pd.concat(tuple(all_query_results.values()))
df_query_results = df_query_results.set_index("From").drop_duplicates()
df_query_results = df_query_results.replace("", float("nan"))
df_query_results
# Out:
# Number of unique queries: 2
#          Entry Gene Names (primary) Organism (ID)  \
# From
# 5138    O00408                PDE2A          9606
# 8789    O00757                 FBP2          9606
# 8566    O00764                 PDXK          9606
# 8611    O14494                PLPP1          9606
# 8613    O14495                PLPP3          9606
# ...        ...                  ...           ...
# 10599   Q9Y6L6              SLCO1B1          9606
# 1607    Q9Y6T7                 DGKB          9606
# O75343  O75343              GUCY1B2          9606
# P53794  P53794               SLC5A3          9606
# Q14409  Q14409                  GK3          9606
#
#                           Alternative products (isoforms)        UniParc  \
# From
# 5138    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000003B340
# 8789                              ALTERNATIVE PRODUCTS:    UPI000013CDC2
# 8566    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000131524
# 8611    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000073CF9
# 8613                              ALTERNATIVE PRODUCTS:    UPI000006F261
# ...                                                   ...            ...
# 10599                             ALTERNATIVE PRODUCTS:    UPI0000043BED
# 1607    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000033B9B
# O75343                            ALTERNATIVE PRODUCTS:    UPI0000128C13
# P53794                            ALTERNATIVE PRODUCTS:    UPI0000EE4C60
# Q14409                            ALTERNATIVE PRODUCTS:    UPI000013EB4C
#
#                                                      CCDS  \
# From
# 5138    CCDS44670.1 [O00408-3];CCDS53678.1 [O00408-4];...
# 8789                                          CCDS6711.1;
# 8566                              CCDS13699.1 [O00764-1];
# 8611       CCDS34159.1 [O14494-1];CCDS34160.1 [O14494-2];
# 8613                                           CCDS604.1;
# ...                                                   ...
# 10599                                         CCDS8685.1;
# 1607       CCDS47547.1 [Q9Y6T7-1];CCDS47548.1 [Q9Y6T7-2];
# O75343                                                NaN
# P53794                                       CCDS33549.1;
# Q14409                                                NaN
#
#                                                      EMBL  \
# From
# 5138    U67733;AY495087;AY495088;AY495089;AK092278;AK1...
# 8789          Y10812;CR536483;AL161728;BC113632;BC117477;
# 8566          U89606;AY303972;AP001752;BC000123;BC005825;
# 8611    AB000888;AF014402;AF014403;Y14436;AF017116;AC0...
# 8613    AB000889;AF017786;AF480883;AF043329;U79294;AK3...
# ...                                                   ...
# 10599   AF060500;AF205071;AJ132573;AB026257;AJ400749;A...
# 1607    AX032742;AC005039;AC005248;AC006150;AC011229;A...
# O75343                                 AF038499;AF218383;
# P53794                          L38500;AF027153;AP001719;
# Q14409                          X78711;AC107059;BC066960;
#
#                                                    RefSeq BMRB  \
# From
# 5138    NP_001137311.1 [O00408-3];NP_001139681.1 [O004...  NaN
# 8789                                         NP_003828.2;  NaN
# 8566    NP_003672.1 [O00764-1];XP_005261256.1 [O00764-...  NaN
# 8611       NP_003702.2 [O14494-1];NP_795714.1 [O14494-2];  NaN
# 8613                                         NP_003704.3;  NaN
# ...                                                   ...  ...
# 10599                                        NP_006437.3;  NaN
# 1607    NP_004071.1;NP_663733.1 [Q9Y6T7-2];XP_00524968...  NaN
# O75343                                                NaN  NaN
# P53794                                                NaN  NaN
# Q14409                                                NaN  NaN
#
#                                                       PDB  ...      HAMAP  \
# From                                                       ...
# 5138    1Z1L;3IBJ;3ITM;3ITU;4C1I;4D08;4D09;4HTX;4HTZ;4...  ...        NaN
# 8789    3IFA;3IFC;4HE0;4HE1;4HE2;5ET5;5ET6;5ET7;5ET8;5...  ...  MF_01855;
# 8566        2AJP;2F7K;2YXT;2YXU;3FHX;3FHY;3KEU;4EN4;4EOH;  ...        NaN
# 8611                                                  NaN  ...        NaN
# 8613                                                  NaN  ...        NaN
# ...                                                   ...  ...        ...
# 10599                                                 NaN  ...        NaN
# 1607                                                  NaN  ...        NaN
# O75343                                                NaN  ...        NaN
# P53794                                                NaN  ...        NaN
# Q14409                                                NaN  ...        NaN
#
#                                                  InterPro  \
# From
# 5138    IPR003018;IPR029016;IPR003607;IPR023088;IPR002...
# 8789    IPR044015;IPR000146;IPR033391;IPR028343;IPR020...
# 8566                       IPR013749;IPR004625;IPR029056;
# 8611                       IPR036938;IPR000326;IPR043216;
# 8613                       IPR036938;IPR000326;IPR043216;
# ...                                                   ...
# 10599   IPR002350;IPR036058;IPR020846;IPR036259;IPR004...
# 1607    IPR017438;IPR046349;IPR047471;IPR047470;IPR029...
# O75343  IPR001054;IPR018297;IPR038158;IPR011644;IPR011...
# P53794           IPR038377;IPR001734;IPR018212;IPR042731;
# Q14409  IPR043129;IPR000577;IPR018485;IPR018483;IPR018...
#
#                            PANTHER                                      Pfam  \
# From
# 5138    PTHR11347:SF102;PTHR11347;                  PF01590;PF13185;PF00233;
# 8789     PTHR11556:SF13;PTHR11556;                          PF00316;PF18913;
# 8566      PTHR10534;PTHR10534:SF2;                                  PF08543;
# 8611     PTHR10165;PTHR10165:SF26;                                  PF01569;
# 8613     PTHR10165;PTHR10165:SF79;                                  PF01569;
# ...                            ...                                       ...
# 10599    PTHR11388;PTHR11388:SF82;                          PF07648;PF03137;
# 1607     PTHR11255;PTHR11255:SF32;  PF00130;PF14513;PF00609;PF00781;PF13499;
# O75343   PTHR45655;PTHR45655:SF17;                  PF00211;PF07700;PF07701;
# P53794  PTHR11819:SF150;PTHR11819;                                  PF00474;
# Q14409   PTHR10196:SF95;PTHR10196;                          PF02782;PF00370;
#
#                            PIRSF    PRINTS ProDom  \
# From
# 5138                         NaN  PR00387;    NaN
# 8789    PIRSF500210;PIRSF000904;  PR00115;    NaN
# 8566                         NaN       NaN    NaN
# 8611                         NaN       NaN    NaN
# 8613                         NaN       NaN    NaN
# ...                          ...       ...    ...
# 10599                        NaN       NaN    NaN
# 1607                         NaN       NaN    NaN
# O75343                       NaN       NaN    NaN
# P53794                       NaN       NaN    NaN
# Q14409              PIRSF000538;       NaN    NaN
#
#                                          PROSITE  \
# From
# 5138                            PS00126;PS51845;
# 8789                                    PS00124;
# 8566                                         NaN
# 8611                                         NaN
# 8613                                         NaN
# ...                                          ...
# 10599                           PS51465;PS50850;
# 1607    PS50146;PS00018;PS50222;PS00479;PS50081;
# O75343                          PS00452;PS50125;
# P53794                  PS00456;PS00457;PS50283;
# Q14409                          PS00933;PS00445;
#
#                                    SMART                        SUPFAM
# From
# 5138                    SM00065;SM00471;           SSF55781;SSF109604;
# 8789                                 NaN                     SSF56655;
# 8566                                 NaN                     SSF53613;
# 8611                            SM00014;                     SSF48317;
# 8613                            SM00014;                     SSF48317;
# ...                                  ...                           ...
# 10599                                NaN          SSF100895;SSF103473;
# 1607    SM00109;SM00045;SM00046;SM00054;  SSF57889;SSF47473;SSF111331;
# O75343                          SM00044;           SSF111126;SSF55073;
# P53794                               NaN                           NaN
# Q14409                               NaN                     SSF53067;
#
# [283 rows x 81 columns]

# %% [markdown]
# ### Save extracted data to database

# %%
df_database = df_query_results.reset_index(drop=True).drop_duplicates()
if compare:
    try:
        df_previous = pd.read_csv(
            f"{database_dirpath}/{database_tag}_{version}.tsv", 
            sep="\t", 
            index_col=0,
            dtype=str,
        )
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=["Entry"], dtype=str)
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    df_comparision = compare_tables(
        df_previous.set_index("Entry"),
        df_database.set_index("Entry")
    )
    ax = visualize_comparison(df_comparision)

if overwrite:
    df_database.to_csv(f"{database_dirpath}/{database_tag}_{version}.tsv", sep="\t")
else:
    df_database.to_csv(f"{ROOT_PATH}{INTERIM_PATH}/{database_tag}_{version}.tsv", sep="\t")
df_database
# Out:
#       Entry Gene Names (primary) Organism (ID)  \
# 0    O00408                PDE2A          9606
# 1    O00757                 FBP2          9606
# 2    O00764                 PDXK          9606
# 3    O14494                PLPP1          9606
# 4    O14495                PLPP3          9606
# ..      ...                  ...           ...
# 278  Q9Y6L6              SLCO1B1          9606
# 279  Q9Y6T7                 DGKB          9606
# 280  O75343              GUCY1B2          9606
# 281  P53794               SLC5A3          9606
# 282  Q14409                  GK3          9606
#
#                        Alternative products (isoforms)        UniParc  \
# 0    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000003B340
# 1                              ALTERNATIVE PRODUCTS:    UPI000013CDC2
# 2    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000131524
# 3    ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000073CF9
# 4                              ALTERNATIVE PRODUCTS:    UPI000006F261
# ..                                                 ...            ...
# 278                            ALTERNATIVE PRODUCTS:    UPI0000043BED
# 279  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000033B9B
# 280                            ALTERNATIVE PRODUCTS:    UPI0000128C13
# 281                            ALTERNATIVE PRODUCTS:    UPI0000EE4C60
# 282                            ALTERNATIVE PRODUCTS:    UPI000013EB4C
#
#                                                   CCDS  \
# 0    CCDS44670.1 [O00408-3];CCDS53678.1 [O00408-4];...
# 1                                          CCDS6711.1;
# 2                              CCDS13699.1 [O00764-1];
# 3       CCDS34159.1 [O14494-1];CCDS34160.1 [O14494-2];
# 4                                           CCDS604.1;
# ..                                                 ...
# 278                                        CCDS8685.1;
# 279     CCDS47547.1 [Q9Y6T7-1];CCDS47548.1 [Q9Y6T7-2];
# 280                                                NaN
# 281                                       CCDS33549.1;
# 282                                                NaN
#
#                                                   EMBL  \
# 0    U67733;AY495087;AY495088;AY495089;AK092278;AK1...
# 1          Y10812;CR536483;AL161728;BC113632;BC117477;
# 2          U89606;AY303972;AP001752;BC000123;BC005825;
# 3    AB000888;AF014402;AF014403;Y14436;AF017116;AC0...
# 4    AB000889;AF017786;AF480883;AF043329;U79294;AK3...
# ..                                                 ...
# 278  AF060500;AF205071;AJ132573;AB026257;AJ400749;A...
# 279  AX032742;AC005039;AC005248;AC006150;AC011229;A...
# 280                                 AF038499;AF218383;
# 281                          L38500;AF027153;AP001719;
# 282                          X78711;AC107059;BC066960;
#
#                                                 RefSeq BMRB  \
# 0    NP_001137311.1 [O00408-3];NP_001139681.1 [O004...  NaN
# 1                                         NP_003828.2;  NaN
# 2    NP_003672.1 [O00764-1];XP_005261256.1 [O00764-...  NaN
# 3       NP_003702.2 [O14494-1];NP_795714.1 [O14494-2];  NaN
# 4                                         NP_003704.3;  NaN
# ..                                                 ...  ...
# 278                                       NP_006437.3;  NaN
# 279  NP_004071.1;NP_663733.1 [Q9Y6T7-2];XP_00524968...  NaN
# 280                                                NaN  NaN
# 281                                                NaN  NaN
# 282                                                NaN  NaN
#
#                                                    PDB  ...      HAMAP  \
# 0    1Z1L;3IBJ;3ITM;3ITU;4C1I;4D08;4D09;4HTX;4HTZ;4...  ...        NaN
# 1    3IFA;3IFC;4HE0;4HE1;4HE2;5ET5;5ET6;5ET7;5ET8;5...  ...  MF_01855;
# 2        2AJP;2F7K;2YXT;2YXU;3FHX;3FHY;3KEU;4EN4;4EOH;  ...        NaN
# 3                                                  NaN  ...        NaN
# 4                                                  NaN  ...        NaN
# ..                                                 ...  ...        ...
# 278                                                NaN  ...        NaN
# 279                                                NaN  ...        NaN
# 280                                                NaN  ...        NaN
# 281                                                NaN  ...        NaN
# 282                                                NaN  ...        NaN
#
#                                               InterPro  \
# 0    IPR003018;IPR029016;IPR003607;IPR023088;IPR002...
# 1    IPR044015;IPR000146;IPR033391;IPR028343;IPR020...
# 2                       IPR013749;IPR004625;IPR029056;
# 3                       IPR036938;IPR000326;IPR043216;
# 4                       IPR036938;IPR000326;IPR043216;
# ..                                                 ...
# 278  IPR002350;IPR036058;IPR020846;IPR036259;IPR004...
# 279  IPR017438;IPR046349;IPR047471;IPR047470;IPR029...
# 280  IPR001054;IPR018297;IPR038158;IPR011644;IPR011...
# 281           IPR038377;IPR001734;IPR018212;IPR042731;
# 282  IPR043129;IPR000577;IPR018485;IPR018483;IPR018...
#
#                         PANTHER                                      Pfam  \
# 0    PTHR11347:SF102;PTHR11347;                  PF01590;PF13185;PF00233;
# 1     PTHR11556:SF13;PTHR11556;                          PF00316;PF18913;
# 2      PTHR10534;PTHR10534:SF2;                                  PF08543;
# 3     PTHR10165;PTHR10165:SF26;                                  PF01569;
# 4     PTHR10165;PTHR10165:SF79;                                  PF01569;
# ..                          ...                                       ...
# 278   PTHR11388;PTHR11388:SF82;                          PF07648;PF03137;
# 279   PTHR11255;PTHR11255:SF32;  PF00130;PF14513;PF00609;PF00781;PF13499;
# 280   PTHR45655;PTHR45655:SF17;                  PF00211;PF07700;PF07701;
# 281  PTHR11819:SF150;PTHR11819;                                  PF00474;
# 282   PTHR10196:SF95;PTHR10196;                          PF02782;PF00370;
#
#                         PIRSF    PRINTS ProDom  \
# 0                         NaN  PR00387;    NaN
# 1    PIRSF500210;PIRSF000904;  PR00115;    NaN
# 2                         NaN       NaN    NaN
# 3                         NaN       NaN    NaN
# 4                         NaN       NaN    NaN
# ..                        ...       ...    ...
# 278                       NaN       NaN    NaN
# 279                       NaN       NaN    NaN
# 280                       NaN       NaN    NaN
# 281                       NaN       NaN    NaN
# 282              PIRSF000538;       NaN    NaN
#
#                                       PROSITE  \
# 0                            PS00126;PS51845;
# 1                                    PS00124;
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 278                          PS51465;PS50850;
# 279  PS50146;PS00018;PS50222;PS00479;PS50081;
# 280                          PS00452;PS50125;
# 281                  PS00456;PS00457;PS50283;
# 282                          PS00933;PS00445;
#
#                                 SMART                        SUPFAM
# 0                    SM00065;SM00471;           SSF55781;SSF109604;
# 1                                 NaN                     SSF56655;
# 2                                 NaN                     SSF53613;
# 3                            SM00014;                     SSF48317;
# 4                            SM00014;                     SSF48317;
# ..                                ...                           ...
# 278                               NaN          SSF100895;SSF103473;
# 279  SM00109;SM00045;SM00046;SM00054;  SSF57889;SSF47473;SSF111331;
# 280                          SM00044;           SSF111126;SSF55073;
# 281                               NaN                           NaN
# 282                               NaN                     SSF53067;
#
# [283 rows x 81 columns]

# %%
df_model = pd.DataFrame.from_dict(
    {"From": model_search_mapping}, 
    orient="columns", 
)
df_model.index.name = annotation_type
df_model = df_model.reset_index(drop=False)
df_annotations = pd.merge(df_model, df_query_results, left_on="From", right_index=True, how="outer")
df_annotations = df_annotations.drop(["From"], axis=1).set_index("genes")
df_annotations
# Out:
#             Entry Gene Names (primary) Organism (ID)  \
# genes
# 10007_AT1  P46926               GNPDA1          9606
# 100_AT1    P00813                  ADA          9606
# 10201_AT1  O75414                 NME6          9606
# 10257_AT1  O15439                ABCC4          9606
# 10327_AT1  P14550               AKR1A1          9606
# ...           ...                  ...           ...
# 8867_AT2   O43426                SYNJ1          9606
# 9162_AT1   O75912                 DGKI          9606
# 9429_AT1   Q9UNQ0                ABCG2          9606
# 9468_AT1   Q9Y5K3               PCYT1B          9606
# 9942_AT1   O75191                 XYLB          9606
#
#                              Alternative products (isoforms)        UniParc  \
# genes
# 10007_AT1  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000004D014
# 100_AT1                              ALTERNATIVE PRODUCTS:    UPI000000D982
# 10201_AT1  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000012FE8A
# 10257_AT1  ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI00001A36E6
# 10327_AT1                            ALTERNATIVE PRODUCTS:    UPI000013D31D
# ...                                                      ...            ...
# 8867_AT2   ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000206D91
# 9162_AT1                             ALTERNATIVE PRODUCTS:    UPI000012DD23
# 9429_AT1   ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000001275
# 9468_AT1   ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI000012864E
# 9942_AT1   ALTERNATIVE PRODUCTS:  Event=Alternative splic...  UPI0000160544
#
#                                                         CCDS  \
# genes
# 10007_AT1                             CCDS4272.1 [P46926-1];
# 100_AT1                                         CCDS13335.1;
# 10201_AT1  CCDS77733.1 [O75414-3];CCDS77734.1 [O75414-1];...
# 10257_AT1  CCDS45061.1 [O15439-3];CCDS76643.1 [O15439-4];...
# 10327_AT1                                         CCDS523.1;
# ...                                                      ...
# 8867_AT2      CCDS33540.3 [O43426-2];CCDS54483.1 [O43426-4];
# 9162_AT1                                         CCDS5845.1;
# 9429_AT1       CCDS3628.1 [Q9UNQ0-1];CCDS58910.1 [Q9UNQ0-2];
# 9468_AT1   CCDS14213.1 [Q9Y5K3-1];CCDS55391.1 [Q9Y5K3-2];...
# 9942_AT1                              CCDS2678.1 [O75191-1];
#
#                                                         EMBL  \
# genes
# 10007_AT1  AF048826;AJ002231;AF029914;AF035809;AF035804;A...
# 100_AT1    X02994;X02189;X02190;X02191;X02192;X02193;X021...
# 10201_AT1  AF051941;U90449;AK294809;AK297364;AK222555;AC1...
# 10257_AT1  AF071202;AY081219;AY207008;AF541977;AK296247;A...
# 10327_AT1  J04794;AF036683;AF036680;AF036681;AF036682;AF1...
# ...                                                      ...
# 8867_AT2   AF009039;AF009040;AB020717;AP000275;AP000276;A...
# 9162_AT1                         AF061936;CH236950;AH009185;
# 9429_AT1   AF103796;AF098951;AB056867;AB051855;AY017168;A...
# 9468_AT1   AF052510;AF148464;AK296333;AK315323;EU181262;A...
# 9942_AT1   AK293325;AK314386;AP006191;AP006193;CH471055;B...
#
#                                                       RefSeq BMRB  \
# genes
# 10007_AT1  NP_005462.1 [P46926-1];XP_006714810.1 [P46926-...  NaN
# 100_AT1                                         NP_000013.2;  NaN
# 10201_AT1  NP_001295355.1 [O75414-1];NP_001295356.1 [O754...  NaN
# 10257_AT1  NP_001098985.1 [O15439-3];NP_001288758.1 [O154...  NaN
# 10327_AT1  NP_001189342.1;NP_001189343.1;NP_006057.1;NP_6...  NaN
# ...                                                      ...  ...
# 8867_AT2   NP_001153774.1 [O43426-4];NP_001153778.1;NP_00...  NaN
# 9162_AT1   NP_001308637.1;NP_001308638.1;NP_001308639.1;N...  NaN
# 9429_AT1   NP_001244315.1 [Q9UNQ0-2];NP_004818.2 [Q9UNQ0-...  NaN
# 9468_AT1   NP_001156736.1 [Q9Y5K3-4];NP_001156737.1 [Q9Y5...  NaN
# 9942_AT1                             NP_005099.2 [O75191-1];  NaN
#
#                                                          PDB  ...      HAMAP  \
# genes                                                         ...
# 10007_AT1                                              1NE7;  ...  MF_01241;
# 100_AT1                                           3IAR;7RTG;  ...  MF_00540;
# 10201_AT1                                                NaN  ...        NaN
# 10257_AT1                          8I4A;8I4B;8I4C;8J3W;8J3Z;  ...        NaN
# 10327_AT1                                              2ALR;  ...        NaN
# ...                                                      ...  ...        ...
# 8867_AT2                                1W80;2DNR;2VJ0;7A0V;  ...        NaN
# 9162_AT1                                                 NaN  ...        NaN
# 9429_AT1   5NJ3;5NJG;6ETI;6FEQ;6FFC;6HBU;6HCO;6HIJ;6HZM;6...  ...        NaN
# 9468_AT1                                                 NaN  ...        NaN
# 9942_AT1                                4BC2;4BC3;4BC4;4BC5;  ...        NaN
#
#                                                     InterPro  \
# genes
# 10007_AT1           IPR006148;IPR004547;IPR018321;IPR037171;
# 100_AT1    IPR006650;IPR028893;IPR001365;IPR006330;IPR032...
# 10201_AT1  IPR034907;IPR036850;IPR037994;IPR001564;IPR023...
# 10257_AT1  IPR003593;IPR011527;IPR036640;IPR003439;IPR017...
# 10327_AT1  IPR020471;IPR044481;IPR018170;IPR023210;IPR036...
# ...                                                      ...
# 8867_AT2   IPR036691;IPR005135;IPR046985;IPR000300;IPR012...
# 9162_AT1   IPR002110;IPR036770;IPR017438;IPR047486;IPR047...
# 9429_AT1   IPR003593;IPR013525;IPR003439;IPR043926;IPR027...
# 9468_AT1            IPR041723;IPR004821;IPR045049;IPR014729;
# 9942_AT1   IPR043129;IPR000577;IPR018485;IPR018484;IPR042...
#
#                               PANTHER                              Pfam  \
# genes
# 10007_AT1    PTHR11280;PTHR11280:SF8;                          PF01182;
# 100_AT1     PTHR11409;PTHR11409:SF43;                          PF00962;
# 10201_AT1    PTHR46956;PTHR46956:SF1;                          PF00334;
# 10257_AT1  PTHR24223;PTHR24223:SF357;                  PF00664;PF00005;
# 10327_AT1  PTHR11732:SF507;PTHR11732;                          PF00248;
# ...                               ...                               ...
# 8867_AT2   PTHR11200;PTHR11200:SF158;          PF08952;PF03372;PF02383;
# 9162_AT1    PTHR11255;PTHR11255:SF92;  PF12796;PF00130;PF00609;PF00781;
# 9429_AT1    PTHR48041;PTHR48041:SF92;          PF01061;PF19055;PF00005;
# 9468_AT1    PTHR10739:SF20;PTHR10739;                          PF01467;
# 9942_AT1    PTHR10196;PTHR10196:SF57;                  PF02782;PF00370;
#
#                   PIRSF    PRINTS ProDom                   PROSITE  \
# genes
# 10007_AT1           NaN       NaN    NaN                  PS01161;
# 100_AT1             NaN       NaN    NaN                  PS00485;
# 10201_AT1           NaN  PR01243;    NaN                  PS00469;
# 10257_AT1           NaN       NaN    NaN  PS50929;PS00211;PS50893;
# 10327_AT1  PIRSF000097;  PR00069;    NaN  PS00798;PS00062;PS00063;
# ...                 ...       ...    ...                       ...
# 8867_AT2            NaN       NaN    NaN          PS50102;PS50275;
# 9162_AT1            NaN       NaN    NaN  PS50297;PS50088;PS50146;
# 9429_AT1            NaN       NaN    NaN                  PS50893;
# 9468_AT1            NaN       NaN    NaN                       NaN
# 9942_AT1   PIRSF000538;       NaN    NaN                       NaN
#
#                                       SMART               SUPFAM
# genes
# 10007_AT1                               NaN           SSF100950;
# 100_AT1                                 NaN            SSF51556;
# 10201_AT1                          SM00562;            SSF54919;
# 10257_AT1                          SM00382;   SSF90123;SSF52540;
# 10327_AT1                               NaN            SSF51430;
# ...                                     ...                  ...
# 8867_AT2                   SM01165;SM00128;   SSF56219;SSF54928;
# 9162_AT1   SM00248;SM00109;SM00045;SM00046;  SSF48403;SSF111331;
# 9429_AT1                           SM00382;            SSF52540;
# 9468_AT1                                NaN            SSF52374;
# 9942_AT1                                NaN            SSF53067;
#
# [349 rows x 81 columns]

# %% [markdown]
# ### Format UniProt information for annotation files
# #### Map to chosen MIRIAMs
# As formatting may be needed for some MIRIAMS, keep it simple for now until formatting methods are developed.

# %%
# Keeping it simple for now, group items regardless of isoforms for the time being
uniprot_miriam_mapping = get_label_miriam_mapping_UniProt(get_query_fields_UniProt(miriam_only=True))
df_annotations = df_annotations.loc[:, list(uniprot_miriam_mapping)].rename(uniprot_miriam_mapping, axis=1)
df_annotations = df_annotations.loc[:, [
    "uniprot", 
    "uniprot.isoform",
    "hgnc.symbol",
    "ncbigene",
    "ccds",
    "refseq",
    "mim",
    "drugbank",
]]
df_annotations
# Out:
#           uniprot                                    uniprot.isoform  \
# genes
# 10007_AT1  P46926  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 100_AT1    P00813                            ALTERNATIVE PRODUCTS:
# 10201_AT1  O75414  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 10257_AT1  O15439  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 10327_AT1  P14550                            ALTERNATIVE PRODUCTS:
# ...           ...                                                ...
# 8867_AT2   O43426  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 9162_AT1   O75912                            ALTERNATIVE PRODUCTS:
# 9429_AT1   Q9UNQ0  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 9468_AT1   Q9Y5K3  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 9942_AT1   O75191  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
#
#           hgnc.symbol ncbigene  \
# genes
# 10007_AT1      GNPDA1   10007;
# 100_AT1           ADA     100;
# 10201_AT1        NME6   10201;
# 10257_AT1       ABCC4   10257;
# 10327_AT1      AKR1A1   10327;
# ...               ...      ...
# 8867_AT2        SYNJ1    8867;
# 9162_AT1         DGKI    9162;
# 9429_AT1        ABCG2    9429;
# 9468_AT1       PCYT1B    9468;
# 9942_AT1         XYLB    9942;
#
#                                                         ccds  \
# genes
# 10007_AT1                             CCDS4272.1 [P46926-1];
# 100_AT1                                         CCDS13335.1;
# 10201_AT1  CCDS77733.1 [O75414-3];CCDS77734.1 [O75414-1];...
# 10257_AT1  CCDS45061.1 [O15439-3];CCDS76643.1 [O15439-4];...
# 10327_AT1                                         CCDS523.1;
# ...                                                      ...
# 8867_AT2      CCDS33540.3 [O43426-2];CCDS54483.1 [O43426-4];
# 9162_AT1                                         CCDS5845.1;
# 9429_AT1       CCDS3628.1 [Q9UNQ0-1];CCDS58910.1 [Q9UNQ0-2];
# 9468_AT1   CCDS14213.1 [Q9Y5K3-1];CCDS55391.1 [Q9Y5K3-2];...
# 9942_AT1                              CCDS2678.1 [O75191-1];
#
#                                                       refseq  \
# genes
# 10007_AT1  NP_005462.1 [P46926-1];XP_006714810.1 [P46926-...
# 100_AT1                                         NP_000013.2;
# 10201_AT1  NP_001295355.1 [O75414-1];NP_001295356.1 [O754...
# 10257_AT1  NP_001098985.1 [O15439-3];NP_001288758.1 [O154...
# 10327_AT1  NP_001189342.1;NP_001189343.1;NP_006057.1;NP_6...
# ...                                                      ...
# 8867_AT2   NP_001153774.1 [O43426-4];NP_001153778.1;NP_00...
# 9162_AT1   NP_001308637.1;NP_001308638.1;NP_001308639.1;N...
# 9429_AT1   NP_001244315.1 [Q9UNQ0-2];NP_004818.2 [Q9UNQ0-...
# 9468_AT1   NP_001156736.1 [Q9Y5K3-4];NP_001156737.1 [Q9Y5...
# 9942_AT1                             NP_005099.2 [O75191-1];
#
#                              mim  \
# genes
# 10007_AT1                601798;
# 100_AT1           102700;608958;
# 10201_AT1                608294;
# 10257_AT1                605250;
# 10327_AT1                103830;
# ...                          ...
# 8867_AT2   604297;615530;617389;
# 9162_AT1                 604072;
# 9429_AT1   138900;603756;614490;
# 9468_AT1                 300948;
# 9942_AT1                 604049;
#
#                                                     drugbank
# genes
# 10007_AT1                           DB02445;DB02379;DB03951;
# 100_AT1    DB07711;DB07783;DB07786;DB04218;DB07785;DB0301...
# 10201_AT1                                                NaN
# 10257_AT1  DB00718;DB00770;DB01076;DB00171;DB01327;DB0048...
# 10327_AT1  DB08904;DB09130;DB00997;DB00898;DB06077;DB0015...
# ...                                                      ...
# 8867_AT2                                                 NaN
# 9162_AT1                                            DB14001;
# 9429_AT1   DB12001;DB08916;DB11363;DB00437;DB12015;DB0349...
# 9468_AT1                                    DB00122;DB14006;
# 9942_AT1                                                 NaN
#
# [349 rows x 8 columns]

# %%
# Identify isoforms 
df_isoforms = df_annotations.loc[:, ["uniprot", "uniprot.isoform"]].copy()
df_isoforms = parse_isoforms_UniProt(df_isoforms, add_canonical=True)
double_check = []
for gene, (uniprot_id, isoforms) in df_isoforms.loc[:, ["uniprot", "uniprot.isoform"]].iterrows():
    isoforms = isoforms.split(";")
    isonum = gene.split("_AT")[-1]
    expected_isoform = f"{uniprot_id}-{isonum}"
    if expected_isoform in isoforms:
        df_isoforms.loc[gene, "uniprot.isoform"] = expected_isoform
    else:
        double_check += [gene]
        df_isoforms.loc[gene, "uniprot.isoform"] = float("nan")

df_annotations["uniprot.isoform"] = df_isoforms["uniprot.isoform"]
columns = df_annotations.columns.difference([
    # Uniprot, UniProt Isoform and the "canonical" custom column are not formatted for isoforms
    'uniprot', 'uniprot.isoform', "uniprot.canonical"
])

for idx, row in df_annotations.loc[:, columns].iterrows():
    uniprot_id, isoform_id = df_isoforms.loc[idx, ["uniprot", "uniprot.isoform"]].fillna("")
    # No isoform ID set, just aggregate all without regards to isoform.
    row = row.apply(lambda x: get_isoform_value_from_entry_UniProt(x, isoform_id))
    df_annotations.loc[idx, columns] = row.values
df_annotations = df_annotations.reset_index(drop=False)

if compare:
    try:
        df_previous = pd.read_csv(
            f"{annotation_dirpath}/{annotation_type}_{database_tag}.tsv", 
            sep="\t", 
            index_col=0,
            dtype=str,
        )
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=[annotation_type], dtype=str)
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    # Comparisons should be done with annotation type as index to ensure correct entries get compared.
    df_comparision = compare_tables(
        df_previous.set_index(annotation_type),
        df_annotations.set_index(annotation_type),
    )
    ax = visualize_comparison(df_comparision)

if overwrite:
    df_annotations.to_csv(f"{annotation_dirpath}/{annotation_type}_{database_tag}.tsv", sep="\t")
else:
    df_annotations.to_csv(f"{ROOT_PATH}{INTERIM_PATH}/{annotation_type}_{database_tag}.tsv", sep="\t")
df_annotations
# Out:
#          genes uniprot uniprot.isoform hgnc.symbol ncbigene         ccds  \
# 0    10007_AT1  P46926        P46926-1      GNPDA1    10007   CCDS4272.1
# 1      100_AT1  P00813        P00813-1         ADA      100  CCDS13335.1
# 2    10201_AT1  O75414        O75414-1        NME6    10201  CCDS77734.1
# 3    10257_AT1  O15439        O15439-1       ABCC4    10257   CCDS9474.1
# 4    10327_AT1  P14550        P14550-1      AKR1A1    10327    CCDS523.1
# ..         ...     ...             ...         ...      ...          ...
# 344   8867_AT2  O43426        O43426-2       SYNJ1     8867  CCDS33540.3
# 345   9162_AT1  O75912        O75912-1        DGKI     9162   CCDS5845.1
# 346   9429_AT1  Q9UNQ0        Q9UNQ0-1       ABCG2     9429   CCDS3628.1
# 347   9468_AT1  Q9Y5K3        Q9Y5K3-1      PCYT1B     9468  CCDS14213.1
# 348   9942_AT1  O75191        O75191-1        XYLB     9942   CCDS2678.1
#
#                                                 refseq                   mim  \
# 0                           NP_005462.1;XP_006714810.1                601798
# 1                                          NP_000013.2         102700;608958
# 2         NP_001295355.1;NP_001295356.1;NP_001295357.1                608294
# 3                                          NP_005836.2                605250
# 4    NP_001189342.1;NP_001189343.1;NP_006057.1;NP_6...                103830
# ..                                                 ...                   ...
# 344                                        NP_982271.2  604297;615530;617389
# 345  NP_001308637.1;NP_001308638.1;NP_001308639.1;N...                604072
# 346                         NP_004818.2;XP_011530722.1  138900;603756;614490
# 347                                        NP_004836.2                300948
# 348                                        NP_005099.2                604049
#
#                                               drugbank
# 0                              DB02445;DB02379;DB03951
# 1    DB07711;DB07783;DB07786;DB04218;DB07785;DB0301...
# 2                                                  NaN
# 3    DB00718;DB00770;DB01076;DB00171;DB01327;DB0048...
# 4    DB08904;DB09130;DB00997;DB00898;DB06077;DB0015...
# ..                                                 ...
# 344                                                NaN
# 345                                            DB14001
# 346  DB12001;DB08916;DB11363;DB00437;DB12015;DB0349...
# 347                                    DB00122;DB14006
# 348                                                NaN
#
# [349 rows x 9 columns]

# %% [markdown]
# #### Double check
# These didn't have isoforms, with current database mapping.

# %%
df_annotations.set_index(annotation_type).loc[double_check]
# Out:
#            uniprot uniprot.isoform hgnc.symbol ncbigene  \
# genes
# 10327_AT2   P14550             NaN      AKR1A1    10327
# 221823_AT2  P21108             NaN     PRPS1L1   221823
# 226_AT3     P04075             NaN       ALDOA      226
# 2592_AT3    P07902             NaN        GALT     2592
# 3098_AT5    P19367             NaN         HK1     3098
# 318_AT2     P50583             NaN       NUDT2      318
# 318_AT3     P50583             NaN       NUDT2      318
# 5052_AT2    Q06830             NaN       PRDX1     5052
# 5052_AT3    Q06830             NaN       PRDX1     5052
# 669_AT2     P07738             NaN        BPGM      669
# 7001_AT3    P32119             NaN       PRDX2     7001
#
#                                         ccds  \
# genes
# 10327_AT2                          CCDS523.1
# 221823_AT2                       CCDS47552.1
# 226_AT3              CCDS10668.1;CCDS58450.1
# 2592_AT3              CCDS59122.1;CCDS6565.1
# 3098_AT5    CCDS7289.1;CCDS7291.1;CCDS7292.1
# 318_AT2                           CCDS6552.1
# 318_AT3                           CCDS6552.1
# 5052_AT2                           CCDS522.1
# 5052_AT3                           CCDS522.1
# 669_AT2                           CCDS5833.1
# 7001_AT3                         CCDS12281.1
#
#                                                        refseq  \
# genes
# 10327_AT2   NP_001189342.1;NP_001189343.1;NP_006057.1;NP_6...
# 221823_AT2                                        NP_787082.1
# 226_AT3     NP_000025.1;NP_001121089.1;NP_001230106.1;NP_9...
# 2592_AT3                           NP_000146.2;NP_001245261.1
# 3098_AT5    NP_000179.2;NP_001309293.1;NP_277031.1;NP_2770...
# 318_AT2     NP_001152.1;NP_001231319.1;NP_671701.1;NP_6717...
# 318_AT3     NP_001152.1;NP_001231319.1;NP_671701.1;NP_6717...
# 5052_AT2    NP_001189360.1;NP_002565.1;NP_859047.1;NP_8590...
# 5052_AT3    NP_001189360.1;NP_002565.1;NP_859047.1;NP_8590...
# 669_AT2     NP_001280014.1;NP_001715.1;NP_954655.1;XP_0115...
# 7001_AT3                                          NP_005800.3
#
#                                            mim  \
# genes
# 10327_AT2                               103830
# 221823_AT2                              611566
# 226_AT3                          103850;611881
# 2592_AT3                         230400;606999
# 3098_AT5    142600;235700;605285;617460;618547
# 318_AT2                          602852;619844
# 318_AT3                          602852;619844
# 5052_AT2                                176763
# 5052_AT3                                176763
# 669_AT2                          222800;613896
# 7001_AT3                                600538
#
#                                                      drugbank
# genes
# 10327_AT2   DB08904;DB09130;DB00997;DB00898;DB06077;DB0015...
# 221823_AT2                                                NaN
# 226_AT3     DB04733;DB02512;DB11638;DB04326;DB08240;DB0159...
# 2592_AT3                                                  NaN
# 3098_AT5    DB02007;DB02379;DB01914;DB09341;DB09502;DB0626...
# 318_AT2                                                   NaN
# 318_AT3                                                   NaN
# 5052_AT2    DB11638;DB09130;DB09221;DB01593;DB14487;DB1453...
# 5052_AT3    DB11638;DB09130;DB09221;DB01593;DB14487;DB1453...
# 669_AT2                                                   NaN
# 7001_AT3                              DB02153;DB09130;DB04048
