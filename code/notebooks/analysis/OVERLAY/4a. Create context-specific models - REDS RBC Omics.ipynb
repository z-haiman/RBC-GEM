# %% [markdown]
# # Create context-specific models - REDS RBC Omics data
# ## Setup
# ### Import packages

# %%
import re
from collections import defaultdict

import gurobipy as gp
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib_venn as mpl_venn
import numpy as np
import pandas as pd
import seaborn as sns
import sympy
from rbc_gem_utils import (
    COBRA_CONFIGURATION,
    get_dirpath,
    read_cobra_model,
    show_versions,
    write_cobra_model,
)
from rbc_gem_utils.analysis.overlay import (
    DEFAULT_PREFIX_SUFFIX_VALUES,
    ProteinDilution,
    add_relaxation_budget,
    load_overlay_model,
    update_slack_value,
)
from rbc_gem_utils.util import AVOGADRO_NUMBER, DEFAULT_DRY_MASS_PER_CELL
from sklearn.metrics import r2_score

gp.setParam("OutputFlag", 0)
gp.setParam("LogToConsole", 0)

# Show versions of notebook
show_versions()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2664191
#
# Package Information
# -------------------
# rbc-gem-utils 0.0.3
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.13.4
# bio                                   1.8.0
# cobra                                0.29.1
# depinfo                               2.2.0
# gurobipy                             12.0.2
# matplotlib                           3.10.3
# matplotlib-venn                       1.1.2
# memote                               0.17.0
# networkx                                3.5
# notebook                              7.4.3
# openpyxl                              3.1.5
# pandas                                2.2.3
# pre-commit                            4.2.0
# rbc-gem-utils[database,network,vis] missing
# requests                             2.32.3
# scikit-learn                          1.6.1
# scipy                                1.15.3
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip          25.1
# setuptools 78.1.1
# wheel      0.45.1
#
# Platform Information
# --------------------
# Windows 10-AMD64
# CPython  3.11.11

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION.solver = "gurobi"
COBRA_CONFIGURATION.bounds = (-1e8, 1e8)
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -100000000.0
# upper_bound: 100000000.0
# processes: 127
# cache_directory: C:\Users\P7875\AppData\Local\opencobra\cobrapy\Cache
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ### Define organism, model, and dataset

# %%
organism = "Human"
model_id = "RBC_GEM"
dataset_name = "REDS_RBCOmics"

# %% [markdown]
# ### Set variables for columns keys and sample identification

# %%
sample_key = "SAMPLE ID"
donor_key = "PUBLIC DONOR ID"
time_key = "DAY"

# For sample IDs
timepoints = ["D10", "D23", "D42"]
phenotypes = ["G6PD_V68M"]
donor_re = re.compile(r"(?P<donor>(S\d\d\d))")
time_re = re.compile(r"D(?P<time>(\d\d))")
phenotype_re = re.compile(rf"(?P<phenotype>({'|'.join(phenotypes)})\S+)")

operations = "|".join([x.capitalize() for x in ["mean", "median"]])

operation_re = re.compile(r"(?P<op>" + operations + r")\_(?P<group>\w+)")
sample_id_re = re.compile(
    r"(?!" + operations + r")" + donor_re.pattern + r"\_" + time_re.pattern
)

# %% [markdown]
# ### Set computation options

# %%
run_computations = True
verbose = True
objective_reactions = ["NaKt"]

# %% [markdown]
# ### Set figure options

# %%
save_figures = True
transparent = False
imagetype = "svg"

# %% [markdown]
# ### Set paths

# %%
valid_organisms = {"Human", "Mouse"}
if organism not in valid_organisms:
    raise ValueError(f"Organism must be one of the following: {valid_organisms}")

# Set paths
processed_data_dirpath = get_dirpath(use_temp="processed") / organism / dataset_name
overlay_dirpath = get_dirpath("analysis") / "OVERLAY" / organism
model_dirpath = overlay_dirpath / model_id

results_dirpath = (
    get_dirpath(use_temp="processed") / model_id / "OVERLAY" / organism / dataset_name
)

fitting_dirpath = results_dirpath / "fitting"
sample_pcmodels_dirpath = results_dirpath / "sample_pcmodels"
# Ensure directories exist
results_dirpath.mkdir(exist_ok=True, parents=True)
fitting_dirpath.mkdir(exist_ok=True, parents=True)
sample_pcmodels_dirpath.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ### Define hemoglobin proteins

# %%
# Identify hemoglobin proteins
if organism == "Mouse":
    hemoglobin_proteins = {
        k.replace("-", "_"): v
        for k, v in {
            "Hba": "P01942",  # Hemoglobin subunit alpha
            "Hba-a1": "P01942",
            "Hbb-b1": "P02088",  # Hemoglobin subunit beta-1
            "Hbb-b2": "P02089",  # Hemoglobin subunit beta-2
            "Hbb-bh0": "P04443",  # Hemoglobin subunit beta-H0
            "Hbb-bh1": "P04444",  # Hemoglobin subunit beta-H1
            "Hbz": "P06467",  # Hemoglobin subunit zeta
            "Hba-x": "P06467",
            "Hbz1": "P06467",
            "Hbb-y": "P02104",  # Hemoglobin subunit epsilon-Y2
        }.items()
    }
else:
    hemoglobin_proteins = {
        "HBA": "P69905",  # Hemoglobin subunit alpha
        "HBB": "P68871",  # Hemoglobin subunit beta
        "HBD": "P02042",  # Hemoglobin subunit delta
        "HBE1": "P02100",  # Hemoglobin subunit beta
        "HBG1": "P69891",  # Hemoglobin subunit gamma-1
        "HBG2": "P69892",  # Hemoglobin subunit gamma-2
        "HBM": "Q6B0K9",  # Hemoglobin subunit mu
        "HBQ1": "P09105",  # Hemoglobin subunit theta-1
        "HBZ": "P02008",  # Hemoglobin subunit zeta
    }

# %% [markdown]
# ## Load RBC-GEM model

# %%
# Load models
model = read_cobra_model(filename=model_dirpath / f"{model_id}.xml")
pcmodel = load_overlay_model(filename=model_dirpath / f"{model_id}_PC.xml")

pcmodel
# Out:
# <Model RBC_GEM_PC at 0x168581125d0>

# %% [markdown]
# ## Load copy numbers and protein data

# %%
# Load protein copy numbers
df_copy_numbers = pd.read_csv(
    processed_data_dirpath / f"{dataset_name}_ProteinCopyNumbers.tsv",
    sep="\t",
    index_col=sample_key,
)

# Load MCH for transforming data
df_MCH = pd.read_csv(
    processed_data_dirpath / f"{dataset_name}_MCH.tsv", sep="\t", index_col=sample_key
)
# Load intensity data as weighting matrix
df_weighting_mat = pd.read_csv(
    processed_data_dirpath / f"{dataset_name}_ProteinIntensities.tsv",
    sep="\t",
    index_col=sample_key,
)

# Load protein data
df_protein_data = pd.read_csv(
    processed_data_dirpath / f"{dataset_name}_ProteinData.tsv",
    sep="\t",
    index_col="Entry",
)

all_ids = list(df_copy_numbers.index.unique())
operation_ids = [x for x in all_ids if operation_re.match(x)]
sample_ids = [x for x in all_ids if sample_id_re.match(x)]

print(f"Number of measured samples: {len(sample_ids)}")
print(f"Number of operation samples: {len(operation_ids)}")
print(f"Number of models to generate: {len(all_ids)}")
# Out:
# Number of measured samples: 1910
# Number of operation samples: 12
# Number of models to generate: 1922

# %% [markdown]
# ## Integrate proteomics with model
# ### Convert copy numbers to mg / gDW

# %%
df_uniprot_to_mw = df_protein_data["Mass"] / 1000  # g/mol --> # kg / mol
df_mg_prot_per_gDW = (
    df_copy_numbers[df_protein_data.index].mul(
        1 / df_MCH.squeeze(), axis=0
    )  # cell / pgDW
    * (1e12 / 1)  # pgDW / gDW
    * (1 / AVOGADRO_NUMBER)  # mol / protein copies
    * (df_uniprot_to_mw)  # kg / mol
    * (1e6 / 1)  # mg / kg
).copy()
df_mg_prot_per_gDW = df_mg_prot_per_gDW.loc[df_copy_numbers.index]
df_mg_prot_per_gDW[df_mg_prot_per_gDW.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [A0A075B6I0, A0A075B6I9, A0A075B6J9, A0A075B6K4, A0A075B6K5, A0A075B6R2, A0A075B6S5, A0A075B6S9, A0A087WSY6, A0A0A0MRZ8, A0A0A0MS15, A0A0A0MT36, A0A0B4J1U3, A0A0B4J1U7, A0A0B4J1V0, A0A0B4J1V2, A0A0B4J1X5, A0A0B4J1Y8, A0A0B4J1Y9, A0A0B4J2D9, A0A0C4DH24, A0A0C4DH25, A0A0C4DH34, A0A0C4DH36, A0A0C4DH38, A0A0C4DH67, A0A0C4DH73, A0AVT1, A0FGR8, A0M8Q6, A2RRP1, A4D126, A4D1P6, A4FU01, A5D8V6, A6NDG6, A6NDU8, A6NGG8, A6NHX0, B2RUZ4, E9PAV3, O00154, O00159, O00161, O00178, O00182, O00186, O00187, O00231, O00232, O00233, O00267, O00299, O00303, O00391, O00399, O00410, O00421, O00429, O00442, O00487, O00505, O00571, O00629, O00743, O00764, O14523, O14562, O14602, O14618, O14662, O14735, O14737, O14744, O14745, O14787, O14791, O14818, O14880, O14950, O14964, O14980, O15067, O15084, O15116, O15118, O15127, O15143, O15144, O15145, O15162, O15173, O15212, O15247, O15294, O15305, O15400, O15439, O15440, O15484, ...]
# Index: []
#
# [0 rows x 1827 columns]

# %% [markdown]
# ### Scale measurements for proteome budget
# Note that this step will help ensure its theoretically possible for a perfect fit

# %%
budget_proteome_la_value = 50
budget_hemoglobin_value = 950
budget_total_value = None

# %%
# Split into hemoglobin and low abundance proteomes
budget_rxn_prefix = DEFAULT_PREFIX_SUFFIX_VALUES["budgets"]["prefix.dilution"]
budget_met_prefix = DEFAULT_PREFIX_SUFFIX_VALUES["budgets"]["prefix.metabolite"]
df_mg_prot_per_gDW_hb = df_mg_prot_per_gDW.loc[
    :, df_mg_prot_per_gDW.columns.isin(hemoglobin_proteins.values())
]
df_mg_prot_per_gDW_la = df_mg_prot_per_gDW.loc[
    :, ~df_mg_prot_per_gDW.columns.isin(hemoglobin_proteins.values())
]

df_summary = {
    "Perfect total": 1000,
    "Current total": df_mg_prot_per_gDW.loc[sample_ids].sum(axis=1).mean().item(),
    "Hemoglobin total": df_mg_prot_per_gDW_hb.loc[sample_ids].sum(axis=1).mean().item(),
    "Low abundance total": df_mg_prot_per_gDW_la.loc[sample_ids]
    .sum(axis=1)
    .mean()
    .item(),
}
df_summary["Remaining/Excess"] = df_summary["Perfect total"] - (
    df_summary["Hemoglobin total"] + df_summary["Low abundance total"]
)

budget_rxn_proteome = pcmodel.reactions.get_by_id(
    f"{budget_rxn_prefix}{budget_met_prefix}proteome"
)
budget_rxn_hemoglobin = pcmodel.reactions.get_by_id(
    f"{budget_rxn_prefix}{budget_met_prefix}hemoglobin"
)
budget_rxn_total = pcmodel.reactions.get_by_id(
    f"{budget_rxn_prefix}{budget_met_prefix}total"
)

if budget_proteome_la_value is None:
    budget_proteome_la_value = budget_rxn_proteome.upper_bound
if budget_hemoglobin_value is None:
    budget_hemoglobin_value = budget_rxn_hemoglobin.upper_bound
if budget_total_value is None:
    budget_total_value = budget_rxn_total.upper_bound

assert budget_total_value >= (budget_proteome_la_value + budget_hemoglobin_value)

budget_rxn_proteome.upper_bound = budget_proteome_la_value
budget_rxn_hemoglobin.upper_bound = budget_hemoglobin_value
budget_rxn_total.upper_bound = budget_total_value

# Scale values for low abundance proteome
budget_value = budget_proteome_la_value
df_mg_prot_per_gDW_la = (
    budget_value * (df_mg_prot_per_gDW_la.T / df_mg_prot_per_gDW_la.sum(axis=1)).T
)
df_summary["Low abundance scaled"] = budget_value

# Scale values for hemoglobin proteome
budget_value = budget_hemoglobin_value
df_mg_prot_per_gDW_hb = (
    budget_value * (df_mg_prot_per_gDW_hb.T / df_mg_prot_per_gDW_hb.sum(axis=1)).T
)
df_summary["Hemoglobin scaled"] = budget_value

budget_value = budget_total_value - sum(
    [budget_proteome_la_value, budget_hemoglobin_value]
)
df_summary["Remaining scaled"] = budget_value

# Combine dataframes back into one
df_mg_prot_per_gDW_normalized = pd.concat(
    (df_mg_prot_per_gDW_hb, df_mg_prot_per_gDW_la), axis=1
)
df_summary = pd.DataFrame.from_dict(
    {
        " " * max(30 - len(k), 0) + k: [f"{v:.4f}", f"{v / 1000 * 100:.1f}%"]
        for k, v in df_summary.items()
    },
    orient="index",
    columns=["mg protein / gDW / cell", "Percentage"],
)
print(df_summary)
df_mg_prot_per_gDW_normalized.sum(axis=1)
# Out:
#                      mg protein / gDW / cell Percentage
#        Perfect total               1000.0000     100.0%
#        Current total               1000.0000     100.0%
#     Hemoglobin total                429.2329      42.9%
#  Low abundance total                570.7671      57.1%
#     Remaining/Excess                  0.0000       0.0%
# Low abundance scaled                 50.0000       5.0%
#    Hemoglobin scaled                950.0000      95.0%
#     Remaining scaled                  0.0000       0.0%
# SAMPLE ID
# S001_D10              1000.0
# S001_D23              1000.0
# S001_D42              1000.0
# S002_D10              1000.0
# S002_D23              1000.0
#                        ...
# Mean_G6PD_V68M_1      1000.0
# Mean_G6PD_V68M_2      1000.0
# Median_G6PD_V68M_0    1000.0
# Median_G6PD_V68M_1    1000.0
# Median_G6PD_V68M_2    1000.0
# Length: 1922, dtype: float64

# %% [markdown]
# ### Convert mg / gDW to nmol / gDW

# %%
df_nmol_prot_per_gDW = (
    df_mg_prot_per_gDW_normalized  # mg / gDW
    * (1 / df_uniprot_to_mw)  # mol / kg --> mmol / g --> umol / mg
    * (1e3 / 1)  # nmol / umol
).loc[:, df_mg_prot_per_gDW_normalized.columns]
df_nmol_prot_per_gDW = df_nmol_prot_per_gDW.T
df_nmol_prot_per_gDW
# Out:
# SAMPLE ID      S001_D10      S001_D23      S001_D42      S002_D10  \
# P02008      5711.701488   6195.993951   8202.371061  10030.992827
# P02042     23598.528519  23922.365911  15256.582852  27625.580957
# P02100         2.705134      3.509404      7.697601      4.510245
# P09105        38.067281     36.529563     42.859252     60.526125
# P68871      9503.146391  10031.605421  11963.335657   5453.197068
# ...                 ...           ...           ...           ...
# Q9Y6E0         0.038086      0.040313      0.054938      0.062468
# Q9Y6I3         0.023621      0.155896      0.019620      0.000000
# Q9Y6M4         0.000000      0.024880      0.025744      0.000000
# Q9Y6M5         0.042697      0.040559      0.030378      0.124667
# Q9Y6R7         0.021924      0.021617      0.019990      0.028078
#
# SAMPLE ID      S002_D23      S002_D42      S003_D10      S003_D23  \
# P02008      9267.072179   9577.944760   7761.886683   9585.442147
# P02042     27930.313499  25892.111687  23732.280301  18498.546948
# P02100       289.081171      6.809605     17.970784      4.306167
# P09105        81.707715     52.171248     29.875331     41.622117
# P68871      5092.491052   6879.143103   9390.955205  11351.030090
# ...                 ...           ...           ...           ...
# Q9Y6E0         0.090008      0.072397      0.045219      0.055560
# Q9Y6I3         0.000000      0.000000      0.029578      0.000000
# Q9Y6M4         0.000000      0.000000      0.000000      0.035888
# Q9Y6M5         0.133595      0.114644      0.050889      0.081279
# Q9Y6R7         0.009369      0.014330      0.025784      0.020198
#
# SAMPLE ID      S003_D42      S004_D10  ...      Mean_D42    Median_D10  \
# P02008      7386.126355   7139.463629  ...   7279.104455   7629.879980
# P02042     30364.640014  15743.006155  ...  24232.621191  24350.515255
# P02100         8.942239      4.057600  ...     23.924982      6.350425
# P09105        38.394597     34.410908  ...     41.169826     41.409411
# P68871      9217.858990  11122.192261  ...  10283.167873  10248.257504
# ...                 ...           ...  ...           ...           ...
# Q9Y6E0         0.068864      0.042550  ...      0.054266      0.056460
# Q9Y6I3         0.000000      0.016981  ...      0.014917      0.018536
# Q9Y6M4         0.000000      0.027049  ...      0.152978      0.000000
# Q9Y6M5         0.107624      0.036415  ...      0.059019      0.058818
# Q9Y6R7         0.021677      0.018649  ...      0.015506      0.015298
#
# SAMPLE ID    Median_D23    Median_D42  Mean_G6PD_V68M_0  Mean_G6PD_V68M_1  \
# P02008      7427.628716   7607.527461       7225.845929       6540.293557
# P02042     24320.705999  24056.836034      24318.374946      23469.947666
# P02100         5.814418      6.058318         26.481363         18.040539
# P09105        41.079871     41.620059         41.142515         50.710543
# P68871     10200.214449  10354.465542      10246.487314      10406.205152
# ...                 ...           ...               ...               ...
# Q9Y6E0         0.055458      0.054736          0.054572          0.052295
# Q9Y6I3         0.014322      0.012857          0.017690          0.022743
# Q9Y6M4         0.012083      0.000000          0.131675          0.289553
# Q9Y6M5         0.058039      0.058652          0.058422          0.052077
# Q9Y6R7         0.014721      0.014809          0.015794          0.012109
#
# SAMPLE ID  Mean_G6PD_V68M_2  Median_G6PD_V68M_0  Median_G6PD_V68M_1  \
# P02008          7372.242450         7561.610167         6826.602365
# P02042         24879.851410        24208.307138        23036.957589
# P02100            33.828837            6.092511            6.366363
# P09105            41.998024           41.369208           48.758482
# P68871         10492.765620        10248.695218        10761.226833
# ...                     ...                 ...                 ...
# Q9Y6E0             0.056473            0.055423            0.055366
# Q9Y6I3             0.012110            0.015184            0.018341
# Q9Y6M4             0.471490            0.000000            0.019306
# Q9Y6M5             0.057144            0.058385            0.054389
# Q9Y6R7             0.014961            0.014982            0.011997
#
# SAMPLE ID  Median_G6PD_V68M_2
# P02008            7713.013567
# P02042           24494.073380
# P02100               6.948159
# P09105              44.328675
# P68871           10593.014145
# ...                       ...
# Q9Y6E0               0.056894
# Q9Y6I3               0.011105
# Q9Y6M4               0.000000
# Q9Y6M5               0.053556
# Q9Y6R7               0.014950
#
# [1827 rows x 1922 columns]

# %% [markdown]
# ## Create DataFrame for protein dilution reactions

# %%
df_model_protein_dilutions = pd.concat(
    (
        pd.Series(
            {g.annotation.get("uniprot"): g.id for g in model.genes}, name="genes"
        ),
        pd.Series(
            {
                protdl.annotation.get("uniprot"): protdl.id
                for protdl in pcmodel.reactions.query(
                    lambda x: isinstance(x, ProteinDilution)
                )
            },
            name="PROTDL",
        ),
    ),
    axis=1,
).dropna()
df_model_protein_dilutions.index.name = "uniprot"
df_model_protein_dilutions = df_model_protein_dilutions[
    df_model_protein_dilutions["genes"].isin(model.genes.list_attr("id"))
].sort_values("PROTDL")
df_model_protein_dilutions
# Out:
#             genes                      PROTDL
# uniprot
# Q9NPC4     A4GALT    PROTDL_protein_A4GALT_pc
# P49588      AARS1     PROTDL_protein_AARS1_pc
# Q9NRN7   AASDHPPT  PROTDL_protein_AASDHPPT_pc
# O95477      ABCA1     PROTDL_protein_ABCA1_pc
# Q8IZY2      ABCA7     PROTDL_protein_ABCA7_pc
# ...           ...                         ...
# P07947       YES1      PROTDL_protein_YES1_pc
# Q5W0Z9    ZDHHC20   PROTDL_protein_ZDHHC20_pc
# Q9UIJ5     ZDHHC2    PROTDL_protein_ZDHHC2_pc
# Q9NYG2     ZDHHC3    PROTDL_protein_ZDHHC3_pc
# Q9C0B5     ZDHHC5    PROTDL_protein_ZDHHC5_pc
#
# [820 rows x 2 columns]

# %% [markdown]
# ## Organize samples (optional)
# Use this for organizing samples if time-outs are an issue or multiple runs are necessary

# %%
df_samples = df_nmol_prot_per_gDW.copy()
df_samples
# Out:
# SAMPLE ID      S001_D10      S001_D23      S001_D42      S002_D10  \
# P02008      5711.701488   6195.993951   8202.371061  10030.992827
# P02042     23598.528519  23922.365911  15256.582852  27625.580957
# P02100         2.705134      3.509404      7.697601      4.510245
# P09105        38.067281     36.529563     42.859252     60.526125
# P68871      9503.146391  10031.605421  11963.335657   5453.197068
# ...                 ...           ...           ...           ...
# Q9Y6E0         0.038086      0.040313      0.054938      0.062468
# Q9Y6I3         0.023621      0.155896      0.019620      0.000000
# Q9Y6M4         0.000000      0.024880      0.025744      0.000000
# Q9Y6M5         0.042697      0.040559      0.030378      0.124667
# Q9Y6R7         0.021924      0.021617      0.019990      0.028078
#
# SAMPLE ID      S002_D23      S002_D42      S003_D10      S003_D23  \
# P02008      9267.072179   9577.944760   7761.886683   9585.442147
# P02042     27930.313499  25892.111687  23732.280301  18498.546948
# P02100       289.081171      6.809605     17.970784      4.306167
# P09105        81.707715     52.171248     29.875331     41.622117
# P68871      5092.491052   6879.143103   9390.955205  11351.030090
# ...                 ...           ...           ...           ...
# Q9Y6E0         0.090008      0.072397      0.045219      0.055560
# Q9Y6I3         0.000000      0.000000      0.029578      0.000000
# Q9Y6M4         0.000000      0.000000      0.000000      0.035888
# Q9Y6M5         0.133595      0.114644      0.050889      0.081279
# Q9Y6R7         0.009369      0.014330      0.025784      0.020198
#
# SAMPLE ID      S003_D42      S004_D10  ...      Mean_D42    Median_D10  \
# P02008      7386.126355   7139.463629  ...   7279.104455   7629.879980
# P02042     30364.640014  15743.006155  ...  24232.621191  24350.515255
# P02100         8.942239      4.057600  ...     23.924982      6.350425
# P09105        38.394597     34.410908  ...     41.169826     41.409411
# P68871      9217.858990  11122.192261  ...  10283.167873  10248.257504
# ...                 ...           ...  ...           ...           ...
# Q9Y6E0         0.068864      0.042550  ...      0.054266      0.056460
# Q9Y6I3         0.000000      0.016981  ...      0.014917      0.018536
# Q9Y6M4         0.000000      0.027049  ...      0.152978      0.000000
# Q9Y6M5         0.107624      0.036415  ...      0.059019      0.058818
# Q9Y6R7         0.021677      0.018649  ...      0.015506      0.015298
#
# SAMPLE ID    Median_D23    Median_D42  Mean_G6PD_V68M_0  Mean_G6PD_V68M_1  \
# P02008      7427.628716   7607.527461       7225.845929       6540.293557
# P02042     24320.705999  24056.836034      24318.374946      23469.947666
# P02100         5.814418      6.058318         26.481363         18.040539
# P09105        41.079871     41.620059         41.142515         50.710543
# P68871     10200.214449  10354.465542      10246.487314      10406.205152
# ...                 ...           ...               ...               ...
# Q9Y6E0         0.055458      0.054736          0.054572          0.052295
# Q9Y6I3         0.014322      0.012857          0.017690          0.022743
# Q9Y6M4         0.012083      0.000000          0.131675          0.289553
# Q9Y6M5         0.058039      0.058652          0.058422          0.052077
# Q9Y6R7         0.014721      0.014809          0.015794          0.012109
#
# SAMPLE ID  Mean_G6PD_V68M_2  Median_G6PD_V68M_0  Median_G6PD_V68M_1  \
# P02008          7372.242450         7561.610167         6826.602365
# P02042         24879.851410        24208.307138        23036.957589
# P02100            33.828837            6.092511            6.366363
# P09105            41.998024           41.369208           48.758482
# P68871         10492.765620        10248.695218        10761.226833
# ...                     ...                 ...                 ...
# Q9Y6E0             0.056473            0.055423            0.055366
# Q9Y6I3             0.012110            0.015184            0.018341
# Q9Y6M4             0.471490            0.000000            0.019306
# Q9Y6M5             0.057144            0.058385            0.054389
# Q9Y6R7             0.014961            0.014982            0.011997
#
# SAMPLE ID  Median_G6PD_V68M_2
# P02008            7713.013567
# P02042           24494.073380
# P02100               6.948159
# P09105              44.328675
# P68871           10593.014145
# ...                       ...
# Q9Y6E0               0.056894
# Q9Y6I3               0.011105
# Q9Y6M4               0.000000
# Q9Y6M5               0.053556
# Q9Y6R7               0.014950
#
# [1827 rows x 1922 columns]

# %% [markdown]
# ### Map samples to model

# %%
merge_key = "uniprot"
df_samples.index.name = merge_key

df_model = (
    df_model_protein_dilutions[["PROTDL"]]
    .merge(df_samples, left_index=True, right_index=True, how="left")
    .set_index("PROTDL")
    .sort_index()
)
no_experimental_measurements = [
    protein_dilution
    for protein_dilution, has_measurement in df_model.isna().all(axis=1).items()
    if has_measurement
]
print(
    f"Model proteins mapped to measurements: {len(df_model) - len(no_experimental_measurements)}"
)
print(f"Model proteins without measurements: {len(no_experimental_measurements)}")
df_model.dropna()
# Out:
# Model proteins mapped to measurements: 524
# Model proteins without measurements: 296
#                             S001_D10  S001_D23  S001_D42  S002_D10  S002_D23  \
# PROTDL
# PROTDL_protein_AARS1_pc     0.016548  0.016056  0.022910  0.039456  0.030369
# PROTDL_protein_AASDHPPT_pc  0.105539  0.094642  0.106604  0.023180  0.000000
# PROTDL_protein_ABCB6_pc     0.157586  0.141928  0.132416  0.094033  0.095336
# PROTDL_protein_ABCC1_pc     0.014914  0.014828  0.027336  0.000000  0.000000
# PROTDL_protein_ABCC4_pc     0.042641  0.046250  0.037210  0.056579  0.054304
# ...                              ...       ...       ...       ...       ...
# PROTDL_protein_WDR77_pc     0.468144  0.489826  0.485841  0.494281  0.520838
# PROTDL_protein_WNK1_pc      0.047562  0.055109  0.052594  0.025514  0.037551
# PROTDL_protein_XPNPEP1_pc   0.110483  0.109043  0.108751  0.115400  0.152629
# PROTDL_protein_XYLB_pc      0.002652  0.000000  0.001022  0.000000  0.000000
# PROTDL_protein_YARS1_pc     0.162248  0.199224  0.143664  0.136541  0.135399
#
#                             S002_D42  S003_D10  S003_D23  S003_D42  S004_D10  \
# PROTDL
# PROTDL_protein_AARS1_pc     0.037975  0.019119  0.008683  0.005173  0.010755
# PROTDL_protein_AASDHPPT_pc  0.000000  0.000000  0.000000  0.000000  0.111859
# PROTDL_protein_ABCB6_pc     0.104518  0.176915  0.086452  0.065404  0.139074
# PROTDL_protein_ABCC1_pc     0.000000  0.013321  0.045371  0.000000  0.017636
# PROTDL_protein_ABCC4_pc     0.045073  0.051173  0.046281  0.069150  0.051205
# ...                              ...       ...       ...       ...       ...
# PROTDL_protein_WDR77_pc     0.477451  0.442753  0.389425  0.376230  0.528052
# PROTDL_protein_WNK1_pc      0.015743  0.047097  0.049747  0.019674  0.058304
# PROTDL_protein_XPNPEP1_pc   0.089800  0.117508  0.122700  0.117942  0.096528
# PROTDL_protein_XYLB_pc      0.000000  0.014483  0.000000  0.006672  0.000000
# PROTDL_protein_YARS1_pc     0.202882  0.232887  0.142774  0.189996  0.166267
#
#                             ...  Mean_D42  Median_D10  Median_D23  Median_D42  \
# PROTDL                      ...
# PROTDL_protein_AARS1_pc     ...  0.022820    0.023447    0.022811    0.022664
# PROTDL_protein_AASDHPPT_pc  ...  0.009864    0.000000    0.000000    0.000000
# PROTDL_protein_ABCB6_pc     ...  0.138610    0.142695    0.144256    0.143795
# PROTDL_protein_ABCC1_pc     ...  0.023760    0.018013    0.020254    0.020951
# PROTDL_protein_ABCC4_pc     ...  0.053586    0.056817    0.055530    0.056215
# ...                         ...       ...         ...         ...         ...
# PROTDL_protein_WDR77_pc     ...  0.467756    0.492214    0.497079    0.493172
# PROTDL_protein_WNK1_pc      ...  0.039385    0.041858    0.042808    0.042303
# PROTDL_protein_XPNPEP1_pc   ...  0.122295    0.129456    0.127242    0.125648
# PROTDL_protein_XYLB_pc      ...  0.002329    0.000000    0.000000    0.000000
# PROTDL_protein_YARS1_pc     ...  0.201297    0.202856    0.200919    0.198106
#
#                             Mean_G6PD_V68M_0  Mean_G6PD_V68M_1  \
# PROTDL
# PROTDL_protein_AARS1_pc             0.023114          0.020525
# PROTDL_protein_AASDHPPT_pc          0.011542          0.008280
# PROTDL_protein_ABCB6_pc             0.138170          0.155891
# PROTDL_protein_ABCC1_pc             0.023418          0.021872
# PROTDL_protein_ABCC4_pc             0.053548          0.057569
# ...                                      ...               ...
# PROTDL_protein_WDR77_pc             0.468421          0.466589
# PROTDL_protein_WNK1_pc              0.039440          0.042785
# PROTDL_protein_XPNPEP1_pc           0.124027          0.134695
# PROTDL_protein_XYLB_pc              0.002376          0.001724
# PROTDL_protein_YARS1_pc             0.203630          0.174697
#
#                             Mean_G6PD_V68M_2  Median_G6PD_V68M_0  \
# PROTDL
# PROTDL_protein_AARS1_pc             0.026827            0.022811
# PROTDL_protein_AASDHPPT_pc          0.008467            0.000000
# PROTDL_protein_ABCB6_pc             0.135160            0.143849
# PROTDL_protein_ABCC1_pc             0.021174            0.019578
# PROTDL_protein_ABCC4_pc             0.063111            0.056017
# ...                                      ...                 ...
# PROTDL_protein_WDR77_pc             0.445078            0.494857
# PROTDL_protein_WNK1_pc              0.035149            0.042200
# PROTDL_protein_XPNPEP1_pc           0.142029            0.127354
# PROTDL_protein_XYLB_pc              0.001192            0.000000
# PROTDL_protein_YARS1_pc             0.206572            0.201689
#
#                             Median_G6PD_V68M_1  Median_G6PD_V68M_2
# PROTDL
# PROTDL_protein_AARS1_pc               0.020269            0.025102
# PROTDL_protein_AASDHPPT_pc            0.005436            0.000000
# PROTDL_protein_ABCB6_pc               0.161140            0.154520
# PROTDL_protein_ABCC1_pc               0.020216            0.020761
# PROTDL_protein_ABCC4_pc               0.059867            0.068651
# ...                                        ...                 ...
# PROTDL_protein_WDR77_pc               0.480073            0.470388
# PROTDL_protein_WNK1_pc                0.043295            0.037276
# PROTDL_protein_XPNPEP1_pc             0.142941            0.143033
# PROTDL_protein_XYLB_pc                0.000000            0.000000
# PROTDL_protein_YARS1_pc               0.175556            0.201565
#
# [524 rows x 1922 columns]

# %% [markdown]
# #### Summarize mapping

# %%
dataset_proteins = set(df_samples.index)
model_proteins = set(df_model_protein_dilutions.index)

df_mg_prot_per_gDW_hb = df_mg_prot_per_gDW_normalized.loc[
    [
        x for x in df_mg_prot_per_gDW_normalized.index if x in sample_ids
    ],  # Don't include operation IDs
    [
        x
        for x in df_mg_prot_per_gDW_normalized.columns
        if x in list(hemoglobin_proteins.values())
    ],
]
df_mg_prot_per_gDW_la = df_mg_prot_per_gDW_normalized.loc[
    [
        x for x in df_mg_prot_per_gDW_normalized.index if x in sample_ids
    ],  # Don't include operation IDs
    [
        x
        for x in df_mg_prot_per_gDW.columns
        if not x in list(hemoglobin_proteins.values())
    ],
]

df_mapped_mass_la = df_mg_prot_per_gDW_la.loc[
    :, df_mg_prot_per_gDW_la.columns.isin(model_proteins)
].sum(axis=1)
df_unmapped_mass_la = df_mg_prot_per_gDW_la.loc[
    :, ~df_mg_prot_per_gDW_la.columns.isin(model_proteins)
].sum(axis=1)
df_mapped_mass_hb = df_mg_prot_per_gDW_hb.loc[
    :, df_mg_prot_per_gDW_hb.columns.isin(model_proteins)
].sum(axis=1)
df_unmapped_mass_hb = df_mg_prot_per_gDW_hb.loc[
    :, ~df_mg_prot_per_gDW_hb.columns.isin(model_proteins)
].sum(axis=1)

proteomes = {}
round_int = 6
for label, df in zip(
    ["hemoglobin", "low abundance"], [df_mg_prot_per_gDW_hb, df_mg_prot_per_gDW_la]
):
    df_modeled = df.loc[:, df.columns.isin(model_proteins)].sum(axis=1)
    df_remaining = df.loc[:, ~df.columns.isin(model_proteins)].sum(axis=1)
    means = (df_modeled.mean(), df_remaining.mean())
    stdevs = (df_modeled.std(), df_remaining.std())
    proteomes[(label, "modeled")] = round(means[0], round_int)
    proteomes[(label, "remaining")] = round(means[1], round_int)
proteomes = pd.Series(proteomes, name="Mean value across samples")
proteomes.index = [f"Mean {k[0]} mass {k[1]}" for k in proteomes.index]
print(proteomes.head())
proteomes = proteomes[proteomes != 0]
# Out:
# Mean hemoglobin mass modeled         950.00000
# Mean hemoglobin mass remaining         0.00000
# Mean low abundance mass modeled       25.29725
# Mean low abundance mass remaining     24.70275
# Name: Mean value across samples, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(3, 6))
subsets = (
    len(dataset_proteins),
    len(model_proteins),
    len(dataset_proteins.intersection(model_proteins)),
)


venn = mpl_venn.venn2(
    subsets=subsets,
    set_labels=(dataset_name, model.id),
    set_colors=("red", "blue"),
    alpha=0.5,
    ax=ax1,
)
circles = mpl_venn.venn2_circles(
    subsets=subsets, linestyle="-", color="black", ax=ax1, linewidth=1
)
for text in venn.set_labels:
    text.set_fontsize("x-large")
for text in venn.subset_labels:
    text.set_fontsize("x-large")
ax1.set_title("Modeled proteome", fontsize="xx-large")


label_color_map = {
    "Mean hemoglobin mass modeled": ("Hemoglobin", "xkcd:dark red"),
    "Mean low abundance mass modeled": ("Low abundance", "xkcd:light blue"),
    "Mean low abundance mass remaining": ("Not modeled", "xkcd:green"),
}
edgecolor = "black"
linewidth = 1
ax2.pie(
    x=proteomes.values,
    colors=[label_color_map[k][1] for k in proteomes.index],
    pctdistance=1.35,
    counterclock=False,
    autopct=lambda pct: f"{pct * 1000/100:.2f}\n",
    textprops=dict(fontsize="large", ha="center", va="top"),
    wedgeprops=dict(edgecolor=edgecolor, linewidth=linewidth),
)
handles = [
    mpl.patches.Patch(
        edgecolor=edgecolor,
        linewidth=linewidth,
        label=label_color_map[k][0],
        facecolor=label_color_map[k][1],
    )
    for k in proteomes.index
]
ax2.legend(
    handles=handles,
    ncols=1,
    bbox_to_anchor=(0.5, 0),
    loc="upper center",
    fontsize="large",
    frameon=False,
)
ax2.set_xlabel("Mass (mg/gDW)", fontsize="large", labelpad=-10)
if save_figures:
    fig.savefig(
        results_dirpath / f"ModeledProteome.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )
fig;

# %% [markdown]
# ## Create QP model for each sample

# %%
def solve_qp(pcmodel, df):
    x = []  # Variables
    c = []  # Data * Weights
    F = []  # Weights

    for protdl, (data_value, weight) in df.iterrows():
        protdl = pcmodel.reactions.get_by_id(protdl)
        x.append(protdl.flux_expression)
        c.append(weight * data_value)
        F.append(weight)

    x = sympy.Matrix(x)
    c = sympy.Matrix(c)
    F = sympy.DiagMatrix(sympy.Matrix(F))
    # # QP Objective must be in form of 0.5 * x.T * F * x - c.T * x
    objective = 0.5 * x.T * F * x - c.T * x
    pcmodel.objective = objective[0]
    pcmodel.objective_direction = "min"
    pcmodel.tolerance = 1e-9

    qp_sol = pcmodel.optimize()
    return qp_sol


def solve_qp_for_samples(
    pcmodel, df_samples, df_weights=None, log_zero_replacement=1e-6, verbose=False
):
    qp_solutions_dict = {}
    for sample_id, data_series in df_samples.items():
        # Get protein values
        data_series.name = "Data"
        if df_weights is None:
            data_weights = 1 / data_series.replace(0, 1)
            data_weights = data_weights / data_weights.mean()
        else:
            data_weights = df_weights.loc[:, sample_id]
        # Get protein weights
        data_weights.name = "Weights"

        # Map to model, currently model mapping DataFrame generated outside scope of function
        df_model_data_weights = (
            df_model_protein_dilutions[["PROTDL"]]
            .merge(data_series, left_index=True, right_index=True, how="left")
            .merge(data_weights, left_index=True, right_index=True, how="left")
            .set_index("PROTDL")
            .sort_index()
        )

        df = (
            df_model_data_weights.loc[:, [data_series.name, data_weights.name]]
            .dropna(axis=0, how="all")
            .astype(float)
        )

        with pcmodel:
            qp_sol = solve_qp(pcmodel, df)

        df_qp_sol = qp_sol.fluxes.loc[
            pcmodel.reactions.query(lambda x: isinstance(x, ProteinDilution)).list_attr(
                "id"
            )
        ]
        df_qp_sol = (
            pd.concat((df_model_data_weights, df_qp_sol), axis=1).dropna().sort_index()
        )
        # data_weights = df_qp_sol.loc[:, "Weights"]

        df_qp_sol = df_qp_sol.rename(
            {"Data": "Measured Proteome", "fluxes": "Best-Fitted Proteome"}, axis=1
        )
        df_qp_sol = df_qp_sol.loc[:, ["Measured Proteome", "Best-Fitted Proteome"]]

        df = df_qp_sol.copy()
        r2 = r2_score(
            df.iloc[:, 0].values, df.iloc[:, 1].values, multioutput="uniform_average"
        )

        df = df_qp_sol.apply(
            lambda x: [
                log_zero_replacement if np.isclose(y, 0, atol=1e-12) else y for y in x
            ]
        ).apply(np.log10)
        r2_log10_w_outliers = r2_score(
            df.iloc[:, 0].values, df.iloc[:, 1].values, multioutput="uniform_average"
        )

        df = df_qp_sol[
            ~df_qp_sol.apply(lambda x: np.isclose(x, 0).any(), axis=1)
        ].apply(np.log10)
        r2_log10_wo_outliers = r2_score(
            df.iloc[:, 0].values, df.iloc[:, 1].values, multioutput="uniform_average"
        )
        r2_values = (r2, r2_log10_w_outliers, r2_log10_wo_outliers)
        qp_solutions_dict[sample_id] = (df_qp_sol, qp_sol.objective_value, r2_values)
        if verbose:
            # Recall that the objective is designed to try to minimize fitting error via maximizing R2, so 1 is a possibility
            print(
                "Sample '{}'\tR^2: {:.4f}\tR^2 log10 w/outliers: {:.4f}\tR^2 log10 wo/outliers: {:.4f}\tObjective: {:.5f}".format(
                    sample_id, *r2_values, qp_sol.objective_value
                )
            )
        # TODO catch bad fits

    return qp_solutions_dict

# %% [markdown]
# ### Set weightings for QP problem

# %%
# Ensure data is provided as (Protein IDs x Sample IDs)
# Use original copy number values for weights
df_weights = df_weighting_mat.T.loc[df_protein_data.index, df_samples.columns]
df_weights = 1 / df_weights.infer_objects(copy=False).replace(0, 1)
df_weights /= df_weights.mean()
df_weights
# Out:
# SAMPLE ID   S001_D10  S001_D23  S001_D42  S002_D10  S002_D23  S002_D42  \
# Entry
# A0A075B6I0  0.045838  0.055799  0.043846  3.247836  0.044752  0.029903
# A0A075B6I9  0.085482  0.268390  0.109159  3.247836  2.886157  3.597611
# A0A075B6J9  0.307696  5.060673  0.087411  3.247836  0.005885  3.597611
# A0A075B6K4  5.230472  5.060673  5.395902  3.247836  2.886157  3.597611
# A0A075B6K5  0.021754  0.021535  0.024399  0.012144  0.005561  0.005221
# ...              ...       ...       ...       ...       ...       ...
# Q9Y6E0      0.172518  0.149802  0.118851  0.063915  0.037077  0.060280
# Q9Y6I3      0.227488  0.031680  0.272153  3.247836  2.886157  3.597611
# Q9Y6M4      5.230472  0.232898  0.243353  3.247836  2.886157  3.597611
# Q9Y6M5      0.137213  0.132761  0.191651  0.028556  0.022274  0.033941
# Q9Y6R7      0.025834  0.024081  0.028156  0.012257  0.030706  0.026251
#
# SAMPLE ID   S003_D10  S003_D23  S003_D42  S004_D10  ...   Mean_D42  \
# Entry                                               ...
# A0A075B6I0  0.101152  0.090863  2.796661  0.137842  ...   0.073242
# A0A075B6I9  4.815362  3.717770  2.796661  5.676844  ...   0.750703
# A0A075B6J9  4.815362  3.717770  2.796661  5.676844  ...   0.087701
# A0A075B6K4  4.815362  3.717770  2.796661  5.676844  ...  36.921176
# A0A075B6K5  0.044768  0.013060  0.009201  0.015819  ...   0.020782
# ...              ...       ...       ...       ...  ...        ...
# Q9Y6E0      0.134882  0.073497  0.039531  0.156467  ...   0.166847
# Q9Y6I3      0.168640  3.717770  2.796661  0.320633  ...   0.496398
# Q9Y6M4      4.815362  0.109176  2.796661  0.236170  ...   0.056789
# Q9Y6M5      0.106867  0.044797  0.022553  0.163018  ...   0.136788
# Q9Y6R7      0.020391  0.017427  0.010825  0.030774  ...   0.050334
#
# SAMPLE ID   Median_D10  Median_D23  Median_D42  Mean_G6PD_V68M_0  \
# Entry
# A0A075B6I0    0.047498    0.049616    0.047745          0.078697
# A0A075B6I9    4.216259    4.299706    4.163339          0.752687
# A0A075B6J9    0.136180    0.183843    0.135785          0.100516
# A0A075B6K4    4.216259    4.299706    4.163339         34.586232
# A0A075B6K5    0.013797    0.014536    0.013529          0.022343
# ...                ...         ...         ...               ...
# Q9Y6E0        0.094939    0.098368    0.096185          0.175894
# Q9Y6I3        0.236492    0.311516    0.334884          0.443763
# Q9Y6M4        4.216259    0.433192    4.163339          0.069946
# Q9Y6M5        0.081258    0.083809    0.080037          0.146500
# Q9Y6R7        0.030203    0.031943    0.030645          0.052388
#
# SAMPLE ID   Mean_G6PD_V68M_1  Mean_G6PD_V68M_2  Median_G6PD_V68M_0  \
# Entry
# A0A075B6I0          0.055823          0.037466            0.047968
# A0A075B6I9          0.231624          0.674091            4.205181
# A0A075B6J9          0.121475          0.062729            0.150334
# A0A075B6K4          5.385648          5.380267            4.205181
# A0A075B6K5          0.033476          0.008478            0.013910
# ...                      ...               ...                 ...
# Q9Y6E0              0.161865          0.116882            0.096342
# Q9Y6I3              0.304374          0.445732            0.287588
# Q9Y6M4              0.028050          0.013433            4.205181
# Q9Y6M5              0.144931          0.102992            0.081545
# Q9Y6R7              0.060258          0.038030            0.030721
#
# SAMPLE ID   Median_G6PD_V68M_1  Median_G6PD_V68M_2
# Entry
# A0A075B6I0            0.054753            0.032992
# A0A075B6I9            5.017497            4.119326
# A0A075B6J9            0.164333            0.419605
# A0A075B6K4            5.017497            4.119326
# A0A075B6K5            0.021397            0.008261
# ...                        ...                 ...
# Q9Y6E0                0.109705            0.093850
# Q9Y6I3                0.270834            0.393209
# Q9Y6M4                0.301873            4.119326
# Q9Y6M5                0.099575            0.088898
# Q9Y6R7                0.043641            0.030786
#
# [1827 rows x 1922 columns]

# %% [markdown]
# ### Fit data by solving QP

# %%
log_zero_replacement = 1e-9
fitting_data = {"measured": {}, "best_fit": {}, "r2_objective": {}}
if run_computations:
    qp_solutions_dict = solve_qp_for_samples(
        pcmodel,
        df_samples,
        df_weights=df_weights,
        log_zero_replacement=log_zero_replacement,
        verbose=True,
    )

    for sample_id, (
        df_qp_sol,
        objective_value,
        r2_values,
    ) in qp_solutions_dict.items():
        fitting_data["measured"][sample_id] = df_qp_sol["Measured Proteome"].to_dict()
        fitting_data["best_fit"][sample_id] = df_qp_sol[
            "Best-Fitted Proteome"
        ].to_dict()
        fitting_data["r2_objective"][sample_id] = {
            "Objective": objective_value,
            "R^2": r2_values[0],
            "R^2 log10 w/ outliers": r2_values[1],
            "R^2 log10 w/o outliers": r2_values[2],
        }
    for key, data in fitting_data.items():
        data = pd.DataFrame.from_dict(data, orient="columns")
        data.to_csv(fitting_dirpath / f"proteome_{key}.tsv", sep="\t", index=True)
        fitting_data[key] = data
else:
    for key in fitting_data.keys():
        fitting_data[key] = pd.read_csv(
            fitting_dirpath / f"proteome_{key}.tsv", sep="\t", index_col=0
        )
    qp_solutions_dict = {}
    for sample_id in df_samples.columns:
        df_qp_sol = pd.concat(
            (
                fitting_data["measured"].loc[:, sample_id],
                fitting_data["best_fit"].loc[:, sample_id],
            ),
            axis=1,
        )
        df_qp_sol.columns = ["Measured Proteome", "Best-Fitted Proteome"]
        r2_values = fitting_data["r2_objective"].loc[:, sample_id].values
        objective_value, r2_values = r2_values[0], r2_values[1:]
        qp_solutions_dict[sample_id] = (df_qp_sol, objective_value, r2_values)
print(f"Number of QP solutions: {len(qp_solutions_dict)}")
# Out:
# Sample 'S001_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6787	R^2 log10 wo/outliers: 0.9268	Objective: -17170.52618
# Sample 'S001_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6340	R^2 log10 wo/outliers: 0.9553	Objective: -14589.37691
# Sample 'S001_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6524	R^2 log10 wo/outliers: 0.9456	Objective: -19346.71152
# Sample 'S002_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8331	R^2 log10 wo/outliers: 0.9137	Objective: -7385.94190
# Sample 'S002_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8129	R^2 log10 wo/outliers: 0.9077	Objective: -5965.75300
# Sample 'S002_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7617	R^2 log10 wo/outliers: 0.9662	Objective: -8622.40494
# Sample 'S003_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6863	R^2 log10 wo/outliers: 0.9516	Objective: -12858.76642
# Sample 'S003_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7331	R^2 log10 wo/outliers: 0.9685	Objective: -8940.65132
# Sample 'S003_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8270	R^2 log10 wo/outliers: 0.8562	Objective: -3136.96641
# Sample 'S004_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5892	R^2 log10 wo/outliers: 0.9662	Objective: -20644.57676
# Sample 'S004_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5599	R^2 log10 wo/outliers: 0.9671	Objective: -14113.28358
# Sample 'S004_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6107	R^2 log10 wo/outliers: 0.9450	Objective: -12706.22799
# Sample 'S005_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6875	R^2 log10 wo/outliers: 0.9603	Objective: -12406.48179
# Sample 'S005_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7483	R^2 log10 wo/outliers: 0.9283	Objective: -9442.58372
# Sample 'S005_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7196	R^2 log10 wo/outliers: 0.9603	Objective: -12191.14860
# Sample 'S006_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8029	R^2 log10 wo/outliers: 0.9696	Objective: -8154.27664
# Sample 'S006_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7809	R^2 log10 wo/outliers: 0.9193	Objective: -8896.91834
# Sample 'S006_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7943	R^2 log10 wo/outliers: 0.9717	Objective: -7803.99781
# Sample 'S007_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7651	R^2 log10 wo/outliers: 0.9584	Objective: -11282.87863
# Sample 'S007_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7095	R^2 log10 wo/outliers: 0.9356	Objective: -11481.10462
# Sample 'S007_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8284	R^2 log10 wo/outliers: 0.9391	Objective: -8030.07517
# Sample 'S008_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5840	R^2 log10 wo/outliers: 0.9287	Objective: -12364.35807
# Sample 'S008_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6826	R^2 log10 wo/outliers: 0.9535	Objective: -14184.37611
# Sample 'S008_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7322	R^2 log10 wo/outliers: 0.9459	Objective: -11652.72575
# Sample 'S009_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7823	R^2 log10 wo/outliers: 0.9684	Objective: -8370.68287
# Sample 'S009_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7357	R^2 log10 wo/outliers: 0.9521	Objective: -12051.68037
# Sample 'S009_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7294	R^2 log10 wo/outliers: 0.9786	Objective: -12421.69380
# Sample 'S010_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7214	R^2 log10 wo/outliers: 0.9464	Objective: -13254.53684
# Sample 'S010_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6432	R^2 log10 wo/outliers: 0.9748	Objective: -11825.50953
# Sample 'S010_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7796	R^2 log10 wo/outliers: 0.8673	Objective: -12658.08857
# Sample 'S011_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7715	R^2 log10 wo/outliers: 0.9392	Objective: -14677.96676
# Sample 'S011_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6622	R^2 log10 wo/outliers: 0.9507	Objective: -13750.56933
# Sample 'S011_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6984	R^2 log10 wo/outliers: 0.9515	Objective: -15615.44756
# Sample 'S012_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8254	R^2 log10 wo/outliers: 0.9307	Objective: -11951.38844
# Sample 'S012_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7300	R^2 log10 wo/outliers: 0.9616	Objective: -11311.07068
# Sample 'S012_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7455	R^2 log10 wo/outliers: 0.9795	Objective: -17578.27244
# Sample 'S013_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6678	R^2 log10 wo/outliers: 0.9506	Objective: -13781.10935
# Sample 'S013_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7719	R^2 log10 wo/outliers: 0.9360	Objective: -14902.94086
# Sample 'S013_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5459	R^2 log10 wo/outliers: 0.9777	Objective: -16892.39371
# Sample 'S014_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7559	R^2 log10 wo/outliers: 0.9396	Objective: -20669.06343
# Sample 'S014_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8564	R^2 log10 wo/outliers: 0.9375	Objective: -6662.04432
# Sample 'S014_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8194	R^2 log10 wo/outliers: 0.9248	Objective: -11140.22228
# Sample 'S015_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7575	R^2 log10 wo/outliers: 0.9706	Objective: -9853.89246
# Sample 'S015_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7591	R^2 log10 wo/outliers: 0.9591	Objective: -10836.18988
# Sample 'S015_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7654	R^2 log10 wo/outliers: 0.9750	Objective: -11967.01389
# Sample 'S016_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7648	R^2 log10 wo/outliers: 0.9437	Objective: -10473.70981
# Sample 'S016_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6832	R^2 log10 wo/outliers: 0.9447	Objective: -14218.96075
# Sample 'S016_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6704	R^2 log10 wo/outliers: 0.9445	Objective: -30415.27302
# Sample 'S017_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7449	R^2 log10 wo/outliers: 0.9614	Objective: -11306.62167
# Sample 'S017_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7930	R^2 log10 wo/outliers: 0.9412	Objective: -8089.44961
# Sample 'S017_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7666	R^2 log10 wo/outliers: 0.9720	Objective: -10288.20302
# Sample 'S018_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6960	R^2 log10 wo/outliers: 0.9773	Objective: -13300.08334
# Sample 'S018_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5950	R^2 log10 wo/outliers: 0.9622	Objective: -14863.67342
# Sample 'S018_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7039	R^2 log10 wo/outliers: 0.9340	Objective: -10880.48031
# Sample 'S019_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6882	R^2 log10 wo/outliers: 0.9451	Objective: -11076.20770
# Sample 'S019_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7576	R^2 log10 wo/outliers: 0.9492	Objective: -7858.63835
# Sample 'S019_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6924	R^2 log10 wo/outliers: 0.9460	Objective: -11076.12663
# Sample 'S020_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7106	R^2 log10 wo/outliers: 0.9458	Objective: -12853.93596
# Sample 'S020_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7071	R^2 log10 wo/outliers: 0.9694	Objective: -11486.72511
# Sample 'S020_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7698	R^2 log10 wo/outliers: 0.8975	Objective: -11376.60432
# Sample 'S021_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8367	R^2 log10 wo/outliers: 0.9533	Objective: -9684.43407
# Sample 'S021_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8241	R^2 log10 wo/outliers: 0.9319	Objective: -8164.20389
# Sample 'S021_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7961	R^2 log10 wo/outliers: 0.9500	Objective: -8705.52078
# Sample 'S022_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7138	R^2 log10 wo/outliers: 0.9630	Objective: -9362.29637
# Sample 'S022_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7835	R^2 log10 wo/outliers: 0.9652	Objective: -7735.33078
# Sample 'S022_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7470	R^2 log10 wo/outliers: 0.9388	Objective: -7594.25032
# Sample 'S023_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7152	R^2 log10 wo/outliers: 0.9708	Objective: -14179.28905
# Sample 'S023_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7115	R^2 log10 wo/outliers: 0.8911	Objective: -13499.90201
# Sample 'S023_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7010	R^2 log10 wo/outliers: 0.9768	Objective: -15779.94751
# Sample 'S024_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7903	R^2 log10 wo/outliers: 0.9465	Objective: -9016.18144
# Sample 'S024_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8265	R^2 log10 wo/outliers: 0.9215	Objective: -7947.57842
# Sample 'S024_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8309	R^2 log10 wo/outliers: 0.8785	Objective: -9119.67268
# Sample 'S025_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7357	R^2 log10 wo/outliers: 0.9429	Objective: -8458.37944
# Sample 'S025_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7864	R^2 log10 wo/outliers: 0.9314	Objective: -5325.66902
# Sample 'S025_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6857	R^2 log10 wo/outliers: 0.9659	Objective: -11020.50388
# Sample 'S026_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7663	R^2 log10 wo/outliers: 0.9563	Objective: -6784.16918
# Sample 'S026_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8105	R^2 log10 wo/outliers: 0.9519	Objective: -6305.04228
# Sample 'S026_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7730	R^2 log10 wo/outliers: 0.9471	Objective: -6850.64100
# Sample 'S027_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7717	R^2 log10 wo/outliers: 0.9592	Objective: -9766.31465
# Sample 'S027_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7311	R^2 log10 wo/outliers: 0.9306	Objective: -8735.23292
# Sample 'S027_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7984	R^2 log10 wo/outliers: 0.9297	Objective: -5200.53108
# Sample 'S028_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6922	R^2 log10 wo/outliers: 0.9672	Objective: -10099.04807
# Sample 'S028_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6968	R^2 log10 wo/outliers: 0.9601	Objective: -21826.00484
# Sample 'S028_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8282	R^2 log10 wo/outliers: 0.9581	Objective: -6545.88597
# Sample 'S029_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7800	R^2 log10 wo/outliers: 0.9374	Objective: -9776.74523
# Sample 'S029_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8089	R^2 log10 wo/outliers: 0.9557	Objective: -10996.05501
# Sample 'S029_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7855	R^2 log10 wo/outliers: 0.9351	Objective: -10791.84341
# Sample 'S030_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6788	R^2 log10 wo/outliers: 0.9582	Objective: -16664.72824
# Sample 'S030_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6757	R^2 log10 wo/outliers: 0.9690	Objective: -11411.77932
# Sample 'S030_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6879	R^2 log10 wo/outliers: 0.9485	Objective: -19153.21460
# Sample 'S031_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7301	R^2 log10 wo/outliers: 0.9591	Objective: -23562.57385
# Sample 'S031_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7134	R^2 log10 wo/outliers: 0.9506	Objective: -6569.48863
# Sample 'S031_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.4507	R^2 log10 wo/outliers: 0.9662	Objective: -24732.72393
# Sample 'S032_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7912	R^2 log10 wo/outliers: 0.9603	Objective: -10765.33198
# Sample 'S032_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7237	R^2 log10 wo/outliers: 0.9562	Objective: -8957.86810
# Sample 'S032_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7040	R^2 log10 wo/outliers: 0.9371	Objective: -10001.18309
# Sample 'S033_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8321	R^2 log10 wo/outliers: 0.9418	Objective: -8788.49601
# Sample 'S033_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7775	R^2 log10 wo/outliers: 0.9542	Objective: -8010.21420
# Sample 'S033_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7834	R^2 log10 wo/outliers: 0.9012	Objective: -6838.09470
# Sample 'S034_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6713	R^2 log10 wo/outliers: 0.9603	Objective: -13380.28880
# Sample 'S034_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6999	R^2 log10 wo/outliers: 0.9663	Objective: -12398.71985
# Sample 'S034_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6906	R^2 log10 wo/outliers: 0.9572	Objective: -13151.40533
# Sample 'S035_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7781	R^2 log10 wo/outliers: 0.9598	Objective: -9050.44899
# Sample 'S035_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7959	R^2 log10 wo/outliers: 0.9568	Objective: -9954.33481
# Sample 'S035_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7339	R^2 log10 wo/outliers: 0.9557	Objective: -10627.78706
# Sample 'S036_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7375	R^2 log10 wo/outliers: 0.9688	Objective: -10126.51710
# Sample 'S036_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8464	R^2 log10 wo/outliers: 0.9487	Objective: -9174.88284
# Sample 'S036_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8553	R^2 log10 wo/outliers: 0.9469	Objective: -10395.59041
# Sample 'S037_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7505	R^2 log10 wo/outliers: 0.9491	Objective: -10015.82307
# Sample 'S037_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7209	R^2 log10 wo/outliers: 0.9396	Objective: -12625.98453
# Sample 'S037_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7385	R^2 log10 wo/outliers: 0.9263	Objective: -6531.26833
# Sample 'S038_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7682	R^2 log10 wo/outliers: 0.9481	Objective: -7272.61512
# Sample 'S038_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7474	R^2 log10 wo/outliers: 0.9724	Objective: -9434.56165
# Sample 'S038_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8446	R^2 log10 wo/outliers: 0.9461	Objective: -9571.55997
# Sample 'S039_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7313	R^2 log10 wo/outliers: 0.9490	Objective: -16265.53884
# Sample 'S039_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7154	R^2 log10 wo/outliers: 0.9691	Objective: -12205.86015
# Sample 'S039_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5976	R^2 log10 wo/outliers: 0.9741	Objective: -27941.80367
# Sample 'S040_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7060	R^2 log10 wo/outliers: 0.9691	Objective: -15876.40134
# Sample 'S040_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7014	R^2 log10 wo/outliers: 0.9702	Objective: -13265.59356
# Sample 'S040_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8027	R^2 log10 wo/outliers: 0.9406	Objective: -7501.36969
# Sample 'S041_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7540	R^2 log10 wo/outliers: 0.9659	Objective: -13416.81423
# Sample 'S041_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8497	R^2 log10 wo/outliers: 0.9552	Objective: -11844.49942
# Sample 'S041_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7863	R^2 log10 wo/outliers: 0.9443	Objective: -12204.13835
# Sample 'S042_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7490	R^2 log10 wo/outliers: 0.9644	Objective: -13149.09116
# Sample 'S042_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7956	R^2 log10 wo/outliers: 0.9155	Objective: -8573.63971
# Sample 'S042_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8024	R^2 log10 wo/outliers: 0.9227	Objective: -15377.94888
# Sample 'S043_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6839	R^2 log10 wo/outliers: 0.9604	Objective: -11676.06571
# Sample 'S043_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6952	R^2 log10 wo/outliers: 0.9626	Objective: -11944.11445
# Sample 'S043_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7329	R^2 log10 wo/outliers: 0.9507	Objective: -10380.97048
# Sample 'S044_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7111	R^2 log10 wo/outliers: 0.9321	Objective: -14532.54357
# Sample 'S044_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7140	R^2 log10 wo/outliers: 0.9409	Objective: -12634.72937
# Sample 'S044_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6427	R^2 log10 wo/outliers: 0.9563	Objective: -17913.27611
# Sample 'S045_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6272	R^2 log10 wo/outliers: 0.9515	Objective: -31259.35659
# Sample 'S045_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8287	R^2 log10 wo/outliers: 0.9732	Objective: -15600.27230
# Sample 'S045_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7487	R^2 log10 wo/outliers: 0.9674	Objective: -9089.56462
# Sample 'S046_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7272	R^2 log10 wo/outliers: 0.9553	Objective: -8506.45178
# Sample 'S046_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6847	R^2 log10 wo/outliers: 0.9330	Objective: -17460.71711
# Sample 'S046_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5792	R^2 log10 wo/outliers: 0.9629	Objective: -29465.26815
# Sample 'S047_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6214	R^2 log10 wo/outliers: 0.9611	Objective: -21566.84545
# Sample 'S047_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7488	R^2 log10 wo/outliers: 0.9072	Objective: -16885.14793
# Sample 'S047_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7161	R^2 log10 wo/outliers: 0.9486	Objective: -16242.52270
# Sample 'S048_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7289	R^2 log10 wo/outliers: 0.9141	Objective: -12502.39058
# Sample 'S048_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7457	R^2 log10 wo/outliers: 0.9615	Objective: -10580.13378
# Sample 'S048_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7295	R^2 log10 wo/outliers: 0.9614	Objective: -11879.62206
# Sample 'S049_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5752	R^2 log10 wo/outliers: 0.9748	Objective: -18765.83299
# Sample 'S049_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6530	R^2 log10 wo/outliers: 0.9584	Objective: -17486.70453
# Sample 'S049_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5523	R^2 log10 wo/outliers: 0.9740	Objective: -19412.53710
# Sample 'S050_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7662	R^2 log10 wo/outliers: 0.9614	Objective: -15670.12232
# Sample 'S050_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7698	R^2 log10 wo/outliers: 0.9440	Objective: -11778.04996
# Sample 'S050_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7340	R^2 log10 wo/outliers: 0.9645	Objective: -15010.71272
# Sample 'S051_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7403	R^2 log10 wo/outliers: 0.9274	Objective: -17476.28908
# Sample 'S051_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6563	R^2 log10 wo/outliers: 0.9546	Objective: -15746.99853
# Sample 'S051_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7375	R^2 log10 wo/outliers: 0.9365	Objective: -15679.50028
# Sample 'S052_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8270	R^2 log10 wo/outliers: 0.9706	Objective: -15122.23119
# Sample 'S052_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6032	R^2 log10 wo/outliers: 0.9529	Objective: -11464.63857
# Sample 'S052_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7432	R^2 log10 wo/outliers: 0.9548	Objective: -16206.56519
# Sample 'S053_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7162	R^2 log10 wo/outliers: 0.9481	Objective: -10487.27378
# Sample 'S053_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7669	R^2 log10 wo/outliers: 0.9630	Objective: -5835.08898
# Sample 'S053_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6935	R^2 log10 wo/outliers: 0.9591	Objective: -20502.03989
# Sample 'S054_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7367	R^2 log10 wo/outliers: 0.9510	Objective: -17025.26118
# Sample 'S054_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7458	R^2 log10 wo/outliers: 0.9493	Objective: -18853.33890
# Sample 'S054_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7617	R^2 log10 wo/outliers: 0.9577	Objective: -19429.80562
# Sample 'S055_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5832	R^2 log10 wo/outliers: 0.9409	Objective: -11431.07124
# Sample 'S055_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6477	R^2 log10 wo/outliers: 0.9614	Objective: -11330.84599
# Sample 'S055_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6169	R^2 log10 wo/outliers: 0.9460	Objective: -15079.36496
# Sample 'S056_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7491	R^2 log10 wo/outliers: 0.9370	Objective: -10924.65415
# Sample 'S056_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7575	R^2 log10 wo/outliers: 0.9638	Objective: -10215.36877
# Sample 'S056_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8055	R^2 log10 wo/outliers: 0.9360	Objective: -7375.11816
# Sample 'S057_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7547	R^2 log10 wo/outliers: 0.9543	Objective: -14467.70209
# Sample 'S057_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7440	R^2 log10 wo/outliers: 0.9706	Objective: -9504.97082
# Sample 'S057_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7683	R^2 log10 wo/outliers: 0.9314	Objective: -11804.47105
# Sample 'S058_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7357	R^2 log10 wo/outliers: 0.9386	Objective: -8972.36848
# Sample 'S058_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7215	R^2 log10 wo/outliers: 0.9304	Objective: -10804.23510
# Sample 'S058_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7049	R^2 log10 wo/outliers: 0.9491	Objective: -9541.81443
# Sample 'S059_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6440	R^2 log10 wo/outliers: 0.9579	Objective: -21876.68204
# Sample 'S059_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5941	R^2 log10 wo/outliers: 0.9526	Objective: -20672.05779
# Sample 'S059_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6167	R^2 log10 wo/outliers: 0.9509	Objective: -19432.43122
# Sample 'S060_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6566	R^2 log10 wo/outliers: 0.9767	Objective: -18030.94228
# Sample 'S060_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6432	R^2 log10 wo/outliers: 0.9728	Objective: -21404.95286
# Sample 'S060_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7623	R^2 log10 wo/outliers: 0.9182	Objective: -20415.21683
# Sample 'S061_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8198	R^2 log10 wo/outliers: 0.9592	Objective: -11748.18230
# Sample 'S061_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6929	R^2 log10 wo/outliers: 0.9693	Objective: -12334.98122
# Sample 'S061_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8079	R^2 log10 wo/outliers: 0.9522	Objective: -10465.55350
# Sample 'S062_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7581	R^2 log10 wo/outliers: 0.9624	Objective: -9939.34156
# Sample 'S062_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6354	R^2 log10 wo/outliers: 0.9718	Objective: -27367.71694
# Sample 'S062_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6778	R^2 log10 wo/outliers: 0.9469	Objective: -16828.24180
# Sample 'S063_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7381	R^2 log10 wo/outliers: 0.9495	Objective: -19357.39504
# Sample 'S063_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6515	R^2 log10 wo/outliers: 0.9413	Objective: -18790.44008
# Sample 'S063_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6824	R^2 log10 wo/outliers: 0.9614	Objective: -17830.13033
# Sample 'S064_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7772	R^2 log10 wo/outliers: 0.9482	Objective: -8521.31409
# Sample 'S064_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6171	R^2 log10 wo/outliers: 0.9841	Objective: -20658.88509
# Sample 'S064_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7654	R^2 log10 wo/outliers: 0.9404	Objective: -10509.84550
# Sample 'S065_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7399	R^2 log10 wo/outliers: 0.9627	Objective: -11153.36377
# Sample 'S065_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7365	R^2 log10 wo/outliers: 0.9702	Objective: -8603.71861
# Sample 'S065_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7967	R^2 log10 wo/outliers: 0.9359	Objective: -11240.26537
# Sample 'S066_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6861	R^2 log10 wo/outliers: 0.9740	Objective: -10475.93854
# Sample 'S066_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7283	R^2 log10 wo/outliers: 0.9500	Objective: -7974.54674
# Sample 'S066_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6923	R^2 log10 wo/outliers: 0.9021	Objective: -12098.98532
# Sample 'S067_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6827	R^2 log10 wo/outliers: 0.9689	Objective: -10793.09766
# Sample 'S067_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7066	R^2 log10 wo/outliers: 0.9557	Objective: -10230.37010
# Sample 'S067_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7548	R^2 log10 wo/outliers: 0.9638	Objective: -9945.42962
# Sample 'S068_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7508	R^2 log10 wo/outliers: 0.9389	Objective: -11349.84002
# Sample 'S068_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7312	R^2 log10 wo/outliers: 0.9591	Objective: -12768.12504
# Sample 'S068_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7437	R^2 log10 wo/outliers: 0.9692	Objective: -11005.92287
# Sample 'S069_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7156	R^2 log10 wo/outliers: 0.9612	Objective: -12767.93217
# Sample 'S069_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6999	R^2 log10 wo/outliers: 0.9684	Objective: -16009.24856
# Sample 'S069_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7074	R^2 log10 wo/outliers: 0.9587	Objective: -15442.77051
# Sample 'S070_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7935	R^2 log10 wo/outliers: 0.9462	Objective: -5312.38634
# Sample 'S070_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5636	R^2 log10 wo/outliers: 0.9790	Objective: -24993.90128
# Sample 'S070_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7559	R^2 log10 wo/outliers: 0.9653	Objective: -7485.32702
# Sample 'S071_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6715	R^2 log10 wo/outliers: 0.9248	Objective: -11645.31490
# Sample 'S071_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7672	R^2 log10 wo/outliers: 0.9707	Objective: -9794.24059
# Sample 'S071_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7821	R^2 log10 wo/outliers: 0.9556	Objective: -7863.76980
# Sample 'S072_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6387	R^2 log10 wo/outliers: 0.9744	Objective: -21322.16963
# Sample 'S072_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7919	R^2 log10 wo/outliers: 0.9661	Objective: -8024.64753
# Sample 'S072_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5736	R^2 log10 wo/outliers: 0.9713	Objective: -28197.45592
# Sample 'S073_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6629	R^2 log10 wo/outliers: 0.9593	Objective: -10488.32453
# Sample 'S073_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6937	R^2 log10 wo/outliers: 0.9508	Objective: -11880.53817
# Sample 'S073_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7567	R^2 log10 wo/outliers: 0.9670	Objective: -11432.12558
# Sample 'S074_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7182	R^2 log10 wo/outliers: 0.9704	Objective: -9996.58560
# Sample 'S074_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6413	R^2 log10 wo/outliers: 0.9634	Objective: -11933.73429
# Sample 'S074_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6558	R^2 log10 wo/outliers: 0.9243	Objective: -11454.09788
# Sample 'S075_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7605	R^2 log10 wo/outliers: 0.9568	Objective: -8595.30267
# Sample 'S075_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8342	R^2 log10 wo/outliers: 0.9558	Objective: -12780.16878
# Sample 'S075_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7879	R^2 log10 wo/outliers: 0.9725	Objective: -10959.75867
# Sample 'S076_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7463	R^2 log10 wo/outliers: 0.9383	Objective: -13647.87233
# Sample 'S076_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7126	R^2 log10 wo/outliers: 0.9670	Objective: -16206.31494
# Sample 'S076_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6740	R^2 log10 wo/outliers: 0.9433	Objective: -15900.90582
# Sample 'S077_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7019	R^2 log10 wo/outliers: 0.9659	Objective: -9748.87692
# Sample 'S077_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7696	R^2 log10 wo/outliers: 0.9414	Objective: -10233.49964
# Sample 'S077_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7146	R^2 log10 wo/outliers: 0.9482	Objective: -11054.21768
# Sample 'S078_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7490	R^2 log10 wo/outliers: 0.9547	Objective: -9829.43918
# Sample 'S078_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5037	R^2 log10 wo/outliers: 0.9759	Objective: -17503.68626
# Sample 'S078_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7229	R^2 log10 wo/outliers: 0.9636	Objective: -8814.96590
# Sample 'S079_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7052	R^2 log10 wo/outliers: 0.9795	Objective: -11656.94542
# Sample 'S079_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6001	R^2 log10 wo/outliers: 0.9633	Objective: -12459.90536
# Sample 'S079_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5971	R^2 log10 wo/outliers: 0.9538	Objective: -21961.22661
# Sample 'S080_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6870	R^2 log10 wo/outliers: 0.9513	Objective: -11428.26070
# Sample 'S080_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6786	R^2 log10 wo/outliers: 0.9350	Objective: -13396.46667
# Sample 'S080_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7386	R^2 log10 wo/outliers: 0.9577	Objective: -12156.24292
# Sample 'S081_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6236	R^2 log10 wo/outliers: 0.9630	Objective: -16710.14822
# Sample 'S081_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7730	R^2 log10 wo/outliers: 0.9392	Objective: -14010.28471
# Sample 'S081_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8257	R^2 log10 wo/outliers: 0.9458	Objective: -9480.22175
# Sample 'S082_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6872	R^2 log10 wo/outliers: 0.9097	Objective: -8260.00931
# Sample 'S082_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6291	R^2 log10 wo/outliers: 0.9414	Objective: -10649.82389
# Sample 'S082_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7656	R^2 log10 wo/outliers: 0.9277	Objective: -9924.13872
# Sample 'S083_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7565	R^2 log10 wo/outliers: 0.9716	Objective: -8907.40241
# Sample 'S083_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6400	R^2 log10 wo/outliers: 0.9579	Objective: -27107.94292
# Sample 'S083_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6905	R^2 log10 wo/outliers: 0.9559	Objective: -12556.88166
# Sample 'S084_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5445	R^2 log10 wo/outliers: 0.9676	Objective: -21827.02024
# Sample 'S084_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8216	R^2 log10 wo/outliers: 0.9227	Objective: -8036.26356
# Sample 'S084_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6770	R^2 log10 wo/outliers: 0.8819	Objective: -11660.48367
# Sample 'S085_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6787	R^2 log10 wo/outliers: 0.9632	Objective: -10319.28769
# Sample 'S085_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6714	R^2 log10 wo/outliers: 0.9845	Objective: -12935.94317
# Sample 'S085_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6144	R^2 log10 wo/outliers: 0.9798	Objective: -11479.17486
# Sample 'S086_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7707	R^2 log10 wo/outliers: 0.9292	Objective: -14357.68594
# Sample 'S086_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7026	R^2 log10 wo/outliers: 0.9615	Objective: -12743.92968
# Sample 'S086_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6632	R^2 log10 wo/outliers: 0.9766	Objective: -14461.96068
# Sample 'S087_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6481	R^2 log10 wo/outliers: 0.9380	Objective: -11665.64996
# Sample 'S087_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6405	R^2 log10 wo/outliers: 0.9653	Objective: -12252.00024
# Sample 'S087_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6865	R^2 log10 wo/outliers: 0.9545	Objective: -11872.04818
# Sample 'S088_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6699	R^2 log10 wo/outliers: 0.9669	Objective: -13139.04723
# Sample 'S088_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6466	R^2 log10 wo/outliers: 0.9663	Objective: -23116.53073
# Sample 'S088_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6706	R^2 log10 wo/outliers: 0.9557	Objective: -7714.77823
# Sample 'S089_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7489	R^2 log10 wo/outliers: 0.9409	Objective: -8969.32164
# Sample 'S089_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6016	R^2 log10 wo/outliers: 0.9791	Objective: -28929.98625
# Sample 'S089_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6896	R^2 log10 wo/outliers: 0.9747	Objective: -9798.20846
# Sample 'S090_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5779	R^2 log10 wo/outliers: 0.9651	Objective: -17386.86302
# Sample 'S090_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7275	R^2 log10 wo/outliers: 0.9564	Objective: -11603.16409
# Sample 'S090_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7369	R^2 log10 wo/outliers: 0.9549	Objective: -17020.69254
# Sample 'S091_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7677	R^2 log10 wo/outliers: 0.9199	Objective: -6621.41042
# Sample 'S091_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5527	R^2 log10 wo/outliers: 0.9748	Objective: -13536.39781
# Sample 'S091_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6856	R^2 log10 wo/outliers: 0.9789	Objective: -11095.64201
# Sample 'S092_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7410	R^2 log10 wo/outliers: 0.9648	Objective: -10608.92981
# Sample 'S092_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7114	R^2 log10 wo/outliers: 0.9449	Objective: -21703.15348
# Sample 'S092_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7295	R^2 log10 wo/outliers: 0.9665	Objective: -12351.62829
# Sample 'S093_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7894	R^2 log10 wo/outliers: 0.9220	Objective: -6585.60854
# Sample 'S093_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7985	R^2 log10 wo/outliers: 0.9289	Objective: -5089.19059
# Sample 'S093_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7693	R^2 log10 wo/outliers: 0.9558	Objective: -7870.34300
# Sample 'S094_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7886	R^2 log10 wo/outliers: 0.9566	Objective: -12610.67959
# Sample 'S094_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5988	R^2 log10 wo/outliers: 0.9639	Objective: -12120.16087
# Sample 'S094_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6788	R^2 log10 wo/outliers: 0.9540	Objective: -11220.21401
# Sample 'S095_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7767	R^2 log10 wo/outliers: 0.9371	Objective: -6193.42336
# Sample 'S095_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7047	R^2 log10 wo/outliers: 0.9700	Objective: -17523.32961
# Sample 'S095_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7505	R^2 log10 wo/outliers: 0.9714	Objective: -6906.55087
# Sample 'S096_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7774	R^2 log10 wo/outliers: 0.9582	Objective: -15828.51750
# Sample 'S096_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7073	R^2 log10 wo/outliers: 0.9359	Objective: -13216.79238
# Sample 'S096_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7466	R^2 log10 wo/outliers: 0.9423	Objective: -14209.93089
# Sample 'S097_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8426	R^2 log10 wo/outliers: 0.9576	Objective: -15293.72560
# Sample 'S097_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7970	R^2 log10 wo/outliers: 0.9315	Objective: -13908.62018
# Sample 'S097_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7637	R^2 log10 wo/outliers: 0.9401	Objective: -17590.74752
# Sample 'S098_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8139	R^2 log10 wo/outliers: 0.9562	Objective: -10650.15297
# Sample 'S098_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8004	R^2 log10 wo/outliers: 0.9523	Objective: -8687.37153
# Sample 'S098_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7508	R^2 log10 wo/outliers: 0.9626	Objective: -13700.50232
# Sample 'S099_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6837	R^2 log10 wo/outliers: 0.9446	Objective: -22861.12884
# Sample 'S099_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7861	R^2 log10 wo/outliers: 0.9576	Objective: -10276.40145
# Sample 'S099_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8341	R^2 log10 wo/outliers: 0.9467	Objective: -8027.70638
# Sample 'S100_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7652	R^2 log10 wo/outliers: 0.9579	Objective: -10567.08583
# Sample 'S100_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7424	R^2 log10 wo/outliers: 0.9603	Objective: -12101.01006
# Sample 'S100_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7662	R^2 log10 wo/outliers: 0.9556	Objective: -10896.81387
# Sample 'S101_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7374	R^2 log10 wo/outliers: 0.9707	Objective: -11261.91984
# Sample 'S101_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7292	R^2 log10 wo/outliers: 0.9448	Objective: -14401.23326
# Sample 'S101_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7763	R^2 log10 wo/outliers: 0.9491	Objective: -18180.67975
# Sample 'S102_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7638	R^2 log10 wo/outliers: 0.9226	Objective: -10565.79377
# Sample 'S102_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8761	R^2 log10 wo/outliers: 0.9595	Objective: -8040.34699
# Sample 'S102_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7353	R^2 log10 wo/outliers: 0.9415	Objective: -13382.63448
# Sample 'S103_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8050	R^2 log10 wo/outliers: 0.9277	Objective: -6432.90589
# Sample 'S103_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7886	R^2 log10 wo/outliers: 0.9172	Objective: -16321.71150
# Sample 'S103_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6341	R^2 log10 wo/outliers: 0.9681	Objective: -24692.22194
# Sample 'S104_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6692	R^2 log10 wo/outliers: 0.9484	Objective: -15092.67965
# Sample 'S104_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7982	R^2 log10 wo/outliers: 0.9400	Objective: -13122.90251
# Sample 'S104_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7157	R^2 log10 wo/outliers: 0.9667	Objective: -15055.10225
# Sample 'S105_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7775	R^2 log10 wo/outliers: 0.9581	Objective: -10829.11024
# Sample 'S105_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7887	R^2 log10 wo/outliers: 0.9721	Objective: -10698.55118
# Sample 'S105_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8066	R^2 log10 wo/outliers: 0.9371	Objective: -10922.69339
# Sample 'S106_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7776	R^2 log10 wo/outliers: 0.9628	Objective: -8992.50954
# Sample 'S106_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6649	R^2 log10 wo/outliers: 0.9682	Objective: -26065.01736
# Sample 'S106_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7709	R^2 log10 wo/outliers: 0.9497	Objective: -12784.36273
# Sample 'S107_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7799	R^2 log10 wo/outliers: 0.9641	Objective: -8553.52174
# Sample 'S107_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6708	R^2 log10 wo/outliers: 0.9410	Objective: -22195.47751
# Sample 'S107_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8125	R^2 log10 wo/outliers: 0.9566	Objective: -9879.29871
# Sample 'S108_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7413	R^2 log10 wo/outliers: 0.9402	Objective: -16631.08555
# Sample 'S108_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6803	R^2 log10 wo/outliers: 0.9486	Objective: -15707.34050
# Sample 'S108_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7174	R^2 log10 wo/outliers: 0.9456	Objective: -14729.21983
# Sample 'S109_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7362	R^2 log10 wo/outliers: 0.9254	Objective: -11939.00880
# Sample 'S109_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7188	R^2 log10 wo/outliers: 0.9562	Objective: -12228.02559
# Sample 'S109_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7259	R^2 log10 wo/outliers: 0.9500	Objective: -10077.29495
# Sample 'S110_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8082	R^2 log10 wo/outliers: 0.9187	Objective: -10864.55341
# Sample 'S110_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8403	R^2 log10 wo/outliers: 0.9499	Objective: -11730.84669
# Sample 'S110_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8135	R^2 log10 wo/outliers: 0.8966	Objective: -6814.29191
# Sample 'S111_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5404	R^2 log10 wo/outliers: 0.9544	Objective: -19065.52034
# Sample 'S111_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6959	R^2 log10 wo/outliers: 0.9276	Objective: -16567.02726
# Sample 'S111_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6473	R^2 log10 wo/outliers: 0.9567	Objective: -18560.06670
# Sample 'S112_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7733	R^2 log10 wo/outliers: 0.9233	Objective: -13244.76486
# Sample 'S112_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6983	R^2 log10 wo/outliers: 0.9456	Objective: -15373.97117
# Sample 'S112_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7140	R^2 log10 wo/outliers: 0.9635	Objective: -16328.29289
# Sample 'S113_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6930	R^2 log10 wo/outliers: 0.9668	Objective: -11524.29178
# Sample 'S113_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7168	R^2 log10 wo/outliers: 0.9575	Objective: -10349.76606
# Sample 'S113_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7329	R^2 log10 wo/outliers: 0.9793	Objective: -10789.29299
# Sample 'S114_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7144	R^2 log10 wo/outliers: 0.9588	Objective: -12047.08632
# Sample 'S114_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7189	R^2 log10 wo/outliers: 0.9474	Objective: -9980.56938
# Sample 'S114_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6967	R^2 log10 wo/outliers: 0.9427	Objective: -10152.34989
# Sample 'S115_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6791	R^2 log10 wo/outliers: 0.9587	Objective: -20189.55146
# Sample 'S115_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7786	R^2 log10 wo/outliers: 0.9308	Objective: -16307.90177
# Sample 'S115_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7851	R^2 log10 wo/outliers: 0.9553	Objective: -14598.37854
# Sample 'S116_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6187	R^2 log10 wo/outliers: 0.9470	Objective: -20726.85671
# Sample 'S116_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6017	R^2 log10 wo/outliers: 0.9537	Objective: -20722.21012
# Sample 'S116_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7891	R^2 log10 wo/outliers: 0.9468	Objective: -22243.30547
# Sample 'S117_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7906	R^2 log10 wo/outliers: 0.9514	Objective: -10020.78324
# Sample 'S117_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8041	R^2 log10 wo/outliers: 0.9536	Objective: -12862.40179
# Sample 'S117_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7353	R^2 log10 wo/outliers: 0.9290	Objective: -8671.18969
# Sample 'S118_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7798	R^2 log10 wo/outliers: 0.9537	Objective: -15517.73373
# Sample 'S118_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7598	R^2 log10 wo/outliers: 0.9609	Objective: -15980.75319
# Sample 'S118_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7699	R^2 log10 wo/outliers: 0.9689	Objective: -14697.70603
# Sample 'S119_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6809	R^2 log10 wo/outliers: 0.9406	Objective: -13074.93017
# Sample 'S119_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7202	R^2 log10 wo/outliers: 0.9569	Objective: -10173.53493
# Sample 'S119_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7279	R^2 log10 wo/outliers: 0.9778	Objective: -10779.01605
# Sample 'S120_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6268	R^2 log10 wo/outliers: 0.9646	Objective: -14307.34757
# Sample 'S120_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6795	R^2 log10 wo/outliers: 0.9754	Objective: -24158.25577
# Sample 'S120_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7389	R^2 log10 wo/outliers: 0.9373	Objective: -10616.96149
# Sample 'S121_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6796	R^2 log10 wo/outliers: 0.9529	Objective: -22243.17694
# Sample 'S121_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6855	R^2 log10 wo/outliers: 0.9146	Objective: -19867.76763
# Sample 'S121_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8009	R^2 log10 wo/outliers: 0.9453	Objective: -16550.27063
# Sample 'S122_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7489	R^2 log10 wo/outliers: 0.9217	Objective: -13319.23166
# Sample 'S122_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7522	R^2 log10 wo/outliers: 0.9757	Objective: -12873.59000
# Sample 'S122_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7908	R^2 log10 wo/outliers: 0.9346	Objective: -11794.05268
# Sample 'S123_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6963	R^2 log10 wo/outliers: 0.9432	Objective: -14323.37881
# Sample 'S123_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8345	R^2 log10 wo/outliers: 0.9589	Objective: -13083.37324
# Sample 'S123_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7157	R^2 log10 wo/outliers: 0.9553	Objective: -19051.86688
# Sample 'S124_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7360	R^2 log10 wo/outliers: 0.9659	Objective: -14771.71629
# Sample 'S124_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7491	R^2 log10 wo/outliers: 0.9502	Objective: -12597.33964
# Sample 'S124_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7807	R^2 log10 wo/outliers: 0.9444	Objective: -15133.66856
# Sample 'S125_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7419	R^2 log10 wo/outliers: 0.9226	Objective: -9316.79836
# Sample 'S125_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6672	R^2 log10 wo/outliers: 0.9616	Objective: -24496.02759
# Sample 'S125_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7854	R^2 log10 wo/outliers: 0.9751	Objective: -12446.81996
# Sample 'S126_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7654	R^2 log10 wo/outliers: 0.9684	Objective: -12353.22179
# Sample 'S126_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8157	R^2 log10 wo/outliers: 0.9500	Objective: -11406.75759
# Sample 'S126_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8300	R^2 log10 wo/outliers: 0.9474	Objective: -8363.65794
# Sample 'S127_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8296	R^2 log10 wo/outliers: 0.9336	Objective: -21538.81063
# Sample 'S127_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7494	R^2 log10 wo/outliers: 0.9464	Objective: -18223.17247
# Sample 'S127_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7501	R^2 log10 wo/outliers: 0.9491	Objective: -18157.46598
# Sample 'S128_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8346	R^2 log10 wo/outliers: 0.9704	Objective: -16888.12686
# Sample 'S128_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8479	R^2 log10 wo/outliers: 0.9183	Objective: -11961.40931
# Sample 'S128_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7516	R^2 log10 wo/outliers: 0.9484	Objective: -19397.42970
# Sample 'S129_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6173	R^2 log10 wo/outliers: 0.9692	Objective: -14271.70568
# Sample 'S129_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6966	R^2 log10 wo/outliers: 0.9579	Objective: -12515.36657
# Sample 'S129_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7125	R^2 log10 wo/outliers: 0.9627	Objective: -12442.79029
# Sample 'S130_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7329	R^2 log10 wo/outliers: 0.9564	Objective: -10823.24784
# Sample 'S130_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7344	R^2 log10 wo/outliers: 0.9661	Objective: -23468.59307
# Sample 'S130_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6684	R^2 log10 wo/outliers: 0.9706	Objective: -18933.66113
# Sample 'S131_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7696	R^2 log10 wo/outliers: 0.9459	Objective: -8902.05995
# Sample 'S131_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7790	R^2 log10 wo/outliers: 0.9745	Objective: -7729.77494
# Sample 'S131_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7600	R^2 log10 wo/outliers: 0.9631	Objective: -7769.20044
# Sample 'S132_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7475	R^2 log10 wo/outliers: 0.9654	Objective: -11475.75984
# Sample 'S132_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7348	R^2 log10 wo/outliers: 0.9634	Objective: -11475.49721
# Sample 'S132_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6212	R^2 log10 wo/outliers: 0.9642	Objective: -11366.10760
# Sample 'S133_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7300	R^2 log10 wo/outliers: 0.9462	Objective: -17334.83546
# Sample 'S133_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7253	R^2 log10 wo/outliers: 0.9293	Objective: -17129.30842
# Sample 'S133_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7694	R^2 log10 wo/outliers: 0.9068	Objective: -20803.79443
# Sample 'S134_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7111	R^2 log10 wo/outliers: 0.9482	Objective: -10716.90208
# Sample 'S134_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7579	R^2 log10 wo/outliers: 0.9701	Objective: -11234.83812
# Sample 'S134_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7673	R^2 log10 wo/outliers: 0.9342	Objective: -9651.32822
# Sample 'S135_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7389	R^2 log10 wo/outliers: 0.9741	Objective: -10441.89156
# Sample 'S135_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7391	R^2 log10 wo/outliers: 0.9773	Objective: -8772.54238
# Sample 'S135_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7475	R^2 log10 wo/outliers: 0.9473	Objective: -8595.10552
# Sample 'S136_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7853	R^2 log10 wo/outliers: 0.9327	Objective: -8395.24980
# Sample 'S136_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7360	R^2 log10 wo/outliers: 0.9288	Objective: -8745.86411
# Sample 'S136_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7922	R^2 log10 wo/outliers: 0.9431	Objective: -6806.90472
# Sample 'S137_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6687	R^2 log10 wo/outliers: 0.9457	Objective: -13928.66677
# Sample 'S137_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7395	R^2 log10 wo/outliers: 0.9657	Objective: -15016.96794
# Sample 'S137_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6068	R^2 log10 wo/outliers: 0.9636	Objective: -13072.53095
# Sample 'S138_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7397	R^2 log10 wo/outliers: 0.9399	Objective: -12957.85051
# Sample 'S138_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7446	R^2 log10 wo/outliers: 0.9513	Objective: -17202.21306
# Sample 'S138_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7583	R^2 log10 wo/outliers: 0.9659	Objective: -13925.17199
# Sample 'S139_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8212	R^2 log10 wo/outliers: 0.9335	Objective: -13299.12239
# Sample 'S139_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7943	R^2 log10 wo/outliers: 0.9327	Objective: -11378.47581
# Sample 'S139_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7295	R^2 log10 wo/outliers: 0.9601	Objective: -11154.11554
# Sample 'S140_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7130	R^2 log10 wo/outliers: 0.9678	Objective: -13100.05386
# Sample 'S140_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7479	R^2 log10 wo/outliers: 0.9515	Objective: -12237.26365
# Sample 'S140_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7914	R^2 log10 wo/outliers: 0.9408	Objective: -13929.21700
# Sample 'S141_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7418	R^2 log10 wo/outliers: 0.9541	Objective: -13214.74479
# Sample 'S141_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7813	R^2 log10 wo/outliers: 0.9546	Objective: -12076.92175
# Sample 'S141_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7355	R^2 log10 wo/outliers: 0.9573	Objective: -14391.42367
# Sample 'S142_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7871	R^2 log10 wo/outliers: 0.9415	Objective: -10115.31102
# Sample 'S142_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7490	R^2 log10 wo/outliers: 0.9449	Objective: -7497.04756
# ...
# Sample 'S594_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7036	R^2 log10 wo/outliers: 0.9551	Objective: -15966.72422
# Sample 'S595_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7924	R^2 log10 wo/outliers: 0.9523	Objective: -8186.10732
# Sample 'S595_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7985	R^2 log10 wo/outliers: 0.9470	Objective: -8579.34957
# Sample 'S595_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7236	R^2 log10 wo/outliers: 0.9262	Objective: -10280.98143
# Sample 'S596_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8026	R^2 log10 wo/outliers: 0.9394	Objective: -12460.47669
# Sample 'S596_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7729	R^2 log10 wo/outliers: 0.9398	Objective: -10519.72634
# Sample 'S596_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7751	R^2 log10 wo/outliers: 0.9548	Objective: -9674.50252
# Sample 'S597_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7735	R^2 log10 wo/outliers: 0.9485	Objective: -12351.49735
# Sample 'S597_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7410	R^2 log10 wo/outliers: 0.9734	Objective: -13361.41104
# Sample 'S597_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7134	R^2 log10 wo/outliers: 0.9536	Objective: -17201.51334
# Sample 'S598_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7394	R^2 log10 wo/outliers: 0.9443	Objective: -13268.01316
# Sample 'S598_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7160	R^2 log10 wo/outliers: 0.9581	Objective: -14594.10246
# Sample 'S598_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7401	R^2 log10 wo/outliers: 0.9503	Objective: -10652.08299
# Sample 'S599_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8030	R^2 log10 wo/outliers: 0.9720	Objective: -8344.84690
# Sample 'S599_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7894	R^2 log10 wo/outliers: 0.9598	Objective: -12601.85695
# Sample 'S599_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7305	R^2 log10 wo/outliers: 0.9510	Objective: -11849.59797
# Sample 'S600_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7846	R^2 log10 wo/outliers: 0.9599	Objective: -6738.50915
# Sample 'S600_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6377	R^2 log10 wo/outliers: 0.9603	Objective: -21305.25179
# Sample 'S600_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8576	R^2 log10 wo/outliers: 0.9624	Objective: -7802.58480
# Sample 'S601_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7103	R^2 log10 wo/outliers: 0.9592	Objective: -9089.75767
# Sample 'S601_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7343	R^2 log10 wo/outliers: 0.9456	Objective: -9138.29068
# Sample 'S601_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8157	R^2 log10 wo/outliers: 0.9671	Objective: -8511.82714
# Sample 'S602_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7370	R^2 log10 wo/outliers: 0.9469	Objective: -14203.60368
# Sample 'S602_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7555	R^2 log10 wo/outliers: 0.9643	Objective: -11872.99726
# Sample 'S602_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6867	R^2 log10 wo/outliers: 0.9524	Objective: -14488.46152
# Sample 'S603_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.5831	R^2 log10 wo/outliers: 0.9631	Objective: -26287.68019
# Sample 'S603_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7946	R^2 log10 wo/outliers: 0.9305	Objective: -5788.70379
# Sample 'S603_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7331	R^2 log10 wo/outliers: 0.9548	Objective: -12712.36940
# Sample 'S604_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7308	R^2 log10 wo/outliers: 0.9406	Objective: -11846.46626
# Sample 'S604_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6777	R^2 log10 wo/outliers: 0.9633	Objective: -13789.24478
# Sample 'S604_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7792	R^2 log10 wo/outliers: 0.9390	Objective: -10484.04285
# Sample 'S605_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6899	R^2 log10 wo/outliers: 0.9431	Objective: -17595.32569
# Sample 'S605_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7404	R^2 log10 wo/outliers: 0.9497	Objective: -17109.07150
# Sample 'S605_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6926	R^2 log10 wo/outliers: 0.9360	Objective: -16440.41332
# Sample 'S606_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8112	R^2 log10 wo/outliers: 0.9391	Objective: -9280.34344
# Sample 'S606_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8254	R^2 log10 wo/outliers: 0.9646	Objective: -4823.44027
# Sample 'S606_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6982	R^2 log10 wo/outliers: 0.9478	Objective: -20054.01826
# Sample 'S607_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6490	R^2 log10 wo/outliers: 0.9562	Objective: -10745.00295
# Sample 'S607_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7711	R^2 log10 wo/outliers: 0.9685	Objective: -8312.85265
# Sample 'S607_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6508	R^2 log10 wo/outliers: 0.9782	Objective: -24828.70790
# Sample 'S608_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7393	R^2 log10 wo/outliers: 0.9351	Objective: -6305.94283
# Sample 'S608_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6139	R^2 log10 wo/outliers: 0.9727	Objective: -24787.71817
# Sample 'S608_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7183	R^2 log10 wo/outliers: 0.9586	Objective: -9464.42152
# Sample 'S609_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6582	R^2 log10 wo/outliers: 0.9710	Objective: -14097.97107
# Sample 'S609_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6775	R^2 log10 wo/outliers: 0.9573	Objective: -11980.11101
# Sample 'S609_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6741	R^2 log10 wo/outliers: 0.9572	Objective: -13553.68205
# Sample 'S610_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7285	R^2 log10 wo/outliers: 0.9526	Objective: -11763.76946
# Sample 'S610_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.4935	R^2 log10 wo/outliers: 0.9748	Objective: -20725.99878
# Sample 'S610_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7883	R^2 log10 wo/outliers: 0.9607	Objective: -8587.02147
# Sample 'S611_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6182	R^2 log10 wo/outliers: 0.9776	Objective: -15759.73473
# Sample 'S611_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6733	R^2 log10 wo/outliers: 0.9342	Objective: -12618.71389
# Sample 'S612_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7765	R^2 log10 wo/outliers: 0.9436	Objective: -8637.39714
# Sample 'S612_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7766	R^2 log10 wo/outliers: 0.9482	Objective: -8735.65904
# Sample 'S613_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.8353	R^2 log10 wo/outliers: 0.9277	Objective: -10861.38064
# Sample 'S613_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7409	R^2 log10 wo/outliers: 0.9477	Objective: -13805.76881
# Sample 'S614_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6202	R^2 log10 wo/outliers: 0.9265	Objective: -17668.04468
# Sample 'S614_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7144	R^2 log10 wo/outliers: 0.9650	Objective: -16542.72425
# Sample 'S615_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6537	R^2 log10 wo/outliers: 0.9105	Objective: -11688.38340
# Sample 'S615_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7324	R^2 log10 wo/outliers: 0.9610	Objective: -14645.40142
# Sample 'S616_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6584	R^2 log10 wo/outliers: 0.9632	Objective: -18053.23121
# Sample 'S616_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8000	R^2 log10 wo/outliers: 0.9467	Objective: -15990.84896
# Sample 'S617_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7818	R^2 log10 wo/outliers: 0.9455	Objective: -10226.90600
# Sample 'S617_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7832	R^2 log10 wo/outliers: 0.9324	Objective: -10469.88336
# Sample 'S618_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7930	R^2 log10 wo/outliers: 0.9373	Objective: -10253.53441
# Sample 'S618_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7923	R^2 log10 wo/outliers: 0.9491	Objective: -9450.64582
# Sample 'S619_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7153	R^2 log10 wo/outliers: 0.9370	Objective: -10220.33204
# Sample 'S619_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7783	R^2 log10 wo/outliers: 0.9753	Objective: -9061.70847
# Sample 'S620_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7549	R^2 log10 wo/outliers: 0.9630	Objective: -13737.42980
# Sample 'S620_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7908	R^2 log10 wo/outliers: 0.9493	Objective: -16323.05287
# Sample 'S621_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6815	R^2 log10 wo/outliers: 0.9143	Objective: -19375.53054
# Sample 'S621_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6835	R^2 log10 wo/outliers: 0.9820	Objective: -18136.92946
# Sample 'S622_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7467	R^2 log10 wo/outliers: 0.9804	Objective: -14809.23668
# Sample 'S622_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7164	R^2 log10 wo/outliers: 0.9770	Objective: -19197.94512
# Sample 'S623_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8049	R^2 log10 wo/outliers: 0.9080	Objective: -14096.32362
# Sample 'S623_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7965	R^2 log10 wo/outliers: 0.9404	Objective: -12971.19043
# Sample 'S624_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7096	R^2 log10 wo/outliers: 0.9712	Objective: -18964.22847
# Sample 'S624_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6451	R^2 log10 wo/outliers: 0.9638	Objective: -16935.31837
# Sample 'S625_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7151	R^2 log10 wo/outliers: 0.9675	Objective: -11974.66208
# Sample 'S625_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6367	R^2 log10 wo/outliers: 0.9779	Objective: -8758.77463
# Sample 'S626_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8460	R^2 log10 wo/outliers: 0.9447	Objective: -4818.35780
# Sample 'S626_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8130	R^2 log10 wo/outliers: 0.9392	Objective: -9739.90237
# Sample 'S627_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5925	R^2 log10 wo/outliers: 0.9412	Objective: -18628.77121
# Sample 'S627_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7171	R^2 log10 wo/outliers: 0.9284	Objective: -14346.88671
# Sample 'S628_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7316	R^2 log10 wo/outliers: 0.9559	Objective: -16108.95833
# Sample 'S628_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7106	R^2 log10 wo/outliers: 0.9669	Objective: -12654.42098
# Sample 'S629_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8219	R^2 log10 wo/outliers: 0.9217	Objective: -5025.09139
# Sample 'S629_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8679	R^2 log10 wo/outliers: 0.9121	Objective: -3488.91610
# Sample 'S630_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7404	R^2 log10 wo/outliers: 0.9494	Objective: -15082.60531
# Sample 'S630_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7796	R^2 log10 wo/outliers: 0.9749	Objective: -7983.87841
# Sample 'S631_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7542	R^2 log10 wo/outliers: 0.9703	Objective: -10428.69172
# Sample 'S631_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7616	R^2 log10 wo/outliers: 0.9572	Objective: -8597.62453
# Sample 'S632_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6961	R^2 log10 wo/outliers: 0.9620	Objective: -9995.49842
# Sample 'S632_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7158	R^2 log10 wo/outliers: 0.9724	Objective: -13608.90342
# Sample 'S633_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.5986	R^2 log10 wo/outliers: 0.9376	Objective: -19139.59050
# Sample 'S633_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.5669	R^2 log10 wo/outliers: 0.9569	Objective: -19021.23292
# Sample 'S634_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7934	R^2 log10 wo/outliers: 0.8921	Objective: -5636.62578
# Sample 'S634_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8789	R^2 log10 wo/outliers: 0.8805	Objective: -8561.49080
# Sample 'S635_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6489	R^2 log10 wo/outliers: 0.9566	Objective: -18026.08690
# Sample 'S635_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6463	R^2 log10 wo/outliers: 0.9500	Objective: -17188.75007
# Sample 'S636_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6691	R^2 log10 wo/outliers: 0.9354	Objective: -14986.42159
# Sample 'S636_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6600	R^2 log10 wo/outliers: 0.9730	Objective: -19086.91410
# Sample 'S637_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8078	R^2 log10 wo/outliers: 0.9141	Objective: -15955.05777
# Sample 'S637_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8100	R^2 log10 wo/outliers: 0.9415	Objective: -16607.98924
# Sample 'S638_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6550	R^2 log10 wo/outliers: 0.9713	Objective: -13777.58608
# Sample 'S638_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8087	R^2 log10 wo/outliers: 0.9726	Objective: -16297.83098
# Sample 'S639_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6490	R^2 log10 wo/outliers: 0.9683	Objective: -13914.91796
# Sample 'S639_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6983	R^2 log10 wo/outliers: 0.9593	Objective: -13376.54269
# Sample 'S640_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7881	R^2 log10 wo/outliers: 0.9558	Objective: -10577.72858
# Sample 'S640_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.8076	R^2 log10 wo/outliers: 0.9074	Objective: -16265.71699
# Sample 'S641_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6848	R^2 log10 wo/outliers: 0.9686	Objective: -17363.94174
# Sample 'S641_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6807	R^2 log10 wo/outliers: 0.9487	Objective: -16505.63353
# Sample 'S642_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7319	R^2 log10 wo/outliers: 0.9628	Objective: -10338.51166
# Sample 'S642_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7714	R^2 log10 wo/outliers: 0.9506	Objective: -11421.55395
# Sample 'S643_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7363	R^2 log10 wo/outliers: 0.9549	Objective: -12537.67644
# Sample 'S643_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7303	R^2 log10 wo/outliers: 0.9606	Objective: -12773.97554
# Sample 'S644_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7319	R^2 log10 wo/outliers: 0.9284	Objective: -14560.21472
# Sample 'S644_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7248	R^2 log10 wo/outliers: 0.9468	Objective: -14333.65758
# Sample 'S645_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6872	R^2 log10 wo/outliers: 0.9598	Objective: -11806.33859
# Sample 'S645_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7602	R^2 log10 wo/outliers: 0.9617	Objective: -10743.08027
# Sample 'S646_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.6634	R^2 log10 wo/outliers: 0.9693	Objective: -25226.85331
# Sample 'S646_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7324	R^2 log10 wo/outliers: 0.9478	Objective: -9526.56854
# Sample 'S647_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.8440	R^2 log10 wo/outliers: 0.9101	Objective: -9484.43361
# Sample 'S647_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.6838	R^2 log10 wo/outliers: 0.9414	Objective: -14476.04525
# Sample 'S648_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7416	R^2 log10 wo/outliers: 0.9626	Objective: -10011.30026
# Sample 'S648_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6913	R^2 log10 wo/outliers: 0.9417	Objective: -10893.67879
# Sample 'S649_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7603	R^2 log10 wo/outliers: 0.9423	Objective: -14426.29511
# Sample 'S649_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.6099	R^2 log10 wo/outliers: 0.9621	Objective: -19836.06807
# Sample 'S650_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7076	R^2 log10 wo/outliers: 0.9279	Objective: -8950.08863
# Sample 'S650_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7824	R^2 log10 wo/outliers: 0.9377	Objective: -8204.47679
# Sample 'Mean_D10'	R^2: 1.0000	R^2 log10 w/outliers: -1.3155	R^2 log10 wo/outliers: 0.9855	Objective: -17073.70229
# Sample 'Mean_D23'	R^2: 1.0000	R^2 log10 w/outliers: -1.3285	R^2 log10 wo/outliers: 0.9847	Objective: -18357.95813
# Sample 'Mean_D42'	R^2: 1.0000	R^2 log10 w/outliers: -1.3086	R^2 log10 wo/outliers: 0.9859	Objective: -21102.11726
# Sample 'Median_D10'	R^2: 1.0000	R^2 log10 w/outliers: 0.7427	R^2 log10 wo/outliers: 0.9612	Objective: -11970.31441
# Sample 'Median_D23'	R^2: 1.0000	R^2 log10 w/outliers: 0.7244	R^2 log10 wo/outliers: 0.9683	Objective: -12440.12137
# Sample 'Median_D42'	R^2: 1.0000	R^2 log10 w/outliers: 0.7395	R^2 log10 wo/outliers: 0.9691	Objective: -11862.29264
# Sample 'Mean_G6PD_V68M_0'	R^2: 1.0000	R^2 log10 w/outliers: -1.3195	R^2 log10 wo/outliers: 0.9853	Objective: -22500.67359
# Sample 'Mean_G6PD_V68M_1'	R^2: 1.0000	R^2 log10 w/outliers: -0.4061	R^2 log10 wo/outliers: 0.9864	Objective: -20650.40826
# Sample 'Mean_G6PD_V68M_2'	R^2: 1.0000	R^2 log10 w/outliers: -0.6268	R^2 log10 wo/outliers: 0.9727	Objective: -14796.11858
# Sample 'Median_G6PD_V68M_0'	R^2: 1.0000	R^2 log10 w/outliers: 0.7292	R^2 log10 wo/outliers: 0.9690	Objective: -12064.66057
# Sample 'Median_G6PD_V68M_1'	R^2: 1.0000	R^2 log10 w/outliers: 0.6709	R^2 log10 wo/outliers: 0.9725	Objective: -14673.56714
# Sample 'Median_G6PD_V68M_2'	R^2: 1.0000	R^2 log10 w/outliers: 0.7283	R^2 log10 wo/outliers: 0.9546	Objective: -12087.04956
# Number of QP solutions: 1922

# %% [markdown]
# ### Plot fitting
# #### For the mean and median samples of each time point and for each chosen phenotype

# %%
samples_to_plot = np.array(
    [
        [
            x
            for x in operation_ids
            if time_re.search(x) and operation_re.search(x).group("op") == "Mean"
        ],
        [
            x
            for x in operation_ids
            if time_re.search(x) and operation_re.search(x).group("op") == "Median"
        ],
        [
            x
            for x in operation_ids
            if phenotype_re.search(x) and operation_re.search(x).group("op") == "Mean"
        ],
        [
            x
            for x in operation_ids
            if phenotype_re.search(x) and operation_re.search(x).group("op") == "Median"
        ],
    ]
).T
samples_to_plot
# Out:
# array([['Mean_D10', 'Median_D10', 'Mean_G6PD_V68M_0',
#         'Median_G6PD_V68M_0'],
#        ['Mean_D23', 'Median_D23', 'Mean_G6PD_V68M_1',
#         'Median_G6PD_V68M_1'],
#        ['Mean_D42', 'Median_D42', 'Mean_G6PD_V68M_2',
#         'Median_G6PD_V68M_2']], dtype='<U18')

# %%
r2_text_loc = "upper left"
transform = False

length = 4
nrows, ncols = samples_to_plot.shape
fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(length * ncols, length * nrows),
    sharex=True,
    sharey=True,
)
sns.despine(fig)
for idx, (sample_id, ax) in enumerate(zip(samples_to_plot.flatten(), axes.flatten())):
    df_qp_sol, objective_value, r2_values = qp_solutions_dict[sample_id]
    # Copy to prevent alterations to the original
    df_qp_sol = df_qp_sol.copy()
    xlabel, ylabel = df_qp_sol.columns

    ticks = 10 ** np.arange(*np.log10([log_zero_replacement, 1e8]), 3)
    if transform:
        ticks = np.log10(ticks)
        df_qp_sol.iloc[:, 0] = (
            df_qp_sol.iloc[:, 0]
            .apply(lambda x: log_zero_replacement if np.isclose(x, 0) else x)
            .apply(np.log10)
        )
        df_qp_sol.iloc[:, 1] = (
            df_qp_sol.iloc[:, 1]
            .apply(lambda x: log_zero_replacement if np.isclose(x, 0) else x)
            .apply(np.log10)
        )
    perfect_fit_line = ax.plot(
        [ticks[0], ticks[-1]],
        [ticks[0], ticks[-1]],
        linestyle=":",
        color="black",
        linewidth=1,
        alpha=1,
    )

    zero_val = 0 if not transform else np.log10(log_zero_replacement)

    df_zeros = df_qp_sol[
        (df_qp_sol.apply(lambda x: np.isclose(x, zero_val))).any(axis=1)
    ]
    df_perfect = df_qp_sol[
        np.isclose(
            abs(df_qp_sol["Measured Proteome"] - df_qp_sol["Best-Fitted Proteome"]), 0
        )
    ]
    df_perfect = df_perfect[~df_perfect.index.isin(df_zeros.index)]

    df_altered = df_qp_sol[
        ~np.isclose(
            abs(df_qp_sol["Measured Proteome"] - df_qp_sol["Best-Fitted Proteome"]), 0
        )
    ]
    df_altered = df_altered[~df_altered.index.isin(df_zeros.index)]
    df_always_zero = df_zeros[(df_zeros == zero_val).all(axis=1)]
    df_zeros = df_zeros[~df_zeros.index.isin(df_always_zero.index)]
    df_from_zeros = df_zeros[np.isclose(df_zeros["Measured Proteome"], zero_val)]
    df_to_zeros = df_zeros[np.isclose(df_zeros["Best-Fitted Proteome"], zero_val)]

    handles = [
        ax.scatter(
            data=df_perfect.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:blue",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_altered.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:yellow",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_from_zeros.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:green",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_to_zeros.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:red",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
        ax.scatter(
            data=df_always_zero.replace(0, ticks[0]),
            x=xlabel,
            y=ylabel,
            color="xkcd:black",
            alpha=0.5,
            edgecolors="black",
            linewidths=1,
        ),
    ]
    labels = [
        f"Perfect fit",
        f"Adjusted abundance",
        f"Unexpressed to expressed",
        f"Expressed to unexpressed",
        f"Never expressed",
    ]

    sample_label = str(sample_id.replace(f"{pcmodel.id}_", "").replace("_", " "))
    if not transform:
        ax.set_xscale("log")
        ax.set_yscale("log")

    fontdict = {"size": "xx-large"}
    if idx >= len(samples_to_plot.flatten()) - ncols:
        ax.set_xlabel(xlabel, fontdict=fontdict)
    fig.legend(
        handles=handles,
        labels=labels,
        loc="upper center",
        ncols=len(labels),
        frameon=False,
        fontsize="large",
        markerscale=2,
        bbox_to_anchor=(0.5, -0.01),
    )
    if idx % ncols == 0:
        ax.set_ylabel(ylabel, fontdict=fontdict)

    ax.set_xticks(ticks)
    ax.set_yticks(ticks)

    ax.xaxis.set_tick_params(labelsize="x-large")
    ax.yaxis.set_tick_params(labelsize="x-large")

    r2_format = " = {:.4f}"
    if r2_text_loc == "lower right":
        ax.text(
            0.95,
            0.1,
            "\n".join(
                (
                    sample_label,
                    r"$R^{2}$" + r2_format.format(r2_values[0]),
                    r"$R^{2}\text{log}_{10}\text{ w/  outliers}$"
                    + r2_format.format(r2_values[1]),
                    r"$R^{2}\text{log}_{10}\text{ w/o outliers}$"
                    + r2_format.format(r2_values[2]),
                )
            ),
            transform=ax.transAxes,
            color="black",
            fontsize="medium",
            ha="right",
        )
    elif r2_text_loc == "upper left":
        ax.text(
            0.05,
            0.8,
            "\n".join(
                (
                    sample_label,
                    r"$R^{2}$" + r2_format.format(r2_values[0]),
                    r"$R^{2}\text{log}_{10}\text{ w/  outliers}$"
                    + r2_format.format(r2_values[1]),
                    r"$R^{2}\text{log}_{10}\text{ w/o outliers}$"
                    + r2_format.format(r2_values[2]),
                )
            ),
            transform=ax.transAxes,
            color="black",
            fontsize="medium",
            ha="left",
        )
    else:
        pass
fig.tight_layout()
if save_figures:
    fig.savefig(
        fitting_dirpath
        / f"QPfitting_{'' if not transform else 'log10_'}{model_id}.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )

# %% [markdown]
# ### Determine best value for slack variable

# %%
verbose = True
objective_rxns = ["NaKt"]
slack_determination_models = samples_to_plot.flatten()

list_of_pcmodels = []
for sample_id in slack_determination_models:
    df_qp_sol, objective_value, r2_values = qp_solutions_dict[sample_id]
    # Create a copy of the model
    pcmodel_sample = pcmodel.copy()
    pcmodel_sample.id = f"{pcmodel.id}_{sample_id}"
    for protdl in pcmodel_sample.reactions.query(
        lambda x: isinstance(x, ProteinDilution)
    ):
        if protdl.id in df_qp_sol.index:
            prot_bound = df_qp_sol.loc[protdl.id]["Best-Fitted Proteome"]
        else:
            prot_bound = 0
        protdl.bounds = (float(prot_bound), float(prot_bound))
    # Add the relaxation budget with slack = 0 first
    add_relaxation_budget(pcmodel_sample, 0, int(verbose))
    list_of_pcmodels += [pcmodel_sample]
# Out:
# Relaxation budget added to RBC_GEM_PC_Mean_D10, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_D10, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_G6PD_V68M_0, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_G6PD_V68M_0, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_D23, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_D23, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_G6PD_V68M_1, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_G6PD_V68M_1, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_D42, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_D42, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_G6PD_V68M_2, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_G6PD_V68M_2, extra 0.0000 mg/gDW (0.0000 mg HB/gDW) from 0.0000% slack

# %%
chosen_slack_var = 0.03
colors = {
    "D10": "xkcd:green",
    "D23": "xkcd:gold",
    "D42": "xkcd:red",
    "G6PD_V68M_0": "xkcd:light blue",
    "G6PD_V68M_1": "xkcd:blue",
    "G6PD_V68M_2": "xkcd:dark blue",
}
linestyles = {
    "Mean": "-",
    "Median": "-.",
}
use_percents = True

fig, axes = plt.subplots(
    3, 1, figsize=(4, 10), sharex=True, gridspec_kw=dict(hspace=0.05)
)
axes = axes.flatten()
sns.despine(fig)
for pcmodel_sample in list(sorted(list(solutions))):
    op, group = pcmodel_sample.replace(f"{pcmodel.id}_", "").split("_", maxsplit=1)
    color = colors.get(group, "xkcd:black")
    linestyle = linestyles.get(op, ":")
    s_values = solutions[str(pcmodel_sample)]["slack"].values
    r_values = solutions[str(pcmodel_sample)]["relaxation"].values * (
        100 if use_percents else 1
    )
    o_values = solutions[str(pcmodel_sample)]["objective"].values
    rxn_values = solutions[str(pcmodel_sample)]["_".join(objective_rxns)].values

    zorder = 1
    lw = 2
    axes[0].plot(
        s_values,
        r_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )
    axes[1].plot(
        s_values,
        o_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )
    axes[2].plot(
        s_values,
        rxn_values,
        label=str(pcmodel_sample),
        color=color,
        linestyle=linestyle,
        linewidth=lw,
        zorder=zorder,
    )

fontdict = {"size": "x-large"}
axes[-1].set_xlabel(r"Slack variable $s$", fontdict=fontdict)

zorder = 2
alpha = 0.7
limit_pad_sclar = 1.3
smin = s_values[0]

for i, ax in enumerate(axes):
    if i == 0:
        ymin, ymax = (
            -0.001 * (100 if use_percents else 1),
            max(r_values) * limit_pad_sclar,
        )
    elif i == 1:
        ymin, ymax = (
            min(0, min(o_values)) * limit_pad_sclar,
            max(o_values) * limit_pad_sclar,
        )
    elif i == 2:
        ymin, ymax = (0, max(rxn_values) * limit_pad_sclar)
    else:
        pass
    ax.vlines(chosen_slack_var, ymin=ymin, ymax=ymax, color="black", linestyle=":")
    ax.vlines(
        smin,
        ymin=ymin,
        ymax=ymax,
        color="black",
        linestyle="-",
        zorder=zorder,
        alpha=alpha,
    )
    ax.vlines(
        1,
        ymin=ymin,
        ymax=ymax,
        color="black",
        linestyle="-",
        zorder=zorder,
        alpha=alpha,
    )
    ax.set_xlim(smin / 2, slack_max)
    ax.set_ylim(ymin, ymax)
    ax.set_xscale("log")
    if i == 0:
        ax.annotate(
            rf"$s > 0$",
            xy=(smin, ymax),
            xycoords="data",
            xytext=(10, 5),
            textcoords="offset points",
            ha="center",
            fontsize=fontdict["size"],
        )
        ax.annotate(
            rf"$s \leq 1$",
            xy=(1, ymax),
            xycoords="data",
            xytext=(10, 5),
            textcoords="offset points",
            ha="center",
            fontsize=fontdict["size"],
        )
        ax.annotate(
            rf"$s = {chosen_slack_var}$",
            xy=(chosen_slack_var, 0),
            xycoords="data",
            xytext=(5, 0),
            textcoords="offset points",
            ha="left",
            fontsize=fontdict["size"],
        )
    ax.fill_between((smin / 2, smin), ymin, ymax, color="xkcd:light grey")
    ax.annotate(
        "Infeasible",
        xy=(smin, (ymax + ymin) / 2),
        xycoords="data",
        rotation=90,
        xytext=(-2, 0),
        textcoords="offset points",
        va="center",
        ha="right",
        fontsize=fontdict["size"],
    )


handles, labels = axes[2].get_legend_handles_labels()
labels = [label.replace(f"{pcmodel.id}_", "").replace("_", " ") for label in labels]
axes[2].legend(
    handles=handles,
    labels=labels,
    ncols=2,
    frameon=False,
    loc="upper center",
    fontsize="large",
    bbox_to_anchor=(0.5, -0.2),
)


axes[0].set_ylabel("Relaxation budget used (%)", fontdict=fontdict)
axes[1].set_ylabel("Objective value", fontdict=fontdict)
axes[2].set_ylabel("NaKt (mmol/gDW/hr)", fontdict=fontdict)

fig.align_labels()
if save_figures:
    fig.savefig(
        fitting_dirpath / f"SlackPercentDetermination_{model_id}.{imagetype}",
        transparent=transparent,
        format=imagetype,
    )

# %% [markdown]
# ### Formulate models from QP solutions

# %%
# TODO consider using compressed files to save space
overwrite = False

# SBML/XML loads faster, but will take up to 4x more space uncompressed as compared to JSON
ftypes = {
    "xml"
    # "json",
}

slack_value = chosen_slack_var  # Slack %
ftypes = set([ftypes]) if isinstance(ftypes, str) else set(ftypes)
for sample_id, (df_qp_sol, objective_value, r2_values) in qp_solutions_dict.items():
    # Create a copy of the model
    sample_id = f"{pcmodel.id}_{sample_id}"
    filenames = [sample_pcmodels_dirpath / f"{sample_id}.{ftype}" for ftype in ftypes]
    if not overwrite and all([filename.exists() for filename in filenames]):
        print(f"Model already created for {sample_id}")
        continue
    pcmodel_sample = pcmodel.copy()
    pcmodel_sample.id = sample_id
    for protdl in pcmodel_sample.reactions.query(
        lambda x: isinstance(x, ProteinDilution)
    ):
        if protdl.id in df_qp_sol.index:
            prot_bound = df_qp_sol.loc[protdl.id]["Best-Fitted Proteome"]
        else:
            prot_bound = 0
        protdl.bounds = (float(prot_bound), float(prot_bound))
    # Add the relaxation budget
    add_relaxation_budget(pcmodel_sample, slack_value, verbose)
    budget_rxn_relaxation = pcmodel_sample.reactions.get_by_id(
        f"{budget_rxn_prefix}{budget_met_prefix}relaxation"
    )
    with pcmodel_sample:
        pcmodel_sample.objective = budget_rxn_relaxation.flux_expression
        pcmodel_sample.objective_direction = "min"
        budget_min = pcmodel_sample.slim_optimize()
        pcmodel_sample.objective_direction = "max"
        budget_max = pcmodel_sample.slim_optimize()
    budget_rxn_relaxation.bounds = (budget_min, budget_max)
    # # Store model for later use
    # list_of_relaxed_models += [pcmodel_sample]
    for filename in filenames:
        # Might as well overwrite all files, especially if model needed to be regenerated anyways
        write_cobra_model(
            pcmodel_sample,
            filename=filename,
        )
# Out:
# Relaxation budget added to RBC_GEM_PC_S001_D10, extra 29.2788 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S001_D23, extra 29.2864 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S001_D42, extra 29.2838 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S002_D10, extra 29.2181 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S002_D23, extra 29.2709 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S002_D42, extra 29.2035 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S003_D10, extra 29.3182 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S003_D23, extra 29.2310 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S003_D42, extra 29.2062 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S004_D10, extra 29.3113 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S004_D23, extra 29.3251 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S004_D42, extra 29.3149 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S005_D10, extra 29.2471 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S005_D23, extra 29.2263 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S005_D42, extra 29.2602 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S006_D10, extra 29.2139 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S006_D23, extra 29.2994 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S006_D42, extra 29.2933 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S007_D10, extra 29.2931 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S007_D23, extra 29.2944 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S007_D42, extra 29.3247 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S008_D10, extra 29.2469 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S008_D23, extra 29.3133 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S008_D42, extra 29.2992 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S009_D10, extra 29.2771 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S009_D23, extra 29.2670 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S009_D42, extra 29.2872 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S010_D10, extra 29.2016 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S010_D23, extra 29.2285 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S010_D42, extra 29.2289 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S011_D10, extra 29.2695 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S011_D23, extra 29.2857 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S011_D42, extra 29.2586 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S012_D10, extra 29.2846 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S012_D23, extra 29.3032 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S012_D42, extra 29.3090 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S013_D10, extra 29.2719 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S013_D23, extra 29.3085 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S013_D42, extra 29.2868 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S014_D10, extra 29.2796 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S014_D23, extra 29.2593 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S014_D42, extra 29.2843 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S015_D10, extra 29.2530 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S015_D23, extra 29.2345 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S015_D42, extra 29.2359 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S016_D10, extra 29.2707 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S016_D23, extra 29.3092 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S016_D42, extra 29.3035 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S017_D10, extra 29.2465 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S017_D23, extra 29.2668 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S017_D42, extra 29.2378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S018_D10, extra 29.3286 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S018_D23, extra 29.3813 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S018_D42, extra 29.4003 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S019_D10, extra 29.2961 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S019_D23, extra 29.2533 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S019_D42, extra 29.2595 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S020_D10, extra 29.2054 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S020_D23, extra 29.2267 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S020_D42, extra 29.2195 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S021_D10, extra 29.2680 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S021_D23, extra 29.2644 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S021_D42, extra 29.2448 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S022_D10, extra 29.2976 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S022_D23, extra 29.3448 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S022_D42, extra 29.2932 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S023_D10, extra 29.2488 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S023_D23, extra 29.2808 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S023_D42, extra 29.2639 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S024_D10, extra 29.2623 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S024_D23, extra 29.2763 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S024_D42, extra 29.2770 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S025_D10, extra 29.2822 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S025_D23, extra 29.3318 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S025_D42, extra 29.3012 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S026_D10, extra 29.2366 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S026_D23, extra 29.2122 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S026_D42, extra 29.2422 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S027_D10, extra 29.2589 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S027_D23, extra 29.2537 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S027_D42, extra 29.1730 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S028_D10, extra 29.2613 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S028_D23, extra 29.2966 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S028_D42, extra 29.2408 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S029_D10, extra 29.1806 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S029_D23, extra 29.2127 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S029_D42, extra 29.2161 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S030_D10, extra 29.2311 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S030_D23, extra 29.2028 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S030_D42, extra 29.2576 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S031_D10, extra 29.3017 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S031_D23, extra 29.3020 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S031_D42, extra 29.2804 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S032_D10, extra 29.3781 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S032_D23, extra 29.3565 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S032_D42, extra 29.3658 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S033_D10, extra 29.2426 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S033_D23, extra 29.2529 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S033_D42, extra 29.2444 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S034_D10, extra 29.2578 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S034_D23, extra 29.2627 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S034_D42, extra 29.2934 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S035_D10, extra 29.2465 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S035_D23, extra 29.2551 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S035_D42, extra 29.2430 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S036_D10, extra 29.3293 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S036_D23, extra 29.3212 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S036_D42, extra 29.3140 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S037_D10, extra 29.2620 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S037_D23, extra 29.2371 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S037_D42, extra 29.1999 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S038_D10, extra 29.2587 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S038_D23, extra 29.2690 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S038_D42, extra 29.1846 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S039_D10, extra 29.2958 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S039_D23, extra 29.3120 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S039_D42, extra 29.2755 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S040_D10, extra 29.3000 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S040_D23, extra 29.3298 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S040_D42, extra 29.3012 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S041_D10, extra 29.2969 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S041_D23, extra 29.3102 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S041_D42, extra 29.2792 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S042_D10, extra 29.2898 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S042_D23, extra 29.2795 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S042_D42, extra 29.3026 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S043_D10, extra 29.2296 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S043_D23, extra 29.2128 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S043_D42, extra 29.2167 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S044_D10, extra 29.1470 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S044_D23, extra 29.1754 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S044_D42, extra 29.2247 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S045_D10, extra 29.2043 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S045_D23, extra 29.2228 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S045_D42, extra 29.1953 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S046_D10, extra 29.2372 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S046_D23, extra 29.1606 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S046_D42, extra 29.1942 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S047_D10, extra 29.2053 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S047_D23, extra 29.1904 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S047_D42, extra 29.1856 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S048_D10, extra 29.2144 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S048_D23, extra 29.2325 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S048_D42, extra 29.2003 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S049_D10, extra 29.2334 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S049_D23, extra 29.2250 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S049_D42, extra 29.2035 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S050_D10, extra 29.2128 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S050_D23, extra 29.2016 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S050_D42, extra 29.1856 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S051_D10, extra 29.1596 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S051_D23, extra 29.2147 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S051_D42, extra 29.1908 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S052_D10, extra 29.2297 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S052_D23, extra 29.2275 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S052_D42, extra 29.2293 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S053_D10, extra 29.1850 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S053_D23, extra 29.1416 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S053_D42, extra 29.1926 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S054_D10, extra 29.1536 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S054_D23, extra 29.1475 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S054_D42, extra 29.1291 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S055_D10, extra 29.2230 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S055_D23, extra 29.2605 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S055_D42, extra 29.2136 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S056_D10, extra 29.1819 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S056_D23, extra 29.1737 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S056_D42, extra 29.1623 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S057_D10, extra 29.2127 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S057_D23, extra 29.2117 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S057_D42, extra 29.2353 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S058_D10, extra 29.1827 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S058_D23, extra 29.1981 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S058_D42, extra 29.1848 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S059_D10, extra 29.2098 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S059_D23, extra 29.2075 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S059_D42, extra 29.2074 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S060_D10, extra 29.2259 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S060_D23, extra 29.1989 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S060_D42, extra 29.2071 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S061_D10, extra 29.1945 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S061_D23, extra 29.1928 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S061_D42, extra 29.2114 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S062_D10, extra 29.1869 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S062_D23, extra 29.2257 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S062_D42, extra 29.2429 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S063_D10, extra 29.2345 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S063_D23, extra 29.2295 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S063_D42, extra 29.2200 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S064_D10, extra 29.2810 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S064_D23, extra 29.3402 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S064_D42, extra 29.2976 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S065_D10, extra 29.2877 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S065_D23, extra 29.3467 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S065_D42, extra 29.3428 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S066_D10, extra 29.3144 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S066_D23, extra 29.2714 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S066_D42, extra 29.3199 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S067_D10, extra 29.3303 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S067_D23, extra 29.3161 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S067_D42, extra 29.3023 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S068_D10, extra 29.3240 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S068_D23, extra 29.3378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S068_D42, extra 29.3439 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S069_D10, extra 29.2543 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S069_D23, extra 29.2869 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S069_D42, extra 29.2754 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S070_D10, extra 29.1507 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S070_D23, extra 29.3328 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S070_D42, extra 29.3500 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S071_D10, extra 29.2530 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S071_D23, extra 29.2829 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S071_D42, extra 29.2730 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S072_D10, extra 29.2984 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S072_D23, extra 29.2260 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S072_D42, extra 29.2865 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S073_D10, extra 29.2001 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S073_D23, extra 29.1992 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S073_D42, extra 29.2566 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S074_D10, extra 29.3007 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S074_D23, extra 29.2579 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S074_D42, extra 29.2540 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S075_D10, extra 29.2986 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S075_D23, extra 29.3089 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S075_D42, extra 29.3022 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S076_D10, extra 29.2743 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S076_D23, extra 29.2003 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S076_D42, extra 29.2235 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S077_D10, extra 29.2652 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S077_D23, extra 29.2490 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S077_D42, extra 29.2903 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S078_D10, extra 29.2733 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S078_D23, extra 29.2634 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S078_D42, extra 29.2817 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S079_D10, extra 29.2945 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S079_D23, extra 29.3361 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S079_D42, extra 29.2672 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S080_D10, extra 29.3188 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S080_D23, extra 29.3571 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S080_D42, extra 29.2997 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S081_D10, extra 29.3492 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S081_D23, extra 29.2659 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S081_D42, extra 29.3076 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S082_D10, extra 29.3368 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S082_D23, extra 29.3282 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S082_D42, extra 29.3304 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S083_D10, extra 29.2777 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S083_D23, extra 29.2799 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S083_D42, extra 29.2715 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S084_D10, extra 29.3479 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S084_D23, extra 29.2772 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S084_D42, extra 29.2808 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S085_D10, extra 29.2818 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S085_D23, extra 29.3302 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S085_D42, extra 29.2699 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S086_D10, extra 29.3135 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S086_D23, extra 29.3027 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S086_D42, extra 29.2949 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S087_D10, extra 29.3372 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S087_D23, extra 29.3188 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S087_D42, extra 29.3302 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S088_D10, extra 29.3500 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S088_D23, extra 29.3416 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S088_D42, extra 29.3535 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S089_D10, extra 29.2328 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S089_D23, extra 29.3097 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S089_D42, extra 29.3030 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S090_D10, extra 29.2813 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S090_D23, extra 29.2769 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S090_D42, extra 29.2778 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S091_D10, extra 29.2211 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S091_D23, extra 29.2584 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S091_D42, extra 29.2701 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S092_D10, extra 29.2861 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S092_D23, extra 29.3211 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S092_D42, extra 29.3236 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S093_D10, extra 29.2834 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S093_D23, extra 29.3196 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S093_D42, extra 29.2402 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S094_D10, extra 29.3709 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S094_D23, extra 29.3168 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S094_D42, extra 29.3027 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S095_D10, extra 29.2246 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S095_D23, extra 29.2769 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S095_D42, extra 29.2655 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S096_D10, extra 29.2609 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S096_D23, extra 29.2503 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S096_D42, extra 29.2201 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S097_D10, extra 29.2208 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S097_D23, extra 29.2637 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S097_D42, extra 29.2059 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S098_D10, extra 29.1767 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S098_D23, extra 29.1345 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S098_D42, extra 29.1715 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S099_D10, extra 29.1799 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S099_D23, extra 29.2031 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S099_D42, extra 29.2528 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S100_D10, extra 29.1881 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S100_D23, extra 29.1862 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S100_D42, extra 29.1650 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S101_D10, extra 29.1997 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S101_D23, extra 29.2059 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S101_D42, extra 29.2136 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S102_D10, extra 29.2337 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S102_D23, extra 29.1866 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S102_D42, extra 29.1822 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S103_D10, extra 29.2040 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S103_D23, extra 29.2122 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S103_D42, extra 29.2167 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S104_D10, extra 29.2378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S104_D23, extra 29.2331 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S104_D42, extra 29.2423 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S105_D10, extra 29.2451 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S105_D23, extra 29.2226 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S105_D42, extra 29.2266 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S106_D10, extra 29.1702 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S106_D23, extra 29.2493 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S106_D42, extra 29.2102 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S107_D10, extra 29.1833 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S107_D23, extra 29.2707 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S107_D42, extra 29.1963 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S108_D10, extra 29.1588 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S108_D23, extra 29.1488 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S108_D42, extra 29.1791 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S109_D10, extra 29.2261 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S109_D23, extra 29.1855 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S109_D42, extra 29.2056 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S110_D10, extra 29.2130 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S110_D23, extra 29.2333 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S110_D42, extra 29.1790 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S111_D10, extra 29.2072 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S111_D23, extra 29.2159 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S111_D42, extra 29.2181 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S112_D10, extra 29.2285 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S112_D23, extra 29.2402 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S112_D42, extra 29.2176 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S113_D10, extra 29.3854 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S113_D23, extra 29.3460 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S113_D42, extra 29.3355 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S114_D10, extra 29.2262 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S114_D23, extra 29.1813 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S114_D42, extra 29.2015 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S115_D10, extra 29.1546 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S115_D23, extra 29.1778 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S115_D42, extra 29.1484 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S116_D10, extra 29.2111 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S116_D23, extra 29.2032 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S116_D42, extra 29.1967 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S117_D10, extra 29.1559 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S117_D23, extra 29.1763 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S117_D42, extra 29.1959 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S118_D10, extra 29.1654 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S118_D23, extra 29.1460 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S118_D42, extra 29.1937 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S119_D10, extra 29.3737 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S119_D23, extra 29.3414 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S119_D42, extra 29.3548 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S120_D10, extra 29.3425 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S120_D23, extra 29.3606 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S120_D42, extra 29.3311 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S121_D10, extra 29.1830 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S121_D23, extra 29.1577 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S121_D42, extra 29.1494 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S122_D10, extra 29.2241 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S122_D23, extra 29.2478 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S122_D42, extra 29.2160 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S123_D10, extra 29.2334 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S123_D23, extra 29.1875 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S123_D42, extra 29.1960 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S124_D10, extra 29.1920 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S124_D23, extra 29.2099 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S124_D42, extra 29.2401 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S125_D10, extra 29.1975 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S125_D23, extra 29.2967 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S125_D42, extra 29.1872 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S126_D10, extra 29.2256 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S126_D23, extra 29.1878 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S126_D42, extra 29.2263 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S127_D10, extra 29.1596 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S127_D23, extra 29.1371 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S127_D42, extra 29.2324 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S128_D10, extra 29.2249 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S128_D23, extra 29.2132 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S128_D42, extra 29.2787 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S129_D10, extra 29.2180 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S129_D23, extra 29.2370 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S129_D42, extra 29.2308 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S130_D10, extra 29.1787 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S130_D23, extra 29.1716 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S130_D42, extra 29.2104 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S131_D10, extra 29.1967 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S131_D23, extra 29.1924 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S131_D42, extra 29.2039 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S132_D10, extra 29.1993 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S132_D23, extra 29.2149 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S132_D42, extra 29.2199 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S133_D10, extra 29.1759 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S133_D23, extra 29.1593 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S133_D42, extra 29.2360 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S134_D10, extra 29.1662 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S134_D23, extra 29.1825 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S134_D42, extra 29.1797 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S135_D10, extra 29.2075 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S135_D23, extra 29.2257 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S135_D42, extra 29.1888 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S136_D10, extra 29.2217 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S136_D23, extra 29.2348 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S136_D42, extra 29.1578 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S137_D10, extra 29.2772 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S137_D23, extra 29.2845 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S137_D42, extra 29.2530 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S138_D10, extra 29.2277 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S138_D23, extra 29.2162 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S138_D42, extra 29.2121 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S139_D10, extra 29.2270 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S139_D23, extra 29.2031 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S139_D42, extra 29.2179 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S140_D10, extra 29.2506 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S140_D23, extra 29.2219 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S140_D42, extra 29.1977 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S141_D10, extra 29.2402 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S141_D23, extra 29.2352 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S141_D42, extra 29.2195 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S142_D10, extra 29.2980 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S142_D23, extra 29.2867 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S142_D42, extra 29.3006 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S143_D10, extra 29.2761 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S143_D23, extra 29.2919 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S143_D42, extra 29.2804 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S144_D10, extra 29.0697 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S144_D23, extra 29.0989 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S144_D42, extra 29.1190 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S145_D10, extra 29.2376 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S145_D23, extra 29.2250 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S145_D42, extra 29.2510 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S146_D10, extra 29.2049 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S146_D23, extra 29.2395 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S146_D42, extra 29.2165 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S147_D10, extra 29.1906 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S147_D23, extra 29.2127 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S147_D42, extra 29.1944 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S148_D10, extra 29.1845 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S148_D23, extra 29.1854 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S148_D42, extra 29.1949 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# ...
# Relaxation budget added to RBC_GEM_PC_S592_D42, extra 29.1955 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S593_D10, extra 29.2177 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S593_D23, extra 29.1891 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S593_D42, extra 29.1612 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S594_D10, extra 29.1723 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S594_D23, extra 29.1385 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S594_D42, extra 29.1495 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S595_D10, extra 29.1776 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S595_D23, extra 29.1932 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S595_D42, extra 29.1733 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S596_D10, extra 29.2213 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S596_D23, extra 29.2227 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S596_D42, extra 29.1924 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S597_D10, extra 29.1981 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S597_D23, extra 29.2318 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S597_D42, extra 29.2227 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S598_D10, extra 29.2060 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S598_D23, extra 29.1878 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S598_D42, extra 29.2225 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S599_D10, extra 29.2041 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S599_D23, extra 29.1932 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S599_D42, extra 29.1799 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S600_D10, extra 29.0931 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S600_D23, extra 29.1171 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S600_D42, extra 29.0789 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S601_D10, extra 29.1927 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S601_D23, extra 29.1812 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S601_D42, extra 29.2091 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S602_D10, extra 29.2294 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S602_D23, extra 29.2045 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S602_D42, extra 29.1756 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S603_D10, extra 29.2228 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S603_D23, extra 29.2305 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S603_D42, extra 29.2132 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S604_D10, extra 29.1950 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S604_D23, extra 29.1753 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S604_D42, extra 29.2016 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S605_D10, extra 29.2054 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S605_D23, extra 29.2436 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S605_D42, extra 29.2459 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S606_D10, extra 29.2254 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S606_D23, extra 29.1880 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S606_D42, extra 29.2210 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S607_D10, extra 29.3217 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S607_D23, extra 29.3042 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S607_D42, extra 29.3413 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S608_D10, extra 29.1819 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S608_D23, extra 29.2811 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S608_D42, extra 29.2427 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S609_D10, extra 29.3329 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S609_D23, extra 29.3001 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S609_D42, extra 29.3477 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S610_D10, extra 29.3004 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S610_D23, extra 29.3575 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S610_D42, extra 29.2784 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S611_D23, extra 29.3419 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S611_D42, extra 29.3221 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S612_D10, extra 29.2338 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S612_D42, extra 29.2006 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S613_D23, extra 29.2865 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S613_D42, extra 29.3010 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S614_D23, extra 29.3513 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S614_D42, extra 29.3358 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S615_D10, extra 29.2812 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S615_D42, extra 29.3017 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S616_D23, extra 29.2987 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S616_D42, extra 29.3084 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S617_D10, extra 29.2552 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S617_D42, extra 29.2812 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S618_D10, extra 29.2284 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S618_D42, extra 29.2478 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S619_D10, extra 29.2894 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S619_D42, extra 29.3188 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S620_D10, extra 29.2104 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S620_D42, extra 29.2458 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S621_D23, extra 29.2447 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S621_D42, extra 29.2063 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S622_D23, extra 29.2590 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S622_D42, extra 29.2388 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S623_D10, extra 29.2322 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S623_D42, extra 29.2551 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S624_D23, extra 29.2417 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S624_D42, extra 29.2581 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S625_D10, extra 29.2681 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S625_D42, extra 29.2889 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S626_D10, extra 29.2509 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S626_D42, extra 29.2646 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S627_D23, extra 29.1695 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S627_D42, extra 29.1838 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S628_D10, extra 29.3483 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S628_D42, extra 29.3799 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S629_D10, extra 29.2823 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S629_D42, extra 29.1686 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S630_D10, extra 29.3141 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S630_D42, extra 29.2679 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S631_D10, extra 29.3522 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S631_D42, extra 29.2861 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S632_D10, extra 29.2605 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S632_D42, extra 29.2894 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S633_D23, extra 29.3206 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S633_D42, extra 29.3630 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S634_D10, extra 29.1841 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S634_D42, extra 29.2533 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S635_D23, extra 29.3015 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S635_D42, extra 29.2943 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S636_D23, extra 29.2304 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S636_D42, extra 29.2645 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S637_D10, extra 29.2714 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S637_D42, extra 29.2638 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S638_D10, extra 29.2281 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S638_D42, extra 29.2854 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S639_D10, extra 29.2304 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S639_D42, extra 29.2660 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S640_D10, extra 29.1946 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S640_D42, extra 29.1764 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S641_D10, extra 29.2763 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S641_D42, extra 29.2405 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S642_D10, extra 29.1220 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S642_D42, extra 29.1608 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S643_D10, extra 29.3251 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S643_D42, extra 29.2380 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S644_D10, extra 29.2505 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S644_D42, extra 29.2280 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S645_D10, extra 29.3134 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S645_D42, extra 29.3381 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S646_D10, extra 29.2721 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S646_D23, extra 29.2365 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S647_D10, extra 29.2118 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S647_D23, extra 29.2244 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S648_D10, extra 29.2378 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S648_D42, extra 29.2533 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S649_D10, extra 29.3147 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S649_D42, extra 29.2561 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S650_D10, extra 29.2129 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_S650_D42, extra 29.2518 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_D10, extra 29.2420 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_D23, extra 29.2450 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_D42, extra 29.2423 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_D10, extra 29.2682 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_D23, extra 29.2686 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_D42, extra 29.2686 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_G6PD_V68M_0, extra 29.2435 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_G6PD_V68M_1, extra 29.2467 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Mean_G6PD_V68M_2, extra 29.2179 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_G6PD_V68M_0, extra 29.2696 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_G6PD_V68M_1, extra 29.2564 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
# Relaxation budget added to RBC_GEM_PC_Median_G6PD_V68M_2, extra 29.2382 mg/gDW (28.5000 mg HB/gDW) from 3.0000% slack
