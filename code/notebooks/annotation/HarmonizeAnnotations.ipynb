# %% [markdown]
# # Harmonize annotations for the RBC-GEM
#
# ## Setup
# ### Import packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
from rbc_gem_utils import (
    ANNOTATION_PATH,
    COBRA_CONFIGURATION,
    INTERIM_PATH,
    MODEL_PATH,
    ROOT_PATH,
    compare_tables,
    explode_column,
    read_rbc_model,
    visualize_comparison,
)
from rbc_gem_utils.database import (
    COMPLEXPORTAL_DB_TAG,
    DRUGBANK_DB_TAG,
    DRUGCENTRAL_DB_TAG,
    HUMANGEM_DB_TAG,
    MIM_DB_TAG,
    TCDB_DB_TAG,
    UNIPROT_DB_TAG,
)

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -1000.0
# upper_bound: 1000.0
# processes: 15
# cache_directory: /Users/zhaiman/Library/Caches/cobrapy
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## Load RBC-GEM model

# %%
model = read_rbc_model(filetype="xml")
model.reactions.sort()
model.genes.sort()
model.metabolites.sort()
model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# <Model RBC_GEM at 0x1492b8c90>

# %% [markdown]
# ## Create annotation tables

# %%
annotation_dirpath = ROOT_PATH / ANNOTATION_PATH
compare = True
display_nunique = True
overwrite = True
compare_figsize = None

preserve_model_previous = True
model_annotation_dfs = {
    "reactions": None,
    "metabolites": None,
    "genes": None,
}
to_double_check = {
    "reactions": {},
    "metabolites": {},
    "genes": {},
}

# %% [markdown]
# ### Reactions

# %%
annotation_type = "reactions"
databases = [HUMANGEM_DB_TAG, "References"]
df_annotations_all = pd.read_csv(
    ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv",
    sep="\t",
)

df_annotations_all = df_annotations_all.set_index(annotation_type)
df_annotations_all = df_annotations_all.rename(
    {c: f"{c}_MODEL" for c in df_annotations_all.columns}, axis=1
)

for db_tag in databases:
    df = pd.read_csv(
        annotation_dirpath / f"{annotation_type}_{db_tag}.tsv",
        sep="\t",
    ).set_index(annotation_type)
    df.columns = [f"{c}_{db_tag}" for c in df.columns]
    df_annotations_all = df_annotations_all.merge(
        df,
        left_index=True,
        right_index=True,
        how="outer",
    )

# Keep database tags on duplicate columns for reconcilliation, remove for unique columns
unique_columns = {name.rsplit("_", 1)[0] for name in df_annotations_all.columns}
to_double_check[annotation_type] = {
    unique: [
        name for name in df_annotations_all.columns if name.rsplit("_", 1)[0] == unique
    ]
    for unique in unique_columns
}
unique_mapping = {
    to_double_check[annotation_type].pop(unique).pop(): unique
    for unique, dbs in to_double_check[annotation_type].copy().items()
    if len(dbs) == 1
}
print(f"Annotation columns to reconcile: {to_double_check[annotation_type]}")
df_annotations_all = df_annotations_all.replace(float("nan"), pd.NA).replace("", pd.NA)
df_annotations_all
# Out:
# Annotation columns to reconcile: {'references': ['references_MODEL', 'references_References'], 'spontaneous': ['spontaneous_MODEL', 'spontaneous_MetAtlas'], 'metatlas': ['metatlas_MODEL', 'metatlas_MetAtlas'], 'vmhreaction': ['vmhreaction_MODEL', 'vmhreaction_MetAtlas'], 'rhea': ['rhea_MODEL', 'rhea_MetAtlas'], 'reactome': ['reactome_MODEL', 'reactome_MetAtlas'], 'bigg.reaction': ['bigg.reaction_MODEL', 'bigg.reaction_MetAtlas'], 'tcdb': ['tcdb_MODEL', 'tcdb_MetAtlas'], 'metanetx.reaction': ['metanetx.reaction_MODEL', 'metanetx.reaction_MetAtlas'], 'kegg.reaction': ['kegg.reaction_MODEL', 'kegg.reaction_MetAtlas'], 'ec-code': ['ec-code_MODEL', 'ec-code_MetAtlas']}
#                 bigg.reaction_MODEL biocyc_MODEL              ec-code_MODEL  \
# reactions
# 13DAMPPOX                 13DAMPPOX         <NA>  1.4.3.6;1.4.3.21;1.4.3.22
# 15KPGE1Ry                 15KPGE1Ry         <NA>                       <NA>
# 15KPGE2Ry                 15KPGE2Ry         <NA>                       <NA>
# 15KPGE3Ry                 15KPGE3Ry         <NA>                       <NA>
# 15KPGF1Ry                 15KPGF1Ry         <NA>                       <NA>
# ...                             ...          ...                        ...
# YYYTPAP                     YYYTPAP         <NA>                       <NA>
# ZN2Htex2                   ZN2Htex2         <NA>                       <NA>
# ZN2_2HCO3t                     <NA>         <NA>                       <NA>
# ZN2_HCO3_SELNIt                <NA>         <NA>                       <NA>
# ZN2t                           ZN2t         <NA>                       <NA>
#
#                 kegg.reaction_MODEL metanetx.reaction_MODEL metatlas_MODEL  \
# reactions
# 13DAMPPOX                      <NA>               MNXR94687       MAR07992
# 15KPGE1Ry                      <NA>                    <NA>           <NA>
# 15KPGE2Ry                      <NA>                    <NA>           <NA>
# 15KPGE3Ry                      <NA>                    <NA>           <NA>
# 15KPGF1Ry                      <NA>                    <NA>           <NA>
# ...                             ...                     ...            ...
# YYYTPAP                        <NA>                    <NA>           <NA>
# ZN2Htex2                       <NA>                    <NA>           <NA>
# ZN2_2HCO3t                     <NA>                    <NA>           <NA>
# ZN2_HCO3_SELNIt                <NA>                    <NA>           <NA>
# ZN2t                           <NA>              MNXR105280       MAR06370
#
#                 reactome_MODEL  \
# reactions
# 13DAMPPOX                 <NA>
# 15KPGE1Ry                 <NA>
# 15KPGE2Ry                 <NA>
# 15KPGE3Ry                 <NA>
# 15KPGF1Ry                 <NA>
# ...                        ...
# YYYTPAP                   <NA>
# ZN2Htex2                  <NA>
# ZN2_2HCO3t                <NA>
# ZN2_HCO3_SELNIt           <NA>
# ZN2t                      <NA>
#
#                                                   references_MODEL rhea_MODEL  \
# reactions
# 13DAMPPOX                                          pubmed:23330127       <NA>
# 15KPGE1Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...       <NA>
# 15KPGE2Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...       <NA>
# 15KPGE3Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...       <NA>
# 15KPGF1Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...       <NA>
# ...                                                            ...        ...
# YYYTPAP                              pubmed:6058286;pubmed:7002549       <NA>
# ZN2Htex2         pubmed:11817695;pubmed:18936201;pubmed:2245666...       <NA>
# ZN2_2HCO3t       pubmed:22456662;pubmed:22898811;pubmed:2484233...       <NA>
# ZN2_HCO3_SELNIt  pubmed:22456662;pubmed:22898811;pubmed:2716625...       <NA>
# ZN2t             pubmed:11817695;pubmed:18936201;pubmed:2161459...       <NA>
#
#                 sabiork.reaction_MODEL  ... kegg.reaction_MetAtlas  \
# reactions                               ...
# 13DAMPPOX                         <NA>  ...                   <NA>
# 15KPGE1Ry                         <NA>  ...                   <NA>
# 15KPGE2Ry                         <NA>  ...                   <NA>
# 15KPGE3Ry                         <NA>  ...                   <NA>
# 15KPGF1Ry                         <NA>  ...                   <NA>
# ...                                ...  ...                    ...
# YYYTPAP                           <NA>  ...                   <NA>
# ZN2Htex2                          <NA>  ...                   <NA>
# ZN2_2HCO3t                        <NA>  ...                   <NA>
# ZN2_HCO3_SELNIt                   <NA>  ...                   <NA>
# ZN2t                              <NA>  ...                   <NA>
#
#                 bigg.reaction_MetAtlas reactome_MetAtlas vmhreaction_MetAtlas  \
# reactions
# 13DAMPPOX                    13DAMPPOX              <NA>            13DAMPPOX
# 15KPGE1Ry                         <NA>              <NA>                 <NA>
# 15KPGE2Ry                         <NA>              <NA>                 <NA>
# 15KPGE3Ry                         <NA>              <NA>                 <NA>
# 15KPGF1Ry                         <NA>              <NA>                 <NA>
# ...                                ...               ...                  ...
# YYYTPAP                           <NA>              <NA>                 <NA>
# ZN2Htex2                          <NA>              <NA>                 <NA>
# ZN2_2HCO3t                        <NA>              <NA>                 <NA>
# ZN2_HCO3_SELNIt                   <NA>              <NA>                 <NA>
# ZN2t                              <NA>              <NA>                r2465
#
#                 metanetx.reaction_MetAtlas tcdb_MetAtlas rhea_MetAtlas  \
# reactions
# 13DAMPPOX                        MNXR94687          <NA>          <NA>
# 15KPGE1Ry                             <NA>          <NA>          <NA>
# 15KPGE2Ry                             <NA>          <NA>          <NA>
# 15KPGE3Ry                             <NA>          <NA>          <NA>
# 15KPGF1Ry                             <NA>          <NA>          <NA>
# ...                                    ...           ...           ...
# YYYTPAP                               <NA>          <NA>          <NA>
# ZN2Htex2                              <NA>          <NA>          <NA>
# ZN2_2HCO3t                            <NA>          <NA>          <NA>
# ZN2_HCO3_SELNIt                       <NA>          <NA>          <NA>
# ZN2t                            MNXR105280     2.A.4.2.3          <NA>
#
#                 spontaneous_MetAtlas           ec-code_MetAtlas  \
# reactions
# 13DAMPPOX                        0.0  1.4.3.6;1.4.3.21;1.4.3.22
# 15KPGE1Ry                       <NA>                       <NA>
# 15KPGE2Ry                       <NA>                       <NA>
# 15KPGE3Ry                       <NA>                       <NA>
# 15KPGF1Ry                       <NA>                       <NA>
# ...                              ...                        ...
# YYYTPAP                         <NA>                       <NA>
# ZN2Htex2                        <NA>                       <NA>
# ZN2_2HCO3t                      <NA>                       <NA>
# ZN2_HCO3_SELNIt                 <NA>                       <NA>
# ZN2t                             0.0                       <NA>
#
#                                              references_References
# reactions
# 13DAMPPOX                                          pubmed:23330127
# 15KPGE1Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 15KPGE2Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 15KPGE3Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 15KPGF1Ry        pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# ...                                                            ...
# YYYTPAP                              pubmed:6058286;pubmed:7002549
# ZN2Htex2         pubmed:11817695;pubmed:18936201;pubmed:2245666...
# ZN2_2HCO3t       pubmed:22456662;pubmed:22898811;pubmed:2484233...
# ZN2_HCO3_SELNIt  pubmed:22456662;pubmed:22898811;pubmed:2716625...
# ZN2t             pubmed:11817695;pubmed:18936201;pubmed:2161459...
#
# [3275 rows x 26 columns]

# %% [markdown]
# #### Reconcile cross-referenced from multiple sources
# These columns had multiple mappings and need to be reconciled.

# %%
reconcilliation = {
    # Overwrite with MetAtlas
    "metanetx.reaction": HUMANGEM_DB_TAG,
    "kegg.reaction": HUMANGEM_DB_TAG,
    "vmhreaction": HUMANGEM_DB_TAG,
    "metatlas": HUMANGEM_DB_TAG,
    "reactome": HUMANGEM_DB_TAG,
    "tcdb": HUMANGEM_DB_TAG,
    "ec-code": HUMANGEM_DB_TAG,
    "rhea": HUMANGEM_DB_TAG,
    # Preserve from model, some BiGG mappings in MetAtlas are off.
    "bigg.reaction": "MODEL",
    # Non-miriam fields, spontaneous comes from References
    "spontaneous": "MODEL",
    "references": "References",
}

df_annotations = df_annotations_all.copy()
for key, chosen_col in reconcilliation.items():
    if key not in to_double_check[annotation_type]:
        continue
    df_base_column = df_annotations_all.loc[:, f"{key}_{chosen_col}"].copy()
    df_base_column.name = key
    df_columns = df_annotations_all.loc[:, to_double_check[annotation_type][key]]
    for idx, row in df_columns.iterrows():
        if preserve_model_previous:
            # Preserve old ID to prevent loss of ID
            try:
                if not row.isna()[f"{key}_MODEL"] and row.isna()[f"{key}_{chosen_col}"]:
                    df_base_column[idx] = row[f"{key}_MODEL"]
            except KeyError as e:
                pass

    df_annotations = df_annotations.drop(to_double_check[annotation_type][key], axis=1)
    to_double_check[annotation_type].pop(key)
    df_annotations[key] = df_base_column


# Overwrite
df_annotations = df_annotations.rename(unique_mapping, axis=1)
df_annotations = df_annotations.reset_index(drop=False).fillna("")
model_annotation_dfs[annotation_type] = df_annotations
df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
df_annotations
# Out:
#             reactions biocyc sabiork.reaction          sbo seed.reaction  \
# 0           13DAMPPOX   <NA>             <NA>  SBO:0000176          <NA>
# 1           15KPGE1Ry   <NA>             <NA>  SBO:0000176          <NA>
# 2           15KPGE2Ry   <NA>             <NA>  SBO:0000176          <NA>
# 3           15KPGE3Ry   <NA>             <NA>  SBO:0000176          <NA>
# 4           15KPGF1Ry   <NA>             <NA>  SBO:0000176          <NA>
# ...               ...    ...              ...          ...           ...
# 3270          YYYTPAP   <NA>             <NA>  SBO:0000176          <NA>
# 3271         ZN2Htex2   <NA>             <NA>  SBO:0000185          <NA>
# 3272       ZN2_2HCO3t   <NA>             <NA>  SBO:0000185          <NA>
# 3273  ZN2_HCO3_SELNIt   <NA>             <NA>  SBO:0000185          <NA>
# 3274             ZN2t   <NA>             <NA>  SBO:0000185          <NA>
#
#      metanetx.reaction kegg.reaction vmhreaction  metatlas reactome  \
# 0            MNXR94687          <NA>   13DAMPPOX  MAR07992     <NA>
# 1                 <NA>          <NA>        <NA>      <NA>     <NA>
# 2                 <NA>          <NA>        <NA>      <NA>     <NA>
# 3                 <NA>          <NA>        <NA>      <NA>     <NA>
# 4                 <NA>          <NA>        <NA>      <NA>     <NA>
# ...                ...           ...         ...       ...      ...
# 3270              <NA>          <NA>        <NA>      <NA>     <NA>
# 3271              <NA>          <NA>        <NA>      <NA>     <NA>
# 3272              <NA>          <NA>        <NA>      <NA>     <NA>
# 3273              <NA>          <NA>        <NA>      <NA>     <NA>
# 3274        MNXR105280          <NA>       r2465  MAR06370     <NA>
#
#            tcdb                    ec-code  rhea bigg.reaction spontaneous  \
# 0          <NA>  1.4.3.6;1.4.3.21;1.4.3.22  <NA>     13DAMPPOX         0.0
# 1          <NA>                       <NA>  <NA>     15KPGE1Ry         0.0
# 2          <NA>                       <NA>  <NA>     15KPGE2Ry         0.0
# 3          <NA>                       <NA>  <NA>     15KPGE3Ry         0.0
# 4          <NA>                       <NA>  <NA>     15KPGF1Ry         0.0
# ...         ...                        ...   ...           ...         ...
# 3270       <NA>                       <NA>  <NA>       YYYTPAP         0.0
# 3271       <NA>                       <NA>  <NA>      ZN2Htex2         0.0
# 3272       <NA>                       <NA>  <NA>          <NA>         0.0
# 3273       <NA>                       <NA>  <NA>          <NA>         0.0
# 3274  2.A.4.2.3                       <NA>  <NA>          ZN2t         0.0
#
#                                              references
# 0                                       pubmed:23330127
# 1     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 2     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 3     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 4     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# ...                                                 ...
# 3270                      pubmed:6058286;pubmed:7002549
# 3271  pubmed:11817695;pubmed:18936201;pubmed:2245666...
# 3272  pubmed:22456662;pubmed:22898811;pubmed:2484233...
# 3273  pubmed:22456662;pubmed:22898811;pubmed:2716625...
# 3274  pubmed:11817695;pubmed:18936201;pubmed:2161459...
#
# [3275 rows x 16 columns]

# %% [markdown]
# #### Save annotations

# %%
assert (
    len(to_double_check[annotation_type]) == 0
), f"There are still columns with data that need reconcilliation: {to_double_check[annotation_type]}"
df_annotations = model_annotation_dfs[annotation_type]

df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
if compare:
    compare_on_index = [annotation_type]
    try:
        df_previous = pd.read_csv(
            ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv",
            sep="\t",
            index_col=None,
            dtype=str,
        )
        df_previous = df_previous.replace(float("nan"), pd.NA).replace("", pd.NA)
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=compare_on_index)
    df_comparision = compare_tables(
        df_previous.set_index(compare_on_index),
        df_annotations.set_index(compare_on_index),
    )

    fig, ax = plt.subplots(1, 1, figsize=compare_figsize)
    ax.yaxis.set_tick_params(labelsize=8)
    ax = visualize_comparison(df_comparision)

if display_nunique:
    for col in df_annotations.columns:
        df = explode_column(df_annotations, name=col, sep=";")
        df = df[col].drop_duplicates()
        print(f"{df.name}: {df.nunique()}")

if overwrite:
    df_annotations.to_csv(
        ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv", sep="\t", index=False
    )
else:
    df_annotations.to_csv(
        ROOT_PATH / INTERIM_PATH / f"{annotation_type}.tsv",
        sep="\t",
        index=False,
    )
df_annotations
# Out:
# reactions: 3275
# biocyc: 188
# sabiork.reaction: 149
# sbo: 4
# seed.reaction: 288
# metanetx.reaction: 1182
# kegg.reaction: 535
# vmhreaction: 1630
# metatlas: 1602
# reactome: 243
# tcdb: 31
# ec-code: 395
# rhea: 508
# bigg.reaction: 3491
# spontaneous: 2
# references: 977
#             reactions biocyc sabiork.reaction          sbo seed.reaction  \
# 0           13DAMPPOX   <NA>             <NA>  SBO:0000176          <NA>
# 1           15KPGE1Ry   <NA>             <NA>  SBO:0000176          <NA>
# 2           15KPGE2Ry   <NA>             <NA>  SBO:0000176          <NA>
# 3           15KPGE3Ry   <NA>             <NA>  SBO:0000176          <NA>
# 4           15KPGF1Ry   <NA>             <NA>  SBO:0000176          <NA>
# ...               ...    ...              ...          ...           ...
# 3270          YYYTPAP   <NA>             <NA>  SBO:0000176          <NA>
# 3271         ZN2Htex2   <NA>             <NA>  SBO:0000185          <NA>
# 3272       ZN2_2HCO3t   <NA>             <NA>  SBO:0000185          <NA>
# 3273  ZN2_HCO3_SELNIt   <NA>             <NA>  SBO:0000185          <NA>
# 3274             ZN2t   <NA>             <NA>  SBO:0000185          <NA>
#
#      metanetx.reaction kegg.reaction vmhreaction  metatlas reactome  \
# 0            MNXR94687          <NA>   13DAMPPOX  MAR07992     <NA>
# 1                 <NA>          <NA>        <NA>      <NA>     <NA>
# 2                 <NA>          <NA>        <NA>      <NA>     <NA>
# 3                 <NA>          <NA>        <NA>      <NA>     <NA>
# 4                 <NA>          <NA>        <NA>      <NA>     <NA>
# ...                ...           ...         ...       ...      ...
# 3270              <NA>          <NA>        <NA>      <NA>     <NA>
# 3271              <NA>          <NA>        <NA>      <NA>     <NA>
# 3272              <NA>          <NA>        <NA>      <NA>     <NA>
# 3273              <NA>          <NA>        <NA>      <NA>     <NA>
# 3274        MNXR105280          <NA>       r2465  MAR06370     <NA>
#
#            tcdb                    ec-code  rhea bigg.reaction spontaneous  \
# 0          <NA>  1.4.3.6;1.4.3.21;1.4.3.22  <NA>     13DAMPPOX         0.0
# 1          <NA>                       <NA>  <NA>     15KPGE1Ry         0.0
# 2          <NA>                       <NA>  <NA>     15KPGE2Ry         0.0
# 3          <NA>                       <NA>  <NA>     15KPGE3Ry         0.0
# 4          <NA>                       <NA>  <NA>     15KPGF1Ry         0.0
# ...         ...                        ...   ...           ...         ...
# 3270       <NA>                       <NA>  <NA>       YYYTPAP         0.0
# 3271       <NA>                       <NA>  <NA>      ZN2Htex2         0.0
# 3272       <NA>                       <NA>  <NA>          <NA>         0.0
# 3273       <NA>                       <NA>  <NA>          <NA>         0.0
# 3274  2.A.4.2.3                       <NA>  <NA>          ZN2t         0.0
#
#                                              references
# 0                                       pubmed:23330127
# 1     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 2     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 3     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# 4     pubmed:236730;pubmed:24657656;pubmed:6597453;p...
# ...                                                 ...
# 3270                      pubmed:6058286;pubmed:7002549
# 3271  pubmed:11817695;pubmed:18936201;pubmed:2245666...
# 3272  pubmed:22456662;pubmed:22898811;pubmed:2484233...
# 3273  pubmed:22456662;pubmed:22898811;pubmed:2716625...
# 3274  pubmed:11817695;pubmed:18936201;pubmed:2161459...
#
# [3275 rows x 16 columns]

# %% [markdown]
# ### Metabolites

# %%
annotation_type = "metabolites"
databases = [HUMANGEM_DB_TAG]
df_annotations_all = pd.read_csv(
    ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv",
    sep="\t",
)

df_annotations_all = df_annotations_all.set_index(annotation_type)
df_annotations_all = df_annotations_all.rename(
    {c: f"{c}_MODEL" for c in df_annotations_all.columns}, axis=1
)

for db_tag in databases:
    df = pd.read_csv(
        annotation_dirpath / f"{annotation_type}_{db_tag}.tsv",
        sep="\t",
    ).set_index(annotation_type)
    df.columns = [f"{c}_{db_tag}" for c in df.columns]
    df_annotations_all = df_annotations_all.merge(
        df,
        left_index=True,
        right_index=True,
        how="outer",
    )

# Keep database tags on duplicate columns for reconcilliation, remove for unique columns
unique_columns = {name.rsplit("_", 1)[0] for name in df_annotations_all.columns}
to_double_check[annotation_type] = {
    unique: [
        name for name in df_annotations_all.columns if name.rsplit("_", 1)[0] == unique
    ]
    for unique in unique_columns
}
unique_mapping = {
    to_double_check[annotation_type].pop(unique).pop(): unique
    for unique, dbs in to_double_check[annotation_type].copy().items()
    if len(dbs) == 1
}
print(f"Annotation columns to reconcile: {to_double_check[annotation_type]}")
df_annotations_all = df_annotations_all.replace(float("nan"), pd.NA).replace("", pd.NA)
df_annotations_all
# Out:
# Annotation columns to reconcile: {'inchi': ['inchi_MODEL', 'inchi_MetAtlas'], 'chebi': ['chebi_MODEL', 'chebi_MetAtlas'], 'metanetx.chemical': ['metanetx.chemical_MODEL', 'metanetx.chemical_MetAtlas'], 'pubchem.compound': ['pubchem.compound_MODEL', 'pubchem.compound_MetAtlas'], 'metatlas': ['metatlas_MODEL', 'metatlas_MetAtlas'], 'lipidmaps': ['lipidmaps_MODEL', 'lipidmaps_MetAtlas'], 'vmhmetabolite': ['vmhmetabolite_MODEL', 'vmhmetabolite_MetAtlas'], 'bigg.metabolite': ['bigg.metabolite_MODEL', 'bigg.metabolite_MetAtlas'], 'kegg.compound': ['kegg.compound_MODEL', 'kegg.compound_MetAtlas'], 'hmdb': ['hmdb_MODEL', 'hmdb_MetAtlas']}
#             bigg.metabolite_MODEL biocyc_MODEL  chebi_MODEL envipath_MODEL  \
# metabolites
# 10fthf_c                   10fthf         <NA>  CHEBI:15637           <NA>
# 12ppd__R_c               12ppd__R         <NA>  CHEBI:16997           <NA>
# 12ppd__S_c               12ppd__S         <NA>         <NA>           <NA>
# 13dampp_c                 13dampp         <NA>  CHEBI:15725           <NA>
# 13dpg_c                     13dpg     META:DPG  CHEBI:16001           <NA>
# ...                           ...          ...          ...            ...
# zn2_c                         zn2         <NA>  CHEBI:29105           <NA>
# zn2_e                         zn2         <NA>  CHEBI:29105           <NA>
# ztp_c                         ztp         <NA>         <NA>           <NA>
# zymst_c                     zymst         <NA>  CHEBI:18252           <NA>
# zymstnl_c                 zymstnl         <NA>  CHEBI:16608           <NA>
#
#               hmdb_MODEL                                        inchi_MODEL  \
# metabolites
# 10fthf_c            <NA>                                               <NA>
# 12ppd__R_c   HMDB0001881           InChI=1S/C3H8O2/c1-3(5)2-4/h3-5H,2H2,1H3
# 12ppd__S_c          <NA>                                               <NA>
# 13dampp_c    HMDB0000002                                               <NA>
# 13dpg_c        HMDB62758                                               <NA>
# ...                  ...                                                ...
# zn2_c        HMDB0015532                                               <NA>
# zn2_e        HMDB0015532                                               <NA>
# ztp_c               <NA>                                               <NA>
# zymst_c             <NA>  InChI=1S/C27H44O/c1-18(2)7-6-8-19(3)23-11-12-2...
# zymstnl_c    HMDB0006841  InChI=1S/C27H46O/c1-18(2)7-6-8-19(3)23-11-12-2...
#
#                           inchikey_MODEL kegg.compound_MODEL kegg.drug_MODEL  \
# metabolites
# 10fthf_c                            <NA>              C00234            <NA>
# 12ppd__R_c                          <NA>              C00583            <NA>
# 12ppd__S_c                          <NA>                <NA>            <NA>
# 13dampp_c                           <NA>              C00986            <NA>
# 13dpg_c      LJQLQCAXBUHEAZ-UWTATZPHSA-J              C00236            <NA>
# ...                                  ...                 ...             ...
# zn2_c                               <NA>              C00038            <NA>
# zn2_e                               <NA>              C00038            <NA>
# ztp_c                               <NA>                <NA>            <NA>
# zymst_c                             <NA>              C05437            <NA>
# zymstnl_c                           <NA>              C03845            <NA>
#
#             kegg.glycan_MODEL  ... metatlas_MetAtlas bigg.metabolite_MetAtlas  \
# metabolites                    ...
# 10fthf_c                 <NA>  ...         MAM00266c                   10fthf
# 12ppd__R_c               <NA>  ...         MAM02771c                 12ppd__R
# 12ppd__S_c               <NA>  ...              <NA>                     <NA>
# 13dampp_c                <NA>  ...         MAM00248c                  13dampp
# 13dpg_c                  <NA>  ...         MAM00247c                    13dpg
# ...                       ...  ...               ...                      ...
# zn2_c                    <NA>  ...         MAM03157c                     <NA>
# zn2_e                    <NA>  ...         MAM03157e                     <NA>
# ztp_c                    <NA>  ...              <NA>                     <NA>
# zymst_c                  <NA>  ...         MAM03158c                    zymst
# zymstnl_c                <NA>  ...         MAM01449c                  zymstnl
#
#             kegg.compound_MetAtlas hmdb_MetAtlas chebi_MetAtlas  \
# metabolites
# 10fthf_c                    C00234          <NA>    CHEBI:15637
# 12ppd__R_c                  C00583   HMDB0001881    CHEBI:16997
# 12ppd__S_c                    <NA>          <NA>           <NA>
# 13dampp_c                   C00986   HMDB0000002    CHEBI:15725
# 13dpg_c                     C00236          <NA>    CHEBI:16001
# ...                            ...           ...            ...
# zn2_c                       C00038   HMDB0015532    CHEBI:29105
# zn2_e                       C00038   HMDB0015532    CHEBI:29105
# ztp_c                         <NA>          <NA>           <NA>
# zymst_c                     C05437          <NA>    CHEBI:18252
# zymstnl_c                   C03845   HMDB0006841    CHEBI:16608
#
#             pubchem.compound_MetAtlas lipidmaps_MetAtlas  \
# metabolites
# 10fthf_c                     122347.0               <NA>
# 12ppd__R_c                     1030.0               <NA>
# 12ppd__S_c                       <NA>               <NA>
# 13dampp_c                       428.0               <NA>
# 13dpg_c                      439191.0               <NA>
# ...                               ...                ...
# zn2_c                         32051.0               <NA>
# zn2_e                         32051.0               <NA>
# ztp_c                            <NA>               <NA>
# zymst_c                       92746.0       LMST01010066
# zymstnl_c                    101770.0       LMST01010096
#
#             vmhmetabolite_MetAtlas   metanetx.chemical_MetAtlas  \
# metabolites
# 10fthf_c                    10fthf                      MNXM237
# 12ppd__R_c                 12ppd_R  MNXM1118;MNXM1255;MNXM90191
# 12ppd__S_c                    <NA>                         <NA>
# 13dampp_c                  13dampp           MNXM146468;MNXM350
# 13dpg_c                      13dpg                      MNXM261
# ...                            ...                          ...
# zn2_c                          zn2                      MNXM149
# zn2_e                          zn2                      MNXM149
# ztp_c                         <NA>                         <NA>
# zymst_c                      zymst                      MNXM574
# zymstnl_c                  zymstnl                     MNXM2494
#
#                                                 inchi_MetAtlas
# metabolites
# 10fthf_c                                                  <NA>
# 12ppd__R_c            InChI=1S/C3H8O2/c1-3(5)2-4/h3-5H,2H2,1H3
# 12ppd__S_c                                                <NA>
# 13dampp_c                                                 <NA>
# 13dpg_c                                                   <NA>
# ...                                                        ...
# zn2_c                                                     <NA>
# zn2_e                                                     <NA>
# ztp_c                                                     <NA>
# zymst_c      InChI=1S/C27H44O/c1-18(2)7-6-8-19(3)23-11-12-2...
# zymstnl_c    InChI=1S/C27H46O/c1-18(2)7-6-8-19(3)23-11-12-2...
#
# [2157 rows x 31 columns]

# %% [markdown]
# #### Reconcile cross-referenced from multiple sources
# These columns had multiple mappings and need to be reconciled.

# %%
reconcilliation = {
    # Overwrite with MetAtlas
    "kegg.compound": HUMANGEM_DB_TAG,
    "lipidmaps": HUMANGEM_DB_TAG,
    "hmdb": HUMANGEM_DB_TAG,
    "vmhmetabolite": HUMANGEM_DB_TAG,
    "metatlas": HUMANGEM_DB_TAG,
    "chebi": HUMANGEM_DB_TAG,
    "pubchem.compound": HUMANGEM_DB_TAG,
    "metanetx.chemical": HUMANGEM_DB_TAG,
    "inchi": HUMANGEM_DB_TAG,
    # Preserve from model, some BiGG mappings in MetAtlas are off.
    "bigg.metabolite": "MODEL",
    # # Non-miriam fields
    "references": "References",
}

df_annotations = df_annotations_all.copy()
for key, chosen_col in reconcilliation.items():
    if key not in to_double_check[annotation_type]:
        continue
    df_base_column = df_annotations_all.loc[:, f"{key}_{chosen_col}"].copy()
    df_base_column.name = key
    df_columns = df_annotations_all.loc[:, to_double_check[annotation_type][key]]
    for idx, row in df_columns.iterrows():
        if preserve_model_previous:
            # Preserve old ID to prevent loss of ID
            try:
                if not row.isna()[f"{key}_MODEL"] and row.isna()[f"{key}_{chosen_col}"]:
                    df_base_column[idx] = row[f"{key}_MODEL"]
            except KeyError as e:
                pass
    df_annotations[key] = df_base_column
    df_annotations = df_annotations.drop(to_double_check[annotation_type][key], axis=1)
    to_double_check[annotation_type].pop(key)


# Overwrite
df_annotations = df_annotations.rename(unique_mapping, axis=1)
df_annotations = df_annotations.reset_index(drop=False).fillna("")
model_annotation_dfs[annotation_type] = df_annotations
df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
df_annotations
# Out:
#      metabolites    biocyc envipath                     inchikey kegg.drug  \
# 0       10fthf_c      <NA>     <NA>                         <NA>      <NA>
# 1     12ppd__R_c      <NA>     <NA>                         <NA>      <NA>
# 2     12ppd__S_c      <NA>     <NA>                         <NA>      <NA>
# 3      13dampp_c      <NA>     <NA>                         <NA>      <NA>
# 4        13dpg_c  META:DPG     <NA>  LJQLQCAXBUHEAZ-UWTATZPHSA-J      <NA>
# ...          ...       ...      ...                          ...       ...
# 2152       zn2_c      <NA>     <NA>                         <NA>      <NA>
# 2153       zn2_e      <NA>     <NA>                         <NA>      <NA>
# 2154       ztp_c      <NA>     <NA>                         <NA>      <NA>
# 2155     zymst_c      <NA>     <NA>                         <NA>      <NA>
# 2156   zymstnl_c      <NA>     <NA>                         <NA>      <NA>
#
#      kegg.glycan metabolite reactome sabiork.compound          sbo  ...  \
# 0           <NA>     10fthf     <NA>             <NA>  SBO:0000247  ...
# 1           <NA>   12ppd__R     <NA>             <NA>  SBO:0000247  ...
# 2           <NA>   12ppd__S     <NA>             <NA>  SBO:0000247  ...
# 3           <NA>    13dampp     <NA>             <NA>  SBO:0000247  ...
# 4           <NA>      13dpg    29800            21215  SBO:0000247  ...
# ...          ...        ...      ...              ...          ...  ...
# 2152        <NA>        zn2     <NA>             <NA>  SBO:0000247  ...
# 2153        <NA>        zn2     <NA>             <NA>  SBO:0000247  ...
# 2154        <NA>        ztp     <NA>             <NA>  SBO:0000247  ...
# 2155        <NA>      zymst     <NA>             <NA>  SBO:0000247  ...
# 2156        <NA>    zymstnl     <NA>             <NA>  SBO:0000247  ...
#
#      kegg.compound     lipidmaps         hmdb vmhmetabolite   metatlas  \
# 0           C00234          <NA>         <NA>        10fthf  MAM00266c
# 1           C00583          <NA>  HMDB0001881       12ppd_R  MAM02771c
# 2             <NA>          <NA>         <NA>          <NA>       <NA>
# 3           C00986          <NA>  HMDB0000002       13dampp  MAM00248c
# 4           C00236          <NA>    HMDB62758         13dpg  MAM00247c
# ...            ...           ...          ...           ...        ...
# 2152        C00038          <NA>  HMDB0015532           zn2  MAM03157c
# 2153        C00038          <NA>  HMDB0015532           zn2  MAM03157e
# 2154          <NA>          <NA>         <NA>          <NA>       <NA>
# 2155        C05437  LMST01010066         <NA>         zymst  MAM03158c
# 2156        C03845  LMST01010096  HMDB0006841       zymstnl  MAM01449c
#
#             chebi pubchem.compound            metanetx.chemical  \
# 0     CHEBI:15637         122347.0                      MNXM237
# 1     CHEBI:16997           1030.0  MNXM1118;MNXM1255;MNXM90191
# 2            <NA>             <NA>                         <NA>
# 3     CHEBI:15725            428.0           MNXM146468;MNXM350
# 4     CHEBI:16001         439191.0                      MNXM261
# ...           ...              ...                          ...
# 2152  CHEBI:29105          32051.0                      MNXM149
# 2153  CHEBI:29105          32051.0                      MNXM149
# 2154         <NA>             <NA>                         <NA>
# 2155  CHEBI:18252          92746.0                      MNXM574
# 2156  CHEBI:16608         101770.0                     MNXM2494
#
#                                                   inchi bigg.metabolite
# 0                                                  <NA>          10fthf
# 1              InChI=1S/C3H8O2/c1-3(5)2-4/h3-5H,2H2,1H3        12ppd__R
# 2                                                  <NA>        12ppd__S
# 3                                                  <NA>         13dampp
# 4                                                  <NA>           13dpg
# ...                                                 ...             ...
# 2152                                               <NA>             zn2
# 2153                                               <NA>             zn2
# 2154                                               <NA>             ztp
# 2155  InChI=1S/C27H44O/c1-18(2)7-6-8-19(3)23-11-12-2...           zymst
# 2156  InChI=1S/C27H46O/c1-18(2)7-6-8-19(3)23-11-12-2...         zymstnl
#
# [2157 rows x 22 columns]

# %% [markdown]
# #### Save annotations

# %%
assert (
    len(to_double_check[annotation_type]) == 0
), f"There are still columns with data that need reconcilliation: {to_double_check[annotation_type]}"
df_annotations = model_annotation_dfs[annotation_type]

df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
if compare:
    compare_on_index = [annotation_type]
    try:
        df_previous = pd.read_csv(
            ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv",
            sep="\t",
            index_col=None,
            dtype=str,
        )
        df_previous = df_previous.replace(float("nan"), pd.NA).replace("", pd.NA)
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=compare_on_index)
    df_comparision = compare_tables(
        df_previous.set_index(compare_on_index),
        df_annotations.set_index(compare_on_index),
    )

    fig, ax = plt.subplots(1, 1, figsize=compare_figsize)
    ax.yaxis.set_tick_params(labelsize=8)
    ax = visualize_comparison(df_comparision)

if display_nunique:
    for col in df_annotations.columns:
        df = explode_column(df_annotations, name=col, sep=";")
        df = df[col].drop_duplicates()
        print(f"{df.name}: {df.nunique()}")

if overwrite:
    df_annotations.to_csv(
        ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv", sep="\t", index=False
    )
else:
    df_annotations.to_csv(
        ROOT_PATH / INTERIM_PATH / f"{annotation_type}.tsv",
    )
df_annotations
# Out:
# metabolites: 2157
# biocyc: 212
# envipath: 72
# inchikey: 184
# kegg.drug: 64
# kegg.glycan: 6
# metabolite: 1685
# reactome: 455
# sabiork.compound: 218
# sbo: 1
# seed.compound: 224
# slm: 7
# kegg.compound: 767
# lipidmaps: 227
# hmdb: 501
# vmhmetabolite: 1144
# metatlas: 1450
# chebi: 710
# pubchem.compound: 676
# metanetx.chemical: 1173
# inchi: 129
# bigg.metabolite: 1571
#      metabolites    biocyc envipath                     inchikey kegg.drug  \
# 0       10fthf_c      <NA>     <NA>                         <NA>      <NA>
# 1     12ppd__R_c      <NA>     <NA>                         <NA>      <NA>
# 2     12ppd__S_c      <NA>     <NA>                         <NA>      <NA>
# 3      13dampp_c      <NA>     <NA>                         <NA>      <NA>
# 4        13dpg_c  META:DPG     <NA>  LJQLQCAXBUHEAZ-UWTATZPHSA-J      <NA>
# ...          ...       ...      ...                          ...       ...
# 2152       zn2_c      <NA>     <NA>                         <NA>      <NA>
# 2153       zn2_e      <NA>     <NA>                         <NA>      <NA>
# 2154       ztp_c      <NA>     <NA>                         <NA>      <NA>
# 2155     zymst_c      <NA>     <NA>                         <NA>      <NA>
# 2156   zymstnl_c      <NA>     <NA>                         <NA>      <NA>
#
#      kegg.glycan metabolite reactome sabiork.compound          sbo  ...  \
# 0           <NA>     10fthf     <NA>             <NA>  SBO:0000247  ...
# 1           <NA>   12ppd__R     <NA>             <NA>  SBO:0000247  ...
# 2           <NA>   12ppd__S     <NA>             <NA>  SBO:0000247  ...
# 3           <NA>    13dampp     <NA>             <NA>  SBO:0000247  ...
# 4           <NA>      13dpg    29800            21215  SBO:0000247  ...
# ...          ...        ...      ...              ...          ...  ...
# 2152        <NA>        zn2     <NA>             <NA>  SBO:0000247  ...
# 2153        <NA>        zn2     <NA>             <NA>  SBO:0000247  ...
# 2154        <NA>        ztp     <NA>             <NA>  SBO:0000247  ...
# 2155        <NA>      zymst     <NA>             <NA>  SBO:0000247  ...
# 2156        <NA>    zymstnl     <NA>             <NA>  SBO:0000247  ...
#
#      kegg.compound     lipidmaps         hmdb vmhmetabolite   metatlas  \
# 0           C00234          <NA>         <NA>        10fthf  MAM00266c
# 1           C00583          <NA>  HMDB0001881       12ppd_R  MAM02771c
# 2             <NA>          <NA>         <NA>          <NA>       <NA>
# 3           C00986          <NA>  HMDB0000002       13dampp  MAM00248c
# 4           C00236          <NA>    HMDB62758         13dpg  MAM00247c
# ...            ...           ...          ...           ...        ...
# 2152        C00038          <NA>  HMDB0015532           zn2  MAM03157c
# 2153        C00038          <NA>  HMDB0015532           zn2  MAM03157e
# 2154          <NA>          <NA>         <NA>          <NA>       <NA>
# 2155        C05437  LMST01010066         <NA>         zymst  MAM03158c
# 2156        C03845  LMST01010096  HMDB0006841       zymstnl  MAM01449c
#
#             chebi pubchem.compound            metanetx.chemical  \
# 0     CHEBI:15637         122347.0                      MNXM237
# 1     CHEBI:16997           1030.0  MNXM1118;MNXM1255;MNXM90191
# 2            <NA>             <NA>                         <NA>
# 3     CHEBI:15725            428.0           MNXM146468;MNXM350
# 4     CHEBI:16001         439191.0                      MNXM261
# ...           ...              ...                          ...
# 2152  CHEBI:29105          32051.0                      MNXM149
# 2153  CHEBI:29105          32051.0                      MNXM149
# 2154         <NA>             <NA>                         <NA>
# 2155  CHEBI:18252          92746.0                      MNXM574
# 2156  CHEBI:16608         101770.0                     MNXM2494
#
#                                                   inchi bigg.metabolite
# 0                                                  <NA>          10fthf
# 1              InChI=1S/C3H8O2/c1-3(5)2-4/h3-5H,2H2,1H3        12ppd__R
# 2                                                  <NA>        12ppd__S
# 3                                                  <NA>         13dampp
# 4                                                  <NA>           13dpg
# ...                                                 ...             ...
# 2152                                               <NA>             zn2
# 2153                                               <NA>             zn2
# 2154                                               <NA>             ztp
# 2155  InChI=1S/C27H44O/c1-18(2)7-6-8-19(3)23-11-12-2...           zymst
# 2156  InChI=1S/C27H46O/c1-18(2)7-6-8-19(3)23-11-12-2...         zymstnl
#
# [2157 rows x 22 columns]

# %% [markdown]
# ### Genes

# %%
annotation_type = "genes"
databases = [
    HUMANGEM_DB_TAG,
    UNIPROT_DB_TAG,
    MIM_DB_TAG,
    TCDB_DB_TAG,
    DRUGBANK_DB_TAG,
    DRUGCENTRAL_DB_TAG,
    # CDCDB_DB_TAG,
    COMPLEXPORTAL_DB_TAG,
    "References",
]
df_annotations_all = pd.read_csv(
    ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv", sep="\t", index_col=None
)

df_annotations_all = df_annotations_all.set_index(annotation_type)
df_annotations_all = df_annotations_all.rename(
    {c: f"{c}_MODEL" for c in df_annotations_all.columns}, axis=1
)

for db_tag in databases:
    df = pd.read_csv(
        annotation_dirpath / f"{annotation_type}_{db_tag}.tsv",
        sep="\t",
    ).set_index(annotation_type)
    df.columns = [f"{c}_{db_tag}" for c in df.columns]
    df_annotations_all = df_annotations_all.merge(
        df,
        left_index=True,
        right_index=True,
        how="outer",
    )

# Keep database tags on duplicate columns for reconcilliation, remove for unique columns
unique_columns = {name.rsplit("_", 1)[0] for name in df_annotations_all.columns}
to_double_check[annotation_type] = {
    unique: [
        name for name in df_annotations_all.columns if name.rsplit("_", 1)[0] == unique
    ]
    for unique in unique_columns
}
unique_mapping = {
    to_double_check[annotation_type].pop(unique).pop(): unique
    for unique, dbs in to_double_check[annotation_type].copy().items()
    if len(dbs) == 1
}
print(f"Annotation columns to reconcile: {to_double_check[annotation_type]}")
df_annotations_all = df_annotations_all.replace(float("nan"), pd.NA).replace("", pd.NA)
df_annotations_all
# Out:
# Annotation columns to reconcile: {'drugbank': ['drugbank_MODEL', 'drugbank_UniProt', 'drugbank_DrugBank'], 'sasbdb': ['sasbdb_MODEL', 'sasbdb_UniProt'], 'eco': ['eco_MODEL', 'eco_ComplexPortal'], 'genetree': ['genetree_MODEL', 'genetree_UniProt'], 'hogenom': ['hogenom_MODEL', 'hogenom_UniProt'], 'complexportal': ['complexportal_MODEL', 'complexportal_UniProt', 'complexportal_ComplexPortal'], 'chembl.target': ['chembl.target_MODEL', 'chembl.target_UniProt'], 'uniparc': ['uniparc_MODEL', 'uniparc_UniProt'], 'dbsnp': ['dbsnp_MODEL', 'dbsnp_UniProt', 'dbsnp_DrugBank'], 'uniprot': ['uniprot_MODEL', 'uniprot_MetAtlas', 'uniprot_UniProt', 'uniprot_TCDB', 'uniprot_DrugBank', 'uniprot_DrugCentral', 'uniprot_ComplexPortal'], 'hamap': ['hamap_MODEL', 'hamap_UniProt'], 'supfam': ['supfam_MODEL', 'supfam_UniProt'], 'nextprot': ['nextprot_MODEL', 'nextprot_UniProt'], 'pfam': ['pfam_MODEL', 'pfam_UniProt', 'pfam_TCDB', 'pfam_DrugBank'], 'orphanet': ['orphanet_MODEL', 'orphanet_UniProt', 'orphanet_ComplexPortal'], 'hgnc.symbol': ['hgnc.symbol_MODEL', 'hgnc.symbol_MetAtlas', 'hgnc.symbol_UniProt', 'hgnc.symbol_MIM', 'hgnc.symbol_DrugBank', 'hgnc.symbol_DrugCentral'], 'references': ['references_MODEL', 'references_References'], 'proteomicsdb.protein': ['proteomicsdb.protein_MODEL', 'proteomicsdb.protein_UniProt'], 'intact': ['intact_MODEL', 'intact_UniProt', 'intact_ComplexPortal'], 'orthodb': ['orthodb_MODEL', 'orthodb_UniProt'], 'peroxibase': ['peroxibase_MODEL', 'peroxibase_UniProt'], 'bgee.gene': ['bgee.gene_MODEL', 'bgee.gene_UniProt'], 'bmrb': ['bmrb_MODEL', 'bmrb_UniProt'], 'iuphar.receptor': ['iuphar.receptor_MODEL', 'iuphar.receptor_UniProt'], 'refseq': ['refseq_MODEL', 'refseq_UniProt', 'refseq_TCDB'], 'pdb': ['pdb_MODEL', 'pdb_UniProt', 'pdb_TCDB', 'pdb_ComplexPortal'], 'smart': ['smart_MODEL', 'smart_UniProt'], 'hgnc': ['hgnc_MODEL', 'hgnc_UniProt'], 'interpro': ['interpro_MODEL', 'interpro_UniProt'], 'ec-code': ['ec-code_MODEL', 'ec-code_UniProt'], 'mim': ['mim_MODEL', 'mim_UniProt', 'mim_MIM', 'mim_ComplexPortal'], 'genewiki': ['genewiki_MODEL', 'genewiki_UniProt'], 'cazy': ['cazy_MODEL', 'cazy_UniProt'], 'chebi': ['chebi_MODEL', 'chebi_ComplexPortal'], 'pubmed': ['pubmed_MODEL', 'pubmed_ComplexPortal'], 'smr': ['smr_MODEL', 'smr_UniProt'], 'mondo': ['mondo_MODEL', 'mondo_ComplexPortal'], 'ideal': ['ideal_MODEL', 'ideal_UniProt'], 'drugcentral': ['drugcentral_MODEL', 'drugcentral_DrugCentral'], 'mgi': ['mgi_MODEL', 'mgi_MIM'], 'tcdb': ['tcdb_MODEL', 'tcdb_UniProt', 'tcdb_TCDB'], 'panther.family': ['panther.family_MODEL', 'panther.family_UniProt'], 'efo': ['efo_MODEL', 'efo_ComplexPortal'], 'brenda': ['brenda_MODEL', 'brenda_UniProt'], 'cdd': ['cdd_MODEL', 'cdd_UniProt'], 'pirsf': ['pirsf_MODEL', 'pirsf_UniProt'], 'pharmgkb.gene': ['pharmgkb.gene_MODEL', 'pharmgkb.gene_UniProt'], 'rhea': ['rhea_MODEL', 'rhea_UniProt', 'rhea_ComplexPortal'], 'reactome': ['reactome_MODEL', 'reactome_UniProt', 'reactome_ComplexPortal'], 'prosite': ['prosite_MODEL', 'prosite_UniProt'], 'ccds': ['ccds_MODEL', 'ccds_UniProt'], 'chromosome': ['chromosome_MODEL', 'chromosome_UniProt'], 'ena.embl': ['ena.embl_MODEL', 'ena.embl_UniProt'], 'smpdb': ['smpdb_MODEL', 'smpdb_DrugBank'], 'merops': ['merops_MODEL', 'merops_UniProt'], 'treefam': ['treefam_MODEL', 'treefam_UniProt'], 'uniprot.chain': ['uniprot.chain_MODEL', 'uniprot.chain_UniProt'], 'oma.grp': ['oma.grp_MODEL', 'oma.grp_UniProt'], 'biocyc': ['biocyc_MODEL', 'biocyc_UniProt'], 'uniprot.isoform': ['uniprot.isoform_MODEL', 'uniprot.isoform_UniProt'], 'kegg.genes': ['kegg.genes_MODEL', 'kegg.genes_UniProt'], 'biogrid': ['biogrid_MODEL', 'biogrid_UniProt'], 'hpa': ['hpa_MODEL', 'hpa_UniProt'], 'dip': ['dip_MODEL', 'dip_UniProt'], 'eggnog': ['eggnog_MODEL', 'eggnog_UniProt'], 'ensembl': ['ensembl_MODEL', 'ensembl_MetAtlas', 'ensembl_UniProt', 'ensembl_MIM'], 'go': ['go_MODEL', 'go_UniProt', 'go_TCDB', 'go_ComplexPortal'], 'disprot': ['disprot_MODEL', 'disprot_UniProt'], 'genecards': ['genecards_MODEL', 'ge ...
#           bgee.gene_MODEL             biocyc_MODEL biogrid_MODEL bmrb_MODEL  \
# genes
# A4GALT    ENSG00000128274  MetaCyc:HS05171-MONOMER        119825       <NA>
# AARS1     ENSG00000090861                     <NA>        106534       <NA>
# AASDHPPT  ENSG00000149313  MetaCyc:HS14278-MONOMER        121927       <NA>
# ABCA1     ENSG00000165029                     <NA>        106537       <NA>
# ABCA7     ENSG00000064687                     <NA>        115629       <NA>
# ...                   ...                      ...           ...        ...
# YES1      ENSG00000176105                     <NA>        113357       <NA>
# ZDHHC2    ENSG00000104219                     <NA>        119374       <NA>
# ZDHHC20   ENSG00000180776                     <NA>        128991       <NA>
# ZDHHC3    ENSG00000163812                     <NA>        119455       <NA>
# ZDHHC5    ENSG00000156599                     <NA>        117422       <NA>
#
#          brenda_MODEL cazy_MODEL               ccds_MODEL  \
# genes
# A4GALT      2.4.1.228       GT32              CCDS14041.1
# AARS1            <NA>       <NA>              CCDS32474.1
# AASDHPPT      2.7.8.7       <NA>              CCDS31664.1
# ABCA1            <NA>       <NA>               CCDS6762.1
# ABCA7            <NA>       <NA>              CCDS12055.1
# ...               ...        ...                      ...
# YES1         2.7.10.2       <NA>              CCDS11824.1
# ZDHHC2      2.3.1.225       <NA>              CCDS47810.1
# ZDHHC20          <NA>       <NA>  CCDS45017.1;CCDS81758.1
# ZDHHC3      2.3.1.225       <NA>   CCDS2724.1;CCDS46811.1
# ZDHHC5      2.3.1.225       <NA>               CCDS7965.1
#
#                         cdd_MODEL chebi_MODEL chembl.target_MODEL  ...  \
# genes                                                              ...
# A4GALT                       <NA>        <NA>                <NA>  ...
# AARS1                     cd00673        <NA>          CHEMBL3574  ...
# AASDHPPT                     <NA>        <NA>       CHEMBL3137295  ...
# ABCA1                     cd03263        <NA>       CHEMBL2362986  ...
# ABCA7                     cd03263        <NA>                <NA>  ...
# ...                           ...         ...                 ...  ...
# YES1      cd05069;cd09933;cd12007        <NA>          CHEMBL2073  ...
# ZDHHC2                       <NA>        <NA>       CHEMBL5169204  ...
# ZDHHC20                      <NA>        <NA>       CHEMBL5169156  ...
# ZDHHC3                       <NA>        <NA>                <NA>  ...
# ZDHHC5                       <NA>        <NA>                <NA>  ...
#
#          pdb_ComplexPortal intact_ComplexPortal reactome_ComplexPortal  \
# genes
# A4GALT                <NA>                 <NA>                   <NA>
# AARS1                 <NA>                 <NA>                   <NA>
# AASDHPPT              <NA>                 <NA>                   <NA>
# ABCA1                 <NA>                 <NA>                   <NA>
# ABCA7                 <NA>                 <NA>                   <NA>
# ...                    ...                  ...                    ...
# YES1                  <NA>                 <NA>                   <NA>
# ZDHHC2                <NA>                 <NA>                   <NA>
# ZDHHC20               <NA>                 <NA>                   <NA>
# ZDHHC3                <NA>                 <NA>                   <NA>
# ZDHHC5                <NA>                 <NA>                   <NA>
#
#          pubmed_ComplexPortal efo_ComplexPortal rhea_ComplexPortal  \
# genes
# A4GALT                   <NA>              <NA>               <NA>
# AARS1                    <NA>              <NA>               <NA>
# AASDHPPT                 <NA>              <NA>               <NA>
# ABCA1                    <NA>              <NA>               <NA>
# ABCA7                    <NA>              <NA>               <NA>
# ...                       ...               ...                ...
# YES1                     <NA>              <NA>               <NA>
# ZDHHC2                   <NA>              <NA>               <NA>
# ZDHHC20                  <NA>              <NA>               <NA>
# ZDHHC3                   <NA>              <NA>               <NA>
# ZDHHC5                   <NA>              <NA>               <NA>
#
#          orphanet_ComplexPortal mondo_ComplexPortal mim_ComplexPortal  \
# genes
# A4GALT                     <NA>                <NA>              <NA>
# AARS1                      <NA>                <NA>              <NA>
# AASDHPPT                   <NA>                <NA>              <NA>
# ABCA1                      <NA>                <NA>              <NA>
# ABCA7                      <NA>                <NA>              <NA>
# ...                         ...                 ...               ...
# YES1                       <NA>                <NA>              <NA>
# ZDHHC2                     <NA>                <NA>              <NA>
# ZDHHC20                    <NA>                <NA>              <NA>
# ZDHHC3                     <NA>                <NA>              <NA>
# ZDHHC5                     <NA>                <NA>              <NA>
#
#                                     references_References
# genes
# A4GALT    pubmed:12888565;pubmed:29662110;pubmed:34360826
# AARS1                     pubmed:19421340;pubmed:35976696
# AASDHPPT                                             <NA>
# ABCA1                     pubmed:27239515;pubmed:32907987
# ABCA7                     pubmed:12917409;pubmed:15520449
# ...                                                   ...
# YES1                                                 <NA>
# ZDHHC2                                               <NA>
# ZDHHC20                                              <NA>
# ZDHHC3                                               <NA>
# ZDHHC5                                               <NA>
#
# [820 rows x 180 columns]

# %% [markdown]
# #### Reconcile cross-referenced from multiple sources
# These columns had multiple mappings and need to be reconciled.
#
# Currently, overwrites with one database and will preserve previous model annotations if nothing exists for a field.

# %%
reconcilliation = {
    # Overwrite with UniProt
    "uniprot": UNIPROT_DB_TAG,
    "uniprot.isoform": UNIPROT_DB_TAG,
    "uniprot.chain": UNIPROT_DB_TAG,
    "refseq": UNIPROT_DB_TAG,
    "ncbigene": UNIPROT_DB_TAG,
    "hgnc.symbol": UNIPROT_DB_TAG,
    "ccds": UNIPROT_DB_TAG,
    "dbsnp": UNIPROT_DB_TAG,
    "ec-code": UNIPROT_DB_TAG,
    "pdb": UNIPROT_DB_TAG,
    "pfam": UNIPROT_DB_TAG,
    "go": UNIPROT_DB_TAG,
    "pharmgkb.gene": UNIPROT_DB_TAG,
    "taxonomy": UNIPROT_DB_TAG,
    "smr": UNIPROT_DB_TAG,
    "iuphar.receptor": UNIPROT_DB_TAG,
    "hgnc": UNIPROT_DB_TAG,
    "intact": UNIPROT_DB_TAG,  # COMPLEXPORTAL_DB_TAG
    "tcdb": UNIPROT_DB_TAG,  # TCDB_DB_TAG,
    # Overwrite with DrugCentral
    "drugcentral": DRUGCENTRAL_DB_TAG,
    # Overwrite with DrugBank
    "drugbank": DRUGBANK_DB_TAG,
    "smpdb": DRUGBANK_DB_TAG,
    # Overwrite with MetAtlas
    "ensembl": HUMANGEM_DB_TAG,
    # Overwrite with MIM
    "mgi": MIM_DB_TAG,
    "mim": MIM_DB_TAG,  # "UniProt",
    # Overwrite with Complex Portal
    "complexportal": COMPLEXPORTAL_DB_TAG,
    # Keep model
    "pubchem.compound": "MODEL",
    "pubmed": "MODEL",
    "efo": "MODEL",
    "eco": "MODEL",
    "chebi": "MODEL",
    "rnacentral": "MODEL",
    "mondo": "MODEL",
    # Non-miriam fields
    "chromosome": UNIPROT_DB_TAG,
    "references": "References",
    # To double check eventually for formatting within model
    "string": "UniProt",
    "hogenom": "UniProt",
    "genewiki": "UniProt",
    "prints": "UniProt",
    "supfam": "UniProt",
    "bindingdb": "UniProt",
    "gxa": "UniProt",
    "sasbdb": "UniProt",
    "merops": "UniProt",
    "allergome": "UniProt",
    "ideal": "UniProt",
    "cazy": "UniProt",
    "bgee.gene": "UniProt",
    "panther.family": "UniProt",
    "ena.embl": "UniProt",
    "nextprot": "UniProt",
    "reactome": "UniProt",
    "pirsf": "UniProt",
    "smart": "UniProt",
    "dip": "UniProt",
    "genetree": "UniProt",
    "rhea": "UniProt",
    "pathwaycommons": "UniProt",
    "depod": "UniProt",
    "kegg.genes": "UniProt",
    "disprot": "UniProt",
    "massive": "UniProt",
    "peptideatlas": "UniProt",
    "elm": "UniProt",
    "maxqb": "UniProt",
    "brenda": "UniProt",
    "hamap": "UniProt",
    "slm": "UniProt",
    "phosphosite.protein": "UniProt",
    "cdd": "UniProt",
    "pride": "UniProt",
    "ctd": "UniProt",
    "phylomedb": "UniProt",
    "paxdb.protein": "UniProt",
    "proteomicsdb.protein": "UniProt",
    "epd": "UniProt",
    "hpa": "UniProt",
    "interpro": "UniProt",
    "mint": "UniProt",
    "signor": "UniProt",
    "orthodb": "UniProt",
    "biocyc": "UniProt",
    "chembl.target": "UniProt",
    "orphanet": "UniProt",
    "genecards": "UniProt",
    "biogrid": "UniProt",
    "uniparc": "UniProt",
    "prosite": "UniProt",
    "corum": "UniProt",
    "bmrb": "UniProt",
    "peroxibase": "UniProt",
    "treefam": "UniProt",
    "oma.grp": "UniProt",
    "eggnog": "UniProt",
}

df_annotations = df_annotations_all.copy()
for key, chosen_col in reconcilliation.items():
    if key not in to_double_check[annotation_type]:
        continue
    df_base_column = df_annotations_all.loc[:, f"{key}_{chosen_col}"].copy()
    df_base_column.name = key
    df_columns = df_annotations_all.loc[:, to_double_check[annotation_type][key]]
    for idx, row in df_columns.iterrows():
        if preserve_model_previous:
            # Preserve old ID to prevent loss of ID
            try:
                if not row.isna()[f"{key}_MODEL"] and row.isna()[f"{key}_{chosen_col}"]:
                    df_base_column[idx] = row[f"{key}_MODEL"]
            except KeyError as e:
                pass

    df_annotations = df_annotations.drop(to_double_check[annotation_type][key], axis=1)
    to_double_check[annotation_type].pop(key)
    df_annotations[key] = df_base_column


# Overwrite
df_annotations = df_annotations.rename(unique_mapping, axis=1)
df_annotations = df_annotations.reset_index(drop=False).fillna("")
model_annotation_dfs[annotation_type] = df_annotations
df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
df_annotations
# Out:
#         genes  hprd ncbigi notes                      pubchem.compound  \
# 0      A4GALT  <NA>   <NA>  <NA>                                  <NA>
# 1       AARS1  <NA>   <NA>  <NA>                                  <NA>
# 2    AASDHPPT  <NA>   <NA>  <NA>                                  <NA>
# 3       ABCA1  <NA>   <NA>  <NA>  14985;2733525;2733526;3488;4912;5957
# 4       ABCA7  <NA>   <NA>  <NA>                                  <NA>
# ..        ...   ...    ...   ...                                   ...
# 815      YES1  <NA>   <NA>  <NA>                                  <NA>
# 816    ZDHHC2  <NA>   <NA>  <NA>                                  <NA>
# 817   ZDHHC20  <NA>   <NA>  <NA>                                  <NA>
# 818    ZDHHC3  <NA>   <NA>  <NA>                                  <NA>
# 819    ZDHHC5  <NA>   <NA>  <NA>                                  <NA>
#
#              sbo rnacentral uniprot                      uniprot.isoform  \
# 0    SBO:0000243       <NA>  Q9NPC4                                 <NA>
# 1    SBO:0000243       <NA>  P49588                    P49588-1;P49588-2
# 2    SBO:0000243       <NA>  Q9NRN7                    Q9NRN7-1;Q9NRN7-2
# 3    SBO:0000243       <NA>  O95477                                 <NA>
# 4    SBO:0000243       <NA>  Q8IZY2                    Q8IZY2-1;Q8IZY2-2
# ..           ...        ...     ...                                  ...
# 815  SBO:0000243       <NA>  P07947                                 <NA>
# 816  SBO:0000243       <NA>  Q9UIJ5                                 <NA>
# 817  SBO:0000243       <NA>  Q5W0Z9  Q5W0Z9-1;Q5W0Z9-2;Q5W0Z9-3;Q5W0Z9-4
# 818  SBO:0000243       <NA>  Q9NYG2                    Q9NYG2-1;Q9NYG2-2
# 819  SBO:0000243       <NA>  Q9C0B5                    Q9C0B5-1;Q9C0B5-2
#
#       uniprot.chain  ...             orphanet genecards biogrid  \
# 0    PRO_0000080578  ...                 <NA>    A4GALT  119825
# 1    PRO_0000075281  ...  228174;442835;33364     AARS1  106534
# 2    PRO_0000175736  ...                 <NA>  AASDHPPT  121927
# 3    PRO_0000093288  ...            425;31150     ABCA1  106537
# 4    PRO_0000250674  ...                 1020     ABCA7  115629
# ..              ...  ...                  ...       ...     ...
# 815  PRO_0000088181  ...                 <NA>      YES1  113357
# 816  PRO_0000212859  ...                 <NA>    ZDHHC2  119374
# 817  PRO_0000212906  ...                 <NA>   ZDHHC20  128991
# 818  PRO_0000422064  ...                 <NA>    ZDHHC3  119455
# 819  PRO_0000212868  ...                 <NA>    ZDHHC5  117422
#
#            uniparc                                  prosite  bmrb peroxibase  \
# 0    UPI000003FF92                                     <NA>  <NA>       <NA>
# 1    UPI0000169F0B                                  PS50860  <NA>       <NA>
# 2    UPI0000034CAD                                     <NA>  <NA>       <NA>
# 3    UPI000013E441                          PS00211;PS50893  <NA>       <NA>
# 4    UPI000013D3A4                          PS00211;PS50893  <NA>       <NA>
# ..             ...                                      ...   ...        ...
# 815  UPI0000062316  PS00107;PS50011;PS00109;PS50001;PS50002  <NA>       <NA>
# 816  UPI000004A02F                                  PS50216  <NA>       <NA>
# 817  UPI000045881B                                  PS50216  <NA>       <NA>
# 818  UPI000002B749                                  PS50216  <NA>       <NA>
# 819  UPI0000049DA3                                  PS50216  <NA>       <NA>
#
#       treefam  oma.grp   eggnog
# 0    TF324053  CKDSYVV  KOG1928
# 1    TF300737  DTYHHTM  KOG0188
# 2    TF313753  WVFEESL  KOG0945
# 3    TF105191  FMWNVIA  KOG0059
# 4    TF105191  AQEPLHS  KOG0059
# ..        ...      ...      ...
# 815  TF351634     <NA>  KOG0197
# 816  TF316044  CFVVMHI  KOG1315
# 817  TF316044  AFHNYKF  KOG1315
# 818  TF319798     <NA>  KOG1311
# 819  TF354263  LAPRYMG  KOG1311
#
# [820 rows x 79 columns]

# %% [markdown]
# #### Save annotations

# %%
assert (
    len(to_double_check[annotation_type]) == 0
), f"There are still columns with data that need reconcilliation: {to_double_check[annotation_type]}"
df_annotations = model_annotation_dfs[annotation_type]

df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
if compare:
    compare_on_index = [annotation_type]
    try:
        df_previous = pd.read_csv(
            ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv",
            sep="\t",
            index_col=None,
            dtype=str,
        )
        df_previous = df_previous.replace(float("nan"), pd.NA).replace("", pd.NA)
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=compare_on_index)
    df_comparision = compare_tables(
        df_previous.set_index(compare_on_index),
        df_annotations.set_index(compare_on_index),
    )

    fig, ax = plt.subplots(1, 1, figsize=(5, 20))
    ax.yaxis.set_tick_params(labelsize=8)
    ax = visualize_comparison(df_comparision)

if display_nunique:
    for col in df_annotations.columns:
        df = explode_column(df_annotations, name=col, sep=";")
        df = df[col].drop_duplicates()
        print(f"{df.name}: {df.nunique()}")

if overwrite:
    df_annotations.to_csv(
        ROOT_PATH / MODEL_PATH / f"{annotation_type}.tsv", sep="\t", index=False
    )
else:
    df_annotations.to_csv(
        ROOT_PATH / INTERIM_PATH / f"{annotation_type}.tsv", sep="\t", index=False
    )
df_annotations
# Out:
# genes: 820
# hprd: 90
# ncbigi: 108
# notes: 4
# pubchem.compound: 1166
# sbo: 1
# rnacentral: 0
# uniprot: 820
# uniprot.isoform: 1610
# uniprot.chain: 871
# refseq: 2471
# ncbigene: 825
# hgnc.symbol: 821
# ccds: 1421
# dbsnp: 5058
# ec-code: 537
# pdb: 12484
# pfam: 761
# go: 5843
# pharmgkb.gene: 814
# taxonomy: 1
# smr: 807
# iuphar.receptor: 186
# hgnc: 821
# intact: 813
# tcdb: 150
# drugcentral: 687
# drugbank: 2712
# smpdb: 648
# ensembl: 557
# mgi: 746
# mim: 1242
# complexportal: 360
# pubmed: 368
# efo: 1
# eco: 5
# chebi: 9
# mondo: 32
# chromosome: 25
# references: 666
# hogenom: 591
# genewiki: 621
# prints: 198
# supfam: 322
# sasbdb: 43
# merops: 41
# ideal: 43
# cazy: 21
# bgee.gene: 819
# panther.family: 1373
# ena.embl: 8405
# nextprot: 820
# reactome: 1073
# pirsf: 152
# smart: 184
# dip: 248
# genetree: 744
# rhea: 1506
# kegg.genes: 824
# disprot: 47
# brenda: 413
# hamap: 92
# cdd: 639
# proteomicsdb.protein: 1752
# hpa: 819
# interpro: 2116
# orthodb: 576
# biocyc: 298
# chembl.target: 526
# orphanet: 541
# genecards: 821
# biogrid: 821
# uniparc: 820
# prosite: 412
# bmrb: 88
# peroxibase: 13
# treefam: 616
# oma.grp: 785
# eggnog: 614
#         genes  hprd ncbigi notes                      pubchem.compound  \
# 0      A4GALT  <NA>   <NA>  <NA>                                  <NA>
# 1       AARS1  <NA>   <NA>  <NA>                                  <NA>
# 2    AASDHPPT  <NA>   <NA>  <NA>                                  <NA>
# 3       ABCA1  <NA>   <NA>  <NA>  14985;2733525;2733526;3488;4912;5957
# 4       ABCA7  <NA>   <NA>  <NA>                                  <NA>
# ..        ...   ...    ...   ...                                   ...
# 815      YES1  <NA>   <NA>  <NA>                                  <NA>
# 816    ZDHHC2  <NA>   <NA>  <NA>                                  <NA>
# 817   ZDHHC20  <NA>   <NA>  <NA>                                  <NA>
# 818    ZDHHC3  <NA>   <NA>  <NA>                                  <NA>
# 819    ZDHHC5  <NA>   <NA>  <NA>                                  <NA>
#
#              sbo rnacentral uniprot                      uniprot.isoform  \
# 0    SBO:0000243       <NA>  Q9NPC4                                 <NA>
# 1    SBO:0000243       <NA>  P49588                    P49588-1;P49588-2
# 2    SBO:0000243       <NA>  Q9NRN7                    Q9NRN7-1;Q9NRN7-2
# 3    SBO:0000243       <NA>  O95477                                 <NA>
# 4    SBO:0000243       <NA>  Q8IZY2                    Q8IZY2-1;Q8IZY2-2
# ..           ...        ...     ...                                  ...
# 815  SBO:0000243       <NA>  P07947                                 <NA>
# 816  SBO:0000243       <NA>  Q9UIJ5                                 <NA>
# 817  SBO:0000243       <NA>  Q5W0Z9  Q5W0Z9-1;Q5W0Z9-2;Q5W0Z9-3;Q5W0Z9-4
# 818  SBO:0000243       <NA>  Q9NYG2                    Q9NYG2-1;Q9NYG2-2
# 819  SBO:0000243       <NA>  Q9C0B5                    Q9C0B5-1;Q9C0B5-2
#
#       uniprot.chain  ...             orphanet genecards biogrid  \
# 0    PRO_0000080578  ...                 <NA>    A4GALT  119825
# 1    PRO_0000075281  ...  228174;442835;33364     AARS1  106534
# 2    PRO_0000175736  ...                 <NA>  AASDHPPT  121927
# 3    PRO_0000093288  ...            425;31150     ABCA1  106537
# 4    PRO_0000250674  ...                 1020     ABCA7  115629
# ..              ...  ...                  ...       ...     ...
# 815  PRO_0000088181  ...                 <NA>      YES1  113357
# 816  PRO_0000212859  ...                 <NA>    ZDHHC2  119374
# 817  PRO_0000212906  ...                 <NA>   ZDHHC20  128991
# 818  PRO_0000422064  ...                 <NA>    ZDHHC3  119455
# 819  PRO_0000212868  ...                 <NA>    ZDHHC5  117422
#
#            uniparc                                  prosite  bmrb peroxibase  \
# 0    UPI000003FF92                                     <NA>  <NA>       <NA>
# 1    UPI0000169F0B                                  PS50860  <NA>       <NA>
# 2    UPI0000034CAD                                     <NA>  <NA>       <NA>
# 3    UPI000013E441                          PS00211;PS50893  <NA>       <NA>
# 4    UPI000013D3A4                          PS00211;PS50893  <NA>       <NA>
# ..             ...                                      ...   ...        ...
# 815  UPI0000062316  PS00107;PS50011;PS00109;PS50001;PS50002  <NA>       <NA>
# 816  UPI000004A02F                                  PS50216  <NA>       <NA>
# 817  UPI000045881B                                  PS50216  <NA>       <NA>
# 818  UPI000002B749                                  PS50216  <NA>       <NA>
# 819  UPI0000049DA3                                  PS50216  <NA>       <NA>
#
#       treefam  oma.grp   eggnog
# 0    TF324053  CKDSYVV  KOG1928
# 1    TF300737  DTYHHTM  KOG0188
# 2    TF313753  WVFEESL  KOG0945
# 3    TF105191  FMWNVIA  KOG0059
# 4    TF105191  AQEPLHS  KOG0059
# ..        ...      ...      ...
# 815  TF351634     <NA>  KOG0197
# 816  TF316044  CFVVMHI  KOG1315
# 817  TF316044  AFHNYKF  KOG1315
# 818  TF319798     <NA>  KOG1311
# 819  TF354263  LAPRYMG  KOG1311
#
# [820 rows x 79 columns]
