# %% [markdown]
# # Extract information from RBC-GEM
#
# Purpose of this notebook is to extract RBC-GEM annotation data and format as a tab-delimited (TSV) file.
#
# ## Setup
# ### Import packages

# %%
import matplotlib.pyplot as plt
import pandas as pd
from rbc_gem_utils import (COBRA_CONFIGURATION, INTERIM_PATH, MODEL_PATH,
                           ROOT_PATH, compare_tables, explode_column,
                           get_annotation_df, read_rbc_model, show_versions,
                           visualize_comparison)
from rbc_gem_utils.annotation import set_sbo_default_annotations

# Display versions of last time notebook ran and worked
show_versions()
# Out:
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.12.3
# bio                                   1.6.2
# cobra                                0.29.0
# depinfo                               2.2.0
# kaleido                               0.2.1
# matplotlib                            3.8.2
# memote                               0.17.0
# networkx                              3.2.1
# notebook                              7.0.7
# openpyxl                              3.1.2
# pandas                                2.2.0
# pre-commit                            3.6.0
# pyvis                                 0.3.2
# rbc-gem-utils[database,network,vis] missing
# requests                             2.31.0
# scipy                                1.12.0
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip        23.3.1
# setuptools 68.2.2
# wheel      0.41.2
#
# Platform Information
# --------------------
# Darwin  23.6.0-x86_64
# CPython        3.11.7

# %% [markdown]
# ### Define configuration
# #### COBRA Configuration

# %%
COBRA_CONFIGURATION
# Out:
# solver: gurobi
# tolerance: 1e-07
# lower_bound: -1000.0
# upper_bound: 1000.0
# processes: 15
# cache_directory: /Users/zhaiman/Library/Caches/cobrapy
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## Load RBC-GEM model

# %%
model = read_rbc_model(filetype="xml")
model.reactions.sort()
model.genes.sort()
model.metabolites.sort()
model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# <Model RBC_GEM at 0x14ec8be50>

# %% [markdown]
# ## Extract annotations from model

# %%
compare_figsize = (10, 5)
compare = True
display_nunique = True
overwrite = True
reset_sbo = False  # Using this option resets the model SBO terms to default values before exporting the sheet.

# %%
if reset_sbo:
    # Reset SBO annotations
    set_sbo_default_annotations(
        model, ["reactions", "metabolites", "genes"], verbose=False
    )

# %% [markdown]
# ### Reactions

# %%
annotation_type = "reactions"
all_annotation_keys = set()
for annotation in getattr(model, annotation_type).list_attr("annotation"):
    all_annotation_keys.update(list(annotation.keys()))
# Get annotation df is agnostic to object type, swap ID column with the `annotation_type`
df_annotations = get_annotation_df(
    getattr(model, annotation_type), sorted(list(all_annotation_keys))
).rename({"id": annotation_type}, axis=1)


df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
if compare:
    compare_on_index = [annotation_type]
    try:
        df_previous = pd.read_csv(
            f"{ROOT_PATH}{MODEL_PATH}/{annotation_type}.tsv", sep="\t", index_col=None
        )
        df_previous = df_previous.replace(float("nan"), pd.NA).replace("", pd.NA)
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=compare_on_index)
    df_comparision = compare_tables(
        df_previous.set_index(compare_on_index),
        df_annotations.set_index(compare_on_index),
    )

    fig, ax = plt.subplots(1, 1, figsize=compare_figsize)
    ax.yaxis.set_tick_params(labelsize=8)
    ax = visualize_comparison(df_comparision)

if display_nunique:
    for col in df_annotations.columns:
        df = explode_column(df_annotations, name=col, sep=";")
        df = df[col].drop_duplicates()
        print(f"{df.name}: {df.nunique()}")

if overwrite:
    df_annotations.to_csv(
        f"{ROOT_PATH}{MODEL_PATH}/{annotation_type}.tsv", sep="\t", index=False
    )
else:
    df_annotations.to_csv(
        f"{ROOT_PATH}{INTERIM_PATH}/{annotation_type}.tsv", sep="\t", index=False
    )
df_annotations
# Out:
# reactions: 3275
# bigg.reaction: 3491
# biocyc: 188
# ec-code: 395
# kegg.reaction: 535
# metanetx.reaction: 1182
# metatlas: 1602
# reactome: 243
# references: 977
# rhea: 508
# sabiork.reaction: 149
# sbo: 4
# seed.reaction: 288
# spontaneous: 2
# tcdb: 31
# vmhreaction: 1630
#             reactions bigg.reaction biocyc                    ec-code  \
# 0           13DAMPPOX     13DAMPPOX   <NA>  1.4.3.6;1.4.3.21;1.4.3.22
# 1           15KPGE1Ry     15KPGE1Ry   <NA>                       <NA>
# 2           15KPGE2Ry     15KPGE2Ry   <NA>                       <NA>
# 3           15KPGE3Ry     15KPGE3Ry   <NA>                       <NA>
# 4           15KPGF1Ry     15KPGF1Ry   <NA>                       <NA>
# ...               ...           ...    ...                        ...
# 3270          YYYTPAP       YYYTPAP   <NA>                       <NA>
# 3271         ZN2Htex2      ZN2Htex2   <NA>                       <NA>
# 3272       ZN2_2HCO3t          <NA>   <NA>                       <NA>
# 3273  ZN2_HCO3_SELNIt          <NA>   <NA>                       <NA>
# 3274             ZN2t          ZN2t   <NA>                       <NA>
#
#      kegg.reaction metanetx.reaction  metatlas reactome  \
# 0             <NA>         MNXR94687  MAR07992     <NA>
# 1             <NA>              <NA>      <NA>     <NA>
# 2             <NA>              <NA>      <NA>     <NA>
# 3             <NA>              <NA>      <NA>     <NA>
# 4             <NA>              <NA>      <NA>     <NA>
# ...            ...               ...       ...      ...
# 3270          <NA>              <NA>      <NA>     <NA>
# 3271          <NA>              <NA>      <NA>     <NA>
# 3272          <NA>              <NA>      <NA>     <NA>
# 3273          <NA>              <NA>      <NA>     <NA>
# 3274          <NA>        MNXR105280  MAR06370     <NA>
#
#                                              references  rhea  \
# 0                                       pubmed:23330127  <NA>
# 1     pubmed:236730;pubmed:24657656;pubmed:6597453;p...  <NA>
# 2     pubmed:236730;pubmed:24657656;pubmed:6597453;p...  <NA>
# 3     pubmed:236730;pubmed:24657656;pubmed:6597453;p...  <NA>
# 4     pubmed:236730;pubmed:24657656;pubmed:6597453;p...  <NA>
# ...                                                 ...   ...
# 3270                      pubmed:6058286;pubmed:7002549  <NA>
# 3271  pubmed:11817695;pubmed:18936201;pubmed:2245666...  <NA>
# 3272  pubmed:22456662;pubmed:22898811;pubmed:2484233...  <NA>
# 3273  pubmed:22456662;pubmed:22898811;pubmed:2716625...  <NA>
# 3274  pubmed:11817695;pubmed:18936201;pubmed:2161459...  <NA>
#
#      sabiork.reaction          sbo seed.reaction spontaneous       tcdb  \
# 0                <NA>  SBO:0000176          <NA>         0.0       <NA>
# 1                <NA>  SBO:0000176          <NA>         0.0       <NA>
# 2                <NA>  SBO:0000176          <NA>         0.0       <NA>
# 3                <NA>  SBO:0000176          <NA>         0.0       <NA>
# 4                <NA>  SBO:0000176          <NA>         0.0       <NA>
# ...               ...          ...           ...         ...        ...
# 3270             <NA>  SBO:0000176          <NA>         0.0       <NA>
# 3271             <NA>  SBO:0000185          <NA>         0.0       <NA>
# 3272             <NA>  SBO:0000185          <NA>         0.0       <NA>
# 3273             <NA>  SBO:0000185          <NA>         0.0       <NA>
# 3274             <NA>  SBO:0000185          <NA>         0.0  2.A.4.2.3
#
#      vmhreaction
# 0      13DAMPPOX
# 1           <NA>
# 2           <NA>
# 3           <NA>
# 4           <NA>
# ...          ...
# 3270        <NA>
# 3271        <NA>
# 3272        <NA>
# 3273        <NA>
# 3274       r2465
#
# [3275 rows x 16 columns]

# %% [markdown]
# ### Metabolites

# %%
annotation_type = "metabolites"
all_annotation_keys = set()
for annotation in getattr(model, annotation_type).list_attr("annotation"):
    all_annotation_keys.update(list(annotation.keys()))
# Get annotation df is agnostic to object type, swap ID column with the `annotation_type`
df_annotations = get_annotation_df(
    getattr(model, annotation_type), sorted(list(all_annotation_keys))
).rename({"id": annotation_type}, axis=1)

df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
if compare:
    compare_on_index = [annotation_type]
    try:
        df_previous = pd.read_csv(
            f"{ROOT_PATH}{MODEL_PATH}/{annotation_type}.tsv", sep="\t", index_col=None
        )
        df_previous = df_previous.replace(float("nan"), pd.NA).replace("", pd.NA)
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=compare_on_index)
    df_comparision = compare_tables(
        df_previous.set_index(compare_on_index),
        df_annotations.set_index(compare_on_index),
    )

    fig, ax = plt.subplots(1, 1, figsize=compare_figsize)
    ax.yaxis.set_tick_params(labelsize=8)
    ax = visualize_comparison(df_comparision)

if display_nunique:
    for col in df_annotations.columns:
        df = explode_column(df_annotations, name=col, sep=";")
        df = df[col].drop_duplicates()
        print(f"{df.name}: {df.nunique()}")

if overwrite:
    df_annotations.to_csv(
        f"{ROOT_PATH}{MODEL_PATH}/{annotation_type}.tsv", sep="\t", index=False
    )
else:
    df_annotations.to_csv(
        f"{ROOT_PATH}{INTERIM_PATH}/{annotation_type}.tsv", sep="\t", index=False
    )
df_annotations
# Out:
# metabolites: 2157
# bigg.metabolite: 1571
# biocyc: 212
# chebi: 710
# envipath: 72
# hmdb: 501
# inchi: 129
# inchikey: 184
# kegg.compound: 767
# kegg.drug: 64
# kegg.glycan: 6
# lipidmaps: 227
# metabolite: 1685
# metanetx.chemical: 1173
# metatlas: 1450
# pubchem.compound: 676
# reactome: 455
# sabiork.compound: 218
# sbo: 1
# seed.compound: 224
# slm: 7
# vmhmetabolite: 1144
#      metabolites bigg.metabolite    biocyc        chebi envipath         hmdb  \
# 0       10fthf_c          10fthf      <NA>  CHEBI:15637     <NA>         <NA>
# 1     12ppd__R_c        12ppd__R      <NA>  CHEBI:16997     <NA>  HMDB0001881
# 2     12ppd__S_c        12ppd__S      <NA>         <NA>     <NA>         <NA>
# 3      13dampp_c         13dampp      <NA>  CHEBI:15725     <NA>  HMDB0000002
# 4        13dpg_c           13dpg  META:DPG  CHEBI:16001     <NA>    HMDB62758
# ...          ...             ...       ...          ...      ...          ...
# 2152       zn2_c             zn2      <NA>  CHEBI:29105     <NA>  HMDB0015532
# 2153       zn2_e             zn2      <NA>  CHEBI:29105     <NA>  HMDB0015532
# 2154       ztp_c             ztp      <NA>         <NA>     <NA>         <NA>
# 2155     zymst_c           zymst      <NA>  CHEBI:18252     <NA>         <NA>
# 2156   zymstnl_c         zymstnl      <NA>  CHEBI:16608     <NA>  HMDB0006841
#
#                                                   inchi  \
# 0                                                  <NA>
# 1              InChI=1S/C3H8O2/c1-3(5)2-4/h3-5H,2H2,1H3
# 2                                                  <NA>
# 3                                                  <NA>
# 4                                                  <NA>
# ...                                                 ...
# 2152                                               <NA>
# 2153                                               <NA>
# 2154                                               <NA>
# 2155  InChI=1S/C27H44O/c1-18(2)7-6-8-19(3)23-11-12-2...
# 2156  InChI=1S/C27H46O/c1-18(2)7-6-8-19(3)23-11-12-2...
#
#                          inchikey kegg.compound kegg.drug  ... metabolite  \
# 0                            <NA>        C00234      <NA>  ...     10fthf
# 1                            <NA>        C00583      <NA>  ...   12ppd__R
# 2                            <NA>          <NA>      <NA>  ...   12ppd__S
# 3                            <NA>        C00986      <NA>  ...    13dampp
# 4     LJQLQCAXBUHEAZ-UWTATZPHSA-J        C00236      <NA>  ...      13dpg
# ...                           ...           ...       ...  ...        ...
# 2152                         <NA>        C00038      <NA>  ...        zn2
# 2153                         <NA>        C00038      <NA>  ...        zn2
# 2154                         <NA>          <NA>      <NA>  ...        ztp
# 2155                         <NA>        C05437      <NA>  ...      zymst
# 2156                         <NA>        C03845      <NA>  ...    zymstnl
#
#                 metanetx.chemical   metatlas pubchem.compound reactome  \
# 0                         MNXM237  MAM00266c         122347.0     <NA>
# 1     MNXM1118;MNXM1255;MNXM90191  MAM02771c           1030.0     <NA>
# 2                            <NA>       <NA>             <NA>     <NA>
# 3              MNXM146468;MNXM350  MAM00248c            428.0     <NA>
# 4                         MNXM261  MAM00247c         439191.0    29800
# ...                           ...        ...              ...      ...
# 2152                      MNXM149  MAM03157c          32051.0     <NA>
# 2153                      MNXM149  MAM03157e          32051.0     <NA>
# 2154                         <NA>       <NA>             <NA>     <NA>
# 2155                      MNXM574  MAM03158c          92746.0     <NA>
# 2156                     MNXM2494  MAM01449c         101770.0     <NA>
#
#      sabiork.compound          sbo seed.compound   slm vmhmetabolite
# 0                <NA>  SBO:0000247          <NA>  <NA>        10fthf
# 1                <NA>  SBO:0000247          <NA>  <NA>       12ppd_R
# 2                <NA>  SBO:0000247          <NA>  <NA>          <NA>
# 3                <NA>  SBO:0000247          <NA>  <NA>       13dampp
# 4               21215  SBO:0000247      cpd00203  <NA>         13dpg
# ...               ...          ...           ...   ...           ...
# 2152             <NA>  SBO:0000247          <NA>  <NA>           zn2
# 2153             <NA>  SBO:0000247          <NA>  <NA>           zn2
# 2154             <NA>  SBO:0000247          <NA>  <NA>          <NA>
# 2155             <NA>  SBO:0000247          <NA>  <NA>         zymst
# 2156             <NA>  SBO:0000247          <NA>  <NA>       zymstnl
#
# [2157 rows x 22 columns]

# %% [markdown]
# ### Genes

# %%
annotation_type = "genes"
all_annotation_keys = set()
for annotation in getattr(model, annotation_type).list_attr("annotation"):
    all_annotation_keys.update(list(annotation.keys()))
# Get annotation df is agnostic to object type, swap ID column with the `annotation_type`
df_annotations = get_annotation_df(
    getattr(model, annotation_type), sorted(list(all_annotation_keys))
).rename({"id": annotation_type}, axis=1)

df_annotations = df_annotations.replace(float("nan"), pd.NA).replace("", pd.NA)
if compare:
    compare_on_index = [annotation_type]
    try:
        df_previous = pd.read_csv(
            f"{ROOT_PATH}{MODEL_PATH}/{annotation_type}.tsv", sep="\t", index_col=None
        )
        df_previous = df_previous.replace(float("nan"), pd.NA).replace("", pd.NA)
    except FileNotFoundError:
        df_previous = pd.DataFrame([], columns=compare_on_index)
    df_comparision = compare_tables(
        df_previous.set_index(compare_on_index),
        df_annotations.set_index(compare_on_index),
    )

    fig, ax = plt.subplots(1, 1, figsize=(10, 20))
    ax.yaxis.set_tick_params(labelsize=8)
    ax = visualize_comparison(df_comparision)

if display_nunique:
    for col in df_annotations.columns:
        df = explode_column(df_annotations, name=col, sep=";")
        df = df[col].drop_duplicates()
        print(f"{df.name}: {df.nunique()}")

if overwrite:
    df_annotations.to_csv(
        f"{ROOT_PATH}{MODEL_PATH}/{annotation_type}.tsv", sep="\t", index=False
    )
else:
    df_annotations.to_csv(
        f"{ROOT_PATH}{INTERIM_PATH}/{annotation_type}.tsv", sep="\t", index=False
    )
df_annotations
# Out:
# genes: 820
# bgee.gene: 819
# biocyc: 298
# biogrid: 821
# bmrb: 88
# brenda: 413
# cazy: 21
# ccds: 1421
# cdd: 639
# chebi: 9
# chembl.target: 526
# chromosome: 25
# complexportal: 360
# dbsnp: 5058
# dip: 248
# disprot: 47
# drugbank: 2712
# drugcentral: 687
# ec-code: 537
# eco: 5
# efo: 1
# eggnog: 614
# ena.embl: 8405
# ensembl: 557
# genecards: 821
# genetree: 744
# genewiki: 621
# go: 5843
# hamap: 92
# hgnc: 821
# hgnc.symbol: 821
# hogenom: 591
# hpa: 819
# hprd: 90
# ideal: 43
# intact: 813
# interpro: 2116
# iuphar.receptor: 186
# kegg.genes: 824
# merops: 41
# mgi: 746
# mim: 1242
# mondo: 32
# ncbigene: 825
# ncbigi: 108
# nextprot: 820
# notes: 4
# oma.grp: 785
# orphanet: 541
# orthodb: 576
# panther.family: 1373
# pdb: 12484
# peroxibase: 13
# pfam: 761
# pharmgkb.gene: 814
# pirsf: 152
# prints: 198
# prosite: 412
# proteomicsdb.protein: 1752
# pubchem.compound: 1166
# pubmed: 368
# reactome: 1073
# references: 666
# refseq: 2471
# rhea: 1506
# sasbdb: 43
# sbo: 1
# smart: 184
# smpdb: 648
# smr: 807
# supfam: 322
# taxonomy: 1
# tcdb: 150
# treefam: 616
# uniparc: 820
# uniprot: 820
# uniprot.chain: 871
# uniprot.isoform: 1610
#         genes        bgee.gene                   biocyc biogrid  bmrb  \
# 0      A4GALT  ENSG00000128274  MetaCyc:HS05171-MONOMER  119825  <NA>
# 1       AARS1  ENSG00000090861                     <NA>  106534  <NA>
# 2    AASDHPPT  ENSG00000149313  MetaCyc:HS14278-MONOMER  121927  <NA>
# 3       ABCA1  ENSG00000165029                     <NA>  106537  <NA>
# 4       ABCA7  ENSG00000064687                     <NA>  115629  <NA>
# ..        ...              ...                      ...     ...   ...
# 815      YES1  ENSG00000176105                     <NA>  113357  <NA>
# 816    ZDHHC2  ENSG00000104219                     <NA>  119374  <NA>
# 817   ZDHHC20  ENSG00000180776                     <NA>  128991  <NA>
# 818    ZDHHC3  ENSG00000163812                     <NA>  119455  <NA>
# 819    ZDHHC5  ENSG00000156599                     <NA>  117422  <NA>
#
#         brenda  cazy                     ccds                      cdd chebi  \
# 0    2.4.1.228  GT32              CCDS14041.1                     <NA>  <NA>
# 1         <NA>  <NA>              CCDS32474.1                  cd00673  <NA>
# 2      2.7.8.7  <NA>              CCDS31664.1                     <NA>  <NA>
# 3         <NA>  <NA>               CCDS6762.1                  cd03263  <NA>
# 4         <NA>  <NA>              CCDS12055.1                  cd03263  <NA>
# ..         ...   ...                      ...                      ...   ...
# 815   2.7.10.2  <NA>              CCDS11824.1  cd05069;cd09933;cd12007  <NA>
# 816  2.3.1.225  <NA>              CCDS47810.1                     <NA>  <NA>
# 817       <NA>  <NA>  CCDS45017.1;CCDS81758.1                     <NA>  <NA>
# 818  2.3.1.225  <NA>   CCDS2724.1;CCDS46811.1                     <NA>  <NA>
# 819  2.3.1.225  <NA>               CCDS7965.1                     <NA>  <NA>
#
#      ...                                        smpdb     smr  \
# 0    ...                                         <NA>  Q9NPC4
# 1    ...  SMP0000055;SMP0000313;SMP0000350;SMP0000352  P49588
# 2    ...                                         <NA>  Q9NRN7
# 3    ...                                         <NA>  O95477
# 4    ...                                         <NA>  Q8IZY2
# ..   ...                                          ...     ...
# 815  ...                                         <NA>  P07947
# 816  ...                                         <NA>  Q9UIJ5
# 817  ...                                         <NA>  Q5W0Z9
# 818  ...                                         <NA>  Q9NYG2
# 819  ...                                         <NA>  Q9C0B5
#
#                                    supfam taxonomy          tcdb   treefam  \
# 0                                SSF53448     9606          <NA>  TF324053
# 1    SSF55681;SSF101353;SSF55186;SSF50447     9606          <NA>  TF300737
# 2                                SSF56214     9606          <NA>  TF313753
# 3                                SSF52540     9606  3.A.1.211.14  TF105191
# 4                                SSF52540     9606  3.A.1.211.10  TF105191
# ..                                    ...      ...           ...       ...
# 815            SSF56112;SSF55550;SSF50044     9606          <NA>  TF351634
# 816                                  <NA>     9606          <NA>  TF316044
# 817                                  <NA>     9606   8.A.114.1.6  TF316044
# 818                                  <NA>     9606          <NA>  TF319798
# 819                                  <NA>     9606          <NA>  TF354263
#
#            uniparc uniprot   uniprot.chain  \
# 0    UPI000003FF92  Q9NPC4  PRO_0000080578
# 1    UPI0000169F0B  P49588  PRO_0000075281
# 2    UPI0000034CAD  Q9NRN7  PRO_0000175736
# 3    UPI000013E441  O95477  PRO_0000093288
# 4    UPI000013D3A4  Q8IZY2  PRO_0000250674
# ..             ...     ...             ...
# 815  UPI0000062316  P07947  PRO_0000088181
# 816  UPI000004A02F  Q9UIJ5  PRO_0000212859
# 817  UPI000045881B  Q5W0Z9  PRO_0000212906
# 818  UPI000002B749  Q9NYG2  PRO_0000422064
# 819  UPI0000049DA3  Q9C0B5  PRO_0000212868
#
#                          uniprot.isoform
# 0                                   <NA>
# 1                      P49588-1;P49588-2
# 2                      Q9NRN7-1;Q9NRN7-2
# 3                                   <NA>
# 4                      Q8IZY2-1;Q8IZY2-2
# ..                                   ...
# 815                                 <NA>
# 816                                 <NA>
# 817  Q5W0Z9-1;Q5W0Z9-2;Q5W0Z9-3;Q5W0Z9-4
# 818                    Q9NYG2-1;Q9NYG2-2
# 819                    Q9C0B5-1;Q9C0B5-2
#
# [820 rows x 78 columns]
