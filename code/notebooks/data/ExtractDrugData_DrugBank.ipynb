# %% [markdown]
# # Extract drug data from DrugBank
#
# Purpose of this notebook is to extract and format Drug Interaction data for subsequent visualization
#
# ## DRUGBANK ONLINE
# To utilize this notebook:
#
# 1. Go to [DrugBank database](https://go.drugbank.com/releases/latest) and create an account.
# 2. Follow the instructions to obtain a free academic license.
# 3. Download and unzip the database file `"drugbank_all_full_database.xml.zip"`.
# 4. Rename the file `"full database.xml"` to `"drugbank_all_full_database.xml"`.
# 5. Remember clear out any personal account information and ensure the downloaded DrugBank file remains local!
#
# The functions `download_database_DrugBank` takes a given username and a password and downloads the data, taking care to change the filename in the process.
#
# Fields for the DrugBank XML schema are found [here](https://docs.drugbank.com/xml/#introduction).
#
# Wishart DS, Feunang YD, Guo AC, Lo EJ, Marcu A, Grant JR, Sajed T, Johnson D, Li C, Sayeeda Z, Assempour N, Iynkkaran I, Liu Y, Maciejewski A, Gale N, Wilson A, Chin L, Cummings R, Le D, Pon A, Knox C, Wilson M. DrugBank 5.0: a major update to the DrugBank database for 2018. Nucleic Acids Res. 2017 Nov 8. doi: 10.1093/nar/gkx1037.
#
# ## Setup
# ### Import packages

# %%
from collections import defaultdict
from xml.etree import ElementTree

import pandas as pd
from rbc_gem_utils import (
    ANNOTATION_PATH,
    DATABASE_PATH,
    INTERIM_PATH,
    ROOT_PATH,
    build_string,
    check_version,
    get_annotation_df,
    read_rbc_model,
    show_versions,
    split_string,
)
from rbc_gem_utils.database.drugbank import (
    DRUGBANK_GENERAL_ELEMENTS,
    DRUGBANK_NS,
    DRUGBANK_PATH,
    DRUGBANK_VERSION_EXPECTED,
    download_database_DrugBank,
    get_version_DrugBank,
    strip_ns_DrugBank,
)
from rbc_gem_utils.util import has_value_type, strip_plural

# Display versions of last time notebook ran and worked
show_versions()
# Out:
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.12.3
# bio                                   1.6.2
# cobra                                0.29.0
# depinfo                               2.2.0
# kaleido                               0.2.1
# matplotlib                            3.8.2
# memote                               0.17.0
# networkx                              3.2.1
# notebook                              7.0.7
# openpyxl                              3.1.2
# pandas                                2.2.0
# pre-commit                            3.6.0
# pyvis                                 0.3.2
# rbc-gem-utils[database,network,vis] missing
# requests                             2.31.0
# scipy                                1.12.0
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip        23.3.1
# setuptools 68.2.2
# wheel      0.41.2
#
# Platform Information
# --------------------
# Darwin  23.6.0-x86_64
# CPython        3.11.7

# %% [markdown]
# ## Check DrugBank version
# If the version does not match the expected version, it is because database has been updated since the last time this code was utilized.
# ### Expected DrugBank version: 5.1.13
# * Last release utilized: [5.1.13](https://go.drugbank.com/releases) published on **2025-01-02**
# * Version in the DrugBank file is formatted as {major}.{minor}

# %%
database_dirpath = ROOT_PATH / DATABASE_PATH / DRUGBANK_PATH
annotation_dirpath = ROOT_PATH / ANNOTATION_PATH
# version = get_version_DrugBank()
# if check_version(version, DRUGBANK_VERSION_EXPECTED, verbose=True):
#     database_dirpath = ROOT_PATH / DATABASE_PATH / DRUGBANK_PATH
#     annotation_dirpath = ROOT_PATH / ANNOTATION_PATH
# else:
#     database_dirpath = ROOT_PATH / INTERIM_PATH / DRUGBANK_PATH
#     annotation_dirpath = ROOT_PATH / INTERIM_PATH
#     version = DRUGBANK_VERSION_EXPECTED

# %% [markdown]
# #### Download new files and update database
# If an argument is not provided (`arg=None`), its default value for the repository used.
# Username and password must be provided for this function, be sure to remove personal information after use!

# %%
download = False
if download:
    # Download data
    download_database_DrugBank(
        username="USERNAME",
        password="PASSWORD",
        database_dirpath=database_dirpath,
        version=version,
    )
filepath = database_dirpath / "drugbank_all_full_database.xml"

# %% [markdown]
# ## Load RBC-GEM model

# %%
model = read_rbc_model(filetype="xml")
model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-21
# <Model RBC_GEM at 0x152b9edd0>

# %%
annotation_type = "genes"
df_model_mappings = get_annotation_df(
    getattr(model, annotation_type), ["uniprot", "drugbank"]
).rename({"id": annotation_type}, axis=1)

df_model_mappings["drugbank"] = df_model_mappings["drugbank"].apply(
    lambda x: split_string(x)
)
df_model_mappings = df_model_mappings.explode("drugbank").drop_duplicates()
print(df_model_mappings.nunique())
drugbank_ids = set(df_model_mappings["drugbank"].dropna().unique())
uniprot_ids = set(df_model_mappings["uniprot"].dropna().unique())
df_model_mappings
# Out:
# genes        820
# uniprot      820
# drugbank    2440
# dtype: int64
#       genes uniprot drugbank
# 0       RPE  Q96AT9  DB00153
# 1      RPIA  P49247  DB01756
# 2      SORD  Q00796  DB00157
# 2      SORD  Q00796  DB04478
# 3    AKR7A2  O43488     <NA>
# ..      ...     ...      ...
# 816  VCPIP1  Q96JH7     <NA>
# 817   VPS4B  O75351     <NA>
# 818   WDR77  Q9BQA1     <NA>
# 819    YES1  P07947  DB01254
# 819    YES1  P07947  DB12010
#
# [4775 rows x 3 columns]

# %% [markdown]
# ## Parse DrugBank information into DataFrame

# %%
all_drug_dfs = {}
root = ElementTree.parse(filepath).getroot()
root
# Out:
# <Element '{http://www.drugbank.ca}drugbank' at 0x110ea76f0>

# %% [markdown]
# #### Extract general information

# %%
idx = 0
data = defaultdict(dict)
for drug in root:
    # General information
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    data[idx].update({"drugbank-id": drugbank_id})
    data[idx].update({attr: drug.get(attr) for attr in ["type", "created", "updated"]})
    for key in DRUGBANK_GENERAL_ELEMENTS:
        if key == "drugbank-id":
            continue

        if key in {"name", "cas-number"}:
            element = drug.find(f"{DRUGBANK_NS}{key}")
            if element is not None and has_value_type(element):
                data[idx].update({key: element.text})

    for key in {"products", "international-brands"}:
        subkey = "name"
        data[idx].update(
            {
                f"{key}": build_string(
                    [
                        element.findtext(f"{DRUGBANK_NS}{subkey}")
                        for element in drug.findall(
                            f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}"
                        )
                    ]
                )
            }
        )
    key = "synonyms"
    data[idx].update(
        {
            f"{key}": build_string(
                [
                    element.text
                    for element in drug.findall(
                        f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}"
                    )
                ]
            )
        }
    )

    idx += 1

df_drugbank_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
all_drug_dfs["General"] = df_drugbank_data
df_drugbank_data = df_drugbank_data.drop(["created", "updated"], axis=1)
df_drugbank_data
# Out:
#      drugbank-id            type               name    cas-number  \
# 0        DB00006  small molecule        Bivalirudin   128270-60-0
# 1        DB00027  small molecule       Gramicidin D     1405-97-6
# 2        DB00030         biotech      Insulin human    11061-68-0
# 3        DB00035  small molecule       Desmopressin    16679-58-6
# 4        DB00041         biotech        Aldesleukin   110942-02-4
# ...          ...             ...                ...           ...
# 2435     DB16732         biotech  Tisotumab vedotin  1418731-10-8
# 2436     DB16826  small molecule      Repotrectinib  1802220-02-5
# 2437     DB17083  small molecule         Linzagolix   935283-04-8
# 2438     DB17472  small molecule      Pirtobrutinib  2101700-15-4
# 2439     DB17635         biotech          Nedosiran  2266591-83-5
#
#      international-brands                                           products  \
# 0          Angiox;Hirulog  Angiomax;Angiomax RTU;Angiox;Bivalirudin;Bival...
# 1                Sofradex  Antibiotic Cream;Antibiotic Cream for Kids;Ant...
# 2                          Actraphane 30;Actraphane 30 Flexpen;Actraphane...
# 3     Adiuretin;DesmoMelt  Apo-desmopressin;Bipazen;Ddavp;Ddavp Inj 4mcg/...
# 4                                                                  Proleukin
# ...                   ...                                                ...
# 2435               Tivdak                                             Tivdak
# 2436                                                                 Augtyro
# 2437                                                 KLH-2109 Choline;Yselty
# 2438             Jaypirca                                           Jaypirca
# 2439                                                                Rivfloza
#
#                                                synonyms
# 0                Bivalirudin;Bivalirudina;Bivalirudinum
# 1     Bacillus brevis gramicidin D;Gramicidin;Gramic...
# 2     High molecular weight insulin human;Human insu...
# 3     1-(3-mercaptopropionic acid)-8-D-arginine-vaso...
# 4     125-L-serine-2-133-interleukin 2 (human reduce...
# ...                                                 ...
# 2435  HuMax-TF-ADC;Tisotumab vedotin;tisotumab vedot...
# 2436  (3R,6S,)-45-FLUORO-3,6-DIMETHYL-5-OXA-2,8-DIAZ...
# 2437  3-(5-((2,3-difluoro-6-methoxyphenyl)methoxy)-2...
# 2438  (s)-5-amino-3-(4-((5-fluoro-2-methoxybenzamido...
# 2439                       DCR-PHXC free acid;Nedosiran
#
# [2440 rows x 7 columns]

# %%
idx = 0
data = defaultdict(dict)
for drug in root:
    # General information
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "categories"
    # Drug catgories
    # For mesh-id: https://registry.identifiers.org/registry/mesh
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        data[idx]["category"] = element.findtext(f"{DRUGBANK_NS}category")
        data[idx]["mesh-id"] = element.findtext(f"{DRUGBANK_NS}mesh-id")
        idx += 1


df_drug_category = (
    pd.DataFrame.from_dict(data, orient="index")
    .replace("", float("nan"))
    .drop_duplicates()
    .reset_index(drop=True)
)
all_drug_dfs["Categories"] = df_drug_category
df_drug_category
# Out:
#       drugbank-id                             category     mesh-id
# 0         DB00006  Amino Acids, Peptides, and Proteins     D000602
# 1         DB00006                       Anticoagulants     D000925
# 2         DB00006                        Antithrombins     D000991
# 3         DB00006       Blood and Blood Forming Organs         NaN
# 4         DB00006                    Enzyme Inhibitors     D004791
# ...           ...                                  ...         ...
# 30683     DB17472            P-glycoprotein inhibitors         NaN
# 30684     DB17472            P-glycoprotein substrates         NaN
# 30685     DB17472            Protein Kinase Inhibitors     D047428
# 30686     DB17472           Tyrosine Kinase Inhibitors  D000092004
# 30687     DB17472                    UGT1A9 Substrates         NaN
#
# [30688 rows x 3 columns]

# %% [markdown]
# #### Extract ATC codes

# %%
idx = 0
data = defaultdict(dict)
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "atc-codes"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    for element in elements:
        data[idx].update(
            {
                "drugbank-id": drugbank_id,
                "substance.code": element.get("code"),
                "substance.description": drug.findtext(f"{DRUGBANK_NS}name"),
            }
        )
        for level, subelement in zip(
            ["chemical", "pharmacological", "therapeutic", "anatomical"], list(element)
        ):
            data[idx].update(
                {
                    f"{level}.description": subelement.text,
                    f"{level}.code": subelement.get("code"),
                }
            )
        idx += 1

df_atc_codes_data = pd.DataFrame.from_dict(data, orient="index")
df_atc_codes_data = df_atc_codes_data.loc[
    :, list(df_atc_codes_data.columns[:1]) + list(df_atc_codes_data.columns[1:][::-1])
]
df_atc_codes_data = (
    df_drugbank_data[["drugbank-id"]]
    .merge(
        df_atc_codes_data,
        left_on="drugbank-id",
        right_on="drugbank-id",
        how="left",
    )
    .drop_duplicates()
    .reset_index(drop=True)
)
all_drug_dfs["ATC"] = df_atc_codes_data

print(df_atc_codes_data.nunique())
df_atc_codes_data
# Out:
# drugbank-id                    2440
# anatomical.code                  14
# anatomical.description           14
# therapeutic.code                 85
# therapeutic.description          85
# pharmacological.code            202
# pharmacological.description     198
# chemical.code                   527
# chemical.description            487
# substance.description          1010
# substance.code                 1852
# dtype: int64
#      drugbank-id anatomical.code  \
# 0        DB00006               B
# 1        DB00027               R
# 2        DB00030               A
# 3        DB00030               A
# 4        DB00030               A
# ...          ...             ...
# 3549     DB16732               L
# 3550     DB16826             NaN
# 3551     DB17083               H
# 3552     DB17472               L
# 3553     DB17635             NaN
#
#                                  anatomical.description therapeutic.code  \
# 0                        BLOOD AND BLOOD FORMING ORGANS              B01
# 1                                    RESPIRATORY SYSTEM              R02
# 2                       ALIMENTARY TRACT AND METABOLISM              A10
# 3                       ALIMENTARY TRACT AND METABOLISM              A10
# 4                       ALIMENTARY TRACT AND METABOLISM              A10
# ...                                                 ...              ...
# 3549         ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS              L01
# 3550                                                NaN              NaN
# 3551  SYSTEMIC HORMONAL PREPARATIONS, EXCL. SEX HORM...              H01
# 3552         ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS              L01
# 3553                                                NaN              NaN
#
#                                 therapeutic.description pharmacological.code  \
# 0                                 ANTITHROMBOTIC AGENTS                 B01A
# 1                                   THROAT PREPARATIONS                 R02A
# 2                                DRUGS USED IN DIABETES                 A10A
# 3                                DRUGS USED IN DIABETES                 A10A
# 4                                DRUGS USED IN DIABETES                 A10A
# ...                                                 ...                  ...
# 3549                              ANTINEOPLASTIC AGENTS                 L01F
# 3550                                                NaN                  NaN
# 3551  PITUITARY AND HYPOTHALAMIC HORMONES AND ANALOGUES                 H01C
# 3552                              ANTINEOPLASTIC AGENTS                 L01E
# 3553                                                NaN                  NaN
#
#                             pharmacological.description chemical.code  \
# 0                                 ANTITHROMBOTIC AGENTS         B01AE
# 1                                   THROAT PREPARATIONS         R02AB
# 2                                INSULINS AND ANALOGUES         A10AC
# 3                                INSULINS AND ANALOGUES         A10AE
# 4                                INSULINS AND ANALOGUES         A10AB
# ...                                                 ...           ...
# 3549  MONOCLONAL ANTIBODIES AND ANTIBODY DRUG CONJUG...         L01FX
# 3550                                                NaN           NaN
# 3551                              HYPOTHALAMIC HORMONES         H01CC
# 3552                          PROTEIN KINASE INHIBITORS         L01EL
# 3553                                                NaN           NaN
#
#                                    chemical.description substance.description  \
# 0                            Direct thrombin inhibitors           Bivalirudin
# 1                                           Antibiotics          Gramicidin D
# 2     Insulins and analogues for injection, intermed...         Insulin human
# 3     Insulins and analogues for injection, long-acting         Insulin human
# 4     Insulins and analogues for injection, fast-acting         Insulin human
# ...                                                 ...                   ...
# 3549  Other monoclonal antibodies and antibody drug ...     Tisotumab vedotin
# 3550                                                NaN                   NaN
# 3551               Anti-gonadotropin-releasing hormones            Linzagolix
# 3552          Bruton's tyrosine kinase (BTK) inhibitors         Pirtobrutinib
# 3553                                                NaN                   NaN
#
#      substance.code
# 0           B01AE06
# 1           R02AB30
# 2           A10AC01
# 3           A10AE01
# 4           A10AB01
# ...             ...
# 3549        L01FX23
# 3550            NaN
# 3551        H01CC04
# 3552        L01EL05
# 3553            NaN
#
# [3554 rows x 11 columns]

# %% [markdown]
# #### Extract drug interactions
# Extracted drug interactions are confined to those that directly map into the reconstruction.

# %%
prefix = True

idx = 0
data = defaultdict(dict)
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "drug-interactions"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        interacting_id = element.findtext(f"{DRUGBANK_NS}drugbank-id")
        if interacting_id in drugbank_ids:
            data[idx].update(
                {
                    "drugbank-id": drugbank_id,
                    "name": drug.findtext(f"{DRUGBANK_NS}name"),
                }
            )
            data[idx].update(
                {
                    f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}")
                    for subkey in ["drugbank-id", "name", "description"]
                }
            )
            idx += 1

df_drug_interactions = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)

# Drug interactions go two ways, generate a field to keep only unique interactions
df_drug_interactions["drug;drug"] = df_drug_interactions[
    ["drugbank-id", "drug-interactions.drugbank-id"]
].apply(lambda x: build_string(sorted(x.values)), axis=1)
df_drug_interactions = df_drug_interactions.drop_duplicates(subset=["drug;drug"])
df_drug_interactions = df_drug_interactions.reset_index(drop=True)
df_drug_interactions = df_drug_interactions.rename(
    {
        "drugbank-id": "drugbank_A",
        "name": "name_A",
        "drug-interactions.drugbank-id": "drugbank_B",
        "drug-interactions.name": "name_B",
        "drug;drug": "drugbank_A;drugbank_B",
    },
    axis=1,
)
all_drug_dfs["Interactions"] = df_drug_interactions

print(df_drug_interactions.nunique())
df_drug_interactions
# Out:
# drugbank_A                         1184
# name_A                             1184
# drugbank_B                         1197
# name_B                             1197
# drug-interactions.description    231553
# drugbank_A;drugbank_B            231553
# dtype: int64
#        drugbank_A           name_A drugbank_B                      name_B  \
# 0         DB00006      Bivalirudin    DB06605                    Apixaban
# 1         DB00006      Bivalirudin    DB06695        Dabigatran etexilate
# 2         DB00006      Bivalirudin    DB01254                   Dasatinib
# 3         DB00006      Bivalirudin    DB01586        Ursodeoxycholic acid
# 4         DB00006      Bivalirudin    DB02123  Glycochenodeoxycholic Acid
# ...           ...              ...        ...                         ...
# 231548    DB16650  Deucravacitinib    DB17472               Pirtobrutinib
# 231549    DB16690       Tegoprazan    DB16703                 Belumosudil
# 231550    DB16703      Belumosudil    DB17472               Pirtobrutinib
# 231551    DB16703      Belumosudil    DB16826               Repotrectinib
# 231552    DB16826    Repotrectinib    DB17472               Pirtobrutinib
#
#                             drug-interactions.description  \
# 0       Apixaban may increase the anticoagulant activi...
# 1       Dabigatran etexilate may increase the anticoag...
# 2       The risk or severity of bleeding and hemorrhag...
# 3       The risk or severity of bleeding and bruising ...
# 4       The risk or severity of bleeding and bruising ...
# ...                                                   ...
# 231548  The risk or severity of adverse effects can be...
# 231549  The serum concentration of Belumosudil can be ...
# 231550  The risk or severity of adverse effects can be...
# 231551  The serum concentration of Repotrectinib can b...
# 231552  The serum concentration of Repotrectinib can b...
#
#        drugbank_A;drugbank_B
# 0            DB00006;DB06605
# 1            DB00006;DB06695
# 2            DB00006;DB01254
# 3            DB00006;DB01586
# 4            DB00006;DB02123
# ...                      ...
# 231548       DB16650;DB17472
# 231549       DB16690;DB16703
# 231550       DB16703;DB17472
# 231551       DB16703;DB16826
# 231552       DB16826;DB17472
#
# [231553 rows x 6 columns]

# %% [markdown]
# ### Extract proteins

# %%
idx = 0
data = defaultdict(dict)
prefix = False
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    prefix = f"proteins." if prefix else ""
    for ptype in ["targets", "enzymes", "carriers", "transporters"]:
        elements = drug.findall(
            f"{DRUGBANK_NS}{ptype}/{DRUGBANK_NS}{strip_plural(ptype)}"
        )
        for element in elements:
            for subelement in element.findall(f"{DRUGBANK_NS}polypeptide"):
                data[idx].update({f"drugbank-id": drugbank_id, f"{prefix}type": ptype})
                data[idx].update(
                    {
                        f"{prefix}{strip_ns_DrugBank(subelement.tag)}": subelement.text
                        for subelement in element
                        if has_value_type(subelement)
                    }
                )

                # Polypeptide
                key = "polypeptide"
                data[idx].update(
                    {
                        f"{prefix}{key}.uniprot-id": subelement.get("id"),
                        f"{prefix}{key}.source": subelement.get("source"),
                    }
                )
                data[idx].update(
                    {
                        f"{prefix}{key}.{strip_ns_DrugBank(subelem.tag)}": subelem.text
                        for subelem in subelement
                        if has_value_type(subelem)
                    }
                )
                subkey = "pfams"
                data[idx].update(
                    {
                        f"{prefix}{key}.{subkey}": build_string(
                            [
                                subelem.text
                                for subelem in subelement.findall(
                                    f"{DRUGBANK_NS}{subkey}/{DRUGBANK_NS}{strip_plural(subkey)}/{DRUGBANK_NS}identifier"
                                )
                                if has_value_type(subelem)
                            ]
                        )
                    }
                )

                idx += 1

df_proteins = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
df_proteins = df_proteins[
    df_proteins[f"{prefix}polypeptide.uniprot-id"].isin(uniprot_ids)
]
df_proteins = df_proteins.drop_duplicates().reset_index(drop=True)
df_proteins = (
    df_model_mappings[["genes", "uniprot"]]
    .merge(df_proteins, left_on="uniprot", right_on="polypeptide.uniprot-id")
    .drop_duplicates()
    .drop(["uniprot"], axis=1)
    .reset_index(drop=True)
)

all_drug_dfs["Proteins"] = df_proteins
df_proteins
# Out:
#      genes drugbank-id     type         id  \
# 0      RPE     DB00153  enzymes  BE0009671
# 1     RPIA     DB01756  targets  BE0004438
# 2     SORD     DB00157  targets  BE0000299
# 3     SORD     DB04478  targets  BE0000299
# 4      SRM     DB00118  enzymes  BE0000300
# ...    ...         ...      ...        ...
# 4655   SLK     DB12010  targets  BE0004041
# 4656  UAP1     DB02196  targets  BE0001429
# 4657  UAP1     DB03397  targets  BE0001429
# 4658  YES1     DB01254  targets  BE0000840
# 4659  YES1     DB12010  targets  BE0000840
#
#                                             name organism known-action  \
# 0                 Ribulose-phosphate 3-epimerase   Humans           no
# 1                   Ribose-5-phosphate isomerase   Humans      unknown
# 2                         Sorbitol dehydrogenase   Humans      unknown
# 3                         Sorbitol dehydrogenase   Humans      unknown
# 4                            Spermidine synthase   Humans      unknown
# ...                                          ...      ...          ...
# 4655  STE20-like serine/threonine-protein kinase   Humans      unknown
# 4656    UDP-N-acetylhexosamine pyrophosphorylase   Humans      unknown
# 4657    UDP-N-acetylhexosamine pyrophosphorylase   Humans      unknown
# 4658                 Tyrosine-protein kinase Yes   Humans          yes
# 4659                 Tyrosine-protein kinase Yes   Humans      unknown
#
#      polypeptide.uniprot-id polypeptide.source  \
# 0                    Q96AT9         Swiss-Prot
# 1                    P49247         Swiss-Prot
# 2                    Q00796         Swiss-Prot
# 3                    Q00796         Swiss-Prot
# 4                    P19623         Swiss-Prot
# ...                     ...                ...
# 4655                 Q9H2G2         Swiss-Prot
# 4656                 Q16222         Swiss-Prot
# 4657                 Q16222         Swiss-Prot
# 4658                 P07947         Swiss-Prot
# 4659                 P07947         Swiss-Prot
#
#                                 polypeptide.name  ...  \
# 0                 Ribulose-phosphate 3-epimerase  ...
# 1                   Ribose-5-phosphate isomerase  ...
# 2                         Sorbitol dehydrogenase  ...
# 3                         Sorbitol dehydrogenase  ...
# 4                            Spermidine synthase  ...
# ...                                          ...  ...
# 4655  STE20-like serine/threonine-protein kinase  ...
# 4656    UDP-N-acetylhexosamine pyrophosphorylase  ...
# 4657    UDP-N-acetylhexosamine pyrophosphorylase  ...
# 4658                 Tyrosine-protein kinase Yes  ...
# 4659                 Tyrosine-protein kinase Yes  ...
#
#      polypeptide.theoretical-pi polypeptide.molecular-weight  \
# 0                                                  24927.555
# 1                                                   33268.72
# 2                          8.06                     38324.25
# 3                          8.06                     38324.25
# 4                          5.17                    33824.455
# ...                         ...                          ...
# 4655                        4.8                    142693.96
# 4656                       6.29                    58768.705
# 4657                       6.29                    58768.705
# 4658                       6.71                     60800.78
# 4659                       6.71                     60800.78
#
#      polypeptide.chromosome-location polypeptide.organism  \
# 0                                  2               Humans
# 1                                  2               Humans
# 2                                 15               Humans
# 3                                 15               Humans
# 4                                  1               Humans
# ...                              ...                  ...
# 4655                              10               Humans
# 4656                               1               Humans
# 4657                               1               Humans
# 4658                              18               Humans
# 4659                              18               Humans
#
#                         polypeptide.amino-acid-sequence  \
# 0     >lcl|BSEQ0052026|Ribulose-phosphate 3-epimeras...
# 1     >lcl|BSEQ0009359|Ribose-5-phosphate isomerase\...
# 2     >lcl|BSEQ0036986|Sorbitol dehydrogenase\nMAAAA...
# 3     >lcl|BSEQ0036986|Sorbitol dehydrogenase\nMAAAA...
# 4     >lcl|BSEQ0010239|Spermidine synthase\nMEPGPDGP...
# ...                                                 ...
# 4655  >lcl|BSEQ0007723|STE20-like serine/threonine-p...
# 4656  >lcl|BSEQ0002837|UDP-N-acetylhexosamine pyroph...
# 4657  >lcl|BSEQ0002837|UDP-N-acetylhexosamine pyroph...
# 4658  >lcl|BSEQ0010592|Tyrosine-protein kinase Yes\n...
# 4659  >lcl|BSEQ0010592|Tyrosine-protein kinase Yes\n...
#
#                               polypeptide.gene-sequence  \
# 0     >lcl|BSEQ0052027|Ribulose-phosphate 3-epimeras...
# 1     >lcl|BSEQ0020766|Ribose-5-phosphate isomerase ...
# 2     >lcl|BSEQ0010069|Sorbitol dehydrogenase (SORD)...
# 3     >lcl|BSEQ0010069|Sorbitol dehydrogenase (SORD)...
# 4     >lcl|BSEQ0010240|Spermidine synthase (SRM)\nAT...
# ...                                                 ...
# 4655  >lcl|BSEQ0019517|STE20-like serine/threonine-p...
# 4656  >lcl|BSEQ0011002|UDP-N-acetylhexosamine pyroph...
# 4657  >lcl|BSEQ0011002|UDP-N-acetylhexosamine pyroph...
# 4658  >lcl|BSEQ0010593|Tyrosine-protein kinase Yes (...
# 4659  >lcl|BSEQ0010593|Tyrosine-protein kinase Yes (...
#
#             polypeptide.pfams inhibition-strength  \
# 0                     PF00834
# 1                     PF06026
# 2             PF08240;PF00107
# 3             PF08240;PF00107
# 4             PF01564;PF17284
# ...                       ...                 ...
# 4655          PF12474;PF00069
# 4656                  PF01704
# 4657                  PF01704
# 4658  PF00018;PF07714;PF00017
# 4659  PF00018;PF07714;PF00017
#
#      polypeptide.transmembrane-regions induction-strength
# 0
# 1
# 2
# 3
# 4
# ...                                ...                ...
# 4655
# 4656
# 4657
# 4658
# 4659
#
# [4660 rows x 26 columns]

# %%
idx = 0
data = defaultdict(dict)
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    # Get only drugbank IDs specified
    for key in ["snp-effects", "snp-adverse-drug-reactions"]:
        elements = drug.findall(
            f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key.split('-')[-1])}"
        )
        for element in elements:
            data[idx].update({"drugbank-id": drugbank_id})
            data[idx].update(
                {
                    f"{strip_ns_DrugBank(subelement.tag)}": subelement.text
                    for subelement in element
                    if has_value_type(subelement)
                }
            )
            idx += 1
df_snp_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
df_snp_data = df_snp_data[df_snp_data["uniprot-id"].isin(uniprot_ids)]
df_snp_data = df_snp_data.drop_duplicates().reset_index(drop=True)
all_drug_dfs["SNP"] = df_snp_data

df_snp_data
# Out:
#    drugbank-id                                       protein-name gene-symbol  \
# 0      DB00215                     Multidrug resistance protein 1       ABCB1
# 1      DB00285                     Multidrug resistance protein 1       ABCB1
# 2      DB00285                     Multidrug resistance protein 1       ABCB1
# 3      DB00295                     Multidrug resistance protein 1       ABCB1
# 4      DB00317         ATP-binding cassette sub-family G member 2       ABCG2
# 5      DB00321                     Multidrug resistance protein 1       ABCB1
# 6      DB00321                     Multidrug resistance protein 1       ABCB1
# 7      DB00352                     Thiopurine S-methyltransferase        TPMT
# 8      DB00352                     Thiopurine S-methyltransferase        TPMT
# 9      DB00352                     Thiopurine S-methyltransferase        TPMT
# 10     DB00352                     Thiopurine S-methyltransferase        TPMT
# 11     DB00448                     Multidrug resistance protein 1       ABCB1
# 12     DB00515                     Glutathione S-transferase Mu 1       GSTM1
# 13     DB00515                        Glutathione S-transferase P       GSTP1
# 14     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 15     DB00544                        Glutathione S-transferase P       GSTP1
# 16     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 17     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 18     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 19     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 20     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 21     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 22     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 23     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 24     DB00544          Dihydropyrimidine dehydrogenase [NADP(+)]        DPYD
# 25     DB00715                     Multidrug resistance protein 1       ABCB1
# 26     DB00864                     Multidrug resistance protein 1       ABCB1
# 27     DB00993                     Thiopurine S-methyltransferase        TPMT
# 28     DB00993                     Thiopurine S-methyltransferase        TPMT
# 29     DB00993                     Thiopurine S-methyltransferase        TPMT
# 30     DB01033                     Thiopurine S-methyltransferase        TPMT
# 31     DB01033                     Thiopurine S-methyltransferase        TPMT
# 32     DB01033                     Thiopurine S-methyltransferase        TPMT
# 33     DB01098         ATP-binding cassette sub-family G member 2       ABCG2
# 34     DB01233                     Multidrug resistance protein 1       ABCB1
# 35     DB08820  Cystic fibrosis transmembrane conductance regu...        CFTR
#
#    uniprot-id       rs-id                      defining-change  \
# 0      P08183   rs2032583                             C Allele
# 1      P08183   rs2032583                             C Allele
# 2      P08183   rs2032583                                T > C
# 3      P08183   rs1045642                             T Allele
# 4      Q9UNQ0   rs2231142
# 5      P08183   rs2032583                             C Allele
# 6      P08183   rs2032583                                T > C
# 7      P51580   rs1800462
# 8      P51580   rs1800460
# 9      P51580   rs1142345
# 10     P51580   rs1800584
# 11     P08183   rs1045642              C Allele,  heterozygote
# 12     P09488
# 13     P09211
# 14     Q12882   rs1801265
# 15     P09211      rs1695
# 16     Q12882   rs3918290
# 17     Q12882  rs67376798
# 18     Q12882   rs3918290
# 19     Q12882  rs55886062
# 20     Q12882  rs67376798
# 21     Q12882   rs1801158
# 22     Q12882   rs1801159
# 23     Q12882   rs1801160
# 24     Q12882   rs1801265
# 25     P08183   rs2032583                             C Allele
# 26     P08183   rs2032582
# 27     P51580   rs1800462
# 28     P51580   rs1800460
# 29     P51580   rs1142345
# 30     P51580   rs1800462
# 31     P51580   rs1800460
# 32     P51580   rs1142345
# 33     Q9UNQ0   rs2231142                                G > T
# 34     P08183   rs1045642                             T Allele
# 35     P13569  rs75527207  A allele (G > A), double homozygote
#
#                                           description pubmed-id   allele  \
# 0   Patients with this genotype have an increased ...  17913323
# 1   Patients with this genotype have an increased ...  17913323
# 2   Patients with this genotype have increased ris...  22641028
# 3   Patients with this genotype may have an increa...  17898703
# 4   Patients with this genotype have an increased ...  17148776
# 5   Patients with this genotype have an increased ...  17913323
# 6   Patients with this genotype have increased ris...  22641028
# 7   The presence of this polymorphism in TPMT may ...  21270794   TPMT*2
# 8   The presence of this polymorphism in TPMT may ...  21270794  TPMT*3A
# 9   The presence of this polymorphism in TPMT may ...  21270794  TPMT*3C
# 10  The presence of this polymorphism in TPMT may ...  21270794  TPMT*4A
# 11  Patients with this genotype have increased pla...  17190370
# 12  Patients with this genotype have increased ris...  18162130    GSTM1
# 13  Patients with this genotype have increased ris...  18162130
# 14  Patients with this genotype have reduced metab...  17848752
# 15  Patients with this genotype have increased ris...  18540691
# 16  Patients with this genotype have reduced metab...  18299612
# 17  Patients with this genotype have reduced metab...  23603345
# 18  The presence of this genotype in DPYD is assoc...  23988873  DPYD*2A
# 19  The presence of this genotype in DPYD is assoc...  23988873  DPYD*13
# 20  The presence of this genotype in DPYD is assoc...  23988873
# 21  The presence of this genotype in DPYD may be a...  23988873   DPYD*4
# 22  The presence of this genotype in DPYD may be a...  23988873   DPYD*5
# 23  The presence of this genotype in DPYD may be a...  23988873   DPYD*6
# 24  The presence of this genotype in DPYD may be a...  23988873  DPYD*9A
# 25  Patients with this genotype have an increased ...  17913323
# 26  The presence of this genotype in ABCB1 may ind...  12352921
# 27  Patients with this genotype have reduced metab...  16509759   TPMT*2
# 28  Patients with this genotype have reduced metab...  16509759  TPMT*3A
# 29  Patients with this genotype have reduced metab...  16509759  TPMT*3C
# 30  Patients with this genotype have reduced metab...  16509759   TPMT*2
# 31  Patients with this genotype have reduced metab...  16509759  TPMT*3A
# 32  Patients with this genotype have reduced metab...  16509759  TPMT*3C
# 33  Patients with this genotype have a greater red...  20130569
# 34  Patients with this polymorphism in ABCB1 may h...  21840870
# 35  Patients who carry this polymorphism in CFTR w...  23757359
#
#                 adverse-reaction
# 0
# 1
# 2
# 3
# 4                       A allele
# 5
# 6
# 7                       G Allele
# 8                       A Allele
# 9                       G Allele
# 10                         G > A
# 11
# 12  presence of functional GSTM1
# 13
# 14                      C allele
# 15                      A allele
# 16                      A allele
# 17                         T > A
# 18                         G > A
# 19                         A > C
# 20                         T > A
# 21                         G > A
# 22                         A > G
# 23                         G > A
# 24                         T > C
# 25
# 26             T Allele (G2677T)
# 27                      G Allele
# 28                      A Allele
# 29                      G Allele
# 30                      G Allele
# 31                      A Allele
# 32                      G Allele
# 33
# 34
# 35

# %% [markdown]
# ## Export drug data for subsequent visualization

# %%
print(list(all_drug_dfs.keys()))
for sheet_name, df in all_drug_dfs.items():
    df.to_csv(database_dirpath / f"{sheet_name}_DrugBank.tsv", sep="\t")
# Out:
# ['General', 'Categories', 'ATC', 'Interactions', 'Proteins', 'SNP']
