# %% [markdown]
# # Extract information from DrugBank
#
# This notebook demonstrates how to extract information from various fields in the DrugBank Database.
# Purpose of this notebook is to serve as examples of how DrugBank data can be extracted.
#
# Data extracted for specific purposes and with subsequent analysis notebooks (e.g., drug interaction visualization) should be kept and maintained seperately.
#
#
# ## DRUGBANK ONLINE
# To utilize this notebook:
#
# 1. Go to [DrugBank database](https://go.drugbank.com/releases/latest) and create an account.
# 2. Follow the instructions to obtain a free academic license.
# 3. Download and unzip the database file `"drugbank_all_full_database.xml.zip"`.
# 4. Rename the file `"full database.xml"` to `"drugbank_all_full_database.xml"`.
# 5. Remember clear out any personal account information and ensure the downloaded DrugBank file remains local!
#
# The functions `download_database_DrugBank` takes a given username and a password and downloads the data, taking care to change the filename in the process.
#
# Fields for the DrugBank XML schema are found [here](https://docs.drugbank.com/xml/#introduction).
#
# Wishart DS, Feunang YD, Guo AC, Lo EJ, Marcu A, Grant JR, Sajed T, Johnson D, Li C, Sayeeda Z, Assempour N, Iynkkaran I, Liu Y, Maciejewski A, Gale N, Wilson A, Chin L, Cummings R, Le D, Pon A, Knox C, Wilson M. DrugBank 5.0: a major update to the DrugBank database for 2018. Nucleic Acids Res. 2017 Nov 8. doi: 10.1093/nar/gkx1037.
#
# ### Import packages

# %%
from collections import defaultdict
from warnings import warn
from xml.etree import ElementTree

import pandas as pd
from rbc_gem_utils import (
    ANNOTATION_PATH,
    DATABASE_PATH,
    ROOT_PATH,
    check_version,
    get_annotation_df,
    read_rbc_model,
    show_versions,
)
from rbc_gem_utils.database.drugbank import (
    DRUGBANK_CLASSIFICATION_ELEMENTS,
    DRUGBANK_DOSAGE_ELEMENTS,
    DRUGBANK_GENERAL_ELEMENTS,
    DRUGBANK_MIXTURES_ELEMENTS,
    DRUGBANK_NS,
    DRUGBANK_PATENT_ELEMENTS,
    DRUGBANK_PATH,
    DRUGBANK_PATHWAY_ELEMENTS,
    DRUGBANK_PHARMACOLOGY_ELEMENTS,
    DRUGBANK_PRICE_ELEMENTS,
    DRUGBANK_SALTS_ELEMENTS,
    DRUGBANK_VERSION_EXPECTED,
    download_database_DrugBank,
    get_version_DrugBank,
    strip_ns_DrugBank,
)
from rbc_gem_utils.util import (
    build_string,
    ensure_iterable,
    has_value_type,
    split_string,
    strip_plural,
)

# Display versions of last time notebook ran and worked
show_versions()
# Out:
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.12.3
# bio                                   1.6.2
# cobra                                0.29.0
# depinfo                               2.2.0
# kaleido                               0.2.1
# matplotlib                            3.8.2
# memote                               0.17.0
# networkx                              3.2.1
# notebook                              7.0.7
# openpyxl                              3.1.2
# pandas                                2.2.0
# pre-commit                            3.6.0
# pyvis                                 0.3.2
# rbc-gem-utils[database,network,vis] missing
# requests                             2.31.0
# scipy                                1.12.0
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip        23.3.1
# setuptools 68.2.2
# wheel      0.41.2
#
# Platform Information
# --------------------
# Darwin  23.6.0-x86_64
# CPython        3.11.7

# %% [markdown]
# ## Check DrugBank version
# If the version does not match the expected version, it is because database has been updated since the last time this code was utilized.
# ### Expected DrugBank version: 5.1.12
# * Last release utilized: [5.1.12](https://go.drugbank.com/releases) published on **2024-03-14**
# * Version in the DrugBank file is formatted as {major}.{minor}

# %%
database_dirpath = ROOT_PATH / DATABASE_PATH / DRUGBANK_PATH
annotation_dirpath = ROOT_PATH / ANNOTATION_PATH
# version = get_version_DrugBank()
# if check_version(version, DRUGBANK_VERSION_EXPECTED, verbose=True):
#     database_dirpath = ROOT_PATH / DATABASE_PATH / DRUGBANK_PATH
#     annotation_dirpath = ROOT_PATH / ANNOTATION_PATH
# else:
#     database_dirpath = ROOT_PATH / INTERIM_PATH / DRUGBANK_PATH
#     annotation_dirpath = ROOT_PATH / INTERIM_PATH
#     version = DRUGBANK_VERSION_EXPECTED
# Out:
# Current and expected versions match.

# %% [markdown]
# #### Download new files and update database
# If an argument is not provided (`arg=None`), its default value for the repository used.
# Username and password must be provided for this function, be sure to remove personal information after use!

# %%
download = False
if download:
    # Download data
    download_database_DrugBank(
        username="USERNAME",
        password="PASSWORD",
        database_dirpath=database_dirpath,
        version=version,
    )
filepath = database_dirpath / "drugbank_all_full_database.xml"

# %% [markdown]
# ## Load RBC-GEM model

# %%
model = read_rbc_model(filetype="xml")
model
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-28
# <Model RBC_GEM at 0x14f1702d0>

# %%
annotation_type = "genes"
df_model_mappings = get_annotation_df(
    getattr(model, annotation_type), ["uniprot", "drugbank"]
).rename({"id": annotation_type}, axis=1)

df_model_mappings["drugbank"] = df_model_mappings["drugbank"].apply(
    lambda x: split_string(x)
)
df_model_mappings = (
    df_model_mappings.explode("drugbank").dropna(subset=["drugbank"]).drop_duplicates()
)
print(df_model_mappings.nunique())
drugbank_ids = set(df_model_mappings["drugbank"].dropna().unique())

df_model_mappings
# Out:
# genes        471
# uniprot      471
# drugbank    2440
# dtype: int64
#     genes uniprot drugbank
# 0     RPE  Q96AT9  DB00153
# 1    RPIA  P49247  DB01756
# 2    SORD  Q00796  DB00157
# 2    SORD  Q00796  DB04478
# 4     SRM  P19623  DB00118
# ..    ...     ...      ...
# 799   SLK  Q9H2G2  DB12010
# 805  UAP1  Q16222  DB02196
# 805  UAP1  Q16222  DB03397
# 819  YES1  P07947  DB01254
# 819  YES1  P07947  DB12010
#
# [4426 rows x 3 columns]

# %% [markdown]
# ## Parse DrugBank information into DataFrame

# %%
root = ElementTree.parse(filepath).getroot()
root
# Out:
# <Element '{http://www.drugbank.ca}drugbank' at 0x1522f4b30>

# %% [markdown]
# ### Extract general information

# %%
dataframes = {}
idx = 0
data = defaultdict(dict)
for drug in root:
    # General information
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    data[idx].update({"drugbank-id": drugbank_id})
    data[idx].update({attr: drug.get(attr) for attr in ["type", "created", "updated"]})
    # Get element values that don't require diving further.
    for key in DRUGBANK_GENERAL_ELEMENTS:
        if key == "drugbank-id":
            continue
        # Get elements that have several values should be joined together for these.
        # AHFS codes seems empty for all entries?
        if key in {
            "groups",
            "affected-organisms",
            "ahfs-codes",
            "pdb-entries",
            "food-interactions",
        }:
            elements = drug.findall(
                f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}"
            )
            data[idx].update(
                {
                    key: build_string(
                        [
                            element.text
                            for element in elements
                            if has_value_type(element)
                        ],
                        sep=";;",
                    )
                }
            )
        elif key == "categories":
            # Drug catgories
            # For mesh-id: https://registry.identifiers.org/registry/mesh
            for subkey in ["category", "mesh-id"]:
                elements = drug.findall(
                    f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}/{DRUGBANK_NS}{subkey}"
                )
                data[idx].update(
                    {
                        f"{key}.{subkey}": build_string(
                            [
                                element.text
                                for element in elements
                                if has_value_type(element)
                            ],
                            sep=";;",
                        )
                    }
                )
        elif key == "general-references":
            # For main dataframe, group all references and use the unique ID from DrugBank
            elements = [
                element.find(f"{DRUGBANK_NS}ref-id")
                for subkey in ["articles", "textbooks", "links", "attachments"]
                for element in drug.findall(
                    f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{subkey}/{DRUGBANK_NS}{strip_plural(subkey)}"
                )
            ]
            data[idx].update(
                {
                    f"{key}.ref-id": build_string(
                        [
                            element.text
                            for element in elements
                            if has_value_type(element)
                        ],
                        sep=";;",
                    )
                }
            )

        else:
            element = drug.find(f"{DRUGBANK_NS}{key}")
            if element is not None and has_value_type(element):
                data[idx].update({key: element.text})

    # Chemical Taxonomy from classyfire
    key = "classification"
    prefix = f"{key}."
    for subkey in DRUGBANK_CLASSIFICATION_ELEMENTS:
        element = drug.find(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{subkey}")
        if element is not None and has_value_type(element):
            data[idx].update({f"{prefix}{subkey}": element.text})

    # Synonyms with international brands elsewhere
    # External codes not included
    # Pharmacology events
    for key in DRUGBANK_PHARMACOLOGY_ELEMENTS:
        prefix = "pharmacology."
        element = drug.find(f"{DRUGBANK_NS}{key}")
        if element is not None and has_value_type(element):
            data[idx].update({f"{prefix}{key}": element.text})

    # Regional availability not included
    # International brands with synonyms elsewhere

    # Mixtures of drugs, names only
    # Packagers of drugs, names only
    # Patents of drugs, numbers only
    # Pathway involvement of drugs, smpdb-id only
    # Products of drugs, names only
    for key, subkey in zip(
        ["mixtures", "packagers", "patents", "pathways", "products"],
        ["names", "names", "numbers", "smpdb-ids", "names"],
    ):
        prefix = f"{key}."
        elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
        data[idx].update(
            {
                f"{prefix}{subkey}": build_string(
                    [
                        element.findtext(f"{DRUGBANK_NS}{strip_plural(subkey)}")
                        for element in elements
                    ],
                    sep=";;",
                )
            }
        )
    # Manufacturers of drugs, names only
    key = "manufacturers"
    prefix = f"{key}."
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    data[idx].update(
        {
            f"{prefix}{key}": build_string(
                [element.text for element in elements if has_value_type(element)],
                sep=";;",
            )
        }
    )
    # Prices of drugs elsewhere
    # Categories of drugs with general information
    # References are included with general
    # Therapeutic categories not included
    # Dosages of drugs elsewhere
    # ATC codes of drugs, codes only
    key = "atc-codes"
    prefix = f"{key}."
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    data[idx].update(
        {
            f"{prefix}{key}": build_string(
                [element.get("code") for element in elements], sep=";;"
            )
        }
    )

    # Drug interactions elsewhere
    # Structured Drug interactions and associated, not included.
    # Sequences
    key = "sequences"
    prefix = f"{key}."
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    data[idx].update(
        {
            f"{prefix}{key}": build_string(
                [element.text for element in elements if has_value_type(element)],
                sep=";;",
            )
        }
    )

    # Calculated and experimental properties
    for key in ["calculated-properties", "experimental-properties"]:
        prefix = f"{key}."
        properties = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}property")
        for property in properties:
            property_dict = dict(
                zip(
                    [strip_ns_DrugBank(sub.tag) for sub in property],
                    [sub.text for sub in property],
                )
            )
            kind = property_dict["kind"].replace(" ", "-").lower()
            if key == "calculated-properties":
                # Include source of calculation in header (ALOGPS, ChemAxon)
                kind = f"{kind}.{property_dict['source']}"
                data[idx].update({f"{prefix}{kind}": property_dict["value"]})
            else:
                # Include source of experimental measurement in data columns
                data[idx].update(
                    {
                        f"{prefix}{kind}": property_dict["value"],
                        f"{prefix}{kind}.source": property_dict["source"],
                    }
                )

    # External Identifiers, not included
    # External Links

    # Reactions are included elsewhere
    # SNP Effects and SNP Adverse Drug Reactions, combined
    # Only SNP dbID, elsewhere
    data[idx].update(
        {
            "snp.rs-ids": build_string(
                [
                    element.text
                    for key in ["snp-effects", "snp-adverse-drug-reactions"]
                    for element in drug.findall(
                        f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key.split('-')[-1])}/{DRUGBANK_NS}rs-id"
                    )
                    if has_value_type(element)
                ],
                sep=";;",
            )
        }
    )

    # References are included with general and elsewhere
    # Salt forms of drugs
    key = "salts"
    prefix = f"{key}."
    elements = drug.findall(
        f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}/{DRUGBANK_NS}drugbank-id[@primary='true']"
    )
    data[idx].update(
        {
            f"{prefix}drugbank-ids": build_string(
                [element.text for element in elements if has_value_type(element)],
                sep=";;",
            )
        }
    )

    # Targets / Enzymes / Carriers / Transporters, only drugbank bioentities IDs
    for key in ["targets", "enzymes", "carriers", "transporters"]:
        prefix = f"{key}."
        elements = drug.findall(
            f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}/{DRUGBANK_NS}id"
        )
        data[idx].update(
            {
                f"{prefix}ids": build_string(
                    [element.text for element in elements if has_value_type(element)],
                    sep=";;",
                )
            }
        )

    idx += 1


df_drugbank_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["general"] = df_drugbank_data
df_drugbank_data
# Out:
#      drugbank-id            type     created     updated               name  \
# 0        DB00006  small molecule  2005-06-13  2024-03-13        Bivalirudin
# 1        DB00027  small molecule  2005-06-13  2024-01-02       Gramicidin D
# 2        DB00030         biotech  2005-06-13  2024-03-13      Insulin human
# 3        DB00035  small molecule  2005-06-13  2024-03-13       Desmopressin
# 4        DB00041         biotech  2005-06-13  2024-03-13        Aldesleukin
# ...          ...             ...         ...         ...                ...
# 2435     DB16732         biotech  2021-09-21  2021-11-08  Tisotumab vedotin
# 2436     DB16826  small molecule  2022-07-15  2024-02-23      Repotrectinib
# 2437     DB17083  small molecule  2022-10-26  2022-12-13         Linzagolix
# 2438     DB17472  small molecule  2023-01-30  2023-12-07      Pirtobrutinib
# 2439     DB17635         biotech  2023-04-17  2024-02-27          Nedosiran
#
#                                             description    cas-number  \
# 0     Bivalirudin is a synthetic 20 residue peptide ...   128270-60-0
# 1     Gramcidin D is a heterogeneous mixture of thre...     1405-97-6
# 2     Human Insulin, also known as Regular Insulin, ...    11061-68-0
# 3     Desmopressin (dDAVP), a synthetic analogue of ...    16679-58-6
# 4     Aldesleukin, a lymphokine, is produced by reco...   110942-02-4
# ...                                                 ...           ...
# 2435  Tisotumab vedotin is a tissue factor-directed ...  1418731-10-8
# 2436  Repotrectinib is a next-generation tyrosine ki...  1802220-02-5
# 2437  Linzagolix is a non-peptide, selective antagon...   935283-04-8
# 2438  Pirtobrutinib is a small molecule and a highly...  2101700-15-4
# 2439  Nedosiran is an RNA interference targeting hep...  2266591-83-5
#
#             unii average-mass monoisotopic-mass  ...  \
# 0     TN9BEX005G    2180.2853    2178.985813062  ...
# 1     5IE62321P4     1811.253    1810.033419343  ...
# 2     1Y17CTI5SR                                 ...
# 3     ENR1LLB0FP      1069.22    1068.426955905  ...
# 4     M89N0Q7EQR                                 ...
# ...          ...          ...               ...  ...
# 2435  T41737F88A                                 ...
# 2436  08O3FQ4UNP      355.373     355.144453003  ...
# 2437  7CDW97HUEX       508.42     508.055206494  ...
# 2438  JNA39I7ZVB      479.436     479.158052208  ...
# 2439  13U9R5J3WL                                 ...
#
#      experimental-properties.logp experimental-properties.logp.source  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.caco2-permeability  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.caco2-permeability.source  \
# 0
# 1
# 2
# 3
# 4
# ...                                                ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.pka experimental-properties.pka.source  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                                ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.logs experimental-properties.logs.source  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.radioactivity  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.radioactivity.source
# 0
# 1
# 2
# 3
# 4
# ...                                           ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
# [2440 rows x 104 columns]

# %%
for c in df_drugbank_data.columns:
    print(c)
# Out:
# drugbank-id
# type
# created
# updated
# name
# description
# cas-number
# unii
# average-mass
# monoisotopic-mass
# state
# groups
# categories.category
# categories.mesh-id
# affected-organisms
# ahfs-codes
# pdb-entries
# fda-label
# food-interactions
# general-references.ref-id
# synthesis-reference
# classification.kingdom
# classification.superclass
# classification.direct-parent
# classification.substituent
# classification.description
# classification.alternative-parent
# pharmacology.indication
# pharmacology.pharmacodynamics
# pharmacology.mechanism-of-action
# pharmacology.toxicity
# pharmacology.metabolism
# pharmacology.absorption
# pharmacology.half-life
# pharmacology.protein-binding
# pharmacology.route-of-elimination
# pharmacology.volume-of-distribution
# pharmacology.clearance
# mixtures.names
# packagers.names
# patents.numbers
# pathways.smpdb-ids
# products.names
# manufacturers.manufacturers
# atc-codes.atc-codes
# sequences.sequences
# calculated-properties.logp.ALOGPS
# calculated-properties.logs.ALOGPS
# calculated-properties.water-solubility.ALOGPS
# calculated-properties.logp.ChemAxon
# calculated-properties.iupac-name.ChemAxon
# calculated-properties.traditional-iupac-name.ChemAxon
# calculated-properties.molecular-weight.ChemAxon
# calculated-properties.monoisotopic-weight.ChemAxon
# calculated-properties.smiles.ChemAxon
# calculated-properties.molecular-formula.ChemAxon
# calculated-properties.inchi.ChemAxon
# calculated-properties.inchikey.ChemAxon
# calculated-properties.polar-surface-area-(psa).ChemAxon
# calculated-properties.refractivity.ChemAxon
# calculated-properties.polarizability.ChemAxon
# calculated-properties.rotatable-bond-count.ChemAxon
# calculated-properties.h-bond-acceptor-count.ChemAxon
# calculated-properties.h-bond-donor-count.ChemAxon
# calculated-properties.pka-(strongest-acidic).ChemAxon
# calculated-properties.pka-(strongest-basic).ChemAxon
# calculated-properties.physiological-charge.ChemAxon
# calculated-properties.number-of-rings.ChemAxon
# calculated-properties.bioavailability.ChemAxon
# calculated-properties.rule-of-five.ChemAxon
# calculated-properties.ghose-filter.ChemAxon
# calculated-properties.mddr-like-rule.ChemAxon
# snp.rs-ids
# salts.drugbank-ids
# targets.ids
# enzymes.ids
# carriers.ids
# transporters.ids
# msds
# experimental-properties.melting-point
# experimental-properties.melting-point.source
# classification.subclass
# experimental-properties.molecular-weight
# experimental-properties.molecular-weight.source
# experimental-properties.molecular-formula
# experimental-properties.molecular-formula.source
# experimental-properties.hydrophobicity
# experimental-properties.hydrophobicity.source
# experimental-properties.isoelectric-point
# experimental-properties.isoelectric-point.source
# experimental-properties.water-solubility
# experimental-properties.water-solubility.source
# experimental-properties.boiling-point
# experimental-properties.boiling-point.source
# experimental-properties.logp
# experimental-properties.logp.source
# experimental-properties.caco2-permeability
# experimental-properties.caco2-permeability.source
# experimental-properties.pka
# experimental-properties.pka.source
# experimental-properties.logs
# experimental-properties.logs.source
# experimental-properties.radioactivity
# experimental-properties.radioactivity.source

# %% [markdown]
# ### Extract property information

# %%
df_properties = df_drugbank_data.loc[
    :,
    ["drugbank-id"]
    + [
        c
        for c in df_drugbank_data.columns
        if c.startswith("calculated-properties")
        or c.startswith("experimental-properties")
    ],
]
df_properties
# Out:
#      drugbank-id calculated-properties.logp.ALOGPS  \
# 0        DB00006                             -0.76
# 1        DB00027                              4.38
# 2        DB00030
# 3        DB00035                                -1
# 4        DB00041
# ...          ...                               ...
# 2435     DB16732
# 2436     DB16826                              2.33
# 2437     DB17083                               3.2
# 2438     DB17472                              3.17
# 2439     DB17635
#
#      calculated-properties.logs.ALOGPS  \
# 0                                 -4.7
# 1                                 -5.7
# 2
# 3                                   -4
# 4
# ...                                ...
# 2435
# 2436                              -3.8
# 2437                              -5.4
# 2438                              -5.1
# 2439
#
#      calculated-properties.water-solubility.ALOGPS  \
# 0                                     4.64e-02 g/l
# 1                                     3.90e-03 g/l
# 2
# 3                                     1.10e-01 g/l
# 4
# ...                                            ...
# 2435
# 2436                                  4.98e-02 g/l
# 2437                                  1.98e-03 g/l
# 2438                                  3.84e-03 g/l
# 2439
#
#      calculated-properties.logp.ChemAxon  \
# 0                                    -14
# 1                                   5.96
# 2
# 3                                   -6.1
# 4
# ...                                  ...
# 2435
# 2436                                2.17
# 2437                                3.88
# 2438                                3.35
# 2439
#
#               calculated-properties.iupac-name.ChemAxon  \
# 0     (4S)-4-[(2S)-2-[(2S)-2-[(2S)-2-{2-[(2S)-2-(2-{...
# 1     (2R)-N-[(1S)-1-{[(1R)-1-{[(1S)-1-{[(1R)-1-{[(1...
# 2
# 3     (2R)-2-{[(2S)-1-[(4R,7S,10S,13S,16S)-13-benzyl...
# 4
# ...                                                 ...
# 2435
# 2436  (3R,11S)-6-fluoro-3,11-dimethyl-10-oxa-2,13,17...
# 2437  3-{5-[(2,3-difluoro-6-methoxyphenyl)methoxy]-2...
# 2438  5-amino-3-(4-{[(5-fluoro-2-methoxyphenyl)forma...
# 2439
#
#      calculated-properties.traditional-iupac-name.ChemAxon  \
# 0                                           bivalirudin
# 1     (2R)-N-[(1S)-1-{[(1R)-1-{[(1S)-1-{[(1R)-1-{[(1...
# 2
# 3                                           tigecycline
# 4
# ...                                                 ...
# 2435
# 2436  5-{[6-(1-cyclopropylpyrazol-4-yl)-[1,2,4]triaz...
# 2437                                         linzagolix
# 2438  6-{[6-(4-aminobenzenesulfonamido)pyridin-3-yl]...
# 2439
#
#      calculated-properties.molecular-weight.ChemAxon  \
# 0                                          2180.2853
# 1                                           1811.253
# 2
# 3                                            1069.22
# 4
# ...                                              ...
# 2435
# 2436                                         355.373
# 2437                                          508.42
# 2438                                         479.436
# 2439
#
#      calculated-properties.monoisotopic-weight.ChemAxon  \
# 0                                        2178.985813062
# 1                                        1810.033419343
# 2
# 3                                        1068.426955905
# 4
# ...                                                 ...
# 2435
# 2436                                      355.144453003
# 2437                                      508.055206494
# 2438                                      479.158052208
# 2439
#
#                   calculated-properties.smiles.ChemAxon  ...  \
# 0     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...  ...
# 1     CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(...  ...
# 2                                                        ...
# 3     NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...  ...
# 4                                                        ...
# ...                                                 ...  ...
# 2435                                                     ...
# 2436  C[C@H]1CNC(=O)C2=C3N=C(N[C@H](C)C4=CC(F)=CC=C4...  ...
# 2437  COC1=C(COC2=C(OC)C=C(F)C(=C2)N2C(=O)NC3=CSC(C(...  ...
# 2438  COC1=C(C=C(F)C=C1)C(=O)NCC1=CC=C(C=C1)C1=NN([C...  ...
# 2439                                                     ...
#
#      experimental-properties.logp experimental-properties.logp.source  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.caco2-permeability  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.caco2-permeability.source  \
# 0
# 1
# 2
# 3
# 4
# ...                                                ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.pka experimental-properties.pka.source  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                                ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.logs experimental-properties.logs.source  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.radioactivity  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.radioactivity.source
# 0
# 1
# 2
# 3
# 4
# ...                                           ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
# [2440 rows x 51 columns]

# %% [markdown]
# ### Extract classification information

# %%
df_drugbank_classification_data = df_drugbank_data.loc[
    :,
    ["drugbank-id"]
    + [f"classification.{subkey}" for subkey in DRUGBANK_CLASSIFICATION_ELEMENTS],
]
df_drugbank_classification_data
# Out:
#      drugbank-id classification.kingdom classification.superclass  \
# 0        DB00006      Organic compounds          Organic Polymers
# 1        DB00027      Organic compounds          Organic Polymers
# 2        DB00030      Organic Compounds             Organic Acids
# 3        DB00035
# 4        DB00041      Organic Compounds             Organic Acids
# ...          ...                    ...                       ...
# 2435     DB16732      Organic Compounds             Organic Acids
# 2436     DB16826
# 2437     DB17083
# 2438     DB17472
# 2439     DB17635
#
#      classification.direct-parent               classification.subclass  \
# 0                    Polypeptides
# 1                    Polypeptides
# 2                        Peptides  Amino Acids, Peptides, and Analogues
# 3
# 4                        Peptides  Amino Acids, Peptides, and Analogues
# ...                           ...                                   ...
# 2435                     Peptides  Amino Acids, Peptides, and Analogues
# 2436
# 2437
# 2438
# 2439
#
#                classification.substituent  \
# 0     1-hydroxy-2-unsubstituted benzenoid
# 1                           3-alkylindole
# 2
# 3
# 4
# ...                                   ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#                              classification.description  \
# 0     This compound belongs to the class of organic ...
# 1     This compound belongs to the class of organic ...
# 2
# 3
# 4
# ...                                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#          classification.alternative-parent
# 0     1-hydroxy-2-unsubstituted benzenoids
# 1                           3-alkylindoles
# 2
# 3
# 4
# ...                                    ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
# [2440 rows x 8 columns]

# %% [markdown]
# ### Extract synonyms and other aliases
# #### Synonyms

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "synonyms"
    prefix = f"{key}." if prefix else ""
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    for element in elements:
        if has_value_type(element):
            data[idx].update({"drugbank-id": drugbank_id})
            data[idx].update({f"{prefix}{key}": element.text})
            data[idx].update(
                {
                    f"{prefix}{attr}": element.get(attr)
                    for attr in ["language", "coder"]
                    if element.get(attr)
                }
            )
            idx += 1

df_drugbank_synonym_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)

df_drugbank_synonym_data
# Out:
#      drugbank-id                                  synonyms.synonyms  \
# 0        DB00006                                        Bivalirudin
# 1        DB00006                                       Bivalirudina
# 2        DB00006                                      Bivalirudinum
# 3        DB00027                       Bacillus brevis gramicidin D
# 4        DB00027                                         Gramicidin
# ...          ...                                                ...
# 7817     DB17472  (s)-5-amino-3-(4-((5-fluoro-2-methoxybenzamido...
# 7818     DB17472  1h-pyrazole-4-carboxamide, 5-amino-3-(4-(((5-f...
# 7819     DB17472  5-amino-3-(4-((5-fluoro-2-methoxybenzamido)met...
# 7820     DB17635                                 DCR-PHXC free acid
# 7821     DB17635                                          Nedosiran
#
#      synonyms.language synonyms.coder
# 0              english       inn/usan
# 1              spanish
# 2                latin
# 3              english
# 4              english
# ...                ...            ...
# 7817           english
# 7818           english
# 7819           english
# 7820           english
# 7821           english       inn/usan
#
# [7822 rows x 4 columns]

# %% [markdown]
# #### International brands
#
# The proprietary names used by the manufacturers for commercially available forms of the drug, focusing on brand names for products that are available in countries other than Canada and the Unites States.

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "international-brands"
    prefix = f"{key}." if prefix else ""
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    for element in elements:
        data[idx].update(
            {"drugbank-id": drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")}
        )
        for subkey in ["name", "company"]:
            data[idx].update(
                {f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}")}
            )
        idx += 1

df_drugbank_intbrand_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
df_drugbank_intbrand_data
# Out:
#      drugbank-id international-brands.name  \
# 0        DB00006                    Angiox
# 1        DB00006                   Hirulog
# 2        DB00027                  Sofradex
# 3        DB00035                 Adiuretin
# 4        DB00035                 DesmoMelt
# ...          ...                       ...
# 3964     DB16390                  Exkivity
# 3965     DB16627                   Pepaxto
# 3966     DB16703                  Rezurock
# 3967     DB16732                    Tivdak
# 3968     DB17472                  Jaypirca
#
#                international-brands.company
# 0
# 1
# 2                                    Sanofi
# 3                                   Ferring
# 4                                   Ferring
# ...                                     ...
# 3964  Takeda Pharmaceutical Company Limited
# 3965                        Oncopeptides AB
# 3966                  Kadmon Holdings, Inc.
# 3967             Seagen Inc. and Genmab A/S
# 3968                              Eli Lilly
#
# [3969 rows x 3 columns]

# %% [markdown]
# ### Extract salts information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "salts"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        data[idx].update(
            {
                f"{prefix}drugbank-id": element.findtext(
                    f"{DRUGBANK_NS}drugbank-id[@primary='true']"
                )
            }
        )
        for subkey in DRUGBANK_SALTS_ELEMENTS:
            if subkey == "drugbank-id":
                continue
            subelement = element.find(f"{DRUGBANK_NS}{subkey}")
            if subelement is not None and has_value_type(subelement):
                data[idx].update(
                    {f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}")}
                )

        idx += 1

df_drugbank_salts_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["salts"] = df_drugbank_salts_data
df_drugbank_salts_data
# Out:
#     drugbank-id salts.drugbank-id                                 salts.name  \
# 0       DB00030      DBSALT001733              Insulin human zinc suspension
# 1       DB00030      DBSALT001734                                NPH insulin
# 2       DB00035      DBSALT001154                       Desmopressin acetate
# 3       DB00035      DBSALT000044             Desmopressin acetate anhydrous
# 4       DB00071      DBSALT001735  Insulin suspension isophane purified pork
# ..          ...               ...                                        ...
# 925     DB16656      DBSALT003170                       Zotiraciclib citrate
# 926     DB16703      DBSALT003188                       Belumosudil mesylate
# 927     DB16703      DBSALT003189               Belumosudil trifluoroacetate
# 928     DB17083      DBSALT003262                         Linzagolix choline
# 929     DB17635      DBSALT003470                           Nedosiran sodium
#
#     salts.cas-number  salts.unii               salts.inchikey  \
# 0
# 1         53027-39-7
# 2         62357-86-2  XB13HYU18U  YNKFCNRZZPFMEX-XHPDKPNGSA-N
# 3         62288-83-9  1K12647SFC  MLSVJHOYXJGGTR-IFHOVBQLSA-N
# 4
# ..               ...         ...                          ...
# 925     1204918-73-9  3VF50SU4RZ  NWYDRHSNEATNRI-SQQVDAMQSA-N
# 926     2109704-99-4  6MX7XE1M0U  BGNMZPDNJWWQCU-UHFFFAOYSA-N
# 927     1243152-02-4  LL4OG4RZ5D  PBWWPJDQYJXRII-UHFFFAOYSA-N
# 928     1321816-57-2  VHS6SC660Q  IAIVRTFCYOGNBW-UHFFFAOYSA-M
# 929                   EGR9KYM536
#
#     salts.average-mass salts.monoisotopic-mass
# 0
# 1
# 2              1183.32          1182.479779327
# 3             1129.269          1128.448084334
# 4
# ..                 ...                     ...
# 925            564.595           564.222014006
# 926             548.62             548.1841892
# 927            580.568           580.204587862
# 928             611.59           611.154920537
# 929
#
# [930 rows x 8 columns]

# %% [markdown]
# ### Extract mixtures information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "mixtures"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        for subkey in DRUGBANK_MIXTURES_ELEMENTS:
            subelement = element.find(f"{DRUGBANK_NS}{subkey}")
            if subelement is not None and has_value_type(subelement):
                data[idx].update({f"{prefix}{subkey}": subelement.text})

        idx += 1

df_drugbank_mixtures_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["mixtures"] = df_drugbank_mixtures_data
df_drugbank_mixtures_data
# Out:
#                                           mixtures.name  \
# 0      Neomycin and Polymyxin B Sulfates and Gramicidin
# 1                                             Neosporin
# 2                                              Neocidin
# 3                                Soframycin Nasal Spray
# 4                            Triple Antibiotic Ointment
# ...                                                 ...
# 18532                                           Augtyro
# 18533                                  KLH-2109 Choline
# 18534                                            Yselty
# 18535                                          Jaypirca
# 18536                                          Rivfloza
#
#                             mixtures.ingredients
# 0          Gramicidin D + Neomycin + Polymyxin B
# 1          Gramicidin D + Neomycin + Polymyxin B
# 2          Gramicidin D + Neomycin + Polymyxin B
# 3      Framycetin + Gramicidin D + Phenylephrine
# 4        Bacitracin + Gramicidin D + Polymyxin B
# ...                                          ...
# 18532                              Repotrectinib
# 18533                                 Linzagolix
# 18534                                 Linzagolix
# 18535                              Pirtobrutinib
# 18536                                  Nedosiran
#
# [18537 rows x 2 columns]

# %% [markdown]
# ### Extract manufacturers information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "manufacturers"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        if has_value_type(element):
            data[idx].update({"drugbank-id": drugbank_id})
            data[idx].update({f"{prefix}{strip_plural(key)}": element.text})
            data[idx].update({f"{prefix}generic": element.get("generic")})
            idx += 1


df_drugbank_manufacturers_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["manufacturers"] = df_drugbank_manufacturers_data
df_drugbank_manufacturers_data
# Out:
#      drugbank-id                         manufacturers.manufacturer  \
# 0        DB00006                                   The medicines co
# 1        DB00030                                   Novo nordisk inc
# 2        DB00035                              Sanofi aventis us llc
# 3        DB00035  Bedford laboratories div ben venue laboratorie...
# 4        DB00035                                        Hospira inc
# ...          ...                                                ...
# 3586     DB01021                             Par pharmaceutical inc
# 3587     DB01021                                         Sandoz inc
# 3588     DB01021                                 Tg united labs llc
# 3589     DB01021                            Watson laboratories inc
# 3590     DB05381                                   Eli lilly and co
#
#      manufacturers.generic
# 0                    false
# 1                    false
# 2                    false
# 3                     true
# 4                     true
# ...                    ...
# 3586                  true
# 3587                  true
# 3588                  true
# 3589                  true
# 3590                  true
#
# [3591 rows x 3 columns]

# %% [markdown]
# ### Extract prices information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "prices"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        data[idx].update(
            {
                f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}")
                for subkey in DRUGBANK_PRICE_ELEMENTS
            }
        )
        data[idx].update(
            {f"{prefix}currency": element.find(f"{DRUGBANK_NS}cost").get("currency")}
        )

        idx += 1

df_drugbank_prices_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["prices"] = df_drugbank_prices_data
df_drugbank_prices_data
# Out:
#      drugbank-id                  prices.description prices.cost prices.unit  \
# 0        DB00006                Angiomax 250 mg vial       780.0        vial
# 1        DB00027       Neosporin gu irr 40 mg/ml amp       23.12          ml
# 2        DB00027                 Gramicidin d powder       240.0           g
# 3        DB00027       Neosporin + pain relief cream        0.32           g
# 4        DB00030          Novolin Ge Nph 100 unit/ml        2.14   cartridge
# ...          ...                                 ...         ...         ...
# 7301     DB06151  Mucomyst-10 10% Solution 30ml Vial       25.99        vial
# 7302     DB06151        Acetylcysteine 20 % Solution        0.68          ml
# 7303     DB06151              Mucomyst 20 % Solution        0.75          ml
# 7304     DB06151          N-acetyl-l-cysteine powder        0.84           g
# 7305     DB06287                   Torisel 25 mg kit     1467.89          ml
#
#      prices.currency
# 0                USD
# 1                USD
# 2                USD
# 3                USD
# 4                USD
# ...              ...
# 7301             USD
# 7302             USD
# 7303             USD
# 7304             USD
# 7305             USD
#
# [7306 rows x 5 columns]

# %% [markdown]
# ### Extract dosage information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "dosages"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        data[idx].update(
            {
                f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}").lower()
                for subkey in DRUGBANK_DOSAGE_ELEMENTS
            }
        )
        idx += 1

df_drugbank_dosages_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["dosages"] = df_drugbank_dosages_data
df_drugbank_dosages_data
# Out:
#       drugbank-id                                  dosages.form  \
# 0         DB00006  injection, powder, lyophilized, for solution
# 1         DB00006                           injection, solution
# 2         DB00006  injection, powder, lyophilized, for solution
# 3         DB00006
# 4         DB00006               injection, powder, for solution
# ...           ...                                           ...
# 41294     DB17472                                tablet, coated
# 41295     DB17472                                tablet, coated
# 41296     DB17635                           injection, solution
# 41297     DB17635                           injection, solution
# 41298     DB17635                           injection, solution
#
#            dosages.route dosages.strength
# 0            intravenous         250 mg/1
# 1            intravenous         250 mg/1
# 2            intravenous           250 mg
# 3            intravenous           250 mg
# 4      intravenous bolus           250 mg
# ...                  ...              ...
# 41294               oral         100 mg/1
# 41295               oral          50 mg/1
# 41296       subcutaneous     128 mg/0.8ml
# 41297       subcutaneous       160 mg/1ml
# 41298       subcutaneous      80 mg/0.5ml
#
# [41299 rows x 4 columns]

# %% [markdown]
# ### Extract ATC codes information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "atc-codes"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        data[idx].update(
            {"drugbank-id": drugbank_id, f"{prefix}atc-code": element.get("code")}
        )
        data[idx].update({f"{prefix}description": drug.findtext(f"{DRUGBANK_NS}name")})
        data[idx].update({f"{prefix}code": element.get("code")})
        data[idx].update({f"{prefix}level": "substance"})
        idx += 1
        for level, subelement in zip(
            ["chemical", "pharmacological", "therapeutic", "anatomical"], list(element)
        ):
            data[idx].update(
                {"drugbank-id": drugbank_id, f"{prefix}atc-code": element.get("code")}
            )
            data[idx].update({f"{prefix}description": subelement.text})
            data[idx].update({f"{prefix}code": subelement.get("code")})
            data[idx].update({f"{prefix}level": level})
            idx += 1
df_atc_codes_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["atc-codes"] = df_atc_codes_data
df_atc_codes_data
# Out:
#       drugbank-id atc-codes.atc-code  \
# 0         DB00006            B01AE06
# 1         DB00006            B01AE06
# 2         DB00006            B01AE06
# 3         DB00006            B01AE06
# 4         DB00006            B01AE06
# ...           ...                ...
# 10405     DB17083            H01CC04
# 10406     DB17083            H01CC04
# 10407     DB17083            H01CC04
# 10408     DB17083            H01CC04
# 10409     DB17083            H01CC04
#
#                                    atc-codes.description atc-codes.code  \
# 0                                            Bivalirudin        B01AE06
# 1                             Direct thrombin inhibitors          B01AE
# 2                                  ANTITHROMBOTIC AGENTS           B01A
# 3                                  ANTITHROMBOTIC AGENTS            B01
# 4                         BLOOD AND BLOOD FORMING ORGANS              B
# ...                                                  ...            ...
# 10405                                         Linzagolix        H01CC04
# 10406               Anti-gonadotropin-releasing hormones          H01CC
# 10407                              HYPOTHALAMIC HORMONES           H01C
# 10408  PITUITARY AND HYPOTHALAMIC HORMONES AND ANALOGUES            H01
# 10409  SYSTEMIC HORMONAL PREPARATIONS, EXCL. SEX HORM...              H
#
#        atc-codes.level
# 0            substance
# 1             chemical
# 2      pharmacological
# 3          therapeutic
# 4           anatomical
# ...                ...
# 10405        substance
# 10406         chemical
# 10407  pharmacological
# 10408      therapeutic
# 10409       anatomical
#
# [10410 rows x 5 columns]

# %% [markdown]
# ### Extract patent information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "patents"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        data[idx].update(
            {
                f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}").lower()
                for subkey in DRUGBANK_PATENT_ELEMENTS
            }
        )

        idx += 1

df_drugbank_dosages_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["patents"] = df_drugbank_dosages_data
df_drugbank_dosages_data
# Out:
#      drugbank-id patents.number patents.country patents.approved  \
# 0        DB00006        5196404   united states       1993-03-23
# 1        DB00006        2065150          canada       1999-12-14
# 2        DB00006        7598343   united states       2009-10-06
# 3        DB00006        7582727   united states       2009-09-01
# 4        DB00030        re37872   united states       2002-10-08
# ...          ...            ...             ...              ...
# 6693     DB17635       11359203   united states       2015-10-09
# 6694     DB17635       11286488   united states       2018-10-12
# 6695     DB17635       10738311   united states       2020-08-11
# 6696     DB17635       11053502   united states       2021-07-06
# 6697     DB17635       10351854   united states       2019-07-16
#
#      patents.expires patents.pediatric-extension
# 0         2010-05-23                       false
# 1         2010-08-17                       false
# 2         2029-01-27                        true
# 3         2029-01-27                        true
# 4         2010-02-12                       false
# ...              ...                         ...
# 6693      2035-10-09                       false
# 6694      2038-10-12                       false
# 6695      2035-10-09                       false
# 6696      2035-10-29                       false
# 6697      2035-10-09                       false
#
# [6698 rows x 6 columns]

# %% [markdown]
# ### Extract drug interactions information
# Note: These are drug interactions based on the free version of drugbank, terminology kept seperate from the [Structured Drug Interactions](https://docs.drugbank.com/xml/#structured-drug-interactions) for DrugBank.

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "drug-interactions"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}." if prefix else ""
    for element in elements:
        data[idx].update(
            {"drugbank-id": drugbank_id, "name": drug.findtext(f"{DRUGBANK_NS}name")}
        )
        data[idx].update(
            {
                f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}")
                for subkey in ["drugbank-id", "name", "description"]
            }
        )
        idx += 1

df_drug_interactions = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)

# # Aggregate dataframe values
# df_drug_interactions["drug-interactions.drugbank-ids"] = df_drug_interactions[["drugbank-id", "drug-interactions.drugbank-id"]].agg(
#     lambda x: build_string(x, sep=";;"),
#     axis=1
# )
# df_drug_interactions["drug-interactions.names"] = df_drug_interactions[["name", "drug-interactions.name"]].agg(
#     lambda x: build_string(x, sep=";;"),
#     axis=1
# )
# df_drug_interactions = df_drug_interactions.loc[:, [
#     "drugbank-id",
#     "drug-interactions.drugbank-ids",
#     "drug-interactions.names",
#     "drug-interactions.description"
# ]]

# dataframes["interactions"] = df_drug_interactions
df_drug_interactions
# Out:
#         drugbank-id           name drug-interactions.drugbank-id  \
# 0           DB00006    Bivalirudin                       DB06605
# 1           DB00006    Bivalirudin                       DB06695
# 2           DB00006    Bivalirudin                       DB01254
# 3           DB00006    Bivalirudin                       DB01609
# 4           DB00006    Bivalirudin                       DB01586
# ...             ...            ...                           ...
# 1082615     DB17472  Pirtobrutinib                       DB11718
# 1082616     DB17472  Pirtobrutinib                       DB11679
# 1082617     DB17472  Pirtobrutinib                       DB12005
# 1082618     DB17472  Pirtobrutinib                       DB18705
# 1082619     DB17472  Pirtobrutinib                       DB16200
#
#                                     drug-interactions.name  \
# 0                                                 Apixaban
# 1                                     Dabigatran etexilate
# 2                                                Dasatinib
# 3                                              Deferasirox
# 4                                     Ursodeoxycholic acid
# ...                                                    ...
# 1082615                                        Encorafenib
# 1082616                                       Fruquintinib
# 1082617                                       Nirogacestat
# 1082618  SARS-CoV-2 virus recombinant spike (S) protein...
# 1082619                                          Iptacopan
#
#                              drug-interactions.description
# 0        Apixaban may increase the anticoagulant activi...
# 1        Dabigatran etexilate may increase the anticoag...
# 2        The risk or severity of bleeding and hemorrhag...
# 3        The risk or severity of gastrointestinal bleed...
# 4        The risk or severity of bleeding and bruising ...
# ...                                                    ...
# 1082615  The serum concentration of Encorafenib can be ...
# 1082616  The metabolism of Fruquintinib can be decrease...
# 1082617  The serum concentration of Nirogacestat can be...
# 1082618  The therapeutic efficacy of SARS-CoV-2 virus r...
# 1082619  The metabolism of Iptacopan can be decreased w...
#
# [1082620 rows x 5 columns]

# %% [markdown]
# ### Extract pathway information

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "pathways"
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    prefix = f"{key}."
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        for subkey in DRUGBANK_PATHWAY_ELEMENTS:
            if subkey in {"smpdb-id", "name", "category"}:
                data[idx].update(
                    {f"{prefix}{subkey}": element.findtext(f"{DRUGBANK_NS}{subkey}")}
                )
            elif subkey == "drugs":
                # All drugbank IDs in this field will be redundant
                # as long as they also appear in the original drugbank ID column
                continue
            else:
                data[idx].update(
                    {
                        f"{prefix}uniprot-id": build_string(
                            [
                                subelem.text
                                for subelem in element.findall(
                                    f"{DRUGBANK_NS}{subkey}/{DRUGBANK_NS}uniprot-id"
                                )
                            ],
                            sep=";;",
                        )
                    }
                )

        idx += 1

df_pathways_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["pathways"] = df_pathways_data
df_pathways_data
# Out:
#      drugbank-id pathways.smpdb-id  \
# 0        DB00006        SMP0000277
# 1        DB00086        SMP0000282
# 2        DB00114        SMP0000002
# 3        DB00114        SMP0000003
# 4        DB00114        SMP0000004
# ...          ...               ...
# 2635     DB08833        SMP0000318
# 2636     DB08836        SMP0000732
# 2637     DB08836        SMP0000733
# 2638     DB08901        SMP0031700
# 2639     DB11591        SMP0060170
#
#                                        pathways.name pathways.category  \
# 0                         Bivalirudin Action Pathway       drug_action
# 1                       Streptokinase Action Pathway       drug_action
# 2          Carbamoyl Phosphate Synthetase Deficiency           disease
# 3                          Argininosuccinic Aciduria           disease
# 4                      Glycine and Serine Metabolism         metabolic
# ...                                              ...               ...
# 2635  Congenital Bile Acid Synthesis Defect Type III           disease
# 2636                   Temocapril Metabolism Pathway   drug_metabolism
# 2637                       Temocapril Action Pathway       drug_action
# 2638                 Ponatinib Inhibition of BCR-ABL       drug_action
# 2639               Bilastine H1-Antihistamine Action       drug_action
#
#                                     pathways.uniprot-id
# 0     P00734;;P00748;;P02452;;P03952;;P03951;;P00740...
# 1     P00747;;P00748;;P02452;;P03952;;P03951;;P00740...
# 2     Q15758;;P43007;;P24298;;Q9UI32;;P00367;;P31327...
# 3     Q15758;;P43007;;P24298;;Q9UI32;;P00367;;P31327...
# 4     P21397;;P05091;;O75600;;Q9UI17;;Q9UL12;;P23378...
# ...                                                 ...
# 2635  P17516;;P51857;;Q02318;;Q9Y2P5;;Q9UHK6;;Q99424...
# 2636                                             P12821
# 2637                     P12821;;P00797;;P01019;;P30556
# 2638  A8E194;;P62993;;Q9UQC2;;Q07889;;P46108;;P46109...
# 2639  Q9NQ66;;P62873;;P59768;;P35367;;P50148;;Q14643...
#
# [2640 rows x 5 columns]

# %% [markdown]
# ### Extract reactions

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "reactions"
    prefix = f"{key}."
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    for element in elements:
        key = "enzymes"
        for subelement in element.findall(
            f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}"
        ):
            data[idx].update({"drugbank-id": drugbank_id})
            data[idx].update(
                {
                    f"{prefix}{subkey}": element.findtext(
                        f"{DRUGBANK_NS}{subkey}/{DRUGBANK_NS}drugbank-id"
                    )
                    for subkey in ["left-element", "right-element"]
                }
            )
            data[idx].update(
                {
                    f"{prefix}{key}.{strip_ns_DrugBank(subelem.tag)}": subelem.text
                    for subelem in subelement
                    if has_value_type(subelem)
                }
            )
            idx += 1

df_reactions_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["reactions"] = df_reactions_data
df_reactions_data
# Out:
#      drugbank-id reactions.left-element reactions.right-element  \
# 0        DB00091                DB00091              DBMET02955
# 1        DB00091                DB00091              DBMET02955
# 2        DB00091                DB00091              DBMET02217
# 3        DB00091                DB00091              DBMET02217
# 4        DB00091                DB00091              DBMET00359
# ...          ...                    ...                     ...
# 2555     DB16650                DB16650              DBMET03545
# 2556     DB16650                DB16650              DBMET03546
# 2557     DB16650                DB16650              DBMET03546
# 2558     DB16650                DB16650              DBMET03547
# 2559     DB16650                DB16650              DBMET03548
#
#      reactions.enzymes.drugbank-id           reactions.enzymes.name  \
# 0                        BE0002638              Cytochrome P450 3A4
# 1                        BE0002362              Cytochrome P450 3A5
# 2                        BE0002638              Cytochrome P450 3A4
# 3                        BE0002362              Cytochrome P450 3A5
# 4                        BE0002638              Cytochrome P450 3A4
# ...                            ...                              ...
# 2555                     BE0002433              Cytochrome P450 1A2
# 2556                     BE0003549              Cytochrome P450 2B6
# 2557                     BE0002363              Cytochrome P450 2D6
# 2558                     BE0004712                 Cocaine esterase
# 2559                     BE0003541  UDP-glucuronosyltransferase 1-1
#
#      reactions.enzymes.uniprot-id
# 0                          P08684
# 1                          P20815
# 2                          P08684
# 3                          P20815
# 4                          P08684
# ...                           ...
# 2555                       P05177
# 2556                       P20813
# 2557                       P10635
# 2558                       O00748
# 2559                       P22309
#
# [2560 rows x 6 columns]

# %% [markdown]
# ### Extract SNPs

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    prefix = f"snp."
    for key in ["snp-effects", "snp-adverse-drug-reactions"]:
        elements = drug.findall(
            f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key.split('-')[-1])}"
        )
        for element in elements:
            data[idx].update({"drugbank-id": drugbank_id})
            data[idx].update(
                {
                    f"{prefix}{strip_ns_DrugBank(subelement.tag)}": subelement.text
                    for subelement in element
                    if has_value_type(subelement)
                }
            )
            idx += 1
df_snp_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["snp"] = df_snp_data
df_snp_data
# Out:
#     drugbank-id                                 snp.protein-name  \
# 0       DB00175                        Kinesin-like protein KIF6
# 1       DB00175  3-hydroxy-3-methylglutaryl-coenzyme A reductase
# 2       DB00176                              Cytochrome P450 2D6
# 3       DB00176                              Cytochrome P450 2D6
# 4       DB00176                              Cytochrome P450 2D6
# ..          ...                                              ...
# 246     DB08916                 Epidermal growth factor receptor
# 247     DB08916                 Epidermal growth factor receptor
# 248     DB08930                  UDP-glucuronosyltransferase 1-1
# 249     DB08930                  UDP-glucuronosyltransferase 1-1
# 250     DB08930                  UDP-glucuronosyltransferase 1-1
#
#     snp.gene-symbol snp.uniprot-id    snp.rs-id   snp.defining-change  \
# 0              KIF6         Q6ZMV9      rs20455              C Allele
# 1             HMGCR         P04035   rs17244841              T Allele
# 2            CYP2D6         P10635   rs35742686              2549delA
# 3            CYP2D6         P10635    rs3892097              A allele
# 4            CYP2D6         P10635                Whole-gene deletion
# ..              ...            ...          ...                   ...
# 246            EGFR         P00533  rs121434568                 T > G
# 247            EGFR         P00533   rs28929495       G > A or C or T
# 248          UGT1A1         P22309    rs8175347  extra TA in promoter
# 249          UGT1A1         P22309    rs4148323                 G > A
# 250          UGT1A1         P22309    rs8175347     TA pair insertion
#
#                                        snp.description snp.pubmed-id  \
# 0    Patients with this genotype have a greater red...      18222353
# 1    Patients with this genotype have a lesser redu...      15199031
# 2    The presence of this polymorphism in CYP2D6 is...      25974703
# 3    The presence of this polymorphism in CYP2D6 is...      25974703
# 4    The presence of this polymorphism in CYP2D6 is...      25974703
# ..                                                 ...           ...
# 246  The presence of this polymorphism in EGFR is a...      15118073
# 247  The presence of this polymorphism in EGFR is a...      15118073
# 248                             Poor drug metabolizer.      24329186
# 249  The presence of this polymorphism in UGT1A1 is...      24329186
# 250  The presence of this polymorphism in UGT1A1 is...      24329186
#
#                  snp.allele snp.adverse-reaction
# 0
# 1
# 2                  CYP2D6*3
# 3                  CYP2D6*4
# 4                  CYP2D6*5
# ..                      ...                  ...
# 246                   L858R
# 247                 G719A/C
# 248  UGT1A1*28 or UGT1A 7/7
# 249                UGT1A1*6
# 250               UGT1A1*37
#
# [251 rows x 10 columns]

# %% [markdown]
# ### Extract products
#
# A list of commercially available products in Canada and the United States that contain the drug.

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    key = "products"
    prefix = f"{key}."
    elements = drug.findall(f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}")
    for element in elements:
        data[idx].update({"drugbank-id": drugbank_id})
        data[idx].update(
            {
                f"{prefix}{strip_ns_DrugBank(subelement.tag)}": subelement.text
                for subelement in element
                if has_value_type(subelement)
            }
        )
        idx += 1

df_products_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["products"] = df_products_data
df_products_data
# Out:
#        drugbank-id products.name           products.labeller  \
# 0          DB00006      Angiomax             Cardinal Health
# 1          DB00006      Angiomax       The Medicines Company
# 2          DB00006      Angiomax                  Sandoz Inc
# 3          DB00006      Angiomax  Sandoz Canada Incorporated
# 4          DB00006  Angiomax RTU  MAIA Pharmaceuticals, Inc.
# ...            ...           ...                         ...
# 204657     DB17472      Jaypirca       Eli Lilly and Company
# 204658     DB17472      Jaypirca       Eli Lilly and Company
# 204659     DB17635      Rivfloza                Novo Nordisk
# 204660     DB17635      Rivfloza                Novo Nordisk
# 204661     DB17635      Rivfloza                Novo Nordisk
#
#        products.ndc-product-code products.started-marketing-on  \
# 0                     55154-2275                    2000-12-15
# 1                      65293-001                    2000-12-15
# 2                      0781-3447                    2019-08-01
# 3                                                   2003-05-08
# 4                      70511-141                    2019-08-08
# ...                          ...                           ...
# 204657                 0002-6902                    2023-01-27
# 204658                 0002-7026                    2023-01-27
# 204659                 0169-5306                    2024-02-19
# 204660                 0169-5307                    2024-02-19
# 204661                 0169-5308                    2024-02-19
#
#        products.ended-marketing-on  \
# 0                       2014-04-30
# 1
# 2
# 3
# 4
# ...                            ...
# 204657
# 204658
# 204659
# 204660
# 204661
#
#                                 products.dosage-form products.strength  \
# 0       Injection, powder, lyophilized, for solution          250 mg/1
# 1       Injection, powder, lyophilized, for solution          250 mg/1
# 2                                          Injection          250 mg/1
# 3                               Powder, for solution     250 mg / vial
# 4                                Injection, solution          250 mg/1
# ...                                              ...               ...
# 204657                                Tablet, coated           50 mg/1
# 204658                                Tablet, coated          100 mg/1
# 204659                           Injection, solution        160 mg/1mL
# 204660                           Injection, solution      128 mg/0.8mL
# 204661                           Injection, solution       80 mg/0.5mL
#
#        products.route products.fda-application-number products.generic  \
# 0         Intravenous                       NDA020873            false
# 1         Intravenous                       NDA020873            false
# 2         Intravenous                       NDA020873            false
# 3         Intravenous                                            false
# 4         Intravenous                       NDA211215            false
# ...               ...                             ...              ...
# 204657           Oral                       NDA216059            false
# 204658           Oral                       NDA216059            false
# 204659   Subcutaneous                       NDA215842            false
# 204660   Subcutaneous                       NDA215842            false
# 204661   Subcutaneous                       NDA215842            false
#
#        products.over-the-counter products.approved products.country  \
# 0                          false              true               US
# 1                          false              true               US
# 2                          false              true               US
# 3                          false              true           Canada
# 4                          false              true               US
# ...                          ...               ...              ...
# 204657                     false              true               US
# 204658                     false              true               US
# 204659                     false              true               US
# 204660                     false              true               US
# 204661                     false              true               US
#
#        products.source products.dpd-id products.ema-product-code  \
# 0              FDA NDC
# 1              FDA NDC
# 2              FDA NDC
# 3                  DPD        02246533
# 4              FDA NDC
# ...                ...             ...                       ...
# 204657         FDA NDC
# 204658         FDA NDC
# 204659         FDA NDC
# 204660         FDA NDC
# 204661         FDA NDC
#
#        products.ema-ma-number
# 0
# 1
# 2
# 3
# 4
# ...                       ...
# 204657
# 204658
# 204659
# 204660
# 204661
#
# [204662 rows x 18 columns]

# %% [markdown]
# ### Extract proteins

# %%
idx = 0
data = defaultdict(dict)
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # Get only drugbank IDs specified
    if drugbank_ids and drugbank_id not in drugbank_ids:
        continue
    prefix = f"proteins."
    for ptype in ["targets", "enzymes", "carriers", "transporters"]:
        elements = drug.findall(
            f"{DRUGBANK_NS}{ptype}/{DRUGBANK_NS}{strip_plural(ptype)}"
        )
        for element in elements:
            for subelement in element.findall(f"{DRUGBANK_NS}polypeptide"):
                data[idx].update({f"drugbank-id": drugbank_id, f"{prefix}type": ptype})
                data[idx].update(
                    {
                        f"{prefix}{strip_ns_DrugBank(subelement.tag)}": subelement.text
                        for subelement in element
                        if has_value_type(subelement)
                    }
                )
                key = "actions"
                data[idx].update(
                    {
                        f"{prefix}{key}": build_string(
                            [
                                subelement.text
                                for subelement in element.findall(
                                    f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}"
                                )
                                if has_value_type(subelement)
                            ],
                            sep=";;",
                        )
                    }
                )
                key = "references"
                # For main dataframe, group all references and use the unique ID from DrugBank
                elements = [
                    element.find(f"{DRUGBANK_NS}ref-id")
                    for subkey in ["articles", "textbooks", "links", "attachments"]
                    for element in drug.findall(
                        f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{subkey}/{DRUGBANK_NS}{strip_plural(subkey)}"
                    )
                ]
                data[idx].update(
                    {
                        f"{prefix}ref-id": build_string(
                            [
                                element.text
                                for element in elements
                                if has_value_type(element)
                            ],
                            sep=";;",
                        )
                    }
                )

                # Polypeptide
                key = "polypeptide"
                data[idx].update(
                    {
                        f"{prefix}{key}.uniprot-id": subelement.get("id"),
                        f"{prefix}{key}.source": subelement.get("source"),
                    }
                )
                data[idx].update(
                    {
                        f"{prefix}{key}.{strip_ns_DrugBank(subelem.tag)}": subelem.text
                        for subelem in subelement
                        if has_value_type(subelem)
                    }
                )
                subkey = "pfams"
                data[idx].update(
                    {
                        f"{prefix}{key}.{subkey}": build_string(
                            [
                                subelem.text
                                for subelem in subelement.findall(
                                    f"{DRUGBANK_NS}{subkey}/{DRUGBANK_NS}{strip_plural(subkey)}/{DRUGBANK_NS}identifier"
                                )
                                if has_value_type(subelem)
                            ]
                        )
                    }
                )

                idx += 1

df_proteins_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .fillna("")
    .drop_duplicates()
    .reset_index(drop=True)
)
dataframes["proteins"] = df_proteins_data
df_proteins_data
# Out:
#       drugbank-id proteins.type proteins.id  \
# 0         DB00006       targets   BE0000048
# 1         DB00006       enzymes   BE0001075
# 2         DB00027  transporters   BE0001032
# 3         DB00030       targets   BE0000033
# 4         DB00030       targets   BE0000858
# ...           ...           ...         ...
# 19124     DB17472       enzymes   BE0002363
# 19125     DB17472       enzymes   BE0002362
# 19126     DB17472  transporters   BE0001032
# 19127     DB17472  transporters   BE0001067
# 19128     DB17635       targets   BE0000425
#
#                                     proteins.name proteins.organism  \
# 0                                     Prothrombin            Humans
# 1                                 Myeloperoxidase            Humans
# 2                                P-glycoprotein 1            Humans
# 3                                Insulin receptor            Humans
# 4           Insulin-like growth factor 1 receptor            Humans
# ...                                           ...               ...
# 19124                         Cytochrome P450 2D6            Humans
# 19125                         Cytochrome P450 3A5            Humans
# 19126                            P-glycoprotein 1            Humans
# 19127  ATP-binding cassette sub-family G member 2            Humans
# 19128             L-lactate dehydrogenase A chain            Humans
#
#       proteins.known-action           proteins.actions proteins.ref-id  \
# 0                       yes                  inhibitor
# 1                   unknown                  inhibitor
# 2                   unknown       substrate;;inhibitor
# 3                       yes                    agonist
# 4                   unknown                  activator
# ...                     ...                        ...             ...
# 19124               unknown                  inhibitor
# 19125               unknown                    inducer
# 19126               unknown       substrate;;inhibitor
# 19127               unknown       substrate;;inhibitor
# 19128               unknown  antisense oligonucleotide
#
#       proteins.polypeptide.uniprot-id proteins.polypeptide.source  ...  \
# 0                              P00734                  Swiss-Prot  ...
# 1                              P05164                  Swiss-Prot  ...
# 2                              P08183                  Swiss-Prot  ...
# 3                              P06213                  Swiss-Prot  ...
# 4                              P08069                  Swiss-Prot  ...
# ...                               ...                         ...  ...
# 19124                          P10635                  Swiss-Prot  ...
# 19125                          P20815                  Swiss-Prot  ...
# 19126                          P08183                  Swiss-Prot  ...
# 19127                          Q9UNQ0                  Swiss-Prot  ...
# 19128                          P00338                  Swiss-Prot  ...
#
#       proteins.polypeptide.theoretical-pi  \
# 0                                     5.7
# 1                                    9.14
# 2                                    9.44
# 3                                    6.18
# 4                                    5.54
# ...                                   ...
# 19124                                7.26
# 19125                                9.09
# 19126                                9.44
# 19127                                 8.9
# 19128                                8.45
#
#       proteins.polypeptide.molecular-weight  \
# 0                                 70036.295
# 1                                  83867.71
# 2                                141477.255
# 3                                156331.465
# 4                                 154791.73
# ...                                     ...
# 19124                              55768.94
# 19125                             57108.065
# 19126                            141477.255
# 19127                              72313.47
# 19128                             36688.465
#
#       proteins.polypeptide.chromosome-location proteins.polypeptide.organism  \
# 0                                           11                        Humans
# 1                                           17                        Humans
# 2                                            7                        Humans
# 3                                           19                        Humans
# 4                                           15                        Humans
# ...                                        ...                           ...
# 19124                                       22                        Humans
# 19125                                        7                        Humans
# 19126                                        7                        Humans
# 19127                                        4                        Humans
# 19128                                       11                        Humans
#
#                 proteins.polypeptide.amino-acid-sequence  \
# 0      >lcl|BSEQ0016004|Prothrombin\nMAHVRGLQLPGCLALA...
# 1      >lcl|BSEQ0002139|Myeloperoxidase\nMGVPFFSSLRCM...
# 2      >lcl|BSEQ0037114|Multidrug resistance protein ...
# 3      >lcl|BSEQ0036940|Insulin receptor\nMATGGRRGAAA...
# 4      >lcl|BSEQ0001710|Insulin-like growth factor 1 ...
# ...                                                  ...
# 19124  >lcl|BSEQ0004641|Cytochrome P450 2D6\nMGLEALVP...
# 19125  >lcl|BSEQ0004639|Cytochrome P450 3A5\nMDLIPNLA...
# 19126  >lcl|BSEQ0037114|Multidrug resistance protein ...
# 19127  >lcl|BSEQ0002125|ATP-binding cassette sub-fami...
# 19128  >lcl|BSEQ0037014|L-lactate dehydrogenase A cha...
#
#                       proteins.polypeptide.gene-sequence  \
# 0      >lcl|BSEQ0016005|Prothrombin (F2)\nATGGCGCACGT...
# 1      >lcl|BSEQ0016304|Myeloperoxidase (MPO)\nATGGGG...
# 2      >lcl|BSEQ0016291|Multidrug resistance protein ...
# 3      >lcl|BSEQ0020443|Insulin receptor (INSR)\nATGG...
# 4      >lcl|BSEQ0020490|Insulin-like growth factor 1 ...
# ...                                                  ...
# 19124  >lcl|BSEQ0019275|Cytochrome P450 2D6 (CYP2D6)\...
# 19125  >lcl|BSEQ0016766|Cytochrome P450 3A5 (CYP3A5)\...
# 19126  >lcl|BSEQ0016291|Multidrug resistance protein ...
# 19127  >lcl|BSEQ0016303|ATP-binding cassette sub-fami...
# 19128  >lcl|BSEQ0016089|L-lactate dehydrogenase A cha...
#
#             proteins.polypeptide.pfams proteins.inhibition-strength  \
# 0      PF00594;PF00051;PF00089;PF09396
# 1                              PF03098                      unknown
# 2                      PF00005;PF00664
# 3      PF07714;PF00041;PF00757;PF01030
# 4              PF07714;PF00757;PF01030
# ...                                ...                          ...
# 19124                          PF00067                      unknown
# 19125                          PF00067
# 19126                  PF00005;PF00664
# 19127                  PF00005;PF01061
# 19128                  PF02866;PF00056
#
#               proteins.polypeptide.transmembrane-regions  \
# 0
# 1
# 2      45-67\n117-137\n187-208\n216-236\n293-316\n331...
# 3                                                957-979
# 4                                                936-959
# ...                                                  ...
# 19124
# 19125
# 19126  45-67\n117-137\n187-208\n216-236\n293-316\n331...
# 19127  396-416\n429-449\n478-498\n507-527\n536-556\n6...
# 19128
#
#       proteins.induction-strength
# 0
# 1
# 2
# 3
# 4
# ...                           ...
# 19124
# 19125                     unknown
# 19126
# 19127
# 19128
#
# [19129 rows x 27 columns]

# %% [markdown]
# #### Pharmacologically active

# %%
df_pharm = df_proteins_data[df_proteins_data["proteins.known-action"] == "yes"]
df_pharm = df_pharm.groupby(["proteins.id", "proteins.polypeptide.uniprot-id"])
df_pharm = df_pharm["drugbank-id"].agg(lambda x: build_string(x.unique())).reset_index()
df_pharm = df_pharm.rename(
    {
        "proteins.id": "bioentity",
        "proteins.polypeptide.uniprot-id": "uniprot",
        "drugbank-id": "drugbank",
    },
    axis=1,
)
df_pharm
# Out:
#      bioentity uniprot                                         drugbank
# 0    BE0000005  P35228                                  DB05383;DB08814
# 1    BE0000008  Q13423                                          DB09092
# 2    BE0000011  P50213                                          DB09092
# 3    BE0000012  Q9P0X4                          DB00381;DB00909;DB01388
# 4    BE0000013  P30542  DB00201;DB00277;DB00640;DB00651;DB01223;DB01303
# ..         ...     ...                                              ...
# 956  BE0010221  F5HCU8                                          DB12070
# 957  BE0010221  F5HGI9                                          DB12070
# 958  BE0010514  Q9Y243                                          DB12218
# 959  BE0010960  P49768                                          DB12005
# 960  BE0010965  P14263                                          DB01167
#
# [961 rows x 3 columns]

# %% [markdown]
# ### Create main dataframe
# #### Map to model

# %%
if not drugbank_ids:
    drugbank_ids = [
        ensure_iterable(gene.annotation.get("drugbank"))
        for gene in model.genes
        if gene.annotation.get("drugbank")
    ]
    drugbank_ids = sorted(
        {db_id for db_id_list in drugbank_ids for db_id in db_id_list}
    )
df_main = dataframes["general"].copy()
df_main = df_main[df_main["drugbank-id"].isin(drugbank_ids)].copy()

# # Add SNP to main dataframe, adds 5 entries per code
# if dataframes.get("snp") is not None:
#     merge_key = "snp.rs-id"
#     df_main[merge_key] = df_main[f"{merge_key}s"].apply(lambda x: split_string(x, sep=";;"))
#     df_main = df_main.explode(merge_key)
#     df_main = df_main.merge(
#         dataframes["snp"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)


# # Add ATC codes to main dataframe, adds 5 entries per code
# if dataframes.get("atc-codes") is not None:
#     merge_key = "atc-codes.atc-code"
#     df_main[merge_key] = df_main[f"{merge_key}s"].apply(lambda x: split_string(x, sep=";;"))
#     df_main = df_main.explode(merge_key)
#     df_main = df_main.merge(
#         dataframes["atc-codes"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# # Add salts to main dataframe, caution with use due to number of entries
# if dataframes.get("salts") is not None:
#     merge_key = "salts.drugbank-id"
#     df_main[merge_key] = df_main[f"{merge_key}s"].apply(lambda x: split_string(x, sep=";;"))
#     df_main = df_main.explode(merge_key)
#     df_main = df_main.merge(
#         dataframes["salts"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)


# # Add mixtures to main dataframe, caution with use due to number of entries
# if dataframes.get("mixtures") is not None:
#     merge_key = "mixtures.name"
#     df_main[merge_key] = df_main[f"{merge_key}s"].apply(lambda x: split_string(x, sep=";;"))
#     df_main = df_main.explode(merge_key)
#     df_main = df_main.merge(
#         dataframes["mixtures"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# # Add pathways to main dataframe, caution with use due to number of entries
# if dataframes.get("pathways") is not None:
#     merge_key = "pathways.smpdb-id"
#     df_main[merge_key] = df_main[f"{merge_key}s"].apply(lambda x: split_string(x, sep=";;"))
#     df_main = df_main.explode(merge_key)
#     df_main = df_main.merge(
#         dataframes["pathways"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# # Add prices to main dataframe, caution with use due to number of entries
# if dataframes.get("prices") is not None:
#     merge_key = "drugbank-id"
#     df_main = df_main.merge(
#         dataframes["prices"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# # Add manufacturers to main dataframe, caution with use due to number of entries
# if dataframes.get("manufacturers") is not None:
#     merge_key = "drugbank-id"
#     df_main = df_main.merge(
#         dataframes["manufacturers"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)


# # Add dosages to main dataframe, caution with use due to number of entries
# if dataframes.get("dosages") is not None:
#     merge_key = "drugbank-id"
#     df_main = df_main.merge(
#         dataframes["dosages"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# Add reactions to main dataframe, caution with use due to number of entries
# if dataframes.get("reactions") is not None:
#     merge_key = "drugbank-id"
#     df_main = df_main.merge(
#         dataframes["reactions"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# Add products to main dataframe, caution with use due to number of entries
# if dataframes.get("products") is not None:
#     merge_key = "drugbank-id"
#     df_main = df_main.merge(
#         dataframes["products"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

# Add proteins to main dataframe, caution with use due to number of entries
# if dataframes.get("proteins") is not None:
#     merge_key = "drugbank-id"
#     df_main = df_main.merge(
#         dataframes["proteins"],
#         left_on=merge_key,
#         right_on=merge_key,
#         how="left",
#         suffixes=("", "_drop"),
#     )
#     df_main = df_main.drop([c for c in df_main.columns if c.endswith("_drop")], axis=1)
#     df_main = df_main.drop_duplicates().reset_index(drop=True)

df_main
# Out:
#      drugbank-id            type     created     updated               name  \
# 0        DB00006  small molecule  2005-06-13  2024-03-13        Bivalirudin
# 1        DB00027  small molecule  2005-06-13  2024-01-02       Gramicidin D
# 2        DB00030         biotech  2005-06-13  2024-03-13      Insulin human
# 3        DB00035  small molecule  2005-06-13  2024-03-13       Desmopressin
# 4        DB00041         biotech  2005-06-13  2024-03-13        Aldesleukin
# ...          ...             ...         ...         ...                ...
# 2435     DB16732         biotech  2021-09-21  2021-11-08  Tisotumab vedotin
# 2436     DB16826  small molecule  2022-07-15  2024-02-23      Repotrectinib
# 2437     DB17083  small molecule  2022-10-26  2022-12-13         Linzagolix
# 2438     DB17472  small molecule  2023-01-30  2023-12-07      Pirtobrutinib
# 2439     DB17635         biotech  2023-04-17  2024-02-27          Nedosiran
#
#                                             description    cas-number  \
# 0     Bivalirudin is a synthetic 20 residue peptide ...   128270-60-0
# 1     Gramcidin D is a heterogeneous mixture of thre...     1405-97-6
# 2     Human Insulin, also known as Regular Insulin, ...    11061-68-0
# 3     Desmopressin (dDAVP), a synthetic analogue of ...    16679-58-6
# 4     Aldesleukin, a lymphokine, is produced by reco...   110942-02-4
# ...                                                 ...           ...
# 2435  Tisotumab vedotin is a tissue factor-directed ...  1418731-10-8
# 2436  Repotrectinib is a next-generation tyrosine ki...  1802220-02-5
# 2437  Linzagolix is a non-peptide, selective antagon...   935283-04-8
# 2438  Pirtobrutinib is a small molecule and a highly...  2101700-15-4
# 2439  Nedosiran is an RNA interference targeting hep...  2266591-83-5
#
#             unii average-mass monoisotopic-mass  ...  \
# 0     TN9BEX005G    2180.2853    2178.985813062  ...
# 1     5IE62321P4     1811.253    1810.033419343  ...
# 2     1Y17CTI5SR                                 ...
# 3     ENR1LLB0FP      1069.22    1068.426955905  ...
# 4     M89N0Q7EQR                                 ...
# ...          ...          ...               ...  ...
# 2435  T41737F88A                                 ...
# 2436  08O3FQ4UNP      355.373     355.144453003  ...
# 2437  7CDW97HUEX       508.42     508.055206494  ...
# 2438  JNA39I7ZVB      479.436     479.158052208  ...
# 2439  13U9R5J3WL                                 ...
#
#      experimental-properties.logp experimental-properties.logp.source  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.caco2-permeability  \
# 0
# 1
# 2
# 3
# 4
# ...                                         ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.caco2-permeability.source  \
# 0
# 1
# 2
# 3
# 4
# ...                                                ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.pka experimental-properties.pka.source  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                                ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.logs experimental-properties.logs.source  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                                 ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.radioactivity  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
#      experimental-properties.radioactivity.source
# 0
# 1
# 2
# 3
# 4
# ...                                           ...
# 2435
# 2436
# 2437
# 2438
# 2439
#
# [2440 rows x 104 columns]

# %% [markdown]
# ### Aggregate all alternate aliases into single columns

# %%
df_aliases = (
    pd.concat(
        tuple(
            [
                df[["drugbank-id", key]].rename({key: "aliases"}, axis=1)
                for df, key in zip(
                    [
                        df_products_data,
                        df_drugbank_synonym_data,
                        df_drugbank_intbrand_data,
                    ],
                    ["products.name", "synonyms.synonyms", "international-brands.name"],
                )
            ]
        )
    )
    .groupby("drugbank-id")
    .agg(lambda x: build_string(x.unique(), sep=";;"))
)
df_aliases = df_aliases.reset_index(drop=False)
df_aliases
# Out:
#      drugbank-id                                            aliases
# 0        DB00006  Angiomax;;Angiomax RTU;;Angiox;;Bivalirudin;;B...
# 1        DB00027  Antibiotic Cream;;Antibiotic Cream for Kids;;A...
# 2        DB00030  Actraphane 30;;Actraphane 30 Flexpen;;Actrapha...
# 3        DB00035  Apo-desmopressin;;Bipazen;;Ddavp;;Ddavp Inj 4m...
# 4        DB00041  Proleukin;;125-L-serine-2-133-interleukin 2 (h...
# ...          ...                                                ...
# 1534     DB16732  Tivdak;;HuMax-TF-ADC;;Tisotumab vedotin;;tisot...
# 1535     DB16826  Augtyro;;(3R,6S,)-45-FLUORO-3,6-DIMETHYL-5-OXA...
# 1536     DB17083  KLH-2109 Choline;;Yselty;;3-(5-((2,3-difluoro-...
# 1537     DB17472  Jaypirca;;(s)-5-amino-3-(4-((5-fluoro-2-methox...
# 1538     DB17635            Rivfloza;;DCR-PHXC free acid;;Nedosiran
#
# [1539 rows x 2 columns]

# %% [markdown]
# ### Extract reference information

# %%
data = {}
idx = 0
prefix = True
for drug in root:
    drugbank_id = drug.findtext(f"{DRUGBANK_NS}drugbank-id[@primary='true']")
    # if drugbank_id not in drugbank_ids:
    #     continue
    key = "general-references"
    element = drug.find(f"{DRUGBANK_NS}{key}")
    for key in ["articles", "textbooks", "links", "attachments"]:
        elements = element.findall(
            f"{DRUGBANK_NS}{key}/{DRUGBANK_NS}{strip_plural(key)}"
        )
        for element in elements:
            data[idx] = {
                strip_ns_DrugBank(subelement.tag): subelement.text
                for subelement in element
                if has_value_type(subelement)
            }
            data[idx].update(
                {
                    # "drugbank-id": drugbank_id,
                    "type": strip_ns_DrugBank(element.tag),
                }
            )

            idx += 1

df_drugbank_reference_data = (
    pd.DataFrame.from_dict(data, orient="index")
    .drop_duplicates()
    .reset_index(drop=True)
)
df_drugbank_reference_data
# Out:
#         ref-id pubmed-id                                           citation  \
# 0           A1  16244762  Smythe MA, Stephens JL, Koerber JM, Mattson JC...
# 1           A2  16690967  Tardy B, Lecompte T, Boelhen F, Tardy-Poncet B...
# 2           A3  16241940  Lubenow N, Eichler P, Lietz T, Greinacher A: L...
# 3      A246609  19707378  Petros S: Lepirudin in the management of patie...
# 4      A246624  25294122  Chapin JC, Hajjar KA: Fibrinolysis and the con...
# ...        ...       ...                                                ...
# 16205  A262960  38140601  Ward BM, Riccio DA, Cartwright M, Maeda-Chubac...
# 16206  A262965  36239905  Lacarrubba F, Micali G, Trecarichi AC, Quattro...
# 16207  A263266  32253212  Bernhard F, Odedra R, Sordello S, Cardin R, Fr...
# 16208  A263271  16223952  Paterson DL, Bonomo RA: Extended-spectrum beta...
# 16209  A263276  12558458  Rupp ME, Fey PD: Extended spectrum beta-lactam...
#
#           type title  url isbn
# 0      article   NaN  NaN  NaN
# 1      article   NaN  NaN  NaN
# 2      article   NaN  NaN  NaN
# 3      article   NaN  NaN  NaN
# 4      article   NaN  NaN  NaN
# ...        ...   ...  ...  ...
# 16205  article   NaN  NaN  NaN
# 16206  article   NaN  NaN  NaN
# 16207  article   NaN  NaN  NaN
# 16208  article   NaN  NaN  NaN
# 16209  article   NaN  NaN  NaN
#
# [16210 rows x 7 columns]

# %%
df_refs = df_main.copy()
df_refs["ref-id"] = df_refs["general-references.ref-id"].apply(
    lambda x: split_string(x, sep=";;")
)
df_refs = df_refs.explode("ref-id")
df_refs = df_refs.loc[:, ["ref-id"]].replace("", float("nan")).dropna()
df_refs = df_refs.merge(
    df_drugbank_reference_data, left_on="ref-id", right_on="ref-id", how="left"
)
df_refs = df_refs.drop_duplicates()
df_refs
# Out:
#         ref-id pubmed-id                                           citation  \
# 0          A17  16466327  Seybert AL, Coons JC, Zerumsky K: Treatment of...
# 1          A18  17381384  Dager WE, Dougherty JA, Nguyen PH, Militello M...
# 2          A19  16553503  Dang CH, Durkalski VL, Nappi JM: Evaluation of...
# 3          A20  11156732  Robson R: The use of bivalirudin in patients w...
# 4          A21  21108549  Van De Car DA, Rao SV, Ohman EM: Bivalirudin: ...
# ...        ...       ...                                                ...
# 10013   L44873       NaN                                                NaN
# 10014  A261685  27188687  Khan SR, Pearle MS, Robertson WG, Gambaro G, C...
# 10015  A261690  36407951  Liu A, Zhao J, Shah M, Migliorati JM, Tawfik S...
# 10016   L48320       NaN                                                NaN
# 10017   L48325       NaN                                                NaN
#
#           type title  url isbn
# 0      article   NaN  NaN  NaN
# 1      article   NaN  NaN  NaN
# 2      article   NaN  NaN  NaN
# 3      article   NaN  NaN  NaN
# 4      article   NaN  NaN  NaN
# ...        ...   ...  ...  ...
# 10013      NaN   NaN  NaN  NaN
# 10014  article   NaN  NaN  NaN
# 10015  article   NaN  NaN  NaN
# 10016      NaN   NaN  NaN  NaN
# 10017      NaN   NaN  NaN  NaN
#
# [9225 rows x 7 columns]

# %% [markdown]
# ### Extract interaction information

# %%
data = df_drug_interactions.copy()
data = data[data["drugbank-id"].isin(drugbank_ids)]
data = data[data["drug-interactions.drugbank-id"].isin(drugbank_ids)]
data = data.reset_index(drop=True)
# Aggregate dataframe values
data["interaction.ids"] = data[["drugbank-id", "drug-interactions.drugbank-id"]].agg(
    lambda x: build_string(sorted(x), sep=";"), axis=1
)
data["interaction.names"] = data[["name", "drug-interactions.name"]].agg(
    lambda x: build_string(sorted(x), sep=";"), axis=1
)

data = data[~data["interaction.ids"].duplicated()]
data = data[~data["interaction.names"].duplicated()]
data
# Out:
#        drugbank-id             name drug-interactions.drugbank-id  \
# 0          DB00006      Bivalirudin                       DB06605
# 1          DB00006      Bivalirudin                       DB06695
# 2          DB00006      Bivalirudin                       DB01254
# 3          DB00006      Bivalirudin                       DB01586
# 4          DB00006      Bivalirudin                       DB02123
# ...            ...              ...                           ...
# 466533     DB16650  Deucravacitinib                       DB17472
# 466600     DB16690       Tegoprazan                       DB16703
# 467032     DB16703      Belumosudil                       DB17472
# 467042     DB16703      Belumosudil                       DB16826
# 467407     DB16826    Repotrectinib                       DB17472
#
#             drug-interactions.name  \
# 0                         Apixaban
# 1             Dabigatran etexilate
# 2                        Dasatinib
# 3             Ursodeoxycholic acid
# 4       Glycochenodeoxycholic Acid
# ...                            ...
# 466533               Pirtobrutinib
# 466600                 Belumosudil
# 467032               Pirtobrutinib
# 467042               Repotrectinib
# 467407               Pirtobrutinib
#
#                             drug-interactions.description  interaction.ids  \
# 0       Apixaban may increase the anticoagulant activi...  DB00006;DB06605
# 1       Dabigatran etexilate may increase the anticoag...  DB00006;DB06695
# 2       The risk or severity of bleeding and hemorrhag...  DB00006;DB01254
# 3       The risk or severity of bleeding and bruising ...  DB00006;DB01586
# 4       The risk or severity of bleeding and bruising ...  DB00006;DB02123
# ...                                                   ...              ...
# 466533  The risk or severity of adverse effects can be...  DB16650;DB17472
# 466600  The serum concentration of Belumosudil can be ...  DB16690;DB16703
# 467032  The risk or severity of adverse effects can be...  DB16703;DB17472
# 467042  The serum concentration of Repotrectinib can b...  DB16703;DB16826
# 467407  The serum concentration of Repotrectinib can b...  DB16826;DB17472
#
#                              interaction.names
# 0                         Apixaban;Bivalirudin
# 1             Bivalirudin;Dabigatran etexilate
# 2                        Bivalirudin;Dasatinib
# 3             Bivalirudin;Ursodeoxycholic acid
# 4       Bivalirudin;Glycochenodeoxycholic Acid
# ...                                        ...
# 466533           Deucravacitinib;Pirtobrutinib
# 466600                  Belumosudil;Tegoprazan
# 467032               Belumosudil;Pirtobrutinib
# 467042               Belumosudil;Repotrectinib
# 467407             Pirtobrutinib;Repotrectinib
#
# [234129 rows x 7 columns]
