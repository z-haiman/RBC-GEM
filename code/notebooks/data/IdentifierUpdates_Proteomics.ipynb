# %% [markdown]
# # Update Protein Identifiers to UniProt
#
# Note: Requires internet connection to download information from the UniProt.
#
# ## Setup
# ### Import packages

# %%
from collections import defaultdict
import re
import pandas as pd
from rbc_gem_utils import (
    ROOT_PATH,
    DATABASE_PATH,
    EXTERNAL_PATH,
    ANNOTATION_PATH,
    INTERIM_PATH,
    check_version,
    check_database_version_online,
    show_versions,
    build_string,
)


from rbc_gem_utils.database.uniprot import (
    UNIPROT_ID_RE,
    UNIPROT_ISOFORM_ID_RE,
    UNIPROT_VERSION_EXPECTED,
    get_version_UniProt,
    query_UniProt,
    get_annotation_to_from_db_UniProt,
    get_label_miriam_mapping_UniProt,
    get_query_fields_UniProt,
    parse_isoforms_UniProt,
    parse_chains_UniProt,
    get_isoform_value_from_entry_UniProt,
)

# Display versions of last time notebook ran and worked
show_versions()
# Out:
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# beautifulsoup4                       4.12.3
# bio                                   1.6.2
# cobra                                0.29.0
# depinfo                               2.2.0
# kaleido                               0.2.1
# matplotlib                            3.8.2
# memote                               0.17.0
# networkx                              3.2.1
# notebook                              7.0.7
# openpyxl                              3.1.2
# pandas                                2.2.0
# pre-commit                            3.6.0
# pyvis                                 0.3.2
# rbc-gem-utils[database,network,vis] missing
# requests                             2.31.0
# scipy                                1.12.0
# seaborn                              0.13.2
#
# Build Tools Information
# -----------------------
# pip        23.3.1
# setuptools 68.2.2
# wheel      0.41.2
#
# Platform Information
# --------------------
# Darwin  22.6.0-x86_64
# CPython        3.11.7

# %% [markdown]
# ## Check UniProt version
# If the version does not match the expected version, it is because database has been updated since the last time this code was utilized.
#
# ### Expected UniProt version: 2024_01
# * According to [UniProt](https://www.uniprot.org/help/downloads), updates to the database are made every eight weeks.
# * Last release utilized: [2024_01](https://www.uniprot.org/uniprotkb/statistics) published on **Wed Jan 24 2024.**

# %%
if not check_database_version_online("UniProt"):
    warn(
        "Online version of database has been updated since the last time notebook was used."
    )

version = get_version_UniProt()
if check_version(version, UNIPROT_VERSION_EXPECTED, verbose=True):
    database_dirpath = f"{ROOT_PATH}{DATABASE_PATH}"
    annotation_dirpath = f"{ROOT_PATH}{ANNOTATION_PATH}"
else:
    # Use different directory paths for unexpected behavior
    database_dirpath = f"{ROOT_PATH}{INTERIM_PATH}"
    annotation_dirpath = f"{ROOT_PATH}{INTERIM_PATH}"
# Out:
# Current and expected versions match.

# %% [markdown]
# ## Load aggregated proteomic data, raw

# %%
overwrite = True

excel_filepath_raw = (
    f"{ROOT_PATH}{EXTERNAL_PATH}/proteomics/proteomics_aggregated_raw.xlsx"
)

# %% [markdown]
# ### Load obsolete identifiers

# %%
df_obsolete = pd.read_csv(
    f"{ROOT_PATH}{EXTERNAL_PATH}/proteomics/proteomics_obsolete.tsv",
    sep="\t",
    dtype=str,
    index_col=0,
)

for col in df_obsolete.columns:
    df_obsolete[col] = df_obsolete[col].str.split(";")
    df_obsolete = df_obsolete.explode(col)

# Use this block to clean up the obsolete ID dataframe file if needed
# df_obsolete = pd.concat((
#     df_obsolete[df_obsolete["UniProt"].notna()].fillna("").groupby("UniProt", as_index=False).agg(lambda x: build_string(i.strip() for i in x.unique())),
#     df_obsolete[~df_obsolete["UniProt"].notna()],
# )

df_obsolete
# Out:
#          UniProt          IPI        GI UniParc EntryNames
# 0     A0A024QZ64          NaN  78070601     NaN        NaN
# 1     A0A024R0L6          NaN   4505587     NaN        NaN
# 1     A0A024R0L6          NaN  14043830     NaN        NaN
# 2     A0A024R1A3          NaN  23510338     NaN        NaN
# 3     A0A024R1I3          NaN  10092677     NaN        NaN
# ...          ...          ...       ...     ...        ...
# 2978         NaN  IPI00843857       NaN     NaN        NaN
# 2979         NaN  IPI00843921       NaN     NaN        NaN
# 2980         NaN  IPI00844038       NaN     NaN        NaN
# 2981         NaN  IPI00844133       NaN     NaN        NaN
# 2982         NaN  IPI00844154       NaN     NaN        NaN
#
# [3529 rows x 5 columns]

# %% [markdown]
# ### Load table of contents, raw

# %%
df_contents_raw = pd.read_excel(
    excel_filepath_raw, sheet_name="Table of Contents", dtype=str
).fillna("")
df_contents_raw
# Out:
#    PubMed/Sheet Name     ID type  Year  \
# 0           12362340     UniProt  2002
# 1           14963112          GI  2004
# 2           16861337         IPI  2006
# 3           18399644         IPI  2008
# 4           18494517         IPI  2008
# 5           18614565         IPI  2008
# 6           19778645          GI  2009
# 7           22157974          GI  2011
# 8           22954596     UniProt  2012
# 9           23781972          GI  2013
# 10          24555563     UniProt  2014
# 11          26078478     UniProt  2015
# 12          26271157     UniProt  2015
# 13          26474164     UniProt  2015
# 14          27006477     UniProt  2016
# 15          28263177     UniProt  2017
# 16          28689405     UniProt  2017
# 17          30327373     UniProt  2018
# 18          31552303     UniProt  2019
# 19          33103907     UniProt  2020
# 20          33341364     UniProt  2021
# 21          33806028  EntryNames  2021
# 22          35858567     UniProt  2022
# 23          36346805     UniProt  2022
# 24          37760001     UniProt  2023
# 25          37942280     UniProt  2023
#
#                                           Publication  \
# 0   Low TY, Seow TK, Chung MC. Separation of human...
# 1   Kakhniashvili DG, Bulla LA Jr, Goodman SR. The...
# 2   Pasini EM, Kirkegaard M, Mortensen P, Lutz HU,...
# 3   Simó C, Bachi A, Cattaneo A, Guerrier L, Forti...
# 4   Ringrose JH, van Solinge WW, Mohammed S, O'Fla...
# 5   Roux-Dalvai F, Gonzalez de Peredo A, Simó C, G...
# 6   van Gestel RA, van Solinge WW, van der Toorn H...
# 7   D'Amici GM, Rinalducci S, Zolla L. Depletion o...
# 8   Pesciotta EN, Sriswasdi S, Tang HY, Mason PJ, ...
# 9   Pallotta V, D'Alessandro A, Rinalducci S, Zoll...
# 10  Lange PF, Huesgen PF, Nguyen K, Overall CM. An...
# 11  Hegedűs T, Chaubey PM, Várady G, Szabó E, Sara...
# 12  Basu A, Harper S, Pesciotta EN, Speicher KD, C...
# 13  Pesciotta EN, Lam HS, Kossenkov A, Ge J, Showe...
# 14  Wilson MC, Trakarnsanga K, Heesom KJ, Cogan N,...
# 15  D'Alessandro A, Dzieciatkowska M, Nemkov T, Ha...
# 16  Bryk AH, Wiśniewski JR. Quantitative Analysis ...
# 17  Gautier EF, Leduc M, Cochet S, Bailly K, Lacom...
# 18  Ravenhill BJ, Kanjee U, Ahouidi A, Nobre L, Wi...
# 19  Thomas T, Stefanoni D, Dzieciatkowska M, Issai...
# 20  Cai L, Zhang J, Hongyun W, Zhu Y, Zhang X, Lia...
# 21  Tzounakas VL, Anastasiadi AT, Dzieciatkowska M...
# 22  Sae-Lee W, McCafferty CL, Verbeke EJ, Havugima...
# 23  Wang S, Wang G, Lu S, Zhang J, Zhang W, Han Y,...
# 24  Reisz JA, Dzieciatkowska M, Stephenson D, Gamb...
# 25  de Oliveira Junior GP, Welsh JA, Pinckney B, P...
#
#                                      Notes
# 0                     Used for iAB-RBC-283
# 1
# 2                     Used for iAB-RBC-283
# 3
# 4
# 5                     Used for iAB-RBC-283
# 6
# 7
# 8                       Disease conditions
# 9
# 10
# 11
# 12
# 13                      Disease conditions
# 14
# 15
# 16
# 17
# 18
# 19                      Disease conditions
# 20                      Storage conditions
# 21  Disease conditions, storage conditions
# 22
# 23                      Disease conditions
# 24                      Disease conditions
# 25

# %% [markdown]
# ### Map other identifiers to UniProt

# %%
updated_table_dict = {"Table of Contents": df_contents_raw.copy()}

index_name = "Uniprot"
for idx, (sheet_name, id_type) in df_contents_raw[
    ["PubMed/Sheet Name", "ID type"]
].iterrows():
    df = pd.read_excel(
        excel_filepath_raw, sheet_name=sheet_name, usecols=[0], dtype=str
    )
    df.columns = [id_type]
    if id_type != "UniProt":
        # Map to obsolete identifiers
        df_obsolete_mapping = (
            df_obsolete[[id_type, "UniProt"]].dropna(how="all").drop_duplicates().copy()
        )
        if id_type == "GI":
            df[id_type] = df[id_type].apply(
                lambda x: x.split("|")[-1] if str(x).startswith("gi|") else x
            )
        df_obsolete_mapping = df.merge(
            df_obsolete_mapping, left_on=id_type, right_on=id_type, how="left"
        )
        counts = df_obsolete_mapping.nunique()
        counts["Obsolete"] = (
            df_obsolete_mapping["UniProt"].isna().value_counts()[True].item()
        )
        counts = {k: v for (k, v) in sorted(counts.to_dict().items())}
        updated_table_dict["Table of Contents"].loc[idx, "ID type"] = "UniProt"
        updated_table_dict["Table of Contents"].loc[idx, "Notes"] = build_string(
            [f"{v} {k}" for k, v in counts.items()]
        )
        updated_table_dict[sheet_name] = list(
            df_obsolete_mapping["UniProt"].dropna().unique()
        )
    else:
        df["UniProt"] = df["UniProt"].apply(
            lambda x: UNIPROT_ID_RE.search(x).group() if UNIPROT_ID_RE.search(x) else x
        )
        updated_table_dict[sheet_name] = list(df["UniProt"].dropna().unique())
        updated_table_dict["Table of Contents"].loc[idx, "Notes"] = "{} UniProt".format(
            df["UniProt"].nunique()
        )

updated_table_dict["Table of Contents"]
# Out:
#    PubMed/Sheet Name  ID type  Year  \
# 0           12362340  UniProt  2002
# 1           14963112  UniProt  2004
# 2           16861337  UniProt  2006
# 3           18399644  UniProt  2008
# 4           18494517  UniProt  2008
# 5           18614565  UniProt  2008
# 6           19778645  UniProt  2009
# 7           22157974  UniProt  2011
# 8           22954596  UniProt  2012
# 9           23781972  UniProt  2013
# 10          24555563  UniProt  2014
# 11          26078478  UniProt  2015
# 12          26271157  UniProt  2015
# 13          26474164  UniProt  2015
# 14          27006477  UniProt  2016
# 15          28263177  UniProt  2017
# 16          28689405  UniProt  2017
# 17          30327373  UniProt  2018
# 18          31552303  UniProt  2019
# 19          33103907  UniProt  2020
# 20          33341364  UniProt  2021
# 21          33806028  UniProt  2021
# 22          35858567  UniProt  2022
# 23          36346805  UniProt  2022
# 24          37760001  UniProt  2023
# 25          37942280  UniProt  2023
#
#                                           Publication  \
# 0   Low TY, Seow TK, Chung MC. Separation of human...
# 1   Kakhniashvili DG, Bulla LA Jr, Goodman SR. The...
# 2   Pasini EM, Kirkegaard M, Mortensen P, Lutz HU,...
# 3   Simó C, Bachi A, Cattaneo A, Guerrier L, Forti...
# 4   Ringrose JH, van Solinge WW, Mohammed S, O'Fla...
# 5   Roux-Dalvai F, Gonzalez de Peredo A, Simó C, G...
# 6   van Gestel RA, van Solinge WW, van der Toorn H...
# 7   D'Amici GM, Rinalducci S, Zolla L. Depletion o...
# 8   Pesciotta EN, Sriswasdi S, Tang HY, Mason PJ, ...
# 9   Pallotta V, D'Alessandro A, Rinalducci S, Zoll...
# 10  Lange PF, Huesgen PF, Nguyen K, Overall CM. An...
# 11  Hegedűs T, Chaubey PM, Várady G, Szabó E, Sara...
# 12  Basu A, Harper S, Pesciotta EN, Speicher KD, C...
# 13  Pesciotta EN, Lam HS, Kossenkov A, Ge J, Showe...
# 14  Wilson MC, Trakarnsanga K, Heesom KJ, Cogan N,...
# 15  D'Alessandro A, Dzieciatkowska M, Nemkov T, Ha...
# 16  Bryk AH, Wiśniewski JR. Quantitative Analysis ...
# 17  Gautier EF, Leduc M, Cochet S, Bailly K, Lacom...
# 18  Ravenhill BJ, Kanjee U, Ahouidi A, Nobre L, Wi...
# 19  Thomas T, Stefanoni D, Dzieciatkowska M, Issai...
# 20  Cai L, Zhang J, Hongyun W, Zhu Y, Zhang X, Lia...
# 21  Tzounakas VL, Anastasiadi AT, Dzieciatkowska M...
# 22  Sae-Lee W, McCafferty CL, Verbeke EJ, Havugima...
# 23  Wang S, Wang G, Lu S, Zhang J, Zhang W, Han Y,...
# 24  Reisz JA, Dzieciatkowska M, Stephenson D, Gamb...
# 25  de Oliveira Junior GP, Welsh JA, Pinckney B, P...
#
#                                       Notes
# 0                                84 UniProt
# 1            183 GI;110 Obsolete;92 UniProt
# 2          590 IPI;146 Obsolete;439 UniProt
# 3           153 IPI;18 Obsolete;135 UniProt
# 4          699 IPI;299 Obsolete;400 UniProt
# 5        1577 IPI;256 Obsolete;1318 UniProt
# 6           561 GI;137 Obsolete;473 UniProt
# 7            134 GI;178 Obsolete;62 UniProt
# 8                               831 UniProt
# 9            140 GI;28 Obsolete;153 UniProt
# 10                             1220 UniProt
# 11                              419 UniProt
# 12                               76 UniProt
# 13                             1245 UniProt
# 14                             1314 UniProt
# 15                             1826 UniProt
# 16                             2577 UniProt
# 17                             2076 UniProt
# 18                              267 UniProt
# 19                              921 UniProt
# 20                              876 UniProt
# 21  1353 EntryNames;8 Obsolete;1343 UniProt
# 22                             1528 UniProt
# 23                              659 UniProt
# 24                              878 UniProt
# 25                             1812 UniProt

# %% [markdown]
# ### Map UniProt IDs to current UniProt

# %%
# Extract all relevant information for now and save
query_parameters = {
    "query": " && ".join(
        [
            "(organism_id:9606)",  # Homo sapiens (Human)
        ]
    ),
    "format": "tsv",
    "size": 500,
    "compressed": True,
    "fields": ",".join(
        [
            "reviewed",
            "accession",
            "gene_primary",
        ]
    ),
}
idx = 0
for sheet_name, query_ids in updated_table_dict.copy().items():
    if sheet_name == "Table of Contents":
        continue
    print(f"{sheet_name}\n{len(sheet_name) * '-'}")
    df_results, uniparc, failed_ids, unmapped_ids = query_UniProt(
        query_ids,
        query_parameters=query_parameters,
        from_db="UniProtKB",
        to_db="UniProtKB",
        return_failed=True,
    )
    df_uniprot = df_results["Entry"].drop_duplicates().dropna().reset_index(drop=True)
    df_uniprot.name = index_name
    updated_table_dict[sheet_name] = df_uniprot
    updated_table_dict["Table of Contents"].loc[
        idx, "Notes"
    ] += f" -->  {len(df_uniprot)} UniProt {version}"
    idx += 1
    print()

updated_table_dict["Table of Contents"]
# Out:
# 12362340
# --------
# Number of failed query IDs : 5
# Fetched: 79 / 79
# Number of failed IDs : 3
# 14963112
# --------
# Fetched: 92 / 92
#
# 16861337
# --------
# Fetched: 442 / 442
#
# 18399644
# --------
# Fetched: 136 / 136
#
# 18494517
# --------
# Fetched: 400 / 400
#
# 18614565
# --------
# Fetched: 500 / 1321
# Fetched: 1000 / 1321
# Fetched: 1321 / 1321
#
# 19778645
# --------
# Fetched: 473 / 473
#
# 22157974
# --------
# Fetched: 62 / 62
#
# 22954596
# --------
# Fetched: 500 / 765
# Number of failed query IDs : 67
# Fetched: 765 / 765
# Number of failed IDs : 8
# Number of obsolete IDs : 54
# 23781972
# --------
# Fetched: 153 / 153
#
# 24555563
# --------
# Fetched: 500 / 1214
# Fetched: 1000 / 1214
# Number of failed query IDs : 9
# Fetched: 1214 / 1214
# Number of obsolete IDs : 5
# 26078478
# --------
# Number of failed query IDs : 6
# Fetched: 416 / 416
# Number of obsolete IDs : 6
# 26271157
# --------
# Number of failed query IDs : 4
# Fetched: 72 / 72
# Number of obsolete IDs : 4
# 26474164
# --------
# Fetched: 500 / 1148
# Fetched: 1000 / 1148
# Number of failed query IDs : 98
# Fetched: 1148 / 1148
# Number of failed IDs : 48
# Number of obsolete IDs : 22
# 27006477
# --------
# Fetched: 500 / 1187
# Fetched: 1000 / 1187
# Number of failed query IDs : 130
# Fetched: 1187 / 1187
# Number of obsolete IDs : 117
# 28263177
# --------
# Fetched: 500 / 1815
# Fetched: 1000 / 1815
# Fetched: 1500 / 1815
# Number of failed query IDs : 14
# Fetched: 1815 / 1815
# Number of obsolete IDs : 2
# 28689405
# --------
# Fetched: 500 / 2557
# Fetched: 1000 / 2557
# Fetched: 1500 / 2557
# Fetched: 2000 / 2557
# Fetched: 2500 / 2557
# Number of failed query IDs : 22
# Fetched: 2557 / 2557
# Number of obsolete IDs : 21
# 30327373
# --------
# Fetched: 500 / 2075
# Fetched: 1000 / 2075
# Fetched: 1500 / 2075
# Fetched: 2000 / 2075
# Number of failed query IDs : 1
# Fetched: 2075 / 2075
#
# 31552303
# --------
# Fetched: 267 / 267
#
# 33103907
# --------
# Fetched: 500 / 921
# Fetched: 921 / 921
#
# 33341364
# --------
# Fetched: 500 / 841
# Number of failed query IDs : 35
# Fetched: 841 / 841
# Number of obsolete IDs : 29
# 33806028
# --------
# Fetched: 500 / 1343
# Fetched: 1000 / 1343
# Fetched: 1343 / 1343
#
# 35858567
# --------
# Fetched: 500 / 1530
# Fetched: 1000 / 1530
# Fetched: 1500 / 1530
# Fetched: 1530 / 1530
#
# 36346805
# --------
# Fetched: 500 / 659
# Fetched: 659 / 659
#
# 37760001
# --------
# Fetched: 500 / 878
# Fetched: 878 / 878
#
# 37942280
# --------
# Fetched: 500 / 1813
# Fetched: 1000 / 1813
# Fetched: 1500 / 1813
# Number of failed query IDs : 1
# Fetched: 1813 / 1813
# Number of obsolete IDs : 1
#    PubMed/Sheet Name  ID type  Year  \
# 0           12362340  UniProt  2002
# 1           14963112  UniProt  2004
# 2           16861337  UniProt  2006
# 3           18399644  UniProt  2008
# 4           18494517  UniProt  2008
# 5           18614565  UniProt  2008
# 6           19778645  UniProt  2009
# 7           22157974  UniProt  2011
# 8           22954596  UniProt  2012
# 9           23781972  UniProt  2013
# 10          24555563  UniProt  2014
# 11          26078478  UniProt  2015
# 12          26271157  UniProt  2015
# 13          26474164  UniProt  2015
# 14          27006477  UniProt  2016
# 15          28263177  UniProt  2017
# 16          28689405  UniProt  2017
# 17          30327373  UniProt  2018
# 18          31552303  UniProt  2019
# 19          33103907  UniProt  2020
# 20          33341364  UniProt  2021
# 21          33806028  UniProt  2021
# 22          35858567  UniProt  2022
# 23          36346805  UniProt  2022
# 24          37760001  UniProt  2023
# 25          37942280  UniProt  2023
#
#                                           Publication  \
# 0   Low TY, Seow TK, Chung MC. Separation of human...
# 1   Kakhniashvili DG, Bulla LA Jr, Goodman SR. The...
# 2   Pasini EM, Kirkegaard M, Mortensen P, Lutz HU,...
# 3   Simó C, Bachi A, Cattaneo A, Guerrier L, Forti...
# 4   Ringrose JH, van Solinge WW, Mohammed S, O'Fla...
# 5   Roux-Dalvai F, Gonzalez de Peredo A, Simó C, G...
# 6   van Gestel RA, van Solinge WW, van der Toorn H...
# 7   D'Amici GM, Rinalducci S, Zolla L. Depletion o...
# 8   Pesciotta EN, Sriswasdi S, Tang HY, Mason PJ, ...
# 9   Pallotta V, D'Alessandro A, Rinalducci S, Zoll...
# 10  Lange PF, Huesgen PF, Nguyen K, Overall CM. An...
# 11  Hegedűs T, Chaubey PM, Várady G, Szabó E, Sara...
# 12  Basu A, Harper S, Pesciotta EN, Speicher KD, C...
# 13  Pesciotta EN, Lam HS, Kossenkov A, Ge J, Showe...
# 14  Wilson MC, Trakarnsanga K, Heesom KJ, Cogan N,...
# 15  D'Alessandro A, Dzieciatkowska M, Nemkov T, Ha...
# 16  Bryk AH, Wiśniewski JR. Quantitative Analysis ...
# 17  Gautier EF, Leduc M, Cochet S, Bailly K, Lacom...
# 18  Ravenhill BJ, Kanjee U, Ahouidi A, Nobre L, Wi...
# 19  Thomas T, Stefanoni D, Dzieciatkowska M, Issai...
# 20  Cai L, Zhang J, Hongyun W, Zhu Y, Zhang X, Lia...
# 21  Tzounakas VL, Anastasiadi AT, Dzieciatkowska M...
# 22  Sae-Lee W, McCafferty CL, Verbeke EJ, Havugima...
# 23  Wang S, Wang G, Lu S, Zhang J, Zhang W, Han Y,...
# 24  Reisz JA, Dzieciatkowska M, Stephenson D, Gamb...
# 25  de Oliveira Junior GP, Welsh JA, Pinckney B, P...
#
#                                                 Notes
# 0                  84 UniProt -->  79 UniProt 2024_01
# 1   183 GI;110 Obsolete;92 UniProt -->  92 UniProt...
# 2   590 IPI;146 Obsolete;439 UniProt -->  442 UniP...
# 3   153 IPI;18 Obsolete;135 UniProt -->  136 UniPr...
# 4   699 IPI;299 Obsolete;400 UniProt -->  400 UniP...
# 5   1577 IPI;256 Obsolete;1318 UniProt -->  1321 U...
# 6   561 GI;137 Obsolete;473 UniProt -->  473 UniPr...
# 7   134 GI;178 Obsolete;62 UniProt -->  62 UniProt...
# 8                831 UniProt -->  765 UniProt 2024_01
# 9   140 GI;28 Obsolete;153 UniProt -->  153 UniPro...
# 10             1220 UniProt -->  1214 UniProt 2024_01
# 11               419 UniProt -->  416 UniProt 2024_01
# 12                 76 UniProt -->  72 UniProt 2024_01
# 13             1245 UniProt -->  1148 UniProt 2024_01
# 14             1314 UniProt -->  1187 UniProt 2024_01
# 15             1826 UniProt -->  1815 UniProt 2024_01
# 16             2577 UniProt -->  2557 UniProt 2024_01
# 17             2076 UniProt -->  2075 UniProt 2024_01
# 18               267 UniProt -->  267 UniProt 2024_01
# 19               921 UniProt -->  921 UniProt 2024_01
# 20               876 UniProt -->  841 UniProt 2024_01
# 21  1353 EntryNames;8 Obsolete;1343 UniProt -->  1...
# 22             1528 UniProt -->  1530 UniProt 2024_01
# 23               659 UniProt -->  659 UniProt 2024_01
# 24               878 UniProt -->  878 UniProt 2024_01
# 25             1812 UniProt -->  1813 UniProt 2024_01

# %% [markdown]
# ### Export aggregated proteomic data, updated IDs

# %%
if overwrite:
    with pd.ExcelWriter(
        f"{ROOT_PATH}{EXTERNAL_PATH}/proteomics/proteomics_aggregated.xlsx"
    ) as writer:
        for sheet_name, df in updated_table_dict.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)
else:
    with pd.ExcelWriter(
        f"{ROOT_PATH}{INTERIM_PATH}/proteomics_aggregated.xlsx"
    ) as writer:
        for sheet_name, df in updated_table_dict.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)
