# %% [markdown]
# # Update Protein Identifiers to UniProt
#
# Note: Requires internet connection to download information from the UniProt.
#
# ## Setup
# ### Import packages

# %%
from collections import defaultdict
import re
import pandas as pd
from rbc_gem_utils import (
    ROOT_PATH,
    DATABASE_PATH,
    EXTERNAL_PATH,
    ANNOTATION_PATH,
    INTERIM_PATH,
    check_version,
    check_database_version_online,
    show_versions,
    build_string,
)


from rbc_gem_utils.database.uniprot import (
    UNIPROT_ID_RE,
    UNIPROT_ISOFORM_ID_RE,
    UNIPROT_VERSION_EXPECTED,
    get_version_UniProt,
    query_UniProt,
    get_annotation_to_from_db_UniProt,
    get_label_miriam_mapping_UniProt,
    get_query_fields_UniProt,
    parse_isoforms_UniProt,
    parse_chains_UniProt,
    get_isoform_value_from_entry_UniProt,
)
# Display versions of last time notebook ran and worked
show_versions()
# Out:
# Package Information
# -------------------
# rbc-gem-utils 0.0.1
#
# Dependency Information
# ----------------------
# cobra      0.29.0
# depinfo     2.2.0
# matplotlib  3.8.2
# memote     0.16.1
# notebook    7.0.6
# requests   2.31.0
# scipy      1.11.4
# seaborn    0.13.0
#
# Build Tools Information
# -----------------------
# pip        23.3.1
# setuptools 68.2.2
# wheel      0.41.2
#
# Platform Information
# --------------------
# Darwin  22.6.0-x86_64
# CPython        3.12.0

# %% [markdown]
# ## Check UniProt version
# If the version does not match the expected version, it is because database has been updated since the last time this code was utilized.
#
# ### Expected UniProt version: 2023_05
# * According to [UniProt](https://www.uniprot.org/help/downloads), updates to the database are made every eight weeks.
# * Last release utilized: [2023_05](https://www.uniprot.org/uniprotkb/statistics) published on **Wed Nov 08 2023**.

# %%
if not check_database_version_online("UniProt"):
    warn("Online version of database has been updated since the last time notebook was used.")

version = get_version_UniProt()
if check_version(version, UNIPROT_VERSION_EXPECTED, verbose=True):
    database_dirpath = f"{ROOT_PATH}{DATABASE_PATH}"
    annotation_dirpath = f"{ROOT_PATH}{ANNOTATION_PATH}"
else:
     # Use different directory paths for unexpected behavior
    database_dirpath = f"{ROOT_PATH}{INTERIM_PATH}" 
    annotation_dirpath = f"{ROOT_PATH}{INTERIM_PATH}"
# Out:
# Current and expected versions match.

# %% [markdown]
# ## Load aggregated proteomic data, raw

# %%
excel_filepath_raw = f"{ROOT_PATH}{EXTERNAL_PATH}/proteomics/proteomics_aggregated_raw.xlsx"

# %% [markdown]
# ### Load obsolete identifiers

# %%
df_obsolete = pd.read_csv(f"{ROOT_PATH}{EXTERNAL_PATH}/proteomics/proteomics_obsolete.tsv",  sep="\t", dtype=str, index_col=0)
for col in df_obsolete.columns:
    df_obsolete[col] = df_obsolete[col].str.split(";")
    df_obsolete = df_obsolete.explode(col)
df_obsolete
# Out:
#          UniProt  IPI        GI        UniParc
# 0     A0A024QZ64  NaN  78070601            NaN
# 1     A0A024R0L6  NaN  14043830            NaN
# 2     A0A024R1I3  NaN  40674427            NaN
# 3     A0A024R4T4  NaN   4507791            NaN
# 4     A0A024R782  NaN  40353764            NaN
# ...          ...  ...       ...            ...
# 2291         NaN  NaN  55960369  UPI000013CAD9
# 2292         NaN  NaN  55960711  UPI00004589D9
# 2293         NaN  NaN  56204677  UPI00000012F5
# 2294         NaN  NaN  57165048  UPI000012723D
# 2295         NaN  NaN  74047534            NaN
#
# [2455 rows x 4 columns]

# %% [markdown]
# ### Load table of contents, raw

# %%
df_contents_raw = pd.read_excel(
    excel_filepath_raw,
    sheet_name="Table of Contents",
    dtype=str
).fillna("")
df_contents_raw
# Out:
#    PubMed/Sheet Name  ID type  Year  \
# 0           16861337      IPI  2006
# 1           18399644      IPI  2008
# 2           18494517      IPI  2008
# 3           18614565      IPI  2008
# 4           19778645       GI  2009
# 5           22954596  UniProt  2012
# 6           24555563  UniProt  2014
# 7           26078478  UniProt  2015
# 8           26474164  UniProt  2015
# 9           27006477  UniProt  2016
# 10          28263177  UniProt  2017
# 11          28689405  UniProt  2017
# 12          30327373  UniProt  2018
# 13          31552303  UniProt  2019
# 14          33103907  UniProt  2020
# 15          33341364  UniProt  2021
# 16          35858567  UniProt  2022
# 17          36346805  UniProt  2022
# 18          37760001  UniProt  2023
# 19          37942280  UniProt  2023
#
#                                           Publication Notes
# 0   Pasini EM, Kirkegaard M, Mortensen P, Lutz HU,...
# 1   Simó C, Bachi A, Cattaneo A, Guerrier L, Forti...
# 2   Ringrose JH, van Solinge WW, Mohammed S, O'Fla...
# 3   Roux-Dalvai F, Gonzalez de Peredo A, Simó C, G...
# 4   van Gestel RA, van Solinge WW, van der Toorn H...
# 5   Pesciotta EN, Sriswasdi S, Tang HY, Mason PJ, ...
# 6   Lange PF, Huesgen PF, Nguyen K, Overall CM. An...
# 7   Hegedűs T, Chaubey PM, Várady G, Szabó E, Sara...
# 8   Pesciotta EN, Lam HS, Kossenkov A, Ge J, Showe...
# 9   Wilson MC, Trakarnsanga K, Heesom KJ, Cogan N,...
# 10  D'Alessandro A, Dzieciatkowska M, Nemkov T, Ha...
# 11  Bryk AH, Wiśniewski JR. Quantitative Analysis ...
# 12  Gautier EF, Leduc M, Cochet S, Bailly K, Lacom...
# 13  Ravenhill BJ, Kanjee U, Ahouidi A, Nobre L, Wi...
# 14  Thomas T, Stefanoni D, Dzieciatkowska M, Issai...
# 15  Cai L, Zhang J, Hongyun W, Zhu Y, Zhang X, Lia...
# 16  Sae-Lee W, McCafferty CL, Verbeke EJ, Havugima...
# 17  Wang S, Wang G, Lu S, Zhang J, Zhang W, Han Y,...
# 18  Reisz JA, Dzieciatkowska M, Stephenson D, Gamb...
# 19  de Oliveira Junior GP, Welsh JA, Pinckney B, P...

# %% [markdown]
# ### Map other identifiers to UniProt

# %%
updated_table_dict = {
    "Table of Contents": df_contents_raw.copy()
}

index_name = "Uniprot"
for idx, (sheet_name, id_type) in df_contents_raw[["PubMed/Sheet Name", "ID type"]].iterrows():
    df = pd.read_excel(excel_filepath_raw, sheet_name=sheet_name, usecols=[0], dtype=str)
    df.columns = [id_type]
    if id_type != "UniProt":        
        # Map to obsolete identifiers
        df_obsolete_mapping = df_obsolete[[id_type, "UniProt"]].dropna(how="all").drop_duplicates().copy()
        if id_type == "GI":
            df[id_type] = df[id_type].apply(lambda x: x.split("|")[-1] if str(x).startswith("gi|") else x)
        df_obsolete_mapping = df.merge(df_obsolete_mapping, left_on=id_type, right_on=id_type, how="left")
        counts = df_obsolete_mapping.nunique()
        counts["Obsolete"] =  df_obsolete_mapping["UniProt"].isna().value_counts()[True].item()
        updated_table_dict["Table of Contents"].loc[idx, "ID type"] = "UniProt"
        updated_table_dict["Table of Contents"].loc[idx, "Notes"] = build_string([f"{v} {k}" for k, v in counts.to_dict().items()])
        updated_table_dict[sheet_name] = list(df_obsolete_mapping["UniProt"].dropna().unique())
    else:
        df["UniProt"] = df["UniProt"].apply(lambda x: UNIPROT_ID_RE.search(x).group() if UNIPROT_ID_RE.search(x) else x)
        updated_table_dict[sheet_name] = list(df["UniProt"].dropna().unique())
        updated_table_dict["Table of Contents"].loc[idx, "Notes"] = f"{df["UniProt"].nunique()} UniProt"

updated_table_dict["Table of Contents"]
# Out:
#    PubMed/Sheet Name  ID type  Year  \
# 0           16861337  UniProt  2006
# 1           18399644  UniProt  2008
# 2           18494517  UniProt  2008
# 3           18614565  UniProt  2008
# 4           19778645  UniProt  2009
# 5           22954596  UniProt  2012
# 6           24555563  UniProt  2014
# 7           26078478  UniProt  2015
# 8           26474164  UniProt  2015
# 9           27006477  UniProt  2016
# 10          28263177  UniProt  2017
# 11          28689405  UniProt  2017
# 12          30327373  UniProt  2018
# 13          31552303  UniProt  2019
# 14          33103907  UniProt  2020
# 15          33341364  UniProt  2021
# 16          35858567  UniProt  2022
# 17          36346805  UniProt  2022
# 18          37760001  UniProt  2023
# 19          37942280  UniProt  2023
#
#                                           Publication  \
# 0   Pasini EM, Kirkegaard M, Mortensen P, Lutz HU,...
# 1   Simó C, Bachi A, Cattaneo A, Guerrier L, Forti...
# 2   Ringrose JH, van Solinge WW, Mohammed S, O'Fla...
# 3   Roux-Dalvai F, Gonzalez de Peredo A, Simó C, G...
# 4   van Gestel RA, van Solinge WW, van der Toorn H...
# 5   Pesciotta EN, Sriswasdi S, Tang HY, Mason PJ, ...
# 6   Lange PF, Huesgen PF, Nguyen K, Overall CM. An...
# 7   Hegedűs T, Chaubey PM, Várady G, Szabó E, Sara...
# 8   Pesciotta EN, Lam HS, Kossenkov A, Ge J, Showe...
# 9   Wilson MC, Trakarnsanga K, Heesom KJ, Cogan N,...
# 10  D'Alessandro A, Dzieciatkowska M, Nemkov T, Ha...
# 11  Bryk AH, Wiśniewski JR. Quantitative Analysis ...
# 12  Gautier EF, Leduc M, Cochet S, Bailly K, Lacom...
# 13  Ravenhill BJ, Kanjee U, Ahouidi A, Nobre L, Wi...
# 14  Thomas T, Stefanoni D, Dzieciatkowska M, Issai...
# 15  Cai L, Zhang J, Hongyun W, Zhu Y, Zhang X, Lia...
# 16  Sae-Lee W, McCafferty CL, Verbeke EJ, Havugima...
# 17  Wang S, Wang G, Lu S, Zhang J, Zhang W, Han Y,...
# 18  Reisz JA, Dzieciatkowska M, Stephenson D, Gamb...
# 19  de Oliveira Junior GP, Welsh JA, Pinckney B, P...
#
#                                  Notes
# 0     590 IPI;438 UniProt;147 Obsolete
# 1      153 IPI;135 UniProt;18 Obsolete
# 2     699 IPI;400 UniProt;299 Obsolete
# 3   1577 IPI;1318 UniProt;256 Obsolete
# 4      561 GI;473 UniProt;138 Obsolete
# 5                          831 UniProt
# 6                         1220 UniProt
# 7                          419 UniProt
# 8                         1245 UniProt
# 9                         1314 UniProt
# 10                        1826 UniProt
# 11                        2577 UniProt
# 12                        2076 UniProt
# 13                         267 UniProt
# 14                         921 UniProt
# 15                         876 UniProt
# 16                        1528 UniProt
# 17                         659 UniProt
# 18                         878 UniProt
# 19                        1812 UniProt

# %% [markdown]
# ### Map UniProt IDs to current UniProt

# %%
# Extract all relevant information for now and save
query_parameters = {
    "query": " && ".join([
        "(organism_id:9606)", # Homo sapiens (Human)
    ]),
    "format": "tsv",
    "size": 500,
    "compressed": True,
    "fields": ",".join([
        "reviewed",
        "accession",
        "gene_primary",
    ])
}
idx = 0
for sheet_name, query_ids in updated_table_dict.copy().items():
    if sheet_name == "Table of Contents":
        continue
    print(f"{sheet_name}\n{len(sheet_name) * '-'}")
    df_results, uniparc, failed_ids, unmapped_ids = query_UniProt(
        query_ids, 
        query_parameters=query_parameters,
        from_db="UniProtKB",
        to_db="UniProtKB",
        return_failed=True
    )
    df_uniprot = df_results["Entry"].drop_duplicates().dropna().reset_index(drop=True)
    df_uniprot.name = index_name
    updated_table_dict[sheet_name] = df_uniprot
    updated_table_dict["Table of Contents"].loc[idx, "Notes"] += f" -->  {len(df_uniprot)} UniProt {version}"
    idx += 1
    print()

updated_table_dict["Table of Contents"]
# Out:
# 16861337
# --------
# Fetched: 441 / 441
#
# 18399644
# --------
# Fetched: 136 / 136
#
# 18494517
# --------
# Fetched: 400 / 400
#
# 18614565
# --------
# Fetched: 500 / 1321
# Fetched: 1000 / 1321
# Fetched: 1321 / 1321
#
# 19778645
# --------
# Fetched: 473 / 473
#
# 22954596
# --------
# Fetched: 500 / 766
# Number of failed query IDs : 66
# Fetched: 766 / 766
# Number of failed IDs : 8
# Number of obsolete IDs : 53
# 24555563
# --------
# Fetched: 500 / 1214
# Fetched: 1000 / 1214
# Number of failed query IDs : 9
# Fetched: 1214 / 1214
# Number of obsolete IDs : 5
# 26078478
# --------
# Number of failed query IDs : 6
# Fetched: 416 / 416
# Number of obsolete IDs : 6
# 26474164
# --------
# Fetched: 500 / 1148
# Fetched: 1000 / 1148
# Number of failed query IDs : 98
# Fetched: 1148 / 1148
# Number of failed IDs : 48
# Number of obsolete IDs : 22
# 27006477
# --------
# Fetched: 500 / 1187
# Fetched: 1000 / 1187
# Number of failed query IDs : 130
# Fetched: 1187 / 1187
# Number of obsolete IDs : 117
# 28263177
# --------
# Fetched: 500 / 1815
# Fetched: 1000 / 1815
# Fetched: 1500 / 1815
# Number of failed query IDs : 14
# Fetched: 1815 / 1815
# Number of obsolete IDs : 2
# 28689405
# --------
# Fetched: 500 / 2557
# Fetched: 1000 / 2557
# Fetched: 1500 / 2557
# Fetched: 2000 / 2557
# Fetched: 2500 / 2557
# Number of failed query IDs : 22
# Fetched: 2557 / 2557
# Number of obsolete IDs : 21
# 30327373
# --------
# Fetched: 500 / 2075
# Fetched: 1000 / 2075
# Fetched: 1500 / 2075
# Fetched: 2000 / 2075
# Number of failed query IDs : 1
# Fetched: 2075 / 2075
#
# 31552303
# --------
# Fetched: 267 / 267
#
# 33103907
# --------
# Fetched: 500 / 921
# Fetched: 921 / 921
#
# 33341364
# --------
# Fetched: 500 / 841
# Number of failed query IDs : 35
# Fetched: 841 / 841
# Number of obsolete IDs : 29
# 35858567
# --------
# Fetched: 500 / 1530
# Fetched: 1000 / 1530
# Fetched: 1500 / 1530
# Fetched: 1530 / 1530
#
# 36346805
# --------
# Fetched: 500 / 659
# Fetched: 659 / 659
#
# 37760001
# --------
# Fetched: 500 / 878
# Fetched: 878 / 878
#
# 37942280
# --------
# Fetched: 500 / 1813
# Fetched: 1000 / 1813
# Fetched: 1500 / 1813
# Number of failed query IDs : 1
# Fetched: 1813 / 1813
# Number of obsolete IDs : 1
#    PubMed/Sheet Name  ID type  Year  \
# 0           16861337  UniProt  2006
# 1           18399644  UniProt  2008
# 2           18494517  UniProt  2008
# 3           18614565  UniProt  2008
# 4           19778645  UniProt  2009
# 5           22954596  UniProt  2012
# 6           24555563  UniProt  2014
# 7           26078478  UniProt  2015
# 8           26474164  UniProt  2015
# 9           27006477  UniProt  2016
# 10          28263177  UniProt  2017
# 11          28689405  UniProt  2017
# 12          30327373  UniProt  2018
# 13          31552303  UniProt  2019
# 14          33103907  UniProt  2020
# 15          33341364  UniProt  2021
# 16          35858567  UniProt  2022
# 17          36346805  UniProt  2022
# 18          37760001  UniProt  2023
# 19          37942280  UniProt  2023
#
#                                           Publication  \
# 0   Pasini EM, Kirkegaard M, Mortensen P, Lutz HU,...
# 1   Simó C, Bachi A, Cattaneo A, Guerrier L, Forti...
# 2   Ringrose JH, van Solinge WW, Mohammed S, O'Fla...
# 3   Roux-Dalvai F, Gonzalez de Peredo A, Simó C, G...
# 4   van Gestel RA, van Solinge WW, van der Toorn H...
# 5   Pesciotta EN, Sriswasdi S, Tang HY, Mason PJ, ...
# 6   Lange PF, Huesgen PF, Nguyen K, Overall CM. An...
# 7   Hegedűs T, Chaubey PM, Várady G, Szabó E, Sara...
# 8   Pesciotta EN, Lam HS, Kossenkov A, Ge J, Showe...
# 9   Wilson MC, Trakarnsanga K, Heesom KJ, Cogan N,...
# 10  D'Alessandro A, Dzieciatkowska M, Nemkov T, Ha...
# 11  Bryk AH, Wiśniewski JR. Quantitative Analysis ...
# 12  Gautier EF, Leduc M, Cochet S, Bailly K, Lacom...
# 13  Ravenhill BJ, Kanjee U, Ahouidi A, Nobre L, Wi...
# 14  Thomas T, Stefanoni D, Dzieciatkowska M, Issai...
# 15  Cai L, Zhang J, Hongyun W, Zhu Y, Zhang X, Lia...
# 16  Sae-Lee W, McCafferty CL, Verbeke EJ, Havugima...
# 17  Wang S, Wang G, Lu S, Zhang J, Zhang W, Han Y,...
# 18  Reisz JA, Dzieciatkowska M, Stephenson D, Gamb...
# 19  de Oliveira Junior GP, Welsh JA, Pinckney B, P...
#
#                                                 Notes
# 0   590 IPI;438 UniProt;147 Obsolete -->  441 UniP...
# 1   153 IPI;135 UniProt;18 Obsolete -->  136 UniPr...
# 2   699 IPI;400 UniProt;299 Obsolete -->  400 UniP...
# 3   1577 IPI;1318 UniProt;256 Obsolete -->  1321 U...
# 4   561 GI;473 UniProt;138 Obsolete -->  473 UniPr...
# 5                831 UniProt -->  766 UniProt 2023_05
# 6              1220 UniProt -->  1214 UniProt 2023_05
# 7                419 UniProt -->  416 UniProt 2023_05
# 8              1245 UniProt -->  1148 UniProt 2023_05
# 9              1314 UniProt -->  1187 UniProt 2023_05
# 10             1826 UniProt -->  1815 UniProt 2023_05
# 11             2577 UniProt -->  2557 UniProt 2023_05
# 12             2076 UniProt -->  2075 UniProt 2023_05
# 13               267 UniProt -->  267 UniProt 2023_05
# 14               921 UniProt -->  921 UniProt 2023_05
# 15               876 UniProt -->  841 UniProt 2023_05
# 16             1528 UniProt -->  1530 UniProt 2023_05
# 17               659 UniProt -->  659 UniProt 2023_05
# 18               878 UniProt -->  878 UniProt 2023_05
# 19             1812 UniProt -->  1813 UniProt 2023_05

# %% [markdown]
# ### Export aggregated proteomic data, updated IDs

# %%
with pd.ExcelWriter(f"{ROOT_PATH}{INTERIM_PATH}/proteomics_aggregated.xlsx") as writer:
    for sheet_name, df in updated_table_dict.items():
        df.to_excel(writer, sheet_name=sheet_name, index=False)
